# %%
from dolfin import *
import numpy as np
import ufl
import time
import meshio
import pygmsh
import matplotlib.pyplot as plt
import csv

set_log_level(50)


def mproject(fun, fun_space):
    return project(fun, fun_space, solver_type="cg", preconditioner_type="hypre_euclid")


# Set log level
set_log_level(LogLevel.ERROR)
comm = MPI.comm_world  # MPI communicator
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
l_mul = 4.0 
hw_ratio = 0.5
for hw_ratio in [0.5, 0.25, 0.0]:
    lc = 2.5 * l_mul    # nonlocal length scale (m)
    l = lc
    targeted_him = 2.0 * l_mul  
    # ---------------------------------------------------------------------------------
    # DOMAIN SIZE # PROBLEM PARAMETERS    ---------------------------------------------
    # ---------------------------------------------------------------------------------
    hs_ratio = 0.0  # water level in crevasse (normalized with crevasse height)
    # water level at right terminus (normalized with glacier thickness)
    
    prec_ratio = 0.08  # depth of pre-crack (normalized with glacier thickness)

    # Threshold for energy
    energy_thsd = 6   # hw = 0.5-thres = 0.5, hw = 0-thres = 10

    alpha_2 = 0.01  # threshold for damage

    Lx, Ly, Lz = 500, 750, 125
    L, B, H = Lx, Ly, Lz
    hw = hw_ratio*H


    # ---------------------------------------------------------------------------------
    # MATERIAL PARAMETERS     ------------------------------------------------
    # ---------------------------------------------------------------------------------

    E = 9.5e9  # Young's modulus (Pa)
    nu = 0.35  # Poisson's ratio
    KIc = 0.1e6  # critical stress intensity factor (Pa*m^0.5)
    rho_ice = 917  # density of ice (kg/m^3)

    # rho_ice = 917  # density of ice (kg/m^3)
    rho_H2O = 1000  # density of freshwater (kg/m^3)
    rho_sea = 1020  # density of seawater (kg/m^3)
    grav = 9.81  # gravity acceleration (m/s**2)

    mu = E / 2 / (1 + nu)  # shear modulus
    K = E / 3 / (1 - 2 * nu)  # bulk modulus
    lmbda = K - 2 / 3 * mu  # Lame's first parameter


    # water level at terminus (absolute height)
    ci = 1

    sigmac = 0.1185e6  # critical stress only for stress based method


    # Step 3: Loading the Mesh
    mesh = Mesh()
    with XDMFFile("mesh/adaptive/mesh.xdmf") as infile:
        infile.read(mesh)

    print(mesh.hmin())

    model = "stress_cdf"
    is_adaptive = True

    # Step 4: Preparing output file
    xdmf = XDMFFile("output/adaptive/"+str(hw_ratio)+"/output.xdmf")
    xdmf.parameters["functions_share_mesh"] = True
    xdmf.parameters["rewrite_function_mesh"] = True
    xdmf.parameters["flush_output"] = True
    # ---------------------------------------------------------------------------------
    # MATERIAL MODEL  --------------------------------------------------------
    # ---------------------------------------------------------------------------------
    def epsilon(u):
        return 0.5 * (grad(u) + grad(u).T)


    def sigma(u):
        return 2.0 * mu * epsilon(u) + lmbda * tr(epsilon(u)) * Identity(len(u))

    # ---------------------------------------------------------------------------------
    # CRACK DEPTH FUNCTION     --------------------------------------------------------
    # ---------------------------------------------------------------------------------


    def get_crack_tip_coord(dmg, Dx,  damage_threshold=0.5):
        y_co_ord = Function(Dx)
        y_co_ord.interpolate(Expression("x[2]", degree=1))
        dmg_dg_1 = mproject(dmg, Dx)
        coord_vec = y_co_ord.vector()[dmg_dg_1.vector()[:] >= damage_threshold]
        coord = 115  # ToDo: Change this
        if coord_vec.size > 0:
            coord = coord_vec.min()
        return MPI.min(comm, coord)

    # ---------------------------------------------------------------------------------
    # PARAMETERS FOR PARALLEL COMPUTATIONS   -----------------------------
    # ---------------------------------------------------------------------------------


    rank = comm.Get_rank()  # number of current process
    size = comm.Get_size()  # total number of processes


    def mwrite(filename, my_list):
        MPI.barrier(comm)
        if rank == 0:
            with open(filename, "w") as f:
                for item in my_list:
                    f.write("%s" % item)


    def mprint(*argv):
        if rank == 0:
            out = ""
            for arg in argv:
                out = out + str(arg)
            # this forces program to output when run in parallel
            print(out, flush=True)


    # -----------------------------------------------------------------------------
    # 3D eigen decomposition
    # -----------------------------------------------------------------------------

    def invariants_principal(A):
        """Principal invariants of (real-valued) tensor A.
        https://doi.org/10.1007/978-3-7091-0174-2_3
        """
        i1 = ufl.tr(A)
        i2 = (ufl.tr(A)**2 - ufl.tr(A * A)) / 2
        i3 = ufl.det(A)
        return i1, i2, i3


    def invariants_main(A):
        """Main invariants of (real-valued) tensor A.
        https://doi.org/10.1007/978-3-7091-0174-2_3
        """
        j1 = ufl.tr(A)
        j2 = ufl.tr(A * A)
        j3 = ufl.tr(A * A * A)
        return j1, j2, j3


    def get_eigenstate(A):
        """Eigenvalues and eigenmprojectors of the 3x3 (real-valued) tensor A.
        Provides the spectral decomposition A = sum_{a=0}^{2} λ_a * E_a
        with eigenvalues λ_a and their associated eigenmprojectors E_a = n_a^R x n_a^L
        ordered by magnitude.
        The eigenmprojectors of eigenvalues with multiplicity n are returned as 1/n-fold mprojector.
        Note: Tensor A must not have complex eigenvalues!
        """
        if ufl.shape(A) != (3, 3):
            raise RuntimeError(
                f"Tensor A of shape {ufl.shape(A)} != (3, 3) is not supported!")
        eps = 1.0e-10

        A = ufl.variable(A)
        #
        # --- determine eigenvalues λ0, λ1, λ2
        #
        # additively decompose: A = tr(A) / 3 * I + dev(A) = q * I + B
        q = ufl.tr(A) / 3
        B = A - q * ufl.Identity(3)
        # observe: det(λI - A) = 0  with shift  λ = q + ω --> det(ωI - B) = 0 = ω**3 - j * ω - b
        # == -I2(B) for trace-free B, j < 0 indicates A has complex eigenvalues
        j = ufl.tr(B * B) / 2
        b = ufl.tr(B * B * B) / 3  # == I3(B) for trace-free B

        p = 2 / ufl.sqrt(3) * ufl.sqrt(j + eps ** 2)  # eps: MMM
        r = 4 * b / p ** 3
        r = ufl.Max(ufl.Min(r, +1 - eps), -1 + eps)  # eps: LMM, MMH
        phi = ufl.acos(r) / 3
        # sorted eigenvalues: λ0 <= λ1 <= λ2
        λ0 = q + p * ufl.cos(phi + 2 / 3 * ufl.pi)  # low
        λ1 = q + p * ufl.cos(phi + 4 / 3 * ufl.pi)  # middle
        λ2 = q + p * ufl.cos(phi)  # high
        return as_tensor([[λ2, 0, 0], [0, λ1, 0], [0, 0, λ0]])


    # ---------------------------------------------------------------------------------
    # ENERGY CALCULATIONS        ------------------------------------------------
    # ---------------------------------------------------------------------------------


    # Apply some scalar-to-scalar mapping `f` to each component of `T`:
    def applyElementwise(f, T):
        from ufl import shape

        sh = shape(T)
        if len(sh) == 0:
            return f(T)
        fT = []
        for i in range(0, sh[0]):
            fT += [applyElementwise(f, T[i, i])]
        return as_tensor([[fT[0], 0, 0], [0, fT[1], 0], [0, 0, fT[2]]])


    def split_plus_minus(T):
        x_plus = applyElementwise(lambda x: 0.5 * (abs(x) + x), T)
        x_minus = applyElementwise(lambda x: 0.5 * (abs(x) - x), T)
        return x_plus, x_minus


    def safeSqrt(x):
        return sqrt(x + DOLFIN_EPS)


    def get_energy(disp, pnew, D):
        if model == "stress_cdf":
            stress_plus, stress_minus = split_plus_minus(
                get_eigenstate(sigma(disp)))
            energy_expr = ci * (
                (stress_plus[0, 0] / sigmac) ** 2 + (stress_plus[1, 1] /
                                                    sigmac) ** 2 + (stress_plus[2, 2] / sigmac) ** 2 - 1
            )
            energy_expr = ufl.Max(energy_expr, 0)
            # Apply the threshold condition
            energy_expr = ufl.conditional(
                ufl.le(energy_expr, energy_thsd), 0, energy_expr)

        return energy_expr


    def problem(mesh, ms_iterations=1, u_adaptive=None, p_adaptive=None, cdf_adaptive=None):
        # Step 6: Defining spaces
        V1 = VectorFunctionSpace(mesh, "CG", 1)
        F1 = FunctionSpace(mesh, "CG", 1)

        FDG0 = FunctionSpace(mesh, "DG", 0)
        TDG0 = TensorFunctionSpace(mesh, "DG", 0)

        # Step 7: Define functions
        u = TrialFunction(V1)
        v = TestFunction(V1)
        unew, uold = Function(V1, name="disp"), Function(V1, name="disp")
        stress_xx = Function(F1, name="sigma_xx")
        cdf = Function(FDG0, name="cdf")

        p = TrialFunction(F1)
        q = TestFunction(F1)
        pnew, pold = Function(F1, name="damage"), Function(F1, name="damage")

        # Step 8: Update old data (New to old)

        if u_adaptive is not None:
            uold.assign(mproject(u_adaptive, V1))
            unew.assign(mproject(u_adaptive, V1))

        if p_adaptive is not None:
            pold.assign(mproject(p_adaptive, F1))
            pnew.assign(mproject(p_adaptive, F1))

        if cdf_adaptive is not None:
            cdf.assign(mproject(cdf_adaptive, FDG0))

        front = CompiledSubDomain("near(x[1], 0)")
        back = CompiledSubDomain("near(x[1], L)", L=Ly)
        left = CompiledSubDomain("near(x[0], 0)")
        right_csd = CompiledSubDomain("near(x[0], B)", B=Lx)
        bottom = CompiledSubDomain("near(x[2], 0)")
        top = CompiledSubDomain("near(x[2], H)", H=Lz)

        bottom_roller = DirichletBC(V1.sub(2), Constant(0), bottom)
        left_roller = DirichletBC(V1.sub(0), Constant(0), left)
        front_roller = DirichletBC(V1.sub(1), Constant(0), front)
        back_roller = DirichletBC(V1.sub(1), Constant(0), back)
        bc_u = [bottom_roller, left_roller, front_roller, back_roller]

        boundaries = MeshFunction("size_t", mesh, mesh.topology().dim() - 1)
        right_csd.mark(boundaries, 1)

        # print(boundaries.where_equal(1))

        ds = Measure("ds", subdomain_data=boundaries)

        # Step 10: Define Loads
        t = Expression(("(h - x[2] >= 0 ?-rho_H2O * grav*(h - x[2]) : 0)",
                    0, 0), h=hw, rho_H2O=rho_sea, grav=grav, degree=1)
        f = Constant((0, 0, -rho_ice * grav))

        # Step 11: Displacement and Damage Problems
        disp_a = inner(((1 - pold) ** 2 + 1e-4) * sigma(u), epsilon(v)) * dx
        step_fun = conditional(gt(pold, 0.001), 0.0, 1.0)
        disp_L = step_fun * dot(f, v) * dx + dot(t, v) * ds(1)

        phase_a = (l**2 * inner(grad(p), grad(q)) + (1)
                * inner(p, q) + cdf * inner(p, q)) * dx
        phase_L = inner(cdf, q) * dx

        # Step 12: Solve
        disp_problem = LinearVariationalProblem(disp_a, disp_L, unew, bc_u)
        disp_solver = LinearVariationalSolver(disp_problem)

        phase_problem = LinearVariationalProblem(phase_a, phase_L, pnew)
        phase_solver = LinearVariationalSolver(phase_problem)

        prm_disp = disp_solver.parameters
        prm_disp["linear_solver"] = "gmres"
        prm_disp["preconditioner"] = "hypre_euclid"

        prm_phase = phase_solver.parameters
        prm_phase["linear_solver"] = "gmres"
        prm_phase["preconditioner"] = "hypre_euclid"

        # Start iterations
        disp_solver.solve()

        # print(unew.vector()[:].max(), " -- ", unew.vector()[:].min())

        # Update history variable
        cdf.vector()[:] = np.maximum(
            mproject(get_energy(unew, pnew, FDG0), FDG0).vector()[:], cdf.vector()[:])

        # print(cdf.vector()[:].max(), " -- ", cdf.vector()[:].min())

        phase_solver.solve()
        # Clip the damage solution to 0-1
        pnew.vector()[:] = np.clip(pnew.vector()[:], 0, 1)

        tol = 1e-14

        norm_u = assemble(unew**2 * dx)
        norm_p = assemble(pnew**2 * dx)

        err_u = sqrt(assemble((unew - uold)**2 * dx) /
                    norm_u) if norm_u > tol else 0.0
        err_phi = sqrt(assemble((pnew - pold)**2 * dx) /
                    norm_p) if norm_p > tol else 0.0

        ms_err = max(err_u, err_phi)
        # print(f"err - u   = {err_u:.3e}  --  err - phi = {err_phi:.3e}")

        min_ms_achieved = False
        if ms_err < 1e-5 or ms_iterations > 1:
            min_ms_achieved = True

        return unew, pnew, cdf, ms_err


    def get_markers(_phi, mesh, target_hmin):
        adaptivity_converged = False

        marker = MeshFunction("bool", mesh, mesh.topology().dim())
        marker.set_all(False)

        DG = FunctionSpace(mesh, "DG", 0)
        phi = (mproject(_phi, DG))
        marker.array()[phi.vector()[:] > alpha_2] = True
        # ---------------------------------------------------------------------------------
        # Scheme S4    -----------------------------------------------------
        # ---------------------------------------------------------------------------------
        cell_dia = Circumradius(mesh)
        dia_vector = mproject(cell_dia, DG).vector()[:]
        marker.array()[dia_vector < target_hmin] = False
        # ---------------------------------------------------------------------------------
        # ---------------------------------------------------------------------------------
        DG = None
        del DG

        adaptivity_converged = np.all(np.invert(marker.array()))
        return marker, adaptivity_converged


    #  ▄▄       ▄▄  ▄▄▄▄▄▄▄▄▄▄▄  ▄▄▄▄▄▄▄▄▄▄▄  ▄▄        ▄
    # ▐░░▌     ▐░░▌▐░░░░░░░░░░░▌▐░░░░░░░░░░░▌▐░░▌      ▐░▌
    # ▐░▌░▌   ▐░▐░▌▐░█▀▀▀▀▀▀▀█░▌ ▀▀▀▀█░█▀▀▀▀ ▐░▌░▌     ▐░▌
    # ▐░▌▐░▌ ▐░▌▐░▌▐░▌       ▐░▌     ▐░▌     ▐░▌▐░▌    ▐░▌
    # ▐░▌ ▐░▐░▌ ▐░▌▐░█▄▄▄▄▄▄▄█░▌     ▐░▌     ▐░▌ ▐░▌   ▐░▌
    # ▐░▌  ▐░▌  ▐░▌▐░░░░░░░░░░░▌     ▐░▌     ▐░▌  ▐░▌  ▐░▌
    # ▐░▌   ▀   ▐░▌▐░█▀▀▀▀▀▀▀█░▌     ▐░▌     ▐░▌   ▐░▌ ▐░▌
    # ▐░▌       ▐░▌▐░▌       ▐░▌     ▐░▌     ▐░▌    ▐░▌▐░▌
    # ▐░▌       ▐░▌▐░▌       ▐░▌ ▄▄▄▄█░█▄▄▄▄ ▐░▌     ▐░▐░▌
    # ▐░▌       ▐░▌▐░▌       ▐░▌▐░░░░░░░░░░░▌▐░▌      ▐░░▌
    #  ▀         ▀  ▀         ▀  ▀▀▀▀▀▀▀▀▀▀▀  ▀        ▀▀
    cpp_code = """
    #include <pybind11/pybind11.h>
    #include <dolfin/adaptivity/adapt.h>
    #include <dolfin/function/Function.h>
    #include <dolfin/mesh/Mesh.h>
    namespace py = pybind11;
    PYBIND11_MODULE(SIGNATURE, m)
    {
    m.def("adapt", [](const dolfin::Function &function,
            std::shared_ptr<const dolfin::Mesh> adapted_mesh,
                    bool interpolate){
                return dolfin::adapt(function, adapted_mesh, interpolate);});
    }
    """
    m = compile_cpp_code(cpp_code)


    def adaptFunction(f, mesh, interp=True):
        return m.adapt(f, mesh, interp)


    def transfer(_p, mesh):
        _p = Function(adaptFunction(_p._cpp_object, mesh))
        return _p

    import csv, os
    # Specify the CSV file path
    csv_file_path = "output/adaptive/crevasse_depth_"+str(hw_ratio)+".csv"

    if os.path.exists(csv_file_path):
        os.remove(csv_file_path)

    file = open(csv_file_path, mode='a', newline='')
    writer = csv.writer(file)
    writer.writerow([
        f"{'step':>8}",
        f"{'crack_depth':>12}",
        f"{'time':>8}",
        f"{'ndof':>8}",
        f"{'ms_err':>8}"
    ])
    # ---------------------------------------------------------------------------------
    D = FunctionSpace(mesh, "CG", 1)
    V = VectorFunctionSpace(mesh, "CG", 1)
    DG = FunctionSpace(mesh, "DG", 0)

    pold = Function(D, name="damage")
    uold = Function(V, name="displacement")
    cdf_old = Function(DG, name="energy")

    u_adaptive_n = uold
    p_adaptive_n = pold
    cdf_adaptive_n = cdf_old
    start = time.time()

    psi_old = Function(DG, name="energy")
    psi_new = Function(DG, name="energy")
    sigma_new = Function(DG, name="sigma")

    time_elapsed = 0
    adaptivity_converged = False

    ms_err = 1.0  # Initialize ms_err to enter the while loop
    tol = 1e-4  # Tolerance for convergence

    while ms_err > tol:

        adaptivity_converged = False
        while not adaptivity_converged:
            u_adaptive_n_1, p_adaptive_n_1, cdf_adaptive_n_1, ms_err = problem(
                mesh, 1, u_adaptive_n, p_adaptive_n, cdf_adaptive_n)
            marker, adaptivity_converged = get_markers(
                p_adaptive_n_1, mesh, target_hmin=targeted_him)
            # print(adaptivity_converged)
            mesh = refine(mesh, marker)
            p_adaptive_n = transfer(p_adaptive_n, mesh)
            u_adaptive_n = transfer(u_adaptive_n, mesh)
            cdf_adaptive_n = transfer(cdf_adaptive_n, mesh)
            adaptivity_converged = True

        p_adaptive_n.assign(p_adaptive_n_1)
        u_adaptive_n.assign(u_adaptive_n_1)
        cdf_adaptive_n.assign(cdf_adaptive_n_1)

        # Write the data
        p_adaptive_n.rename("damage", "damage")
        xdmf.write(p_adaptive_n, time_elapsed+1)
        xdmf.write(u_adaptive_n, time_elapsed+1)

        # Increse time_elapsed
        time_elapsed += 1

        # Define new functions to print data
        CE = FunctionSpace(mesh, "DG", 0)  # CDF
        Dx = FunctionSpace(mesh, "CG", 1)  # CDF

        # Determine crack tip coordinate
        cracktip_coor = get_crack_tip_coord(p_adaptive_n, Dx=Dx)

        # Print
        mprint(
            "step: {0:3}, crack_depth: {1:6.0f}, hmin: {2:5.2f}, ndof: {5:6}, time: {3:6.0f}, ms_err: {4:6.2e}".format(
                time_elapsed,
                H - cracktip_coor,
                MPI.min(comm, mesh.hmin()),
                time.time() - start,
                ms_err,
                Dx.dim()*4
            )
        )

        writer.writerow([
            f"{time_elapsed:>8.2f}",
            f"{H - cracktip_coor:>12.1f}",
            f"{time.time() - start:>8.1f}",
            f"{Dx.dim()*4:>8}",
            f"{ms_err:>8.1f}"
        ])
        file.flush()
# Out:
# 6.736466898444871
# step:   1, crack_depth:     10, hmin:  6.74, ndof:   4396, time:      0, ms_err: 1.00e+00
# step:   2, crack_depth:     10, hmin:  4.54, ndof:   6896, time:      1, ms_err: 9.17e-01
# step:   3, crack_depth:     14, hmin:  3.08, ndof:  12140, time:      1, ms_err: 8.12e-01
# step:   4, crack_depth:     21, hmin:  3.08, ndof:  21448, time:      2, ms_err: 6.41e-01
# step:   5, crack_depth:     28, hmin:  2.42, ndof:  34456, time:      5, ms_err: 4.92e-01
# step:   6, crack_depth:     35, hmin:  2.00, ndof:  49264, time:      8, ms_err: 3.90e-01
# step:   7, crack_depth:     41, hmin:  1.35, ndof:  60740, time:     13, ms_err: 3.11e-01
# step:   8, crack_depth:     44, hmin:  1.35, ndof:  71188, time:     19, ms_err: 2.51e-01
# step:   9, crack_depth:     47, hmin:  1.35, ndof:  80896, time:     26, ms_err: 2.18e-01
# step:  10, crack_depth:     48, hmin:  1.35, ndof:  88564, time:     34, ms_err: 1.90e-01
# step:  11, crack_depth:     49, hmin:  1.35, ndof:  97724, time:     43, ms_err: 1.72e-01
# step:  12, crack_depth:     50, hmin:  1.35, ndof: 104308, time:     52, ms_err: 1.64e-01
# step:  13, crack_depth:     50, hmin:  1.35, ndof: 112960, time:     63, ms_err: 1.52e-01
# step:  14, crack_depth:     50, hmin:  1.35, ndof: 122172, time:     74, ms_err: 1.44e-01
# step:  15, crack_depth:     50, hmin:  1.35, ndof: 129896, time:     86, ms_err: 1.33e-01
# step:  16, crack_depth:     50, hmin:  1.35, ndof: 138120, time:     99, ms_err: 1.26e-01
# step:  17, crack_depth:     50, hmin:  1.35, ndof: 146196, time:    112, ms_err: 1.22e-01
# step:  18, crack_depth:     50, hmin:  1.35, ndof: 153452, time:    126, ms_err: 1.19e-01
# step:  19, crack_depth:     50, hmin:  1.35, ndof: 162124, time:    142, ms_err: 1.16e-01
# step:  20, crack_depth:     50, hmin:  1.35, ndof: 169428, time:    158, ms_err: 1.14e-01
# step:  21, crack_depth:     50, hmin:  1.35, ndof: 178404, time:    174, ms_err: 1.11e-01
# step:  22, crack_depth:     50, hmin:  1.35, ndof: 186256, time:    192, ms_err: 1.07e-01
# step:  23, crack_depth:     50, hmin:  1.35, ndof: 192908, time:    210, ms_err: 1.04e-01
# step:  24, crack_depth:     50, hmin:  1.35, ndof: 201328, time:    229, ms_err: 1.03e-01
# step:  25, crack_depth:     50, hmin:  1.35, ndof: 210984, time:    249, ms_err: 1.01e-01
# step:  26, crack_depth:     50, hmin:  1.35, ndof: 219396, time:    269, ms_err: 1.01e-01
# step:  27, crack_depth:     50, hmin:  1.35, ndof: 226868, time:    291, ms_err: 9.98e-02
# step:  28, crack_depth:     50, hmin:  1.35, ndof: 236732, time:    314, ms_err: 9.73e-02
# step:  29, crack_depth:     50, hmin:  1.35, ndof: 245020, time:    338, ms_err: 9.52e-02
# step:  30, crack_depth:     50, hmin:  1.35, ndof: 253340, time:    363, ms_err: 9.25e-02
# step:  31, crack_depth:     50, hmin:  1.35, ndof: 261596, time:    389, ms_err: 9.15e-02
# step:  32, crack_depth:     50, hmin:  1.35, ndof: 269260, time:    415, ms_err: 8.98e-02
# step:  33, crack_depth:     50, hmin:  1.35, ndof: 277764, time:    442, ms_err: 8.88e-02
# step:  34, crack_depth:     50, hmin:  1.35, ndof: 285464, time:    470, ms_err: 8.77e-02
# step:  35, crack_depth:     50, hmin:  1.35, ndof: 294304, time:    499, ms_err: 8.47e-02
# step:  36, crack_depth:     50, hmin:  1.35, ndof: 302660, time:    528, ms_err: 8.33e-02
# step:  37, crack_depth:     50, hmin:  1.35, ndof: 311412, time:    558, ms_err: 8.05e-02
# step:  38, crack_depth:     50, hmin:  1.35, ndof: 319376, time:    589, ms_err: 7.78e-02
# step:  39, crack_depth:     50, hmin:  1.35, ndof: 325416, time:    620, ms_err: 7.80e-02
# step:  40, crack_depth:     50, hmin:  1.35, ndof: 333824, time:    653, ms_err: 7.59e-02
# step:  41, crack_depth:     50, hmin:  1.35, ndof: 341940, time:    686, ms_err: 7.53e-02
# step:  42, crack_depth:     50, hmin:  1.35, ndof: 350260, time:    720, ms_err: 7.36e-02
# step:  43, crack_depth:     50, hmin:  1.35, ndof: 359108, time:    756, ms_err: 7.37e-02
# step:  44, crack_depth:     50, hmin:  1.35, ndof: 366076, time:    793, ms_err: 7.03e-02
# step:  45, crack_depth:     50, hmin:  1.35, ndof: 374756, time:    831, ms_err: 6.99e-02
# step:  46, crack_depth:     50, hmin:  1.35, ndof: 382672, time:    869, ms_err: 7.05e-02
# step:  47, crack_depth:     50, hmin:  1.35, ndof: 390284, time:    908, ms_err: 6.62e-02
# step:  48, crack_depth:     50, hmin:  1.35, ndof: 396352, time:    948, ms_err: 6.36e-02
# step:  49, crack_depth:     50, hmin:  1.35, ndof: 404276, time:    989, ms_err: 6.12e-02
# step:  50, crack_depth:     50, hmin:  1.35, ndof: 411020, time:   1029, ms_err: 5.78e-02
# step:  51, crack_depth:     50, hmin:  1.35, ndof: 417644, time:   1071, ms_err: 5.37e-02
# step:  52, crack_depth:     50, hmin:  1.35, ndof: 422532, time:   1114, ms_err: 4.83e-02
# step:  53, crack_depth:     50, hmin:  1.35, ndof: 425896, time:   1157, ms_err: 4.65e-02
# step:  54, crack_depth:     50, hmin:  1.35, ndof: 431564, time:   1200, ms_err: 4.46e-02
# step:  55, crack_depth:     50, hmin:  1.35, ndof: 437132, time:   1244, ms_err: 4.16e-02
# step:  56, crack_depth:     50, hmin:  1.35, ndof: 442616, time:   1289, ms_err: 3.97e-02
# step:  57, crack_depth:     50, hmin:  1.35, ndof: 447440, time:   1335, ms_err: 3.78e-02
# step:  58, crack_depth:     50, hmin:  1.35, ndof: 450844, time:   1381, ms_err: 3.83e-02
# step:  59, crack_depth:     50, hmin:  1.35, ndof: 454092, time:   1428, ms_err: 4.17e-02
# step:  60, crack_depth:     50, hmin:  1.35, ndof: 457356, time:   1475, ms_err: 4.90e-02
# step:  61, crack_depth:     50, hmin:  1.35, ndof: 461344, time:   1522, ms_err: 5.56e-02
# step:  62, crack_depth:     50, hmin:  1.35, ndof: 464980, time:   1569, ms_err: 4.72e-02
# step:  63, crack_depth:     50, hmin:  1.35, ndof: 467572, time:   1617, ms_err: 3.32e-02
# step:  64, crack_depth:     50, hmin:  1.35, ndof: 470120, time:   1664, ms_err: 2.23e-02
# step:  65, crack_depth:     50, hmin:  1.35, ndof: 470728, time:   1713, ms_err: 1.48e-02
# step:  66, crack_depth:     50, hmin:  1.35, ndof: 471416, time:   1760, ms_err: 9.14e-03
# step:  67, crack_depth:     50, hmin:  1.35, ndof: 471680, time:   1808, ms_err: 6.23e-03
# step:  68, crack_depth:     50, hmin:  1.35, ndof: 471848, time:   1857, ms_err: 4.35e-03
# step:  69, crack_depth:     50, hmin:  1.35, ndof: 472092, time:   1906, ms_err: 2.84e-03
# step:  70, crack_depth:     50, hmin:  1.35, ndof: 472280, time:   1954, ms_err: 2.02e-03
# step:  71, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2001, ms_err: 1.60e-03
# step:  72, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2049, ms_err: 1.31e-03
# step:  73, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2098, ms_err: 1.04e-03
# step:  74, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2146, ms_err: 8.22e-04
# step:  75, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2194, ms_err: 6.71e-04
# step:  76, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2242, ms_err: 4.72e-04
# step:  77, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2291, ms_err: 5.94e-04
# step:  78, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2339, ms_err: 3.99e-04
# step:  79, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2387, ms_err: 3.06e-04
# step:  80, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2436, ms_err: 2.35e-04
# step:  81, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2484, ms_err: 1.75e-04
# step:  82, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2532, ms_err: 1.25e-04
# step:  83, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2580, ms_err: 1.44e-04
# step:  84, crack_depth:     50, hmin:  1.35, ndof: 472500, time:   2629, ms_err: 1.22e-04
# step:  85, crack_depth:     50, hmin:  1.35, ndof: 472588, time:   2678, ms_err: 1.13e-04
# step:  86, crack_depth:     50, hmin:  1.35, ndof: 472588, time:   2726, ms_err: 7.17e-05
# 6.736466898444871
# step:   1, crack_depth:     10, hmin:  4.54, ndof:   7008, time:      0, ms_err: 1.00e+00
# step:   2, crack_depth:     19, hmin:  3.08, ndof:  15388, time:      1, ms_err: 9.31e-01
# step:   3, crack_depth:     33, hmin:  3.08, ndof:  39660, time:      3, ms_err: 6.81e-01
# step:   4, crack_depth:     45, hmin:  2.00, ndof:  73828, time:      8, ms_err: 4.99e-01
# step:   5, crack_depth:     54, hmin:  1.60, ndof: 107240, time:     16, ms_err: 3.83e-01
# step:   6, crack_depth:     59, hmin:  1.60, ndof: 134296, time:     27, ms_err: 3.13e-01
# step:   7, crack_depth:     61, hmin:  1.60, ndof: 163028, time:     41, ms_err: 2.71e-01
# step:   8, crack_depth:     62, hmin:  1.60, ndof: 189528, time:     58, ms_err: 2.38e-01
# step:   9, crack_depth:     62, hmin:  1.38, ndof: 214192, time:     78, ms_err: 2.18e-01
# step:  10, crack_depth:     63, hmin:  1.38, ndof: 239128, time:    100, ms_err: 2.05e-01
# step:  11, crack_depth:     63, hmin:  1.38, ndof: 267260, time:    125, ms_err: 1.92e-01
# step:  12, crack_depth:     63, hmin:  1.38, ndof: 292128, time:    153, ms_err: 1.78e-01
# step:  13, crack_depth:     64, hmin:  1.38, ndof: 316320, time:    183, ms_err: 1.71e-01
# step:  14, crack_depth:     64, hmin:  1.06, ndof: 341776, time:    216, ms_err: 1.62e-01
# step:  15, crack_depth:     64, hmin:  1.06, ndof: 366016, time:    252, ms_err: 1.56e-01
# step:  16, crack_depth:     64, hmin:  1.06, ndof: 391528, time:    289, ms_err: 1.53e-01
# step:  17, crack_depth:     64, hmin:  1.06, ndof: 415548, time:    330, ms_err: 1.48e-01
# step:  18, crack_depth:     64, hmin:  1.06, ndof: 443680, time:    373, ms_err: 1.41e-01
# step:  19, crack_depth:     64, hmin:  1.06, ndof: 471556, time:    419, ms_err: 1.40e-01
# step:  20, crack_depth:     64, hmin:  1.06, ndof: 497200, time:    468, ms_err: 1.38e-01
# step:  21, crack_depth:     64, hmin:  1.06, ndof: 521864, time:    520, ms_err: 1.33e-01
# step:  22, crack_depth:     64, hmin:  1.06, ndof: 546704, time:    576, ms_err: 1.26e-01
# step:  23, crack_depth:     64, hmin:  1.06, ndof: 572520, time:    632, ms_err: 1.20e-01
# step:  24, crack_depth:     64, hmin:  1.06, ndof: 597824, time:    690, ms_err: 1.13e-01
# step:  25, crack_depth:     64, hmin:  1.06, ndof: 620980, time:    751, ms_err: 1.03e-01
# step:  26, crack_depth:     64, hmin:  1.06, ndof: 642772, time:    815, ms_err: 9.10e-02
# step:  27, crack_depth:     64, hmin:  1.06, ndof: 659764, time:    882, ms_err: 7.56e-02
# step:  28, crack_depth:     64, hmin:  1.06, ndof: 673364, time:    951, ms_err: 6.73e-02
# step:  29, crack_depth:     64, hmin:  1.06, ndof: 685868, time:   1021, ms_err: 8.13e-02
# step:  30, crack_depth:     64, hmin:  1.06, ndof: 695948, time:   1092, ms_err: 8.34e-02
# step:  31, crack_depth:     64, hmin:  1.06, ndof: 706680, time:   1165, ms_err: 6.68e-02
# step:  32, crack_depth:     64, hmin:  1.06, ndof: 713084, time:   1238, ms_err: 4.64e-02
# step:  33, crack_depth:     64, hmin:  1.06, ndof: 718884, time:   1313, ms_err: 2.99e-02
# step:  34, crack_depth:     64, hmin:  1.06, ndof: 722304, time:   1388, ms_err: 1.97e-02
# step:  35, crack_depth:     65, hmin:  1.06, ndof: 724512, time:   1463, ms_err: 1.39e-02
# step:  36, crack_depth:     65, hmin:  1.06, ndof: 727372, time:   1538, ms_err: 1.14e-02
# step:  37, crack_depth:     65, hmin:  1.06, ndof: 728948, time:   1614, ms_err: 1.04e-02
# step:  38, crack_depth:     65, hmin:  1.06, ndof: 729576, time:   1689, ms_err: 9.77e-03
# step:  39, crack_depth:     65, hmin:  1.06, ndof: 730848, time:   1765, ms_err: 8.40e-03
# step:  40, crack_depth:     65, hmin:  1.06, ndof: 732380, time:   1840, ms_err: 7.58e-03
# step:  41, crack_depth:     65, hmin:  1.06, ndof: 732896, time:   1915, ms_err: 7.33e-03
# step:  42, crack_depth:     65, hmin:  1.06, ndof: 734712, time:   1992, ms_err: 6.49e-03
# step:  43, crack_depth:     65, hmin:  1.06, ndof: 736660, time:   2067, ms_err: 6.25e-03
# step:  44, crack_depth:     65, hmin:  1.06, ndof: 739400, time:   2143, ms_err: 5.92e-03
# step:  45, crack_depth:     65, hmin:  1.06, ndof: 741152, time:   2220, ms_err: 5.86e-03
# step:  46, crack_depth:     65, hmin:  1.06, ndof: 742420, time:   2297, ms_err: 5.36e-03
# step:  47, crack_depth:     65, hmin:  1.06, ndof: 742896, time:   2373, ms_err: 4.90e-03
# step:  48, crack_depth:     65, hmin:  1.06, ndof: 743512, time:   2449, ms_err: 4.76e-03
# step:  49, crack_depth:     66, hmin:  1.06, ndof: 744260, time:   2527, ms_err: 4.43e-03
# step:  50, crack_depth:     66, hmin:  1.06, ndof: 745440, time:   2603, ms_err: 4.19e-03
# step:  51, crack_depth:     66, hmin:  1.06, ndof: 747248, time:   2683, ms_err: 4.16e-03
# step:  52, crack_depth:     66, hmin:  1.06, ndof: 748324, time:   2761, ms_err: 3.80e-03
# step:  53, crack_depth:     66, hmin:  1.06, ndof: 748716, time:   2839, ms_err: 3.35e-03
# step:  54, crack_depth:     66, hmin:  1.06, ndof: 750416, time:   2917, ms_err: 3.12e-03
# step:  55, crack_depth:     66, hmin:  1.06, ndof: 750900, time:   2994, ms_err: 2.87e-03
# step:  56, crack_depth:     66, hmin:  1.06, ndof: 751072, time:   3072, ms_err: 2.53e-03
# step:  57, crack_depth:     66, hmin:  1.06, ndof: 751276, time:   3149, ms_err: 2.38e-03
# step:  58, crack_depth:     66, hmin:  1.06, ndof: 751504, time:   3228, ms_err: 2.26e-03
# step:  59, crack_depth:     66, hmin:  1.06, ndof: 752256, time:   3305, ms_err: 2.29e-03
# step:  60, crack_depth:     66, hmin:  1.06, ndof: 753100, time:   3382, ms_err: 2.20e-03
# step:  61, crack_depth:     66, hmin:  1.06, ndof: 754108, time:   3462, ms_err: 1.95e-03
# step:  62, crack_depth:     66, hmin:  1.06, ndof: 754484, time:   3541, ms_err: 1.89e-03
# step:  63, crack_depth:     66, hmin:  1.06, ndof: 755088, time:   3621, ms_err: 1.85e-03
# step:  64, crack_depth:     66, hmin:  1.06, ndof: 755380, time:   3699, ms_err: 1.72e-03
# step:  65, crack_depth:     67, hmin:  1.06, ndof: 755624, time:   3777, ms_err: 1.69e-03
# step:  66, crack_depth:     67, hmin:  1.06, ndof: 755960, time:   3855, ms_err: 1.66e-03
# step:  67, crack_depth:     67, hmin:  1.06, ndof: 755960, time:   3934, ms_err: 1.78e-03
# step:  68, crack_depth:     67, hmin:  1.06, ndof: 756192, time:   4013, ms_err: 1.89e-03
# step:  69, crack_depth:     67, hmin:  1.06, ndof: 756956, time:   4093, ms_err: 1.85e-03
# step:  70, crack_depth:     67, hmin:  1.06, ndof: 757468, time:   4171, ms_err: 2.01e-03
# step:  71, crack_depth:     67, hmin:  1.06, ndof: 757932, time:   4249, ms_err: 1.90e-03
# step:  72, crack_depth:     67, hmin:  1.06, ndof: 758652, time:   4327, ms_err: 1.83e-03
# step:  73, crack_depth:     67, hmin:  1.06, ndof: 758996, time:   4404, ms_err: 2.05e-03
# step:  74, crack_depth:     67, hmin:  1.06, ndof: 759376, time:   4481, ms_err: 1.80e-03
# step:  75, crack_depth:     67, hmin:  1.06, ndof: 759488, time:   4559, ms_err: 1.77e-03
# step:  76, crack_depth:     67, hmin:  1.06, ndof: 759488, time:   4636, ms_err: 1.81e-03
# step:  77, crack_depth:     67, hmin:  1.06, ndof: 759672, time:   4718, ms_err: 1.75e-03
# step:  78, crack_depth:     67, hmin:  1.06, ndof: 759672, time:   4796, ms_err: 1.71e-03
# step:  79, crack_depth:     67, hmin:  1.06, ndof: 759720, time:   4876, ms_err: 1.67e-03
# step:  80, crack_depth:     67, hmin:  1.06, ndof: 759848, time:   4955, ms_err: 1.71e-03
# step:  81, crack_depth:     67, hmin:  1.06, ndof: 760156, time:   5032, ms_err: 1.59e-03
# step:  82, crack_depth:     67, hmin:  1.06, ndof: 760344, time:   5110, ms_err: 1.70e-03
# step:  83, crack_depth:     67, hmin:  1.06, ndof: 760660, time:   5187, ms_err: 1.83e-03
# step:  84, crack_depth:     67, hmin:  1.06, ndof: 760660, time:   5265, ms_err: 1.82e-03
# step:  85, crack_depth:     67, hmin:  1.06, ndof: 760904, time:   5343, ms_err: 1.71e-03
# step:  86, crack_depth:     67, hmin:  1.06, ndof: 761128, time:   5423, ms_err: 1.70e-03
# step:  87, crack_depth:     67, hmin:  1.06, ndof: 761684, time:   5501, ms_err: 1.82e-03
# step:  88, crack_depth:     67, hmin:  1.06, ndof: 761684, time:   5579, ms_err: 1.88e-03
# step:  89, crack_depth:     67, hmin:  1.06, ndof: 762096, time:   5658, ms_err: 1.81e-03
# step:  90, crack_depth:     67, hmin:  1.06, ndof: 762096, time:   5737, ms_err: 1.76e-03
# step:  91, crack_depth:     67, hmin:  1.06, ndof: 762560, time:   5817, ms_err: 1.77e-03
# step:  92, crack_depth:     67, hmin:  1.06, ndof: 763408, time:   5896, ms_err: 1.67e-03
# step:  93, crack_depth:     67, hmin:  1.06, ndof: 763636, time:   5976, ms_err: 1.67e-03
# step:  94, crack_depth:     67, hmin:  1.06, ndof: 763992, time:   6056, ms_err: 1.56e-03
# step:  95, crack_depth:     67, hmin:  1.06, ndof: 764120, time:   6136, ms_err: 1.56e-03
# step:  96, crack_depth:     67, hmin:  1.06, ndof: 764260, time:   6215, ms_err: 1.53e-03
# step:  97, crack_depth:     67, hmin:  1.06, ndof: 764432, time:   6296, ms_err: 1.74e-03
# step:  98, crack_depth:     67, hmin:  1.06, ndof: 764528, time:   6374, ms_err: 1.72e-03
# step:  99, crack_depth:     67, hmin:  1.06, ndof: 764980, time:   6456, ms_err: 1.65e-03
# step: 100, crack_depth:     67, hmin:  1.06, ndof: 765076, time:   6537, ms_err: 1.79e-03
# step: 101, crack_depth:     67, hmin:  1.06, ndof: 765336, time:   6619, ms_err: 1.75e-03
# step: 102, crack_depth:     67, hmin:  1.06, ndof: 765500, time:   6700, ms_err: 1.71e-03
# step: 103, crack_depth:     67, hmin:  1.06, ndof: 765640, time:   6782, ms_err: 1.69e-03
# step: 104, crack_depth:     67, hmin:  1.06, ndof: 765792, time:   6862, ms_err: 1.73e-03
# step: 105, crack_depth:     67, hmin:  1.06, ndof: 766276, time:   6942, ms_err: 1.61e-03
# step: 106, crack_depth:     67, hmin:  1.06, ndof: 766664, time:   7023, ms_err: 1.58e-03
# step: 107, crack_depth:     67, hmin:  1.06, ndof: 767164, time:   7104, ms_err: 1.59e-03
# step: 108, crack_depth:     67, hmin:  1.06, ndof: 767284, time:   7184, ms_err: 1.57e-03
# step: 109, crack_depth:     67, hmin:  1.06, ndof: 767696, time:   7266, ms_err: 1.67e-03
# step: 110, crack_depth:     67, hmin:  1.06, ndof: 768064, time:   7346, ms_err: 1.66e-03
# step: 111, crack_depth:     67, hmin:  1.06, ndof: 768148, time:   7426, ms_err: 1.67e-03
# step: 112, crack_depth:     67, hmin:  1.06, ndof: 768396, time:   7508, ms_err: 1.58e-03
# step: 113, crack_depth:     67, hmin:  1.06, ndof: 768684, time:   7588, ms_err: 1.39e-03
# step: 114, crack_depth:     67, hmin:  1.06, ndof: 768816, time:   7672, ms_err: 1.34e-03
# step: 115, crack_depth:     67, hmin:  1.06, ndof: 768816, time:   7751, ms_err: 1.28e-03
# step: 116, crack_depth:     67, hmin:  1.06, ndof: 768816, time:   7833, ms_err: 1.31e-03
# step: 117, crack_depth:     67, hmin:  1.06, ndof: 769112, time:   7913, ms_err: 1.32e-03
# step: 118, crack_depth:     67, hmin:  1.06, ndof: 769304, time:   7994, ms_err: 1.26e-03
# step: 119, crack_depth:     67, hmin:  1.06, ndof: 769384, time:   8075, ms_err: 1.22e-03
# step: 120, crack_depth:     67, hmin:  1.06, ndof: 769656, time:   8157, ms_err: 1.16e-03
# step: 121, crack_depth:     67, hmin:  1.06, ndof: 769656, time:   8239, ms_err: 1.25e-03
# step: 122, crack_depth:     67, hmin:  1.06, ndof: 769656, time:   8321, ms_err: 1.23e-03
# step: 123, crack_depth:     67, hmin:  1.06, ndof: 769800, time:   8401, ms_err: 1.26e-03
# step: 124, crack_depth:     67, hmin:  1.06, ndof: 769800, time:   8482, ms_err: 1.22e-03
# step: 125, crack_depth:     67, hmin:  1.06, ndof: 769800, time:   8561, ms_err: 1.14e-03
# step: 126, crack_depth:     67, hmin:  1.06, ndof: 769800, time:   8641, ms_err: 9.97e-04
# step: 127, crack_depth:     67, hmin:  1.06, ndof: 769800, time:   8723, ms_err: 1.06e-03
# step: 128, crack_depth:     67, hmin:  1.06, ndof: 770048, time:   8802, ms_err: 1.05e-03
# step: 129, crack_depth:     67, hmin:  1.06, ndof: 770544, time:   8883, ms_err: 9.88e-04
# step: 130, crack_depth:     67, hmin:  1.06, ndof: 771096, time:   8963, ms_err: 9.22e-04
