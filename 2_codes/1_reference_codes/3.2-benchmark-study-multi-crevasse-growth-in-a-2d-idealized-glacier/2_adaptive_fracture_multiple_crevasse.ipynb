# %% [markdown]
# # Stress state within a prestine ground glacier.

# %% [markdown]
# In this code, we'll gain insight into the behaviour of  pristine glaciers that are land terminating and ocean terminating. Mimicking the conditions relevant to grounded glaciers, a free slip condition is applied to the bottom surface, restraining the displacement in the vertical direction. The normal component of the displacement field at the far left edge is restrained to prevent rigid body motion in the horizontal direction. The top surface, representing the atmosphere–ice interface, is defined as a free boundary.

# %%
## Step 1: Preprocessing
# - Define units: N, m
# - Prepare the design basis report
## Step 2: Importing Necessary Libraries
from dolfin import *
import ufl
from helpers import *
from problem_definition import *
from matplotlib import pyplot as plt

# %matplotlib inline
## Step 3: Loading the Mesh
mesh = Mesh()
with XDMFFile("mesh/ice-adaptive.xdmf") as infile:
    infile.read(mesh)
mesh.hmin()
# Out:
# 4.194026304469285

# %%
## Step 4: Preparing output file
xdmf = XDMFFile("output/solution-adaptive.xdmf")
xdmf.parameters["functions_share_mesh"] = True
xdmf.parameters["rewrite_function_mesh"] = True
xdmf.parameters["flush_output"] = True

# %%
def problem(mesh, time_total=100, ms_iterations=1,p_adaptive=None, cdf_adaptive = None):
    ## Step 5: Preparing the sets
    support_left = CompiledSubDomain("on_boundary && near(x[0], 0.0, tol)", tol=1e-14)
    support_bottom = CompiledSubDomain("on_boundary && near(x[1],0.0, tol)", tol=1e-14)
    load_right = CompiledSubDomain("on_boundary && x[1]<= 62.5 && x[0]==500")

    mf_line = MeshFunction("size_t", mesh, 1)
    load_right.mark(mf_line, 1)

    ds = Measure("ds")(subdomain_data=mf_line)

    ## Step 6: Defining  spaces
    V1 = VectorFunctionSpace(mesh, "CG", 1)
    F1 = FunctionSpace(mesh, "CG", 1)

    FDG0 = FunctionSpace(mesh, "DG", 0)
    TDG0 = TensorFunctionSpace(mesh, "DG", 0)
    ## Step 7: Define functions
    u, v = TrialFunction(V1), TestFunction(V1)
    unew, uold = Function(V1, name="disp"), Function(V1, name="disp")
    stress_xx, cdf = Function(F1, name="sigma_xx"), Function(F1, name="cdf")
    p, q = TrialFunction(F1), TestFunction(F1)

    pnew, pold = Function(F1, name="damage"), Function(F1, name="damage")

    if p_adaptive is not None:
        pold.assign(project(p_adaptive,F1))
    if cdf_adaptive is not None:
        cdf.assign(project(cdf_adaptive, F1))
    ## Step 8: Material Model
    # N, m, Pa
    g = 9.81
    rho_sea = 1020
    E0_ice = 9500e6
    nu_ice = 0.35
    rho_i_ice = 917 
    sigma_c_ice = 0.1185e6 
    l = 0.625
    ice = MaterialModel(E0_ice, nu_ice, rho_i_ice, sigma_c_ice, 1)
    ## Step 9: Define supports
    bc_sp_x = DirichletBC(V1.sub(0), Constant(0.0), support_left)
    bc_sp_x2 = DirichletBC(V1.sub(1), Constant(0.0), support_bottom)
    bc_u = [bc_sp_x, bc_sp_x2]
    ## Step 10: Define Loads
    t = Expression(("-(rho_sea*(125/2 -x[1]))", 0), rho_sea=rho_sea*g, degree=1)
    # t = Constant((0, 0))
    f = Constant((0, -ice.rho * g))
    ## Step 11: Define the problem
    a_disp = inner(degradation(pold) * ice.stress(u), ice.strain(v)) * dx
    L_disp = (1-pold)*dot(f, v) * dx + dot(t, v) * ds(1)
    a_phase = ((1 + cdf) * inner(p, q) + l**2 * inner(grad(p), grad(q))) * dx
    L_phase = inner(cdf, q) * dx
    ## Step 12: Solve 
    disp_problem = LinearVariationalProblem(a_disp, L_disp, unew, bc_u)
    phase_problem = LinearVariationalProblem(a_phase, L_phase, pnew)
    problem = FractureProblem(disp_problem, phase_problem, ice, cdf, cdf_adaptive)
    solver = FractureSolver(problem)
    prm = solver.parameters
    prm["time_start"] = 0.0
    prm["time_total"] = time_total
    prm["delta_t"] = 1.0
    prm["multi_staggered"]["tolerance"] = 1e-5
    prm["multi_staggered"]["maximum_iterations"] = ms_iterations
    solver.solve()

    return pnew, cdf

# %%
def get_markers(phi, mesh, target_hmin):
    adaptivity_converged = False

    marker = MeshFunction("bool", mesh, mesh.topology().dim())
    marker.set_all(False)

    DG = FunctionSpace(mesh, "DG", 0)
    phi.assign(project(phi,DG))
    marker.array()[phi.vector()[:] > 0.01] = True
    # ---------------------------------------------------------------------------------
    # Scheme S4    -----------------------------------------------------
    # ---------------------------------------------------------------------------------
    cell_dia = Circumradius(mesh)
    dia_vector = project(cell_dia, DG, solver_type="cg",
        preconditioner_type="hypre_euclid").vector()[:]
    marker.array()[dia_vector < target_hmin] = False
    # ---------------------------------------------------------------------------------
    # ---------------------------------------------------------------------------------
    DG = None
    del DG

    adaptivity_converged = np.all(np.invert(marker.array()))
    return marker, adaptivity_converged

# %%
pold = Function(FunctionSpace(mesh,'DG',0), name="damage")
xdmf.write(pold,0)

# %%
adaptivity_converged = False

while not adaptivity_converged:
    pold,cdf_old = problem(mesh,0.0,1)
    marker, adaptivity_converged = get_markers(pold, mesh, target_hmin=0.3)
    print(adaptivity_converged)
    mesh = refine(mesh,marker)
    plot(mesh)
# Out:
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.414e+00 -- err - phi - 1.078e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.420e+00 -- err - phi - 5.462e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.422e+00 -- err - phi - 4.262e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.423e+00 -- err - phi - 4.062e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.423e+00 -- err - phi - 3.942e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.423e+00 -- err - phi - 4.046e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.423e+00 -- err - phi - 4.045e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.423e+00 -- err - phi - 4.045e+00
# True

# %%
mesh.hmin(), mesh.num_cells()
# Out:
# (0.1310633220146584, 10338)

# %%
plt.figure(figsize=(18, 6))
c = plot(pold)
plt.colorbar(c)  # Adds the colorbar
plt.show()

# %%
xdmf.write(pold,1)

# %%
cpp_code = """
#include <pybind11/pybind11.h>
#include <dolfin/adaptivity/adapt.h>
#include <dolfin/function/Function.h>
#include <dolfin/mesh/Mesh.h>
namespace py = pybind11;
PYBIND11_MODULE(SIGNATURE, m)
{
m.def("adapt", [](const dolfin::Function &function,
          std::shared_ptr<const dolfin::Mesh> adapted_mesh,
                  bool interpolate){
             return dolfin::adapt(function, adapted_mesh, interpolate);});
}
"""
m = compile_cpp_code(cpp_code)


def adaptFunction(f, mesh, interp=True):
    return m.adapt(f, mesh, interp)

def transfer(_p, mesh):
    _p = Function(adaptFunction(_p._cpp_object, mesh))
    return _p

# %%
p_adaptive_n = pold
cdf_adaptive_n = cdf_old


for i in range(100):
    adaptivity_converged = False
    while not adaptivity_converged:
        p_adaptive_n_1, cdf_adaptive_n_1 = problem(mesh,0.0,1,p_adaptive_n, cdf_adaptive_n)
        marker, adaptivity_converged = get_markers(p_adaptive_n_1, mesh, target_hmin=0.3)
        print(adaptivity_converged)
        mesh = refine(mesh,marker)
        p_adaptive_n = transfer(p_adaptive_n, mesh)
        cdf_adaptive_n = transfer(cdf_adaptive_n, mesh)
    
    p_adaptive_n.assign(p_adaptive_n_1)
    cdf_adaptive_n.assign(cdf_adaptive_n_1)

    p_adaptive_n.rename("damage","damage")
    xdmf.write(p_adaptive_n,i+2)
# Out:
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.427e+00 -- err - phi - 6.439e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.427e+00 -- err - phi - 6.585e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.427e+00 -- err - phi - 6.583e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.427e+00 -- err - phi - 6.583e+00
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.431e+00 -- err - phi - 8.031e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.431e+00 -- err - phi - 8.033e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.431e+00 -- err - phi - 8.033e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.431e+00 -- err - phi - 8.035e+00
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.436e+00 -- err - phi - 8.951e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.436e+00 -- err - phi - 8.949e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.436e+00 -- err - phi - 8.952e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.436e+00 -- err - phi - 8.952e+00
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.440e+00 -- err - phi - 9.598e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.440e+00 -- err - phi - 9.597e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.440e+00 -- err - phi - 9.597e+00
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.440e+00 -- err - phi - 9.597e+00
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.444e+00 -- err - phi - 1.005e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.444e+00 -- err - phi - 1.005e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.444e+00 -- err - phi - 1.005e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.444e+00 -- err - phi - 1.005e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.449e+00 -- err - phi - 1.039e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.449e+00 -- err - phi - 1.040e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.449e+00 -- err - phi - 1.040e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.449e+00 -- err - phi - 1.040e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.453e+00 -- err - phi - 1.065e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.453e+00 -- err - phi - 1.066e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.453e+00 -- err - phi - 1.066e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.453e+00 -- err - phi - 1.066e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.457e+00 -- err - phi - 1.085e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.457e+00 -- err - phi - 1.085e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.457e+00 -- err - phi - 1.085e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.460e+00 -- err - phi - 1.102e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.460e+00 -- err - phi - 1.102e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.460e+00 -- err - phi - 1.102e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.464e+00 -- err - phi - 1.117e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.464e+00 -- err - phi - 1.117e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.464e+00 -- err - phi - 1.117e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.467e+00 -- err - phi - 1.129e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.467e+00 -- err - phi - 1.129e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.467e+00 -- err - phi - 1.129e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.469e+00 -- err - phi - 1.142e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.470e+00 -- err - phi - 1.142e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.470e+00 -- err - phi - 1.142e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.472e+00 -- err - phi - 1.154e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.472e+00 -- err - phi - 1.154e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.472e+00 -- err - phi - 1.154e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.474e+00 -- err - phi - 1.168e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.474e+00 -- err - phi - 1.168e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.474e+00 -- err - phi - 1.168e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.476e+00 -- err - phi - 1.181e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.477e+00 -- err - phi - 1.182e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.477e+00 -- err - phi - 1.182e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.478e+00 -- err - phi - 1.195e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.478e+00 -- err - phi - 1.196e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.478e+00 -- err - phi - 1.196e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.480e+00 -- err - phi - 1.209e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.480e+00 -- err - phi - 1.209e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.480e+00 -- err - phi - 1.209e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.481e+00 -- err - phi - 1.222e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.481e+00 -- err - phi - 1.222e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.481e+00 -- err - phi - 1.222e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.483e+00 -- err - phi - 1.237e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.483e+00 -- err - phi - 1.237e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.483e+00 -- err - phi - 1.237e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.484e+00 -- err - phi - 1.249e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.484e+00 -- err - phi - 1.250e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.484e+00 -- err - phi - 1.250e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.485e+00 -- err - phi - 1.262e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.485e+00 -- err - phi - 1.262e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.486e+00 -- err - phi - 1.273e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.486e+00 -- err - phi - 1.273e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.486e+00 -- err - phi - 1.273e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.487e+00 -- err - phi - 1.283e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.487e+00 -- err - phi - 1.283e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.488e+00 -- err - phi - 1.292e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.488e+00 -- err - phi - 1.292e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.488e+00 -- err - phi - 1.292e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.488e+00 -- err - phi - 1.301e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.488e+00 -- err - phi - 1.301e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.488e+00 -- err - phi - 1.301e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.489e+00 -- err - phi - 1.309e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.489e+00 -- err - phi - 1.309e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.490e+00 -- err - phi - 1.317e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.490e+00 -- err - phi - 1.317e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.490e+00 -- err - phi - 1.324e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.490e+00 -- err - phi - 1.325e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.491e+00 -- err - phi - 1.332e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.491e+00 -- err - phi - 1.332e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.491e+00 -- err - phi - 1.332e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.491e+00 -- err - phi - 1.338e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.491e+00 -- err - phi - 1.338e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.491e+00 -- err - phi - 1.338e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.492e+00 -- err - phi - 1.344e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.492e+00 -- err - phi - 1.344e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.492e+00 -- err - phi - 1.350e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.492e+00 -- err - phi - 1.350e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.492e+00 -- err - phi - 1.357e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.492e+00 -- err - phi - 1.357e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.492e+00 -- err - phi - 1.357e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.493e+00 -- err - phi - 1.362e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.493e+00 -- err - phi - 1.362e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.493e+00 -- err - phi - 1.367e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.493e+00 -- err - phi - 1.367e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.493e+00 -- err - phi - 1.371e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.493e+00 -- err - phi - 1.371e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.493e+00 -- err - phi - 1.371e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.493e+00 -- err - phi - 1.376e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.493e+00 -- err - phi - 1.376e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.380e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.380e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.384e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.384e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.388e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.388e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.391e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.391e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.394e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.394e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.397e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.494e+00 -- err - phi - 1.397e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.399e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.399e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.402e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.402e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.404e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.404e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.406e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.406e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.407e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.408e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.409e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.409e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.411e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.411e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.412e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.412e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.414e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.414e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.415e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.415e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.416e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.416e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.417e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.417e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.417e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.417e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.418e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.418e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.419e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.419e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.420e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.420e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.421e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.495e+00 -- err - phi - 1.421e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.422e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.422e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.422e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.422e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.423e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.423e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.423e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.423e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.424e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.424e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.424e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.424e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.425e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.425e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.425e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.425e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.425e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.425e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.426e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.426e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.426e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.426e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.426e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.426e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.426e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.426e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.426e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.427e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.428e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.428e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.428e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.428e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.428e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.428e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.428e+01
# False
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.428e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.428e+01
# True
# -----------------Time Step----------------------
# Solving linear variational problem.
# Solving linear variational problem.
# err - u - 1.496e+00 -- err - phi - 1.428e+01
# True

# %%
mesh.hmin(), mesh.num_cells()
# Out:
# (0.1310633220146584, 61462)

# %%
plt.figure(figsize=(18, 6))
c = plot(p_adaptive_n)
plt.colorbar(c)  # Adds the colorbar
plt.show()
