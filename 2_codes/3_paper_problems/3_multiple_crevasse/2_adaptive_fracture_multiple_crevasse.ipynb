# %% [markdown]
# # Stress state within a prestine ground glacier.

# %% [markdown]
# In this code, we'll gain insight into the behaviour of  pristine glaciers that are land terminating and ocean terminating. Mimicking the conditions relevant to grounded glaciers, a free slip condition is applied to the bottom surface, restraining the displacement in the vertical direction. The normal component of the displacement field at the far left edge is restrained to prevent rigid body motion in the horizontal direction. The top surface, representing the atmosphere–ice interface, is defined as a free boundary.

# %%
## Step 1: Preprocessing
# - Define units: N, m
# - Prepare the design basis report
## Step 2: Importing Necessary Libraries
from dolfin import *
import ufl
from helpers import *
from problem_definition import *
from matplotlib import pyplot as plt

# %matplotlib inline
## Step 3: Loading the Mesh
mesh = Mesh()
with XDMFFile("mesh/Mesh_ad_mul.xdmf") as infile:
    infile.read(mesh)
mesh.hmin()
# Out:
# 2.405014517785878

# %%
## Step 4: Preparing output file
xdmf = XDMFFile("output/solution-adaptive.xdmf")
xdmf.parameters["functions_share_mesh"] = True
xdmf.parameters["rewrite_function_mesh"] = True
xdmf.parameters["flush_output"] = True

# %%
def problem(mesh, time_total=100, ms_iterations=1,p_adaptive=None, cdf_adaptive = None):
    ## Step 5: Preparing the sets
    support_left = CompiledSubDomain("on_boundary && near(x[0], 0.0, tol)", tol=1e-14)
    support_bottom = CompiledSubDomain("on_boundary && near(x[1],0.0, tol)", tol=1e-14)
    load_right = CompiledSubDomain("on_boundary && x[1]<= 62.5 && x[0]==500")

    mf_line = MeshFunction("size_t", mesh, 1)
    load_right.mark(mf_line, 1)

    ds = Measure("ds")(subdomain_data=mf_line)

    ## Step 6: Defining  spaces
    V1 = VectorFunctionSpace(mesh, "CG", 1)
    F1 = FunctionSpace(mesh, "CG", 1)

    FDG0 = FunctionSpace(mesh, "DG", 0)
    TDG0 = TensorFunctionSpace(mesh, "DG", 0)
    ## Step 7: Define functions
    u, v = TrialFunction(V1), TestFunction(V1)
    unew, uold = Function(V1, name="disp"), Function(V1, name="disp")
    stress_xx, cdf = Function(F1, name="sigma_xx"), Function(F1, name="cdf")
    p, q = TrialFunction(F1), TestFunction(F1)

    pnew, pold = Function(F1, name="damage"), Function(F1, name="damage")

    if p_adaptive is not None:
        pold.assign(project(p_adaptive,F1))
    if cdf_adaptive is not None:
        cdf.assign(project(cdf_adaptive, F1))
    ## Step 8: Material Model
    # N, m, Pa
    g = 9.81
    rho_sea = 1020
    E0_ice = 9500e6
    nu_ice = 0.35
    rho_i_ice = 917 
    sigma_c_ice = 0.1185e6 
    l = 0.625
    ice = MaterialModel(E0_ice, nu_ice, rho_i_ice, sigma_c_ice, 1)
    ## Step 9: Define supports
    bc_sp_x = DirichletBC(V1.sub(0), Constant(0.0), support_left)
    bc_sp_x2 = DirichletBC(V1.sub(1), Constant(0.0), support_bottom)
    bc_u = [bc_sp_x, bc_sp_x2]
    ## Step 10: Define Loads
    t = Expression(("-(rho_sea*(125/2 -x[1]))", 0), rho_sea=rho_sea*g, degree=1)
    # t = Constant((0, 0))
    f = Constant((0, -ice.rho * g))
    ## Step 11: Define the problem
    a_disp = inner(degradation(pold) * ice.stress(u), ice.strain(v)) * dx
    L_disp = (1-pold)*dot(f, v) * dx + dot(t, v) * ds(1)
    a_phase = ((1 + cdf) * inner(p, q) + l**2 * inner(grad(p), grad(q))) * dx
    L_phase = inner(cdf, q) * dx
    ## Step 12: Solve 
    disp_problem = LinearVariationalProblem(a_disp, L_disp, unew, bc_u)
    phase_problem = LinearVariationalProblem(a_phase, L_phase, pnew)
    problem = FractureProblem(disp_problem, phase_problem, ice, cdf, cdf_adaptive)
    solver = FractureSolver(problem)
    prm = solver.parameters
    prm["time_start"] = 0.0
    prm["time_total"] = time_total
    prm["delta_t"] = 1.0
    prm["multi_staggered"]["tolerance"] = 1e-5
    prm["multi_staggered"]["maximum_iterations"] = ms_iterations
    solver.solve()

    return pnew, cdf

# %%
def get_markers(phi, mesh, target_hmin):
    adaptivity_converged = False

    marker = MeshFunction("bool", mesh, mesh.topology().dim())
    marker.set_all(False)

    DG = FunctionSpace(mesh, "DG", 0)
    phi.assign(project(phi,DG))
    marker.array()[phi.vector()[:] > 0.01] = True
    # ---------------------------------------------------------------------------------
    # Scheme S4    -----------------------------------------------------
    # ---------------------------------------------------------------------------------
    cell_dia = Circumradius(mesh)
    dia_vector = project(cell_dia, DG, solver_type="cg",
        preconditioner_type="hypre_euclid").vector()[:]
    marker.array()[dia_vector < target_hmin] = False
    # ---------------------------------------------------------------------------------
    # ---------------------------------------------------------------------------------
    DG = None
    del DG

    adaptivity_converged = np.all(np.invert(marker.array()))
    return marker, adaptivity_converged

# %%
pold = Function(FunctionSpace(mesh,'DG',0), name="damage")
xdmf.write(pold,0)

# %%
adaptivity_converged = False

while not adaptivity_converged:
    pold,cdf_old = problem(mesh,0.0,1)
    marker, adaptivity_converged = get_markers(pold, mesh, target_hmin=0.3)
    print(adaptivity_converged)
    mesh = refine(mesh,marker)
    plot(mesh)
# Out:
# -----------------Time Step----------------------
# err - u - 1.400e+00 -- err - phi - 6.895e+00
# False
# -----------------Time Step----------------------
# err - u - 1.401e+00 -- err - phi - 4.522e+00
# False
# -----------------Time Step----------------------
# err - u - 1.402e+00 -- err - phi - 4.092e+00
# False
# -----------------Time Step----------------------
# err - u - 1.402e+00 -- err - phi - 3.890e+00
# False
# -----------------Time Step----------------------
# err - u - 1.402e+00 -- err - phi - 3.882e+00
# False
# -----------------Time Step----------------------
# err - u - 1.402e+00 -- err - phi - 3.882e+00
# True

# %%
mesh.hmin(), mesh.num_cells()
# Out:
# (0.1722152575776317, 7543)

# %%
plt.figure(figsize=(18, 6))
c = plot(pold)
plt.colorbar(c)  # Adds the colorbar
plt.show()

# %%
xdmf.write(pold,1)

# %%
cpp_code = """
#include <pybind11/pybind11.h>
#include <dolfin/adaptivity/adapt.h>
#include <dolfin/function/Function.h>
#include <dolfin/mesh/Mesh.h>
namespace py = pybind11;
PYBIND11_MODULE(SIGNATURE, m)
{
m.def("adapt", [](const dolfin::Function &function,
          std::shared_ptr<const dolfin::Mesh> adapted_mesh,
                  bool interpolate){
             return dolfin::adapt(function, adapted_mesh, interpolate);});
}
"""
m = compile_cpp_code(cpp_code)


def adaptFunction(f, mesh, interp=True):
    return m.adapt(f, mesh, interp)

def transfer(_p, mesh):
    _p = Function(adaptFunction(_p._cpp_object, mesh))
    return _p

# %%
p_adaptive_n = pold
cdf_adaptive_n = cdf_old


for i in range(100):
    adaptivity_converged = False
    while not adaptivity_converged:
        p_adaptive_n_1, cdf_adaptive_n_1 = problem(mesh,0.0,1,p_adaptive_n, cdf_adaptive_n)
        marker, adaptivity_converged = get_markers(p_adaptive_n_1, mesh, target_hmin=0.3)
        print(adaptivity_converged)
        mesh = refine(mesh,marker)
        p_adaptive_n = transfer(p_adaptive_n, mesh)
        cdf_adaptive_n = transfer(cdf_adaptive_n, mesh)
    
    p_adaptive_n.assign(p_adaptive_n_1)
    cdf_adaptive_n.assign(cdf_adaptive_n_1)

    p_adaptive_n.rename("damage","damage")
    xdmf.write(p_adaptive_n,i+2)
# Out:
# -----------------Time Step----------------------
# err - u - 1.405e+00 -- err - phi - 6.417e+00
# False
# -----------------Time Step----------------------
# err - u - 1.405e+00 -- err - phi - 6.467e+00
# False
# -----------------Time Step----------------------
# err - u - 1.405e+00 -- err - phi - 6.473e+00
# False
# -----------------Time Step----------------------
# err - u - 1.405e+00 -- err - phi - 6.473e+00
# False
# -----------------Time Step----------------------
# err - u - 1.405e+00 -- err - phi - 6.473e+00
# True
# -----------------Time Step----------------------
# err - u - 1.409e+00 -- err - phi - 8.328e+00
# False
# -----------------Time Step----------------------
# err - u - 1.409e+00 -- err - phi - 8.212e+00
# False
# -----------------Time Step----------------------
# err - u - 1.409e+00 -- err - phi - 8.209e+00
# False
# -----------------Time Step----------------------
# err - u - 1.409e+00 -- err - phi - 8.209e+00
# True
# -----------------Time Step----------------------
# err - u - 1.412e+00 -- err - phi - 9.739e+00
# False
# -----------------Time Step----------------------
# err - u - 1.412e+00 -- err - phi - 9.537e+00
# False
# -----------------Time Step----------------------
# err - u - 1.413e+00 -- err - phi - 9.538e+00
# True
# -----------------Time Step----------------------
# err - u - 1.416e+00 -- err - phi - 1.089e+01
# False
# -----------------Time Step----------------------
# err - u - 1.416e+00 -- err - phi - 1.064e+01
# False
# -----------------Time Step----------------------
# err - u - 1.416e+00 -- err - phi - 1.064e+01
# False
# -----------------Time Step----------------------
# err - u - 1.416e+00 -- err - phi - 1.064e+01
# True
# -----------------Time Step----------------------
# err - u - 1.419e+00 -- err - phi - 1.178e+01
# False
# -----------------Time Step----------------------
# err - u - 1.419e+00 -- err - phi - 1.154e+01
# False
# -----------------Time Step----------------------
# err - u - 1.419e+00 -- err - phi - 1.154e+01
# False
# -----------------Time Step----------------------
# err - u - 1.419e+00 -- err - phi - 1.154e+01
# True
# -----------------Time Step----------------------
# err - u - 1.423e+00 -- err - phi - 1.261e+01
# False
# -----------------Time Step----------------------
# err - u - 1.423e+00 -- err - phi - 1.232e+01
# False
# -----------------Time Step----------------------
# err - u - 1.423e+00 -- err - phi - 1.232e+01
# False
# -----------------Time Step----------------------
# err - u - 1.423e+00 -- err - phi - 1.232e+01
# True
# -----------------Time Step----------------------
# err - u - 1.426e+00 -- err - phi - 1.331e+01
# False
# -----------------Time Step----------------------
# err - u - 1.426e+00 -- err - phi - 1.299e+01
# False
# -----------------Time Step----------------------
# err - u - 1.426e+00 -- err - phi - 1.299e+01
# True
# -----------------Time Step----------------------
# err - u - 1.428e+00 -- err - phi - 1.389e+01
# False
# -----------------Time Step----------------------
# err - u - 1.429e+00 -- err - phi - 1.358e+01
# False
# -----------------Time Step----------------------
# err - u - 1.429e+00 -- err - phi - 1.358e+01
# True
# -----------------Time Step----------------------
# err - u - 1.431e+00 -- err - phi - 1.446e+01
# False
# -----------------Time Step----------------------
# err - u - 1.431e+00 -- err - phi - 1.410e+01
# False
# -----------------Time Step----------------------
# err - u - 1.431e+00 -- err - phi - 1.410e+01
# False
# -----------------Time Step----------------------
# err - u - 1.431e+00 -- err - phi - 1.410e+01
# True
# -----------------Time Step----------------------
# err - u - 1.434e+00 -- err - phi - 1.489e+01
# False
# -----------------Time Step----------------------
# err - u - 1.434e+00 -- err - phi - 1.455e+01
# False
# -----------------Time Step----------------------
# err - u - 1.434e+00 -- err - phi - 1.455e+01
# True
# -----------------Time Step----------------------
# err - u - 1.436e+00 -- err - phi - 1.533e+01
# False
# -----------------Time Step----------------------
# err - u - 1.437e+00 -- err - phi - 1.495e+01
# False
# -----------------Time Step----------------------
# err - u - 1.437e+00 -- err - phi - 1.495e+01
# True
# -----------------Time Step----------------------
# err - u - 1.439e+00 -- err - phi - 1.571e+01
# False
# -----------------Time Step----------------------
# err - u - 1.439e+00 -- err - phi - 1.531e+01
# False
# -----------------Time Step----------------------
# err - u - 1.439e+00 -- err - phi - 1.531e+01
# False
# -----------------Time Step----------------------
# err - u - 1.439e+00 -- err - phi - 1.531e+01
# True
# -----------------Time Step----------------------
# err - u - 1.441e+00 -- err - phi - 1.602e+01
# False
# -----------------Time Step----------------------
# err - u - 1.441e+00 -- err - phi - 1.563e+01
# False
# -----------------Time Step----------------------
# err - u - 1.441e+00 -- err - phi - 1.563e+01
# True
# -----------------Time Step----------------------
# err - u - 1.443e+00 -- err - phi - 1.636e+01
# False
# -----------------Time Step----------------------
# err - u - 1.443e+00 -- err - phi - 1.593e+01
# False
# -----------------Time Step----------------------
# err - u - 1.443e+00 -- err - phi - 1.593e+01
# True
# -----------------Time Step----------------------
# err - u - 1.445e+00 -- err - phi - 1.664e+01
# False
# -----------------Time Step----------------------
# err - u - 1.445e+00 -- err - phi - 1.618e+01
# False
# -----------------Time Step----------------------
# err - u - 1.445e+00 -- err - phi - 1.618e+01
# True
# -----------------Time Step----------------------
# err - u - 1.447e+00 -- err - phi - 1.689e+01
# False
# -----------------Time Step----------------------
# err - u - 1.447e+00 -- err - phi - 1.642e+01
# False
# -----------------Time Step----------------------
# err - u - 1.447e+00 -- err - phi - 1.642e+01
# True
# -----------------Time Step----------------------
# err - u - 1.448e+00 -- err - phi - 1.712e+01
# False
# -----------------Time Step----------------------
# err - u - 1.448e+00 -- err - phi - 1.664e+01
# False
# -----------------Time Step----------------------
# err - u - 1.448e+00 -- err - phi - 1.664e+01
# True
# -----------------Time Step----------------------
# err - u - 1.450e+00 -- err - phi - 1.734e+01
# False
# -----------------Time Step----------------------
# err - u - 1.450e+00 -- err - phi - 1.683e+01
# False
# -----------------Time Step----------------------
# err - u - 1.450e+00 -- err - phi - 1.683e+01
# True
# -----------------Time Step----------------------
# err - u - 1.451e+00 -- err - phi - 1.755e+01
# False
# -----------------Time Step----------------------
# err - u - 1.451e+00 -- err - phi - 1.700e+01
# False
# -----------------Time Step----------------------
# err - u - 1.451e+00 -- err - phi - 1.700e+01
# False
# -----------------Time Step----------------------
# err - u - 1.451e+00 -- err - phi - 1.700e+01
# True
# -----------------Time Step----------------------
# err - u - 1.453e+00 -- err - phi - 1.771e+01
# False
# -----------------Time Step----------------------
# err - u - 1.453e+00 -- err - phi - 1.716e+01
# False
# -----------------Time Step----------------------
# err - u - 1.453e+00 -- err - phi - 1.716e+01
# True
# -----------------Time Step----------------------
# err - u - 1.454e+00 -- err - phi - 1.788e+01
# False
# -----------------Time Step----------------------
# err - u - 1.454e+00 -- err - phi - 1.731e+01
# False
# -----------------Time Step----------------------
# err - u - 1.454e+00 -- err - phi - 1.731e+01
# True
# -----------------Time Step----------------------
# err - u - 1.455e+00 -- err - phi - 1.802e+01
# False
# -----------------Time Step----------------------
# err - u - 1.455e+00 -- err - phi - 1.744e+01
# False
# -----------------Time Step----------------------
# err - u - 1.455e+00 -- err - phi - 1.744e+01
# True
# -----------------Time Step----------------------
# err - u - 1.456e+00 -- err - phi - 1.817e+01
# False
# -----------------Time Step----------------------
# err - u - 1.456e+00 -- err - phi - 1.756e+01
# False
# -----------------Time Step----------------------
# err - u - 1.456e+00 -- err - phi - 1.756e+01
# True
# -----------------Time Step----------------------
# err - u - 1.457e+00 -- err - phi - 1.829e+01
# False
# -----------------Time Step----------------------
# err - u - 1.457e+00 -- err - phi - 1.767e+01
# False
# -----------------Time Step----------------------
# err - u - 1.457e+00 -- err - phi - 1.767e+01
# True
# -----------------Time Step----------------------
# err - u - 1.458e+00 -- err - phi - 1.842e+01
# False
# -----------------Time Step----------------------
# err - u - 1.458e+00 -- err - phi - 1.777e+01
# False
# -----------------Time Step----------------------
# err - u - 1.458e+00 -- err - phi - 1.777e+01
# True
# -----------------Time Step----------------------
# err - u - 1.459e+00 -- err - phi - 1.851e+01
# False
# -----------------Time Step----------------------
# err - u - 1.459e+00 -- err - phi - 1.786e+01
# True
# -----------------Time Step----------------------
# err - u - 1.459e+00 -- err - phi - 1.860e+01
# False
# -----------------Time Step----------------------
# err - u - 1.459e+00 -- err - phi - 1.794e+01
# True
# -----------------Time Step----------------------
# err - u - 1.460e+00 -- err - phi - 1.870e+01
# False
# -----------------Time Step----------------------
# err - u - 1.460e+00 -- err - phi - 1.802e+01
# False
# -----------------Time Step----------------------
# err - u - 1.460e+00 -- err - phi - 1.802e+01
# True
# -----------------Time Step----------------------
# err - u - 1.460e+00 -- err - phi - 1.878e+01
# False
# -----------------Time Step----------------------
# err - u - 1.460e+00 -- err - phi - 1.809e+01
# True
# -----------------Time Step----------------------
# err - u - 1.461e+00 -- err - phi - 1.885e+01
# False
# -----------------Time Step----------------------
# err - u - 1.461e+00 -- err - phi - 1.815e+01
# True
# -----------------Time Step----------------------
# err - u - 1.461e+00 -- err - phi - 1.893e+01
# False
# -----------------Time Step----------------------
# err - u - 1.462e+00 -- err - phi - 1.821e+01
# False
# -----------------Time Step----------------------
# err - u - 1.462e+00 -- err - phi - 1.821e+01
# True
# -----------------Time Step----------------------
# err - u - 1.462e+00 -- err - phi - 1.896e+01
# False
# -----------------Time Step----------------------
# err - u - 1.462e+00 -- err - phi - 1.826e+01
# False
# -----------------Time Step----------------------
# err - u - 1.462e+00 -- err - phi - 1.826e+01
# True
# -----------------Time Step----------------------
# err - u - 1.462e+00 -- err - phi - 1.905e+01
# False
# -----------------Time Step----------------------
# err - u - 1.462e+00 -- err - phi - 1.831e+01
# False
# -----------------Time Step----------------------
# err - u - 1.462e+00 -- err - phi - 1.831e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 1.911e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 1.836e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 1.836e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 1.915e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 1.840e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 1.920e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 1.844e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.926e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.848e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.848e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.927e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.851e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.931e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.855e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.935e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.857e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.937e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.860e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.942e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.863e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.945e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.865e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.947e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.867e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.951e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.868e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.954e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.870e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.870e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.953e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.872e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.872e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.953e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.873e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.959e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.874e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.958e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.875e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.875e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.960e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.876e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.963e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.877e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.962e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.878e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.963e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.879e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.962e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.880e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.965e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.881e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.965e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.882e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.967e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.883e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.883e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.967e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.883e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.883e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.967e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.884e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.967e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.884e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.967e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.884e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.968e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.885e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.970e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.885e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.974e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.886e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.969e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.886e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.973e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.886e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.971e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.886e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.973e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.887e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.974e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.887e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.971e+01
# False
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.887e+01
# True
# -----------------Time Step----------------------
# err - u - 1.466e+00 -- err - phi - 1.971e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 2.059e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.972e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 2.067e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.973e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.973e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 2.070e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.973e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 2.069e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.974e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 2.072e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.975e+01
# True
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 2.070e+01
# False
# -----------------Time Step----------------------
# err - u - 1.464e+00 -- err - phi - 1.975e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 2.070e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.975e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 2.073e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.976e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 2.074e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.976e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 2.070e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.976e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 2.074e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.976e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 2.073e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.976e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.976e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 2.073e+01
# False
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 1.977e+01
# True
# -----------------Time Step----------------------
# err - u - 1.465e+00 -- err - phi - 2.072e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.155e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.072e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.164e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.073e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.073e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.166e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.073e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.169e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.074e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.165e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.074e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.074e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.169e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.075e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.169e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.075e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.075e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.168e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.075e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.171e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.075e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.167e+01
# False
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.075e+01
# True
# -----------------Time Step----------------------
# err - u - 1.463e+00 -- err - phi - 2.169e+01
# True
# -----------------Time Step----------------------
# err - u - 1.461e+00 -- err - phi - 2.248e+01
# False
# -----------------Time Step----------------------
# err - u - 1.461e+00 -- err - phi - 2.169e+01
# True
# -----------------Time Step----------------------
# err - u - 1.461e+00 -- err - phi - 2.257e+01
# False
# -----------------Time Step----------------------
# err - u - 1.461e+00 -- err - phi - 2.170e+01
# True
# -----------------Time Step----------------------
# err - u - 1.461e+00 -- err - phi - 2.254e+01
# False
# -----------------Time Step----------------------
# err - u - 1.461e+00 -- err - phi - 2.170e+01
# False
# -----------------Time Step----------------------
# err - u - 1.461e+00 -- err - phi - 2.170e+01
# True

# %%
mesh.hmin(), mesh.num_cells()
# Out:
# (0.14951581963614172, 63918)

# %%
plt.figure(figsize=(18, 6))
c = plot(p_adaptive_n)
plt.colorbar(c)  # Adds the colorbar
plt.show()
