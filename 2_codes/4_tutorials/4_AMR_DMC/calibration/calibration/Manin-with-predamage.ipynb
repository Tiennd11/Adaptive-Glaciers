# %%
import ufl
import matplotlib.pyplot as plt
import time
import numpy as np
from dolfin import *
import matplotlib.tri as tri
import warnings
from matplotlib import cm
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# suppress FEniCS output to terminal
set_log_active(False)


# output directory
output_dir = ""


comm = MPI.comm_world  # MPI communications
rank = comm.Get_rank()  # number of current process
size = comm.Get_size()  # total number of processes

# %%
# mesh = Mesh("mesh/notch.xml")

# %%
mesh = Mesh()
with XDMFFile(comm, "mesh/Mesh_x.xdmf") as infile:
    infile.read(mesh)

# %%
# Step 4: Define the xdmf file for writing
xdmf = XDMFFile("Damage1.xdmf")
xdmf.parameters["flush_output"] = True
xdmf.parameters["rewrite_function_mesh"] = True
xdmf.parameters["functions_share_mesh"] = True

# %%
# xdmf = XDMFFile(comm, "output/results.xdmf")
# xdmf.parameters["flush_output"] = True
# xdmf.parameters["functions_share_mesh"] = True
# xdmf.write(mesh)

# %%
# Plot the mesh
plot(mesh,title='Mesh')
plt.show()

# %%
mesh

# %%
# # Plot the mesh
# plot(mesh,title='Mesh')
# plt.show()

# %%
nd = mesh.geometry().dim()  # mesh dimensions (2D or 3D)

# %%
mesh.num_vertices()
# Out:
# 3611

# %%
# Calculate minimum mesh size
min_mesh_size = mesh.hmin()
# Print the minimum mesh size
print("Minimum mesh size:", min_mesh_size)
# Out:
# Minimum mesh size: 2.633498603971342

# %%
"""Material parameters."""

rho_ice = 917  # density of ice (kg/m^3)
rho_H2O = 1020  # density of seawater (kg/m^3)
grav = 9.81  # gravity acceleration (m/s**2)
temp = -10 + 273  # temperature (K)
B0 = 2.207e-3  # viscosity coefficient (kPa * yr**(1/3))
B0 *= 1e3  # convert to (Pa * yr**(1/3))
B0 *= (365*24)**(1/3)  # convert to (Pa * hour**(1/3))
BT = B0*np.exp(3155/temp - 0.16612/(273.39 - temp)**1.17)

# %%
"""Damage parameters."""

alpha = 0.21  # weight of max principal stress  in Hayhurst criterion
beta = 0.63  # weight of von Mises stress in Hayhurst criterion
r = 0.43  # damage exponent
B = 5.232e-7  # damage coefficient
k1, k2 = -2.63, 7.24  # damage rate dependency parameters
Dcr = 0.6  # critical damage
Dmax = 0.99  # maximum damage
lc = 10  # nonlocal length scale
# prec_ratio = 0.08
hs_ratio = 0 # water level in crevasse (normalized with crevasse height)
hw_ratio = 0 # water level at right terminus (normalized with glacier thickness)
prec_ratio = 0.08 # depth of pre-crack (

# %%
"""Set simulation time and timestepping options."""

t_total = 480  # total time (hours)
t_elapsed = 0  # current elapsed time (hours)
t_delay_dmg = 0  # delay damage (hours)
max_Delta_t = 0.5  # max time increment (hours)
max_Delta_D = 0.1  # max damage increment
output_increment = 10  # number of steps between output
time_counter = 0  # current time step

# %%
"""Mesh details."""
# L, H = 500, 125  # domain dimensions
hs = 0  # water level in crevasse (normalized with crevasse height)
hw = 0  # water level at terminus (absolute height)
# mesh = load_mesh(output_dir + "mesh/hdf5/notch.h5")
# nd = mesh.geometry().dim()  # mesh dimensions (2D or 3D)

# %%
"""Define function spaces."""
S1 = FunctionSpace(mesh, "CG", 1)  # first order scalar space
S2 = FunctionSpace(mesh, "CG", 2)  # second order scalar space
V1 = VectorFunctionSpace(mesh, "CG", 1)  # first order vector space
V2 = VectorFunctionSpace(mesh, "CG", 2)  # second order vector space
P1 = FiniteElement("CG", mesh.ufl_cell(), 1)  # first order scalar element
P2 = VectorElement("CG", mesh.ufl_cell(), 2)  # second order vector element
V = FunctionSpace(mesh, MixedElement([P2, P1]))  # mixed finite element

# %%
"""Quadrature elements and function spaces."""

# deg_quad = 2
# scalar_quad = FiniteElement("Quadrature", cell=mesh.ufl_cell(),
#                             degree=deg_quad, quad_scheme="default")
# vector_quad = VectorElement("Quadrature", cell=mesh.ufl_cell(),
#                             degree=deg_quad, quad_scheme="default")
# SQ = FunctionSpace(mesh, scalar_quad)  # quadrature points in scalar space
# VQ = FunctionSpace(mesh, vector_quad)  # quadrature points in vector space
# form_params = {"quadrature_degree": deg_quad}


"""Coordinates of nodes on initial mesh configuration."""

X1, X2 = S1.tabulate_dof_coordinates().reshape((-1, nd)).T  # coordinates
n_local = len(X1)  # number of coordinates on local process
n_global = S1.dim()  # number of coordinates in global system

# %%
L,H= max(X1),max(X2)

# %%
L
# Out:
# 500.0

# %%
H
# Out:
# 125.0

# %%
def mwrite(filename, my_list):
    MPI.barrier(comm)
    if rank == 0:
        with open(filename, "w") as f:
            for item in my_list:
                f.write("%s" % item)


def mprint(*argv):
    if rank == 0:
        out = ""
        for arg in argv:
            out = out + str(arg)
        # this forces program to output when run in parallel
        print(out, flush=True)

# %%
mprint("Number of vertices      : {}".format(S1.dim()))
mprint("Number of cells         : {}".format(V1.dim()))
mprint("Number of DoF           : {}".format(V1.dim()))
mprint("Number of processes     : {}".format(size))
mprint("Number of DoF/process   : {}".format(int(V.dim() / size)))
mprint("-----------------------------------------------------")
# Out:
# Number of vertices      : 3611
# Number of cells         : 7222
# Number of DoF           : 7222
# Number of processes     : 1
# Number of DoF/process   : 31929
# -----------------------------------------------------

# %%
class left_edge(SubDomain):
    """Boundary on the left domain edge."""
    def inside(self, x, on_boundary): return near(x[0], 0) and on_boundary


class right_edge(SubDomain):
    """Boundary on the right domain edge."""
    def inside(self, x, on_boundary): return near(x[0], L) and on_boundary


class bottom_edge(SubDomain):
    """Boundary on the bottom domain edge."""
    def inside(self, x, on_boundary): return near(x[1], 0) and on_boundary


class top_edge(SubDomain):
    """Boundary on the top domain edge."""
    def inside(self, x, on_boundary): return near(x[1], H) and on_boundary


""" Define boundaries and boundary conditions. """

left = left_edge()
right = right_edge()
bottom = bottom_edge()
top = top_edge()

boundaries = MeshFunction("size_t", mesh, mesh.topology().dim() - 1)
left.mark(boundaries, 1)
right.mark(boundaries, 2)
bottom.mark(boundaries, 3)
top.mark(boundaries, 4)
ds = Measure("ds", subdomain_data=boundaries)

free_slip_left = DirichletBC(V.sub(0).sub(0), Constant(0), left)
free_slip_bottom = DirichletBC(V.sub(0).sub(1), Constant(0), bottom)
BC = [free_slip_left, free_slip_bottom]

# %%
"""define functions that are required to solve the problem"""

def bodyforce(dmg, y, h=0):
    """Gravity loading as a body force. Fully failed points have
        no density unless they are filled with water. Then they
        have the same density as water.
    """
    Dcr = 0.6
    b = Function(V1)  # body force as vector function
    by = Function(S1)  # y-component of vector function
    for i in range(n_local):
        if dmg.vector()[i] < Dcr:
            by.vector()[i] = -rho_ice*grav
        if (dmg.vector()[i] >= Dcr)*(y[i] <= h):
            by.vector()[i] = -rho_H2O*grav
    assign(b.sub(1), by)
    return b

def hydrostatic(h):
    h_expression = Expression(("(h - x[1] > 0 ?-rho_H2O * grav*(h - x[1]) : 0)",0), h=hw, rho_H2O=rho_H2O, grav=grav, degree=1)
    return h_expression

def pore_pressure(dmg, x, y, h):
	"""Hydraulic pressure from poro-mechanics formulation."""
	Dcr = 0.6
	b_poro = Function(S1)
	dmg_local = dmg.vector().get_local()
	for i in range(n_local):
		if dmg_local[i] >= Dcr:
			b_poro.vector()[i] = rho_H2O*grav*np.fmax(h - y[i], 0)*dmg_local[i]
	return b_poro


def surface_crevasse_level(dmg, y, hsr, pr):
    """dynamically compute water level in the surface crevasse"""
    crevasse_depth = 0
    crevasse_surface = 0
    if hsr > 0:
        for i in range(n_local):  # Fix: Use 'range' and correct the syntax
            if dmg.vector()[i] > Dcr:
                x2_dmg = y[i]
                if len(x2_dmg) > 0:
                    x2_dmg_local_max = min(max(x2_dmg), H)
                    x2_dmg_local_min = max(min(x2_dmg), 0)
                else:
                    x2_dmg_local_max = H
                    x2_dmg_local_min = 0
                x2_dmg_max = comm.allreduce(x2_dmg_local_max, op=MPI.MAX)
                x2_dmg_min = comm.allreduce(x2_dmg_local_min, op=MPI.MIN)
                crevasse_depth = float(x2_dmg_max - x2_dmg_min)
                crevasse_surface = crevasse_depth * hsr + x2_dmg_min
    return crevasse_depth, crevasse_surface

# %%
"""Define constitutive and kinematic relationships."""


def D(u):
    """Symmetric gradient operator."""
    return sym(nabla_grad(u))


def DII(u):
    """Second strain invariant."""
    return (0.5*(D(u)[0, 0]**2 + D(u)[1, 1]**2) + D(u)[0, 1]**2)


def eta1(u, n=3, gam=1e-14):
    """Nonlinear viscosity."""
    return 0.5*BT*(DII(u) + gam)**((1 - n)/2/n)

def c_bar(dmg=None):
    """Implicit gradient damage constant term."""
    c = Function(S1)
#     dmg_local = dmg.vector().get_local()
    if dmg:
        for i in range(n_local):
            if dmg.vector()[i] < Dcr:
                c.vector()[i] = 0.5*(lc**2)
    else:
        c.vector()[:] = 0.5*(lc**2)
    return c


def update_psi(dmg):
    """Function for enforcing incompressibility."""
    psi = Function(S1)
    psi.vector()[:] = 1
    for i in range(n_local):
    #failed_points = dmg.vector()[:] > Dcr  # failed material points
        if dmg.vector()[i] > Dcr:
            psi.vector()[i] = 1e-32
#     psi.vector()[failed_points] = 1e-32
    return psi


def np_array(x):
    """converts x in to a vector format computed at the nodes"""
    return x.vector().get_local()


def mac(x):
    """Macaulay's bracket"""
    return (x+abs(x))/2

# %%
"Define damage function."""

dmg = Function(S1)
# deg = Function(S2)

# dmg.vector()[(L/2 - 2*lc < XQ1)*(XQ1 < L/2 + 2*lc)*(H*(1-0.08) < XQ2)] = Dmax
# # dmg.vector()[(L/2 - 5 < X1)*(X1 < L/2 + 5)*(H - 10 < X2)] = Dmax

"""define pre-crack zone"""
for i in range(n_local):
    if ((L - lc)/2 < X1[i])*(X1[i] < (L + lc)/2)*(X2[i] > H*(1 - 0.08)):
        dmg.vector()[i] = Dmax
#     else:
#         dmg.vector()[i] = 0

# %%
jet = cm.jet
rainbow = cm.rainbow
redblue = cm.coolwarm
viridis = cm.viridis
plasma = cm.plasma
magma = cm.magma

# %%
plot(dmg)

# %%
"""Initial guess for Picard iterations."""

uk = Function(V2)  # velocity
pk = Function(S1)  # pressure


comm.Barrier()

# %%
"""define crack tip coordinate"""
cracktip_coor = H*(1-0.08)

# %%
"""Main time loop."""
#t_total t_elapsed
while t_elapsed < t_total:

    time_counter += 1
    # get current configuration coordinates
    x1, x2 = S1.tabulate_dof_coordinates().reshape((-1, nd)).T
    """Extract boundaries."""
    L,H= max(x1),max(x2) 
    n_local = len(x1)  # number of coordinates on local process
    n_global = S1.dim()  # number of coordinates in global system


    u, p = TrialFunctions(V)  # trial functions in (V2, S1) space
    v, q = TestFunctions(V)  # test functions in (V2, S1) space

    # hydraulic pressure in surface crevasse
    cdepth, csurfx2 = surface_crevasse_level(dmg=dmg, y=x2, hsr=hs_ratio, pr=prec_ratio)  # height of water column
    b_poro = pore_pressure(dmg=dmg, x=x1, y=x2, h=csurfx2)  # hydraulic pressure
    # pHD = pore_pressure(dmg=dmg, y=xQ2, h=cs)  # hydraulic pressure


    # define loading terms
    b_grav = bodyforce(dmg=dmg, y=x2, h=csurfx2) # gravity for ice and water
    b_hw = hydrostatic(h=hw)  # terminus pressure

    # normal function to mesh
    nhat = FacetNormal(mesh)

  # incompressibility terms

    penalty = False

    psi = update_psi(dmg)
     ### update degradation function with damage value from previous step

    # define variational form
    LHS = (inner(D(v), 2*(1-dmg)*eta1(uk)*D(u)) - (1-dmg)*div(v)*p
           + psi*q*div(u))*dx
    if penalty:
        LHS += 1e12*inner(nabla_div(u), psi*div(v))*dx  # penalty term
    # RHS = (1-dmg)*inner(v, b_grav)*dx  # ice and water gravity
    RHS = inner(v, b_grav)*dx  # ice and water gravity
    if hs > 0:
        RHS += inner(nabla_div(v), b_poro)*dx  # hydraulic pressure in damage zone
    if hw > 0:
        RHS += inner(v, b_hw)*ds(2)  # terminus pressure

    """ Picard iterations. """

    eps_local = 1  # local error norm
    eps_global = 1  # global error norm
    tol = 1e-4  # error tolerance
    picard_count = 0  # iteration count
    picard_max = 50  # maximum iterations
    w = Function(V)  # empty function to dump solution

    while (abs(eps_global) > tol) and (picard_count < picard_max):

        # solve the variational form
        solve(LHS == RHS, w, BC)
        u, p = w.split(deepcopy=True)
        u1, u2 = u.split(deepcopy=True)

        # compute error norms
        u1k, u2k = uk.split(deepcopy=True)
        diff1 = u1.vector().get_local() - u1k.vector().get_local()
        diff2 = u2.vector().get_local() - u2k.vector().get_local()
        diffp = p.vector().get_local() - pk.vector().get_local()
        eps1 = np.linalg.norm(diff1)/np.linalg.norm(u1.vector().get_local())
        eps2 = np.linalg.norm(diff2)/np.linalg.norm(u2.vector().get_local())
        epsp = np.linalg.norm(diffp)/np.linalg.norm(p.vector().get_local())

        # update solution for next iteration
        assign(uk, u)
        assign(pk, p)

        comm.Barrier()

        # obtain the max error on the local process
        eps_local = max(eps1, eps2, epsp)
        # obtain the max error on all processes
        eps_global = comm.allreduce(eps_local, op=MPI.max)


        # update iteration count
        picard_count += 1
    # build effective deviatoric stress tensor
    tau = 2*eta1(u)*D(u)
    t11 = project(tau[0, 0], S1).vector().get_local()
    t22 = project(tau[1, 1], S1).vector().get_local()
    t33 = np.zeros(n_local)
    t12 = project(tau[0, 1], S1).vector().get_local()

    dmg0 = dmg.vector().get_local()# damage from previous time step
    prs = interpolate(p, S1).vector().get_local()# effective pressure

    t23 = np.zeros(n_local)

    t13 = np.zeros(n_local)

 
    # effective Cauchy stress
    s11, s22, s33, s12, s23, s13 = t11 - prs, t22 - prs, t33 - prs, t12, t23, t13
    
    I1 = s11 + s22 + s33  # effective I1 invariant
    I1_true = (1 - dmg0)*I1 - 3*b_poro.vector().get_local()  # true I1 invariant
#     I1_true = (1 - dmg0)*I1  # true I1 invariant

    J2 = 0.5*(t11**2 + t22**2 + t33**2) + t12**2  # effective J2 invariant
    vms = np.sqrt(3*J2)  # effective von Mises stress

    lam1 = s33
    lam2 = 0.5*(s11 + s22 + np.sqrt(s11**2 - 2*s11*s22 + 4*(s12**2) + s22**2))
    mps = np.fmax(lam1, lam2)  # effective max principal stress

    # effective Hayhurst stress
    chi = alpha*mps + beta*vms + (1 - alpha - beta)*I1

    
    
    """ Compute the local damage rate and increment. """

    # local damage rate
    dDloc_dt = np.zeros(n_local)
    for i in range(n_local):
        if (I1[i] > 0 and chi[i] > 0 and dmg0[i] < Dcr):
            k = min(k1 + k2*abs(I1_true[i]/1e6), 30)
            dDloc_dt[i] = B*((chi[i]/1e6)**r)/((1 - dmg0[i])**k)

    # select time increment on each local process
    if max(dDloc_dt) > 0:
        Delta_t_local = float(max_Delta_D/max(dDloc_dt))
        Delta_t_local = min(max_Delta_t*3600, Delta_t_local)
    else:
        Delta_t_local = max_Delta_t*3600

    # obtain the minimum time increment from all processes
    comm.Barrier()
    Delta_t = comm.allreduce(Delta_t_local, op=MPI.min)

    # compute the damage increment
    Delta_Dloc = Function(S1)
    Delta_Dloc.vector()[:] = dDloc_dt*Delta_t

    """ Compute the nonlocal damage increment using implicit gradient. """

    # trial and test functions
    Delta_D = TrialFunction(S1)
    z = TestFunction(S1)

    # define variational form
    LHS = (inner(z, Delta_D) + c_bar(dmg)*inner(nabla_grad(z), nabla_grad(Delta_D)))*dx
    RHS = inner(z, Delta_Dloc)*dx

    # solve for the nonlocal damage increment
    w = Function(S1)  # empty function to dump solution
    solve(LHS == RHS, w)

    # interpolate nonlocal damage increment at quadrature points
    wq = np.clip(interpolate(w, S1).vector().get_local(), 0, max_Delta_D)

    # update damage and psi UFL functions
    dmg = Function(S1)
    dmgv = np.zeros(n_local)

    if t_elapsed >= t_delay_dmg:
#         dmgv = np.clip(dmg0+wq, 0, Dmax)  # 0 < damage < Dmax
        for i in range(n_local):
            dmgv[i] = max(0, min(dmg0[i] + wq[i], Dmax))
            if dmgv[i] > Dcr:
                dmgv[i] = Dmax
            dmg.vector()[i] = dmgv[i]

    """ Output data to mesh file. """

    Delta_t /= 3600  # convert time increment to hours
    
    """ Save data """
#     S2 = FunctionSpace(mesh, "CG", 1)  # first order scalar space
    
    N11 = Function(S1, name="S11")
    H11 = Function(S1, name="H11")
    V11 = Function(S1, name="V11")
    dmgx = Function(S1, name="Dmg")
    
    # Assuming s11, chi, and vms are NumPy arrays or similar
    N11.vector()[:] = s11
    H11.vector()[:] = chi
    V11.vector()[:] = vms
    dmgx.vector()[:] = dmg.vector()[:]

#     xdmf.write(mesh)
    xdmf.write(N11, t_elapsed)
    xdmf.write(V11, t_elapsed)
    xdmf.write(H11, t_elapsed)
    xdmf.write(dmgx, t_elapsed)

    """ Updated Lagrangian implementation. """

  # split velocity into components in S1 space
    u1, u2 = u.split(deepcopy=True)
    u1 = interpolate(u1, S1).vector().get_local()
    u2 = interpolate(u2, S1).vector().get_local()

    # compute the displacement increment vector Delta_u
    Delta_u1 = Function(S1)
    Delta_u2 = Function(S1)
    Delta_u1.vector()[:] = u1*Delta_t
    Delta_u2.vector()[:] = u2*Delta_t
    Delta_u = Function(V1)
    assign(Delta_u.sub(0), Delta_u1)
    assign(Delta_u.sub(1), Delta_u2)
    
#     Delta_u = interpolate(Delta_u, V1)
    # move the mesh, update coordinates
    ALE.move(mesh, Delta_u)


    # update elapsed time
    t_elapsed += Delta_t

    dmgc = dmg.vector().get_local()
    for i in range(n_local):
        # if dmgc[i] >= 0.99:
        if dmgc[i] >= Dcr:
            if x2[i] < cracktip_coor:
                cracktip_coor = x2[i]
    print("Step %d, Crack depth: %g, time: %0.2f" % (t_elapsed,1-cracktip_coor/H,t_elapsed ))
# Out:
# Step 0, Crack depth: 0.08, time: 0.50
# Step 1, Crack depth: 0.0799866, time: 1.00
# Step 1, Crack depth: 0.0799732, time: 1.50
# Step 2, Crack depth: 0.0799598, time: 2.00
# Step 2, Crack depth: 0.0799464, time: 2.50
# Step 3, Crack depth: 0.079933, time: 3.00
# Step 3, Crack depth: 0.0799195, time: 3.50
# Step 4, Crack depth: 0.0799061, time: 4.00
# Step 4, Crack depth: 0.0798927, time: 4.50
# Step 5, Crack depth: 0.0798793, time: 5.00
# Step 5, Crack depth: 0.0798659, time: 5.50
# Step 6, Crack depth: 0.0798524, time: 6.00
# Step 6, Crack depth: 0.079839, time: 6.50
# Step 7, Crack depth: 0.0798256, time: 7.00
# Step 7, Crack depth: 0.0798122, time: 7.50
# Step 8, Crack depth: 0.0797987, time: 8.00
# Step 8, Crack depth: 0.0797853, time: 8.50
# Step 9, Crack depth: 0.0797719, time: 9.00
# Step 9, Crack depth: 0.0797584, time: 9.50
# Step 10, Crack depth: 0.079745, time: 10.00
# Step 10, Crack depth: 0.0797316, time: 10.50
# Step 11, Crack depth: 0.0797181, time: 11.00
# Step 11, Crack depth: 0.0797047, time: 11.50
# Step 12, Crack depth: 0.0796913, time: 12.00
# Step 12, Crack depth: 0.0796778, time: 12.50
# Step 13, Crack depth: 0.0796644, time: 13.00
# Step 13, Crack depth: 0.0796509, time: 13.50
# Step 14, Crack depth: 0.0796375, time: 14.00
# Step 14, Crack depth: 0.079624, time: 14.50
# Step 15, Crack depth: 0.0796106, time: 15.00
# Step 15, Crack depth: 0.0795971, time: 15.50
# Step 16, Crack depth: 0.0795837, time: 16.00
# Step 16, Crack depth: 0.0795702, time: 16.50
# Step 17, Crack depth: 0.0795567, time: 17.00
# Step 17, Crack depth: 0.0795433, time: 17.50
# Step 18, Crack depth: 0.0795298, time: 18.00
# Step 18, Crack depth: 0.0795164, time: 18.50
# Step 19, Crack depth: 0.0795029, time: 19.00
# Step 19, Crack depth: 0.0794894, time: 19.50
# Step 20, Crack depth: 0.079476, time: 20.00
# Step 20, Crack depth: 0.0794625, time: 20.50
# Step 21, Crack depth: 0.079449, time: 21.00
# Step 21, Crack depth: 0.0794355, time: 21.50
# Step 22, Crack depth: 0.0794221, time: 22.00
# Step 22, Crack depth: 0.0794086, time: 22.50
# Step 23, Crack depth: 0.0793951, time: 23.00
# Step 23, Crack depth: 0.0793816, time: 23.50
# Step 24, Crack depth: 0.0793682, time: 24.00
# Step 24, Crack depth: 0.0793547, time: 24.50
# Step 25, Crack depth: 0.0793412, time: 25.00
# Step 25, Crack depth: 0.0793277, time: 25.50
# Step 26, Crack depth: 0.0793142, time: 26.00
# Step 26, Crack depth: 0.0793007, time: 26.50
# Step 27, Crack depth: 0.0792872, time: 27.00
# Step 27, Crack depth: 0.0792737, time: 27.50
# Step 28, Crack depth: 0.0792602, time: 28.00
# Step 28, Crack depth: 0.0792467, time: 28.50
# Step 29, Crack depth: 0.0792332, time: 29.00
# Step 29, Crack depth: 0.0792197, time: 29.50
# Step 30, Crack depth: 0.0792062, time: 30.00
# Step 30, Crack depth: 0.0791927, time: 30.50
# Step 31, Crack depth: 0.0791792, time: 31.00
# Step 31, Crack depth: 0.0791657, time: 31.50
# Step 32, Crack depth: 0.0791522, time: 32.00
# Step 32, Crack depth: 0.0791387, time: 32.50
# Step 33, Crack depth: 0.0791252, time: 33.00
# Step 33, Crack depth: 0.0791117, time: 33.50
# Step 34, Crack depth: 0.0790982, time: 34.00
# Step 34, Crack depth: 0.0790846, time: 34.50
# Step 35, Crack depth: 0.0790711, time: 35.00
# Step 35, Crack depth: 0.0790576, time: 35.50
# Step 36, Crack depth: 0.0790441, time: 36.00
# Step 36, Crack depth: 0.0790305, time: 36.50
# Step 37, Crack depth: 0.079017, time: 37.00
# Step 37, Crack depth: 0.0790035, time: 37.50
# Step 38, Crack depth: 0.0789899, time: 38.00
# Step 38, Crack depth: 0.0789764, time: 38.50
# Step 39, Crack depth: 0.0789629, time: 39.00
# Step 39, Crack depth: 0.0789493, time: 39.50
# Step 40, Crack depth: 0.0789358, time: 40.00
# Step 40, Crack depth: 0.0789223, time: 40.50
# Step 41, Crack depth: 0.0789087, time: 41.00
# Step 41, Crack depth: 0.0788952, time: 41.50
# Step 42, Crack depth: 0.0788816, time: 42.00
# Step 42, Crack depth: 0.0788681, time: 42.50
# Step 43, Crack depth: 0.0788545, time: 43.00
# Step 43, Crack depth: 0.078841, time: 43.50
# Step 44, Crack depth: 0.0788274, time: 44.00
# Step 44, Crack depth: 0.0788139, time: 44.50
# Step 45, Crack depth: 0.0788003, time: 45.00
# Step 45, Crack depth: 0.0787868, time: 45.50
# Step 46, Crack depth: 0.0787732, time: 46.00
# Step 46, Crack depth: 0.0787596, time: 46.50
# Step 47, Crack depth: 0.0787461, time: 47.00
# Step 47, Crack depth: 0.0787325, time: 47.50
# Step 48, Crack depth: 0.0787189, time: 48.00
# Step 48, Crack depth: 0.0787054, time: 48.50
# Step 49, Crack depth: 0.0786918, time: 49.00
# Step 49, Crack depth: 0.0786782, time: 49.50
# Step 50, Crack depth: 0.0786646, time: 50.00
# Step 50, Crack depth: 0.0786511, time: 50.50
# Step 51, Crack depth: 0.0786375, time: 51.00
# Step 51, Crack depth: 0.0786239, time: 51.50
# Step 52, Crack depth: 0.0786103, time: 52.00
# Step 52, Crack depth: 0.0785967, time: 52.50
# Step 53, Crack depth: 0.0785831, time: 53.00
# Step 53, Crack depth: 0.0785696, time: 53.50
# Step 54, Crack depth: 0.078556, time: 54.00
# Step 54, Crack depth: 0.0785424, time: 54.50
# Step 55, Crack depth: 0.0785288, time: 55.00
# Step 55, Crack depth: 0.0785152, time: 55.50
# Step 56, Crack depth: 0.0785016, time: 56.00
# Step 56, Crack depth: 0.078488, time: 56.50
# Step 57, Crack depth: 0.0784744, time: 57.00
# Step 57, Crack depth: 0.0784608, time: 57.50
# Step 58, Crack depth: 0.0784472, time: 58.00
# Step 58, Crack depth: 0.0784335, time: 58.50
# Step 59, Crack depth: 0.0784199, time: 59.00
# Step 59, Crack depth: 0.0784063, time: 59.50
# Step 60, Crack depth: 0.0783927, time: 60.00
# Step 60, Crack depth: 0.0783791, time: 60.50
# Step 61, Crack depth: 0.0783655, time: 61.00
# Step 61, Crack depth: 0.0783519, time: 61.50
# Step 62, Crack depth: 0.0783382, time: 62.00
# Step 62, Crack depth: 0.0783246, time: 62.50
# Step 63, Crack depth: 0.078311, time: 63.00
# Step 63, Crack depth: 0.0782973, time: 63.50
# Step 64, Crack depth: 0.0782837, time: 64.00
# Step 64, Crack depth: 0.0782701, time: 64.50
# Step 65, Crack depth: 0.0782564, time: 65.00
# Step 65, Crack depth: 0.0782428, time: 65.50
# Step 66, Crack depth: 0.0782292, time: 66.00
# Step 66, Crack depth: 0.0782155, time: 66.50
# Step 67, Crack depth: 0.0782019, time: 67.00
# Step 67, Crack depth: 0.0781882, time: 67.50
# Step 68, Crack depth: 0.0781746, time: 68.00
# Step 68, Crack depth: 0.0781609, time: 68.50
# Step 69, Crack depth: 0.0781473, time: 69.00
# Step 69, Crack depth: 0.0781336, time: 69.50
# Step 70, Crack depth: 0.07812, time: 70.00
# Step 70, Crack depth: 0.0781063, time: 70.50
# Step 71, Crack depth: 0.0780927, time: 71.00
# Step 71, Crack depth: 0.078079, time: 71.50
# Step 72, Crack depth: 0.0780653, time: 72.00
# Step 72, Crack depth: 0.0780517, time: 72.50
# Step 73, Crack depth: 0.078038, time: 73.00
# Step 73, Crack depth: 0.0780243, time: 73.50
# Step 74, Crack depth: 0.0780107, time: 74.00
# Step 74, Crack depth: 0.077997, time: 74.50
# Step 75, Crack depth: 0.0779833, time: 75.00
# Step 75, Crack depth: 0.0779697, time: 75.50
# Step 76, Crack depth: 0.077956, time: 76.00
# Step 76, Crack depth: 0.0779423, time: 76.50
# Step 77, Crack depth: 0.0779286, time: 77.00
# Step 77, Crack depth: 0.0779149, time: 77.50
# Step 78, Crack depth: 0.0779012, time: 78.00
# Step 78, Crack depth: 0.0778875, time: 78.50
# Step 79, Crack depth: 0.0778739, time: 79.00
# Step 79, Crack depth: 0.0778602, time: 79.50
# Step 80, Crack depth: 0.0778465, time: 80.00
# Step 80, Crack depth: 0.0778328, time: 80.50
# Step 81, Crack depth: 0.0778191, time: 81.00
# Step 81, Crack depth: 0.0778054, time: 81.50
# Step 82, Crack depth: 0.0777917, time: 82.00
# Step 82, Crack depth: 0.077778, time: 82.50
# Step 83, Crack depth: 0.0777642, time: 83.00
# Step 83, Crack depth: 0.0777505, time: 83.50
# Step 84, Crack depth: 0.0777368, time: 84.00
# Step 84, Crack depth: 0.0777231, time: 84.50
# Step 85, Crack depth: 0.0777094, time: 85.00
# Step 85, Crack depth: 0.0776957, time: 85.50
# Step 86, Crack depth: 0.077682, time: 86.00
# Step 86, Crack depth: 0.0776682, time: 86.50
# Step 87, Crack depth: 0.0776545, time: 87.00
# Step 87, Crack depth: 0.0776408, time: 87.50
# Step 88, Crack depth: 0.077627, time: 88.00
# Step 88, Crack depth: 0.0776133, time: 88.50
# Step 89, Crack depth: 0.0775996, time: 89.00
# Step 89, Crack depth: 0.0775858, time: 89.50
# Step 90, Crack depth: 0.0775721, time: 90.00
# Step 90, Crack depth: 0.0775584, time: 90.50
# Step 91, Crack depth: 0.0775446, time: 91.00
# Step 91, Crack depth: 0.0775309, time: 91.50
# Step 92, Crack depth: 0.0775171, time: 92.00
# Step 92, Crack depth: 0.0775034, time: 92.50
# Step 93, Crack depth: 0.0774896, time: 93.00
# Step 93, Crack depth: 0.0774759, time: 93.50
# Step 94, Crack depth: 0.0774621, time: 94.00
# Step 94, Crack depth: 0.0774484, time: 94.50
# Step 95, Crack depth: 0.0774346, time: 95.00
# Step 95, Crack depth: 0.0774209, time: 95.50
# Step 96, Crack depth: 0.0774071, time: 96.00
# Step 96, Crack depth: 0.0773933, time: 96.50
# Step 97, Crack depth: 0.0773796, time: 97.00
# Step 97, Crack depth: 0.0773658, time: 97.50
# Step 98, Crack depth: 0.077352, time: 98.00
# Step 98, Crack depth: 0.0773383, time: 98.50
# Step 99, Crack depth: 0.0773245, time: 99.00
# Step 99, Crack depth: 0.0773107, time: 99.50
# Step 100, Crack depth: 0.0772969, time: 100.00
# Step 100, Crack depth: 0.0772831, time: 100.50
# Step 101, Crack depth: 0.0772694, time: 101.00
# Step 101, Crack depth: 0.0772556, time: 101.50
# Step 102, Crack depth: 0.0772418, time: 102.00
# Step 102, Crack depth: 0.077228, time: 102.50
# Step 103, Crack depth: 0.0772142, time: 103.00
# Step 103, Crack depth: 0.0772004, time: 103.50
# Step 104, Crack depth: 0.0771866, time: 104.00
# Step 104, Crack depth: 0.0771728, time: 104.50
# Step 105, Crack depth: 0.077159, time: 105.00
# Step 105, Crack depth: 0.0771452, time: 105.50
# Step 106, Crack depth: 0.0771314, time: 106.00
# Step 106, Crack depth: 0.0771176, time: 106.50
# Step 107, Crack depth: 0.0771038, time: 107.00
# Step 107, Crack depth: 0.07709, time: 107.50
# Step 108, Crack depth: 0.0770762, time: 108.00
# Step 108, Crack depth: 0.0770624, time: 108.50
# Step 109, Crack depth: 0.0770485, time: 109.00
# Step 109, Crack depth: 0.0770347, time: 109.50
# Step 110, Crack depth: 0.0770209, time: 110.00
# Step 110, Crack depth: 0.0770071, time: 110.50
# Step 111, Crack depth: 0.0769933, time: 111.00
# Step 111, Crack depth: 0.0769794, time: 111.50
# Step 112, Crack depth: 0.0769656, time: 112.00
# Step 112, Crack depth: 0.0769518, time: 112.50
# Step 113, Crack depth: 0.0769379, time: 113.00
# Step 113, Crack depth: 0.0769241, time: 113.50
# Step 114, Crack depth: 0.0769103, time: 114.00
# Step 114, Crack depth: 0.0768964, time: 114.50
# Step 115, Crack depth: 0.0768826, time: 115.00
# Step 115, Crack depth: 0.0768687, time: 115.50
# Step 116, Crack depth: 0.0768549, time: 116.00
# Step 116, Crack depth: 0.076841, time: 116.50
# Step 117, Crack depth: 0.0768272, time: 117.00
# Step 117, Crack depth: 0.0768133, time: 117.50
# Step 118, Crack depth: 0.0767995, time: 118.00
# Step 118, Crack depth: 0.0767856, time: 118.50
# Step 119, Crack depth: 0.0767718, time: 119.00
# Step 119, Crack depth: 0.0767579, time: 119.50
# Step 120, Crack depth: 0.076744, time: 120.00
# Step 120, Crack depth: 0.0767302, time: 120.50
# Step 121, Crack depth: 0.0767163, time: 121.00
# Step 121, Crack depth: 0.0767024, time: 121.50
# Step 122, Crack depth: 0.0766886, time: 122.00
# Step 122, Crack depth: 0.0766747, time: 122.50
# Step 123, Crack depth: 0.0766608, time: 123.00
# Step 123, Crack depth: 0.0766469, time: 123.50
# Step 124, Crack depth: 0.0766331, time: 124.00
# Step 124, Crack depth: 0.0766192, time: 124.50
# Step 125, Crack depth: 0.0766053, time: 125.00
# Step 125, Crack depth: 0.0765914, time: 125.50
# Step 126, Crack depth: 0.0765775, time: 126.00
# Step 126, Crack depth: 0.0765636, time: 126.50
# Step 127, Crack depth: 0.0765497, time: 127.00
# Step 127, Crack depth: 0.0765359, time: 127.50
# Step 128, Crack depth: 0.076522, time: 128.00
# Step 128, Crack depth: 0.0765081, time: 128.50
# Step 129, Crack depth: 0.0764942, time: 129.00
# Step 129, Crack depth: 0.0764803, time: 129.50
# Step 130, Crack depth: 0.0764664, time: 130.00
# Step 130, Crack depth: 0.0764525, time: 130.50
# Step 131, Crack depth: 0.0764385, time: 131.00
# Step 131, Crack depth: 0.0764246, time: 131.50
# Step 132, Crack depth: 0.0764107, time: 132.00
# Step 132, Crack depth: 0.0763968, time: 132.50
# Step 133, Crack depth: 0.0763829, time: 133.00
# Step 133, Crack depth: 0.076369, time: 133.50
# Step 134, Crack depth: 0.0763551, time: 134.00
# Step 134, Crack depth: 0.0763411, time: 134.50
# Step 135, Crack depth: 0.0763272, time: 135.00
# Step 135, Crack depth: 0.0763133, time: 135.50
# Step 136, Crack depth: 0.0762994, time: 136.00
# Step 136, Crack depth: 0.0762854, time: 136.50
# Step 137, Crack depth: 0.0762715, time: 137.00
# Step 137, Crack depth: 0.0762576, time: 137.50
# Step 138, Crack depth: 0.0762437, time: 138.00
# Step 138, Crack depth: 0.0762297, time: 138.50
# Step 139, Crack depth: 0.0762158, time: 139.00
# Step 139, Crack depth: 0.0762018, time: 139.50
# Step 140, Crack depth: 0.0761879, time: 140.00
# Step 140, Crack depth: 0.076174, time: 140.50
# Step 141, Crack depth: 0.07616, time: 141.00
# Step 141, Crack depth: 0.0761461, time: 141.50
# Step 142, Crack depth: 0.0761321, time: 142.00
# Step 142, Crack depth: 0.0761182, time: 142.50
# Step 143, Crack depth: 0.0761042, time: 143.00
# Step 143, Crack depth: 0.0760903, time: 143.50
# Step 144, Crack depth: 0.0760763, time: 144.00
# Step 144, Crack depth: 0.0760624, time: 144.50
# Step 145, Crack depth: 0.0760484, time: 145.00
# Step 145, Crack depth: 0.0760345, time: 145.50
# Step 146, Crack depth: 0.0760205, time: 146.00
# Step 146, Crack depth: 0.0760065, time: 146.50
# Step 147, Crack depth: 0.0759926, time: 147.00
# Step 147, Crack depth: 0.0759786, time: 147.50
# Step 148, Crack depth: 0.0759647, time: 148.00
# Step 148, Crack depth: 0.0759507, time: 148.50
# Step 149, Crack depth: 0.0759367, time: 149.00
# Step 149, Crack depth: 0.0759228, time: 149.50
# Step 150, Crack depth: 0.0759088, time: 150.00
# Step 150, Crack depth: 0.0758948, time: 150.50
# Step 151, Crack depth: 0.0758808, time: 151.00
# Step 151, Crack depth: 0.0758669, time: 151.50
# Step 152, Crack depth: 0.0758529, time: 152.00
# Step 152, Crack depth: 0.0758389, time: 152.50
# Step 153, Crack depth: 0.075825, time: 153.00
# Step 153, Crack depth: 0.075811, time: 153.50
# Step 154, Crack depth: 0.075797, time: 154.00
# Step 154, Crack depth: 0.075783, time: 154.50
# Step 155, Crack depth: 0.0757691, time: 155.00
# Step 155, Crack depth: 0.0757551, time: 155.50
# Step 156, Crack depth: 0.0757411, time: 156.00
# Step 156, Crack depth: 0.0757271, time: 156.50
# Step 157, Crack depth: 0.0757131, time: 157.00
# Step 157, Crack depth: 0.109619, time: 157.50
# Step 158, Crack depth: 0.109634, time: 158.00
# Step 158, Crack depth: 0.110172, time: 158.50
# Step 158, Crack depth: 0.110187, time: 158.72
# Step 158, Crack depth: 0.110194, time: 158.91
# Step 159, Crack depth: 0.1102, time: 159.09
# Step 159, Crack depth: 0.135567, time: 159.26
# Step 159, Crack depth: 0.13557, time: 159.46
# Step 159, Crack depth: 0.135578, time: 159.65
# Step 159, Crack depth: 0.135585, time: 159.82
# Step 159, Crack depth: 0.135591, time: 159.97
# Step 160, Crack depth: 0.135597, time: 160.12
# Step 160, Crack depth: 0.135602, time: 160.25
# Step 160, Crack depth: 0.135607, time: 160.37
# Step 160, Crack depth: 0.135612, time: 160.48
# Step 160, Crack depth: 0.135616, time: 160.58
# Step 160, Crack depth: 0.13562, time: 160.68
# Step 160, Crack depth: 0.135623, time: 160.77
# Step 160, Crack depth: 0.135627, time: 160.85
# Step 160, Crack depth: 0.13563, time: 160.92
# Step 160, Crack depth: 0.135633, time: 160.99
# Step 161, Crack depth: 0.135635, time: 161.05
# Step 161, Crack depth: 0.135638, time: 161.11
# Step 161, Crack depth: 0.13564, time: 161.17
# Step 161, Crack depth: 0.135642, time: 161.22
# Step 161, Crack depth: 0.135644, time: 161.26
# Step 161, Crack depth: 0.135646, time: 161.31
# Step 161, Crack depth: 0.135648, time: 161.35
# Step 161, Crack depth: 0.13565, time: 161.38
# Step 161, Crack depth: 0.135651, time: 161.42
# Step 161, Crack depth: 0.162104, time: 161.45
# Step 161, Crack depth: 0.162105, time: 161.95
# Step 162, Crack depth: 0.162119, time: 162.45
# Step 162, Crack depth: 0.162134, time: 162.95
# Step 163, Crack depth: 0.16215, time: 163.45
# Step 163, Crack depth: 0.162165, time: 163.95
# Step 164, Crack depth: 0.162181, time: 164.45
# Step 164, Crack depth: 0.162197, time: 164.95
# Step 165, Crack depth: 0.162213, time: 165.45
# Step 165, Crack depth: 0.162229, time: 165.75
# Step 166, Crack depth: 0.162239, time: 166.01
# Step 166, Crack depth: 0.162247, time: 166.25
# Step 166, Crack depth: 0.162255, time: 166.75
# Step 167, Crack depth: 0.162274, time: 167.25
# Step 167, Crack depth: 0.162292, time: 167.75
# Step 168, Crack depth: 0.181043, time: 168.24
# Step 168, Crack depth: 0.18403, time: 168.43
# Step 168, Crack depth: 0.184035, time: 168.93
# Step 169, Crack depth: 0.184048, time: 169.43
# Step 169, Crack depth: 0.184062, time: 169.91
# Step 170, Crack depth: 0.184075, time: 170.34
# Step 170, Crack depth: 0.184087, time: 170.73
# Step 171, Crack depth: 0.184098, time: 171.08
# Step 171, Crack depth: 0.184108, time: 171.40
# Step 171, Crack depth: 0.184117, time: 171.69
# Step 171, Crack depth: 0.184125, time: 171.96
# Step 172, Crack depth: 0.184133, time: 172.20
# Step 172, Crack depth: 0.209797, time: 172.42
# Step 172, Crack depth: 0.209801, time: 172.69
# Step 172, Crack depth: 0.209809, time: 172.92
# Step 173, Crack depth: 0.209817, time: 173.13
# Step 173, Crack depth: 0.209824, time: 173.32
# Step 173, Crack depth: 0.20983, time: 173.49
# Step 173, Crack depth: 0.209835, time: 173.65
# Step 173, Crack depth: 0.20984, time: 173.78
# Step 173, Crack depth: 0.209845, time: 173.91
# Step 174, Crack depth: 0.209849, time: 174.02
# Step 174, Crack depth: 0.209853, time: 174.13
# Step 174, Crack depth: 0.209856, time: 174.22
# Step 174, Crack depth: 0.209859, time: 174.39
# Step 174, Crack depth: 0.209864, time: 174.54
# Step 174, Crack depth: 0.209869, time: 174.68
# Step 174, Crack depth: 0.209873, time: 174.81
# Step 174, Crack depth: 0.209877, time: 174.94
# Step 175, Crack depth: 0.209881, time: 175.05
# Step 175, Crack depth: 0.209884, time: 175.15
# Step 175, Crack depth: 0.209888, time: 175.24
# Step 175, Crack depth: 0.209891, time: 175.33
# Step 175, Crack depth: 0.209893, time: 175.42
# Step 175, Crack depth: 0.209896, time: 175.49
# Step 175, Crack depth: 0.209898, time: 175.56
# Step 175, Crack depth: 0.239174, time: 175.63
# Step 176, Crack depth: 0.239175, time: 176.13
# Step 176, Crack depth: 0.239188, time: 176.62
# Step 177, Crack depth: 0.2392, time: 177.06
# Step 177, Crack depth: 0.239211, time: 177.46
# Step 177, Crack depth: 0.239221, time: 177.82
# Step 177, Crack depth: 0.239231, time: 177.98
# Step 178, Crack depth: 0.239235, time: 178.13
# Step 178, Crack depth: 0.239238, time: 178.25
# Step 178, Crack depth: 0.239242, time: 178.36
# Step 178, Crack depth: 0.239245, time: 178.47
# Step 178, Crack depth: 0.239247, time: 178.56
# Step 178, Crack depth: 0.23925, time: 178.65
# Step 178, Crack depth: 0.239252, time: 178.73
# Step 178, Crack depth: 0.239254, time: 178.80
# Step 178, Crack depth: 0.239256, time: 178.87
# Step 178, Crack depth: 0.239258, time: 178.94
# Step 178, Crack depth: 0.23926, time: 179.00
# Step 179, Crack depth: 0.239261, time: 179.05
# Step 179, Crack depth: 0.239263, time: 179.10
# Step 179, Crack depth: 0.239264, time: 179.15
# Step 179, Crack depth: 0.239266, time: 179.19
# Step 179, Crack depth: 0.239267, time: 179.23
# Step 179, Crack depth: 0.239268, time: 179.27
# Step 179, Crack depth: 0.239269, time: 179.30
# Step 179, Crack depth: 0.23927, time: 179.34
# Step 179, Crack depth: 0.239271, time: 179.42
# Step 179, Crack depth: 0.239274, time: 179.50
# Step 179, Crack depth: 0.239277, time: 179.58
# Step 179, Crack depth: 0.265484, time: 179.65
# Step 180, Crack depth: 0.265485, time: 180.02
# Step 180, Crack depth: 0.265494, time: 180.35
# Step 180, Crack depth: 0.265501, time: 180.66
# Step 180, Crack depth: 0.265508, time: 180.93
# Step 181, Crack depth: 0.265515, time: 181.18
# Step 181, Crack depth: 0.265521, time: 181.40
# Step 181, Crack depth: 0.265526, time: 181.60
# Step 181, Crack depth: 0.26553, time: 181.78
# Step 181, Crack depth: 0.265535, time: 181.95
# Step 182, Crack depth: 0.265539, time: 182.05
# Step 182, Crack depth: 0.265541, time: 182.14
# Step 182, Crack depth: 0.265543, time: 182.23
# Step 182, Crack depth: 0.265546, time: 182.31
# Step 182, Crack depth: 0.265548, time: 182.38
# Step 182, Crack depth: 0.265549, time: 182.45
# Step 182, Crack depth: 0.265551, time: 182.51
# Step 182, Crack depth: 0.265553, time: 182.57
# Step 182, Crack depth: 0.265554, time: 182.62
# Step 182, Crack depth: 0.265555, time: 182.67
# Step 182, Crack depth: 0.265557, time: 182.71
# Step 182, Crack depth: 0.265558, time: 182.75
# Step 182, Crack depth: 0.265559, time: 182.79
# Step 182, Crack depth: 0.26556, time: 182.83
# Step 182, Crack depth: 0.265561, time: 182.86
# Step 182, Crack depth: 0.265562, time: 182.89
# Step 182, Crack depth: 0.265563, time: 182.97
# Step 183, Crack depth: 0.265565, time: 183.05
# Step 183, Crack depth: 0.265568, time: 183.12
# Step 183, Crack depth: 0.26557, time: 183.18
# Step 183, Crack depth: 0.265572, time: 183.25
# Step 183, Crack depth: 0.265574, time: 183.31
# Step 183, Crack depth: 0.290053, time: 183.36
# Step 183, Crack depth: 0.290054, time: 183.76
# Step 184, Crack depth: 0.290062, time: 184.12
# Step 184, Crack depth: 0.29007, time: 184.45
# Step 184, Crack depth: 0.290077, time: 184.75
# Step 185, Crack depth: 0.290083, time: 185.02
# Step 185, Crack depth: 0.290089, time: 185.26
# Step 185, Crack depth: 0.290094, time: 185.49
# Step 185, Crack depth: 0.290099, time: 185.69
# Step 185, Crack depth: 0.290104, time: 185.87
# Step 186, Crack depth: 0.290108, time: 186.04
# Step 186, Crack depth: 0.290112, time: 186.19
# Step 186, Crack depth: 0.290115, time: 186.33
# Step 186, Crack depth: 0.290118, time: 186.46
# Step 186, Crack depth: 0.290121, time: 186.58
# Step 186, Crack depth: 0.290124, time: 186.68
# Step 186, Crack depth: 0.290126, time: 186.76
# Step 186, Crack depth: 0.290128, time: 186.83
# Step 186, Crack depth: 0.29013, time: 186.89
# Step 186, Crack depth: 0.290131, time: 186.95
# Step 187, Crack depth: 0.290133, time: 187.01
# Step 187, Crack depth: 0.290134, time: 187.06
# Step 187, Crack depth: 0.290135, time: 187.10
# Step 187, Crack depth: 0.290137, time: 187.15
# Step 187, Crack depth: 0.290138, time: 187.19
# Step 187, Crack depth: 0.290139, time: 187.22
# Step 187, Crack depth: 0.29014, time: 187.31
# Step 187, Crack depth: 0.290142, time: 187.39
# Step 187, Crack depth: 0.290145, time: 187.47
# Step 187, Crack depth: 0.290147, time: 187.54
# Step 187, Crack depth: 0.290149, time: 187.61
# Step 187, Crack depth: 0.290151, time: 187.67
# Step 187, Crack depth: 0.290153, time: 187.74
# Step 187, Crack depth: 0.290155, time: 187.79
# Step 187, Crack depth: 0.290157, time: 187.85
# Step 187, Crack depth: 0.290159, time: 187.90
# Step 187, Crack depth: 0.314257, time: 187.95
# Step 188, Crack depth: 0.314257, time: 188.34
# Step 188, Crack depth: 0.314265, time: 188.70
# Step 189, Crack depth: 0.314272, time: 189.02
# Step 189, Crack depth: 0.314279, time: 189.31
# Step 189, Crack depth: 0.314285, time: 189.58
# Step 189, Crack depth: 0.31429, time: 189.82
# Step 190, Crack depth: 0.314295, time: 190.04
# Step 190, Crack depth: 0.3143, time: 190.24
# Step 190, Crack depth: 0.314304, time: 190.42
# Step 190, Crack depth: 0.314308, time: 190.58
# Step 190, Crack depth: 0.314311, time: 190.73
# Step 190, Crack depth: 0.314315, time: 190.87
# Step 190, Crack depth: 0.314318, time: 191.00
# Step 191, Crack depth: 0.31432, time: 191.11
# Step 191, Crack depth: 0.314323, time: 191.22
# Step 191, Crack depth: 0.314325, time: 191.31
# Step 191, Crack depth: 0.314327, time: 191.40
# Step 191, Crack depth: 0.314329, time: 191.48
# Step 191, Crack depth: 0.314331, time: 191.56
# Step 191, Crack depth: 0.314333, time: 191.62
# Step 191, Crack depth: 0.314334, time: 191.69
# Step 191, Crack depth: 0.314335, time: 191.74
# Step 191, Crack depth: 0.314337, time: 191.79
# Step 191, Crack depth: 0.314338, time: 191.89
# Step 191, Crack depth: 0.314341, time: 191.98
# Step 192, Crack depth: 0.314343, time: 192.07
# Step 192, Crack depth: 0.314346, time: 192.15
# Step 192, Crack depth: 0.314348, time: 192.23
# Step 192, Crack depth: 0.31435, time: 192.31
# Step 192, Crack depth: 0.314353, time: 192.38
# Step 192, Crack depth: 0.314355, time: 192.44
# Step 192, Crack depth: 0.314357, time: 192.50
# Step 192, Crack depth: 0.314358, time: 192.56
# Step 192, Crack depth: 0.31436, time: 192.62
# Step 192, Crack depth: 0.314362, time: 192.67
# Step 192, Crack depth: 0.314363, time: 192.72
# Step 192, Crack depth: 0.338241, time: 192.77
# Step 193, Crack depth: 0.338242, time: 193.15
# Step 193, Crack depth: 0.338249, time: 193.50
# Step 193, Crack depth: 0.338256, time: 193.82
# Step 194, Crack depth: 0.338262, time: 194.10
# Step 194, Crack depth: 0.338267, time: 194.36
# Step 194, Crack depth: 0.338272, time: 194.60
# Step 194, Crack depth: 0.338277, time: 194.82
# Step 195, Crack depth: 0.338281, time: 195.01
# Step 195, Crack depth: 0.338285, time: 195.19
# Step 195, Crack depth: 0.338288, time: 195.35
# Step 195, Crack depth: 0.338291, time: 195.50
# Step 195, Crack depth: 0.338294, time: 195.64
# Step 195, Crack depth: 0.338297, time: 195.76
# Step 195, Crack depth: 0.3383, time: 195.87
# Step 195, Crack depth: 0.338302, time: 195.98
# Step 196, Crack depth: 0.338304, time: 196.07
# Step 196, Crack depth: 0.338306, time: 196.16
# Step 196, Crack depth: 0.338308, time: 196.24
# Step 196, Crack depth: 0.338309, time: 196.31
# Step 196, Crack depth: 0.338311, time: 196.37
# Step 196, Crack depth: 0.338312, time: 196.43
# Step 196, Crack depth: 0.338314, time: 196.49
# Step 196, Crack depth: 0.338315, time: 196.54
# Step 196, Crack depth: 0.338316, time: 196.59
# Step 196, Crack depth: 0.338317, time: 196.63
# Step 196, Crack depth: 0.338318, time: 196.67
# Step 196, Crack depth: 0.338319, time: 196.70
# Step 196, Crack depth: 0.338319, time: 196.73
# Step 196, Crack depth: 0.33832, time: 196.76
# Step 196, Crack depth: 0.338321, time: 196.84
# Step 196, Crack depth: 0.338323, time: 196.91
# Step 196, Crack depth: 0.338325, time: 196.97
# Step 197, Crack depth: 0.338327, time: 197.03
# Step 197, Crack depth: 0.338328, time: 197.09
# Step 197, Crack depth: 0.33833, time: 197.15
# Step 197, Crack depth: 0.338332, time: 197.20
# Step 197, Crack depth: 0.338333, time: 197.25
# Step 197, Crack depth: 0.362139, time: 197.29
# Step 197, Crack depth: 0.362139, time: 197.71
# Step 198, Crack depth: 0.362146, time: 198.08
# Step 198, Crack depth: 0.362153, time: 198.42
# Step 198, Crack depth: 0.362159, time: 198.73
# Step 199, Crack depth: 0.362164, time: 199.01
# Step 199, Crack depth: 0.362169, time: 199.26
# Step 199, Crack depth: 0.362174, time: 199.49
# Step 199, Crack depth: 0.362178, time: 199.70
# Step 199, Crack depth: 0.362182, time: 199.90
# Step 200, Crack depth: 0.362185, time: 200.07
# Step 200, Crack depth: 0.362189, time: 200.23
# Step 200, Crack depth: 0.362192, time: 200.38
# Step 200, Crack depth: 0.362194, time: 200.51
# Step 200, Crack depth: 0.362197, time: 200.63
# Step 200, Crack depth: 0.362199, time: 200.74
# Step 200, Crack depth: 0.362201, time: 200.84
# Step 200, Crack depth: 0.362203, time: 200.94
# Step 201, Crack depth: 0.362205, time: 201.02
# Step 201, Crack depth: 0.362207, time: 201.10
# Step 201, Crack depth: 0.362208, time: 201.17
# Step 201, Crack depth: 0.362209, time: 201.23
# Step 201, Crack depth: 0.362211, time: 201.29
# Step 201, Crack depth: 0.362212, time: 201.35
# Step 201, Crack depth: 0.362213, time: 201.40
# Step 201, Crack depth: 0.362214, time: 201.44
# Step 201, Crack depth: 0.362215, time: 201.49
# Step 201, Crack depth: 0.362216, time: 201.52
# Step 201, Crack depth: 0.362216, time: 201.56
# Step 201, Crack depth: 0.362217, time: 201.59
# Step 201, Crack depth: 0.362218, time: 201.62
# Step 201, Crack depth: 0.362219, time: 201.65
# Step 201, Crack depth: 0.362219, time: 201.68
# Step 201, Crack depth: 0.36222, time: 201.70
# Step 201, Crack depth: 0.36222, time: 201.76
# Step 201, Crack depth: 0.362222, time: 201.82
# Step 201, Crack depth: 0.362224, time: 201.88
# Step 201, Crack depth: 0.362225, time: 201.93
# Step 201, Crack depth: 0.362227, time: 201.98
# Step 202, Crack depth: 0.386006, time: 202.03
# Step 202, Crack depth: 0.386006, time: 202.48
# Step 202, Crack depth: 0.386013, time: 202.88
# Step 203, Crack depth: 0.38602, time: 203.25
# Step 203, Crack depth: 0.386025, time: 203.58
# Step 203, Crack depth: 0.386031, time: 203.88
# Step 204, Crack depth: 0.386036, time: 204.16
# Step 204, Crack depth: 0.38604, time: 204.41
# Step 204, Crack depth: 0.386045, time: 204.63
# Step 204, Crack depth: 0.386048, time: 204.84
# Step 205, Crack depth: 0.386052, time: 205.03
# Step 205, Crack depth: 0.386055, time: 205.21
# Step 205, Crack depth: 0.386058, time: 205.36
# Step 205, Crack depth: 0.386061, time: 205.51
# Step 205, Crack depth: 0.386063, time: 205.64
# Step 205, Crack depth: 0.386065, time: 205.76
# Step 205, Crack depth: 0.386068, time: 205.87
# Step 205, Crack depth: 0.386069, time: 205.97
# Step 206, Crack depth: 0.386071, time: 206.06
# Step 206, Crack depth: 0.386073, time: 206.15
# Step 206, Crack depth: 0.386074, time: 206.23
# Step 206, Crack depth: 0.386076, time: 206.30
# Step 206, Crack depth: 0.386077, time: 206.36
# Step 206, Crack depth: 0.386078, time: 206.42
# Step 206, Crack depth: 0.386079, time: 206.48
# Step 206, Crack depth: 0.38608, time: 206.53
# Step 206, Crack depth: 0.386081, time: 206.57
# Step 206, Crack depth: 0.386082, time: 206.61
# Step 206, Crack depth: 0.386083, time: 206.65
# Step 206, Crack depth: 0.386084, time: 206.69
# Step 206, Crack depth: 0.386084, time: 206.72
# Step 206, Crack depth: 0.386085, time: 206.75
# Step 206, Crack depth: 0.386086, time: 206.78
# Step 206, Crack depth: 0.386086, time: 206.80
# Step 206, Crack depth: 0.386087, time: 206.83
# Step 206, Crack depth: 0.386087, time: 206.85
# Step 206, Crack depth: 0.386088, time: 206.87
# Step 206, Crack depth: 0.386088, time: 206.89
# Step 206, Crack depth: 0.386088, time: 206.91
# Step 206, Crack depth: 0.386089, time: 206.97
# Step 207, Crack depth: 0.38609, time: 207.02
# Step 207, Crack depth: 0.409853, time: 207.07
# Step 207, Crack depth: 0.409854, time: 207.56
# Step 208, Crack depth: 0.409861, time: 208.00
# Step 208, Crack depth: 0.409868, time: 208.41
# Step 208, Crack depth: 0.409874, time: 208.77
# Step 209, Crack depth: 0.409879, time: 209.11
# Step 209, Crack depth: 0.409884, time: 209.41
# Step 209, Crack depth: 0.409889, time: 209.69
# Step 209, Crack depth: 0.409893, time: 209.94
# Step 210, Crack depth: 0.409897, time: 210.17
# Step 210, Crack depth: 0.4099, time: 210.38
# Step 210, Crack depth: 0.409904, time: 210.57
# Step 210, Crack depth: 0.409907, time: 210.75
# Step 210, Crack depth: 0.40991, time: 210.91
# Step 211, Crack depth: 0.409912, time: 211.05
# Step 211, Crack depth: 0.409914, time: 211.19
# Step 211, Crack depth: 0.409917, time: 211.31
# Step 211, Crack depth: 0.409919, time: 211.42
# Step 211, Crack depth: 0.40992, time: 211.52
# Step 211, Crack depth: 0.409922, time: 211.62
# Step 211, Crack depth: 0.409924, time: 211.70
# Step 211, Crack depth: 0.409925, time: 211.78
# Step 211, Crack depth: 0.409926, time: 211.86
# Step 211, Crack depth: 0.409928, time: 211.92
# Step 211, Crack depth: 0.409929, time: 211.98
# Step 212, Crack depth: 0.40993, time: 212.04
# Step 212, Crack depth: 0.409931, time: 212.09
# Step 212, Crack depth: 0.409932, time: 212.14
# Step 212, Crack depth: 0.409932, time: 212.18
# Step 212, Crack depth: 0.409933, time: 212.22
# Step 212, Crack depth: 0.409934, time: 212.26
# Step 212, Crack depth: 0.409935, time: 212.29
# Step 212, Crack depth: 0.409935, time: 212.32
# Step 212, Crack depth: 0.409936, time: 212.35
# Step 212, Crack depth: 0.409936, time: 212.38
# Step 212, Crack depth: 0.409937, time: 212.40
# Step 212, Crack depth: 0.409937, time: 212.42
# Step 212, Crack depth: 0.409938, time: 212.45
# Step 212, Crack depth: 0.409938, time: 212.47
# Step 212, Crack depth: 0.409939, time: 212.52
# Step 212, Crack depth: 0.40994, time: 212.57
# Step 212, Crack depth: 0.433922, time: 212.62
# Step 213, Crack depth: 0.433922, time: 213.12
# Step 213, Crack depth: 0.433929, time: 213.62
# Step 214, Crack depth: 0.433935, time: 214.09
# Step 214, Crack depth: 0.433942, time: 214.52
# Step 214, Crack depth: 0.433947, time: 214.91
# Step 215, Crack depth: 0.433953, time: 215.26
# Step 215, Crack depth: 0.433958, time: 215.58
# Step 215, Crack depth: 0.433962, time: 215.88
# Step 216, Crack depth: 0.433966, time: 216.15
# Step 216, Crack depth: 0.43397, time: 216.39
# Step 216, Crack depth: 0.433973, time: 216.62
# Step 216, Crack depth: 0.433976, time: 216.83
# Step 217, Crack depth: 0.433979, time: 217.01
# Step 217, Crack depth: 0.433982, time: 217.19
# Step 217, Crack depth: 0.433985, time: 217.35
# Step 217, Crack depth: 0.433987, time: 217.49
# Step 217, Crack depth: 0.433989, time: 217.63
# Step 217, Crack depth: 0.433991, time: 217.75
# Step 217, Crack depth: 0.433993, time: 217.86
# Step 217, Crack depth: 0.433995, time: 217.96
# Step 218, Crack depth: 0.433996, time: 218.06
# Step 218, Crack depth: 0.433998, time: 218.15
# Step 218, Crack depth: 0.433999, time: 218.23
# Step 218, Crack depth: 0.434, time: 218.30
# Step 218, Crack depth: 0.434001, time: 218.37
# Step 218, Crack depth: 0.434002, time: 218.43
# Step 218, Crack depth: 0.434003, time: 218.49
# Step 218, Crack depth: 0.434004, time: 218.54
# Step 218, Crack depth: 0.434005, time: 218.59
# Step 218, Crack depth: 0.434006, time: 218.63
# Step 218, Crack depth: 0.434006, time: 218.67
# Step 218, Crack depth: 0.434007, time: 218.71
# Step 218, Crack depth: 0.434008, time: 218.74
# Step 218, Crack depth: 0.434008, time: 218.78
# Step 218, Crack depth: 0.434009, time: 218.85
# Step 218, Crack depth: 0.434011, time: 218.93
# Step 218, Crack depth: 0.434012, time: 219.00
# Step 219, Crack depth: 0.434014, time: 219.06
# Step 219, Crack depth: 0.434016, time: 219.13
# Step 219, Crack depth: 0.457896, time: 219.19
# Step 219, Crack depth: 0.457896, time: 219.69
# Step 220, Crack depth: 0.457902, time: 220.19
# Step 220, Crack depth: 0.457908, time: 220.69
# Step 221, Crack depth: 0.457913, time: 221.18
# Step 221, Crack depth: 0.457919, time: 221.64
# Step 222, Crack depth: 0.457925, time: 222.05
# Step 222, Crack depth: 0.45793, time: 222.43
# Step 222, Crack depth: 0.457935, time: 222.77
# Step 223, Crack depth: 0.457939, time: 223.09
# Step 223, Crack depth: 0.457943, time: 223.38
# Step 223, Crack depth: 0.457946, time: 223.65
# Step 223, Crack depth: 0.45795, time: 223.89
# Step 224, Crack depth: 0.457953, time: 224.11
# Step 224, Crack depth: 0.457956, time: 224.32
# Step 224, Crack depth: 0.457958, time: 224.51
# Step 224, Crack depth: 0.457961, time: 224.68
# Step 224, Crack depth: 0.457963, time: 224.84
# Step 224, Crack depth: 0.457965, time: 224.99
# Step 225, Crack depth: 0.457967, time: 225.12
# Step 225, Crack depth: 0.457969, time: 225.24
# Step 225, Crack depth: 0.457971, time: 225.36
# Step 225, Crack depth: 0.457972, time: 225.46
# Step 225, Crack depth: 0.457974, time: 225.56
# Step 225, Crack depth: 0.457975, time: 225.65
# Step 225, Crack depth: 0.457976, time: 225.73
# Step 225, Crack depth: 0.457977, time: 225.81
# Step 225, Crack depth: 0.457978, time: 225.88
# Step 225, Crack depth: 0.457979, time: 225.94
# Step 225, Crack depth: 0.45798, time: 226.00
# Step 226, Crack depth: 0.457981, time: 226.05
# Step 226, Crack depth: 0.457982, time: 226.10
# Step 226, Crack depth: 0.457983, time: 226.15
# Step 226, Crack depth: 0.457983, time: 226.19
# Step 226, Crack depth: 0.457984, time: 226.23
# Step 226, Crack depth: 0.457985, time: 226.27
# Step 226, Crack depth: 0.457985, time: 226.31
# Step 226, Crack depth: 0.457986, time: 226.34
# Step 226, Crack depth: 0.457986, time: 226.37
# Step 226, Crack depth: 0.457987, time: 226.40
# Step 226, Crack depth: 0.457987, time: 226.43
# Step 226, Crack depth: 0.481693, time: 226.50
# Step 227, Crack depth: 0.481693, time: 227.00
# Step 227, Crack depth: 0.481698, time: 227.50
# Step 228, Crack depth: 0.481703, time: 228.00
# Step 228, Crack depth: 0.481709, time: 228.50
# Step 229, Crack depth: 0.481714, time: 229.00
# Step 229, Crack depth: 0.481719, time: 229.49
# Step 229, Crack depth: 0.481725, time: 229.94
# Step 230, Crack depth: 0.48173, time: 230.35
# Step 230, Crack depth: 0.481734, time: 230.73
# Step 231, Crack depth: 0.481738, time: 231.07
# Step 231, Crack depth: 0.481742, time: 231.39
# Step 231, Crack depth: 0.481746, time: 231.69
# Step 231, Crack depth: 0.481749, time: 231.96
# Step 232, Crack depth: 0.481752, time: 232.20
# Step 232, Crack depth: 0.481755, time: 232.43
# Step 232, Crack depth: 0.481757, time: 232.64
# Step 232, Crack depth: 0.48176, time: 232.84
# Step 233, Crack depth: 0.481762, time: 233.02
# Step 233, Crack depth: 0.481764, time: 233.18
# Step 233, Crack depth: 0.481766, time: 233.33
# Step 233, Crack depth: 0.481768, time: 233.47
# Step 233, Crack depth: 0.48177, time: 233.60
# Step 233, Crack depth: 0.481771, time: 233.72
# Step 233, Crack depth: 0.481773, time: 233.84
# Step 233, Crack depth: 0.481774, time: 233.94
# Step 234, Crack depth: 0.481776, time: 234.03
# Step 234, Crack depth: 0.481777, time: 234.12
# Step 234, Crack depth: 0.481778, time: 234.20
# Step 234, Crack depth: 0.481779, time: 234.28
# Step 234, Crack depth: 0.48178, time: 234.35
# Step 234, Crack depth: 0.481781, time: 234.41
# Step 234, Crack depth: 0.481781, time: 234.47
# Step 234, Crack depth: 0.481782, time: 234.52
# Step 234, Crack depth: 0.481783, time: 234.57
# Step 234, Crack depth: 0.481784, time: 234.62
# Step 234, Crack depth: 0.481784, time: 234.67
# Step 234, Crack depth: 0.481785, time: 234.71
# Step 234, Crack depth: 0.481786, time: 234.75
# Step 234, Crack depth: 0.481786, time: 234.79
# Step 234, Crack depth: 0.481787, time: 234.82
# Step 234, Crack depth: 0.481787, time: 234.85
# Step 234, Crack depth: 0.505363, time: 234.88
# Step 235, Crack depth: 0.505363, time: 235.38
# Step 235, Crack depth: 0.505367, time: 235.88
# Step 236, Crack depth: 0.505372, time: 236.38
# Step 236, Crack depth: 0.505376, time: 236.88
# Step 237, Crack depth: 0.505381, time: 237.38
# Step 237, Crack depth: 0.505386, time: 237.88
# Step 238, Crack depth: 0.50539, time: 238.38
# Step 238, Crack depth: 0.505395, time: 238.88
# Step 239, Crack depth: 0.5054, time: 239.36
# Step 239, Crack depth: 0.505404, time: 239.81
# Step 240, Crack depth: 0.505409, time: 240.21
# Step 240, Crack depth: 0.505413, time: 240.59
# Step 240, Crack depth: 0.505416, time: 240.93
# Step 241, Crack depth: 0.50542, time: 241.25
# Step 241, Crack depth: 0.505423, time: 241.54
# Step 241, Crack depth: 0.505426, time: 241.82
# Step 242, Crack depth: 0.505429, time: 242.07
# Step 242, Crack depth: 0.505431, time: 242.30
# Step 242, Crack depth: 0.505434, time: 242.51
# Step 242, Crack depth: 0.505436, time: 242.71
# Step 242, Crack depth: 0.505438, time: 242.89
# Step 243, Crack depth: 0.50544, time: 243.06
# Step 243, Crack depth: 0.505442, time: 243.22
# Step 243, Crack depth: 0.505443, time: 243.36
# Step 243, Crack depth: 0.505445, time: 243.50
# Step 243, Crack depth: 0.505446, time: 243.62
# Step 243, Crack depth: 0.505448, time: 243.74
# Step 243, Crack depth: 0.505449, time: 243.84
# Step 243, Crack depth: 0.50545, time: 243.94
# Step 244, Crack depth: 0.505451, time: 244.03
# Step 244, Crack depth: 0.505452, time: 244.12
# Step 244, Crack depth: 0.505453, time: 244.20
# Step 244, Crack depth: 0.505454, time: 244.27
# Step 244, Crack depth: 0.505455, time: 244.34
# Step 244, Crack depth: 0.505456, time: 244.40
# Step 244, Crack depth: 0.505457, time: 244.46
# Step 244, Crack depth: 0.505457, time: 244.51
# Step 244, Crack depth: 0.505458, time: 244.56
# Step 244, Crack depth: 0.505459, time: 244.61
# Step 244, Crack depth: 0.50546, time: 244.66
# Step 244, Crack depth: 0.50546, time: 244.70
# Step 244, Crack depth: 0.52906, time: 244.74
# Step 245, Crack depth: 0.52906, time: 245.24
# Step 245, Crack depth: 0.529064, time: 245.74
# Step 246, Crack depth: 0.529067, time: 246.24
# Step 246, Crack depth: 0.529071, time: 246.74
# Step 247, Crack depth: 0.529075, time: 247.24
# Step 247, Crack depth: 0.529079, time: 247.74
# Step 248, Crack depth: 0.529083, time: 248.24
# Step 248, Crack depth: 0.529087, time: 248.74
# Step 249, Crack depth: 0.529091, time: 249.24
# Step 249, Crack depth: 0.529095, time: 249.74
# Step 250, Crack depth: 0.529099, time: 250.24
# Step 250, Crack depth: 0.529103, time: 250.74
# Step 251, Crack depth: 0.529108, time: 251.24
# Step 251, Crack depth: 0.529112, time: 251.74
# Step 252, Crack depth: 0.529116, time: 252.21
# Step 252, Crack depth: 0.52912, time: 252.65
# Step 253, Crack depth: 0.529124, time: 253.05
# Step 253, Crack depth: 0.529127, time: 253.42
# Step 253, Crack depth: 0.52913, time: 253.77
# Step 254, Crack depth: 0.529133, time: 254.09
# Step 254, Crack depth: 0.529136, time: 254.38
# Step 254, Crack depth: 0.529139, time: 254.66
# Step 254, Crack depth: 0.529141, time: 254.91
# Step 255, Crack depth: 0.529144, time: 255.15
# Step 255, Crack depth: 0.529146, time: 255.37
# Step 255, Crack depth: 0.529148, time: 255.57
# Step 255, Crack depth: 0.52915, time: 255.76
# Step 255, Crack depth: 0.529151, time: 255.93
# Step 256, Crack depth: 0.529153, time: 256.10
# Step 256, Crack depth: 0.529155, time: 256.25
# Step 256, Crack depth: 0.529156, time: 256.39
# Step 256, Crack depth: 0.529157, time: 256.52
# Step 256, Crack depth: 0.529159, time: 256.64
# Step 256, Crack depth: 0.52916, time: 256.75
# Step 256, Crack depth: 0.529161, time: 256.86
# Step 256, Crack depth: 0.529162, time: 256.94
# Step 257, Crack depth: 0.529163, time: 257.02
# Step 257, Crack depth: 0.529164, time: 257.10
# Step 257, Crack depth: 0.529165, time: 257.17
# Step 257, Crack depth: 0.529166, time: 257.24
# Step 257, Crack depth: 0.529166, time: 257.30
# Step 257, Crack depth: 0.529167, time: 257.36
# Step 257, Crack depth: 0.529168, time: 257.42
# Step 257, Crack depth: 0.529169, time: 257.56
# Step 257, Crack depth: 0.553009, time: 257.69
# Step 258, Crack depth: 0.553009, time: 258.19
# Step 258, Crack depth: 0.553012, time: 258.69
# Step 259, Crack depth: 0.553015, time: 259.19
# Step 259, Crack depth: 0.553018, time: 259.69
# Step 260, Crack depth: 0.553022, time: 260.19
# Step 260, Crack depth: 0.553025, time: 260.69
# Step 261, Crack depth: 0.553028, time: 261.19
# Step 261, Crack depth: 0.553031, time: 261.69
# Step 262, Crack depth: 0.553035, time: 262.19
# Step 262, Crack depth: 0.553038, time: 262.69
# Step 263, Crack depth: 0.553041, time: 263.19
# Step 263, Crack depth: 0.553045, time: 263.69
# Step 264, Crack depth: 0.553048, time: 264.19
# Step 264, Crack depth: 0.553052, time: 264.69
# Step 265, Crack depth: 0.553055, time: 265.19
# Step 265, Crack depth: 0.553058, time: 265.69
# Step 266, Crack depth: 0.553062, time: 266.19
# Step 266, Crack depth: 0.553065, time: 266.69
# Step 267, Crack depth: 0.553069, time: 267.19
# Step 267, Crack depth: 0.553072, time: 267.69
# Step 268, Crack depth: 0.553076, time: 268.19
# Step 268, Crack depth: 0.55308, time: 268.68
# Step 269, Crack depth: 0.553083, time: 269.14
# Step 269, Crack depth: 0.553086, time: 269.57
# Step 269, Crack depth: 0.55309, time: 269.97
# Step 270, Crack depth: 0.553093, time: 270.34
# Step 270, Crack depth: 0.553095, time: 270.69
# Step 271, Crack depth: 0.553098, time: 271.01
# Step 271, Crack depth: 0.553101, time: 271.31
# Step 271, Crack depth: 0.553103, time: 271.59
# Step 271, Crack depth: 0.553105, time: 271.85
# Step 272, Crack depth: 0.553107, time: 272.09
# Step 272, Crack depth: 0.553109, time: 272.32
# Step 272, Crack depth: 0.553111, time: 272.53
# Step 272, Crack depth: 0.553112, time: 272.73
# Step 272, Crack depth: 0.553114, time: 272.91
# Step 273, Crack depth: 0.553116, time: 273.08
# Step 273, Crack depth: 0.553117, time: 273.21
# Step 273, Crack depth: 0.553118, time: 273.33
# Step 273, Crack depth: 0.553119, time: 273.44
# Step 273, Crack depth: 0.553121, time: 273.55
# Step 273, Crack depth: 0.553122, time: 273.65
# Step 273, Crack depth: 0.553123, time: 273.75
# Step 273, Crack depth: 0.553124, time: 273.84
# Step 273, Crack depth: 0.553125, time: 273.93
# Step 274, Crack depth: 0.553126, time: 274.12
# Step 274, Crack depth: 0.553128, time: 274.31
# Step 274, Crack depth: 0.576977, time: 274.49
# Step 274, Crack depth: 0.576977, time: 274.99
# Step 275, Crack depth: 0.57698, time: 275.49
# Step 275, Crack depth: 0.576982, time: 275.99
# Step 276, Crack depth: 0.576984, time: 276.49
# Step 276, Crack depth: 0.576987, time: 276.99
# Step 277, Crack depth: 0.576989, time: 277.49
# Step 277, Crack depth: 0.576992, time: 277.99
# Step 278, Crack depth: 0.576994, time: 278.49
# Step 278, Crack depth: 0.576997, time: 278.99
# Step 279, Crack depth: 0.577, time: 279.49
# Step 279, Crack depth: 0.577002, time: 279.99
# Step 280, Crack depth: 0.577005, time: 280.49
# Step 280, Crack depth: 0.577007, time: 280.99
# Step 281, Crack depth: 0.57701, time: 281.49
# Step 281, Crack depth: 0.577013, time: 281.99
# Step 282, Crack depth: 0.577015, time: 282.49
# Step 282, Crack depth: 0.577018, time: 282.99
# Step 283, Crack depth: 0.57702, time: 283.49
# Step 283, Crack depth: 0.577023, time: 283.99
# Step 284, Crack depth: 0.577026, time: 284.49
# Step 284, Crack depth: 0.577029, time: 284.99
# Step 285, Crack depth: 0.577031, time: 285.49
# Step 285, Crack depth: 0.577034, time: 285.99
# Step 286, Crack depth: 0.577037, time: 286.49
# Step 286, Crack depth: 0.57704, time: 286.99
# Step 287, Crack depth: 0.577042, time: 287.49
# Step 287, Crack depth: 0.577045, time: 287.99
# Step 288, Crack depth: 0.577048, time: 288.49
# Step 288, Crack depth: 0.577051, time: 288.99
# Step 289, Crack depth: 0.577054, time: 289.46
# Step 289, Crack depth: 0.577057, time: 289.91
# Step 290, Crack depth: 0.577059, time: 290.32
# Step 290, Crack depth: 0.577062, time: 290.71
# Step 291, Crack depth: 0.577064, time: 291.07
# Step 291, Crack depth: 0.577066, time: 291.40
# Step 291, Crack depth: 0.577068, time: 291.72
# Step 292, Crack depth: 0.57707, time: 292.01
# Step 292, Crack depth: 0.577072, time: 292.29
# Step 292, Crack depth: 0.577074, time: 292.55
# Step 292, Crack depth: 0.577076, time: 292.79
# Step 292, Crack depth: 0.577077, time: 292.97
# Step 293, Crack depth: 0.577079, time: 293.14
# Step 293, Crack depth: 0.57708, time: 293.30
# Step 293, Crack depth: 0.577081, time: 293.45
# Step 293, Crack depth: 0.577083, time: 293.60
# Step 293, Crack depth: 0.577084, time: 293.73
# Step 293, Crack depth: 0.577085, time: 293.87
# Step 294, Crack depth: 0.577086, time: 294.14
# Step 294, Crack depth: 0.577089, time: 294.40
# Step 294, Crack depth: 0.577092, time: 294.66
# Step 294, Crack depth: 0.600533, time: 294.90
# Step 295, Crack depth: 0.600533, time: 295.40
# Step 295, Crack depth: 0.600534, time: 295.90
# Step 296, Crack depth: 0.600536, time: 296.40
# Step 296, Crack depth: 0.600538, time: 296.90
# Step 297, Crack depth: 0.60054, time: 297.40
# Step 297, Crack depth: 0.600542, time: 297.90
# Step 298, Crack depth: 0.600544, time: 298.40
# Step 298, Crack depth: 0.600546, time: 298.90
# Step 299, Crack depth: 0.600548, time: 299.40
# Step 299, Crack depth: 0.60055, time: 299.90
# Step 300, Crack depth: 0.600552, time: 300.40
# Step 300, Crack depth: 0.600554, time: 300.90
# Step 301, Crack depth: 0.600556, time: 301.40
# Step 301, Crack depth: 0.600557, time: 301.90
# Step 302, Crack depth: 0.600559, time: 302.40
# Step 302, Crack depth: 0.600561, time: 302.90
# Step 303, Crack depth: 0.600563, time: 303.40
# Step 303, Crack depth: 0.600565, time: 303.90
# Step 304, Crack depth: 0.600567, time: 304.40
# Step 304, Crack depth: 0.600569, time: 304.90
# Step 305, Crack depth: 0.600571, time: 305.40
# Step 305, Crack depth: 0.600573, time: 305.90
# Step 306, Crack depth: 0.600575, time: 306.40
# Step 306, Crack depth: 0.600578, time: 306.90
# Step 307, Crack depth: 0.60058, time: 307.40
# Step 307, Crack depth: 0.600582, time: 307.90
# Step 308, Crack depth: 0.600584, time: 308.40
# Step 308, Crack depth: 0.600586, time: 308.90
# Step 309, Crack depth: 0.600588, time: 309.40
# Step 309, Crack depth: 0.60059, time: 309.90
# Step 310, Crack depth: 0.600592, time: 310.40
# Step 310, Crack depth: 0.600594, time: 310.90
# Step 311, Crack depth: 0.600596, time: 311.40
# Step 311, Crack depth: 0.600599, time: 311.90
# Step 312, Crack depth: 0.600601, time: 312.40
# Step 312, Crack depth: 0.600603, time: 312.90
# Step 313, Crack depth: 0.600605, time: 313.40
# Step 313, Crack depth: 0.600607, time: 313.90
# Step 314, Crack depth: 0.60061, time: 314.40
# Step 314, Crack depth: 0.600612, time: 314.90
# Step 315, Crack depth: 0.600614, time: 315.40
# Step 315, Crack depth: 0.600616, time: 315.90
# Step 316, Crack depth: 0.600619, time: 316.40
# Step 316, Crack depth: 0.600621, time: 316.90
# Step 317, Crack depth: 0.600623, time: 317.40
# Step 317, Crack depth: 0.600626, time: 317.90
# Step 318, Crack depth: 0.600628, time: 318.40
# Step 318, Crack depth: 0.600631, time: 318.90
# Step 319, Crack depth: 0.600633, time: 319.40
# Step 319, Crack depth: 0.600636, time: 319.87
# Step 320, Crack depth: 0.600638, time: 320.18
# Step 320, Crack depth: 0.60064, time: 320.47
# Step 320, Crack depth: 0.600642, time: 320.75
# Step 321, Crack depth: 0.600643, time: 321.01
# Step 321, Crack depth: 0.600645, time: 321.26
# Step 321, Crack depth: 0.600647, time: 321.50
# Step 321, Crack depth: 0.600648, time: 321.72
# Step 321, Crack depth: 0.60065, time: 321.94
# Step 322, Crack depth: 0.600651, time: 322.14
# Step 322, Crack depth: 0.600652, time: 322.33
# Step 322, Crack depth: 0.600654, time: 322.52
# Step 322, Crack depth: 0.600655, time: 322.69
# Step 323, Crack depth: 0.600656, time: 323.05
# Step 323, Crack depth: 0.60066, time: 323.40
# Step 323, Crack depth: 0.625328, time: 323.74
# Step 324, Crack depth: 0.625328, time: 324.24
# Step 324, Crack depth: 0.625329, time: 324.74
# Step 325, Crack depth: 0.62533, time: 325.24
# Step 325, Crack depth: 0.625331, time: 325.74
# Step 326, Crack depth: 0.625332, time: 326.24
# Step 326, Crack depth: 0.625333, time: 326.74
# Step 327, Crack depth: 0.625335, time: 327.24
# Step 327, Crack depth: 0.625336, time: 327.74
# Step 328, Crack depth: 0.625337, time: 328.24
# Step 328, Crack depth: 0.625338, time: 328.74
# Step 329, Crack depth: 0.625339, time: 329.24
# Step 329, Crack depth: 0.625341, time: 329.74
# Step 330, Crack depth: 0.625342, time: 330.24
# Step 330, Crack depth: 0.625343, time: 330.74
# Step 331, Crack depth: 0.625344, time: 331.24
# Step 331, Crack depth: 0.625345, time: 331.74
# Step 332, Crack depth: 0.625347, time: 332.24
# Step 332, Crack depth: 0.625348, time: 332.74
# Step 333, Crack depth: 0.625349, time: 333.24
# Step 333, Crack depth: 0.62535, time: 333.74
# Step 334, Crack depth: 0.625352, time: 334.24
# Step 334, Crack depth: 0.625353, time: 334.74
# Step 335, Crack depth: 0.625354, time: 335.24
# Step 335, Crack depth: 0.625356, time: 335.74
# Step 336, Crack depth: 0.625357, time: 336.24
# Step 336, Crack depth: 0.625358, time: 336.74
# Step 337, Crack depth: 0.625359, time: 337.24
# Step 337, Crack depth: 0.625361, time: 337.74
# Step 338, Crack depth: 0.625362, time: 338.24
# Step 338, Crack depth: 0.625363, time: 338.74
# Step 339, Crack depth: 0.625365, time: 339.24
# Step 339, Crack depth: 0.625366, time: 339.74
# Step 340, Crack depth: 0.625367, time: 340.24
# Step 340, Crack depth: 0.625369, time: 340.74
# Step 341, Crack depth: 0.62537, time: 341.24
# Step 341, Crack depth: 0.625372, time: 341.74
# Step 342, Crack depth: 0.625373, time: 342.24
# Step 342, Crack depth: 0.625374, time: 342.74
# Step 343, Crack depth: 0.625376, time: 343.24
# Step 343, Crack depth: 0.625377, time: 343.74
# Step 344, Crack depth: 0.625379, time: 344.24
# Step 344, Crack depth: 0.62538, time: 344.74
# Step 345, Crack depth: 0.625381, time: 345.24
# Step 345, Crack depth: 0.625383, time: 345.74
# Step 346, Crack depth: 0.625384, time: 346.24
# Step 346, Crack depth: 0.625386, time: 346.74
# Step 347, Crack depth: 0.625387, time: 347.24
# Step 347, Crack depth: 0.625389, time: 347.74
# Step 348, Crack depth: 0.62539, time: 348.24
# Step 348, Crack depth: 0.625392, time: 348.74
# Step 349, Crack depth: 0.625393, time: 349.24
# Step 349, Crack depth: 0.625395, time: 349.74
# Step 350, Crack depth: 0.625396, time: 350.24
# Step 350, Crack depth: 0.625398, time: 350.74
# Step 351, Crack depth: 0.6254, time: 351.24
# Step 351, Crack depth: 0.625401, time: 351.74
# Step 352, Crack depth: 0.625403, time: 352.24
# Step 352, Crack depth: 0.625404, time: 352.74
# Step 353, Crack depth: 0.625406, time: 353.24
# Step 353, Crack depth: 0.625408, time: 353.70
# Step 354, Crack depth: 0.62541, time: 354.14
# Step 354, Crack depth: 0.625412, time: 354.56
# Step 354, Crack depth: 0.625414, time: 354.96
# Step 355, Crack depth: 0.625415, time: 355.34
# Step 355, Crack depth: 0.625417, time: 355.71
# Step 356, Crack depth: 0.625419, time: 356.05
# Step 356, Crack depth: 0.62542, time: 356.39
# Step 356, Crack depth: 0.625422, time: 356.70
# Step 357, Crack depth: 0.625424, time: 357.01
# Step 357, Crack depth: 0.625425, time: 357.30
# Step 357, Crack depth: 0.625427, time: 357.58
# Step 357, Crack depth: 0.625428, time: 357.85
# Step 358, Crack depth: 0.625429, time: 358.11
# Step 358, Crack depth: 0.625431, time: 358.36
# Step 358, Crack depth: 0.648847, time: 358.60
# Step 359, Crack depth: 0.648846, time: 359.10
# Step 359, Crack depth: 0.648847, time: 359.60
# Step 360, Crack depth: 0.648847, time: 360.10
# Step 360, Crack depth: 0.648848, time: 360.60
# Step 361, Crack depth: 0.648849, time: 361.10
# Step 361, Crack depth: 0.648849, time: 361.60
# Step 362, Crack depth: 0.64885, time: 362.10
# Step 362, Crack depth: 0.648851, time: 362.60
# Step 363, Crack depth: 0.648851, time: 363.10
# Step 363, Crack depth: 0.648852, time: 363.60
# Step 364, Crack depth: 0.648853, time: 364.10
# Step 364, Crack depth: 0.648853, time: 364.60
# Step 365, Crack depth: 0.648854, time: 365.10
# Step 365, Crack depth: 0.648855, time: 365.60
# Step 366, Crack depth: 0.648855, time: 366.10
# Step 366, Crack depth: 0.648856, time: 366.60
# Step 367, Crack depth: 0.648857, time: 367.10
# Step 367, Crack depth: 0.648857, time: 367.60
# Step 368, Crack depth: 0.648858, time: 368.10
# Step 368, Crack depth: 0.648859, time: 368.60
# Step 369, Crack depth: 0.64886, time: 369.10
# Step 369, Crack depth: 0.64886, time: 369.60
# Step 370, Crack depth: 0.648861, time: 370.10
# Step 370, Crack depth: 0.648862, time: 370.60
# Step 371, Crack depth: 0.648862, time: 371.10
# Step 371, Crack depth: 0.648863, time: 371.60
# Step 372, Crack depth: 0.648864, time: 372.10
# Step 372, Crack depth: 0.648865, time: 372.60
# Step 373, Crack depth: 0.648865, time: 373.10
# Step 373, Crack depth: 0.648866, time: 373.60
# Step 374, Crack depth: 0.648867, time: 374.10
# Step 374, Crack depth: 0.648868, time: 374.60
# Step 375, Crack depth: 0.648868, time: 375.10
# Step 375, Crack depth: 0.648869, time: 375.60
# Step 376, Crack depth: 0.64887, time: 376.10
# Step 376, Crack depth: 0.648871, time: 376.60
# Step 377, Crack depth: 0.648871, time: 377.10
# Step 377, Crack depth: 0.648872, time: 377.60
# Step 378, Crack depth: 0.648873, time: 378.10
# Step 378, Crack depth: 0.648874, time: 378.60
# Step 379, Crack depth: 0.648875, time: 379.10
# Step 379, Crack depth: 0.648875, time: 379.60
# Step 380, Crack depth: 0.648876, time: 380.10
# Step 380, Crack depth: 0.648877, time: 380.60
# Step 381, Crack depth: 0.648878, time: 381.10
# Step 381, Crack depth: 0.648879, time: 381.60
# Step 382, Crack depth: 0.648879, time: 382.10
# Step 382, Crack depth: 0.64888, time: 382.60
# Step 383, Crack depth: 0.648881, time: 383.10
# Step 383, Crack depth: 0.648882, time: 383.60
# Step 384, Crack depth: 0.648883, time: 384.10
# Step 384, Crack depth: 0.648884, time: 384.60
# Step 385, Crack depth: 0.648885, time: 385.10
# Step 385, Crack depth: 0.648885, time: 385.60
# Step 386, Crack depth: 0.648886, time: 386.10
# Step 386, Crack depth: 0.648887, time: 386.60
# Step 387, Crack depth: 0.648888, time: 387.10
# Step 387, Crack depth: 0.648889, time: 387.60
# Step 388, Crack depth: 0.64889, time: 388.10
# Step 388, Crack depth: 0.648891, time: 388.60
# Step 389, Crack depth: 0.648892, time: 389.10
# Step 389, Crack depth: 0.648893, time: 389.60
# Step 390, Crack depth: 0.648894, time: 390.10
# Step 390, Crack depth: 0.648895, time: 390.60
# Step 391, Crack depth: 0.648896, time: 391.10
# Step 391, Crack depth: 0.648897, time: 391.60
# Step 392, Crack depth: 0.648897, time: 392.10
# Step 392, Crack depth: 0.648898, time: 392.60
# Step 393, Crack depth: 0.648899, time: 393.10
# Step 393, Crack depth: 0.6489, time: 393.60
# Step 394, Crack depth: 0.648901, time: 394.10
# Step 394, Crack depth: 0.648902, time: 394.60
# Step 395, Crack depth: 0.648904, time: 395.10
# Step 395, Crack depth: 0.648905, time: 395.60
# Step 396, Crack depth: 0.648906, time: 396.10
# Step 396, Crack depth: 0.648907, time: 396.60
# Step 397, Crack depth: 0.648908, time: 397.10
# Step 397, Crack depth: 0.64891, time: 397.60
# Step 398, Crack depth: 0.648911, time: 398.10
# Step 398, Crack depth: 0.648912, time: 398.60
# Step 399, Crack depth: 0.648914, time: 399.10
# Step 399, Crack depth: 0.648915, time: 399.60
# Step 400, Crack depth: 0.648917, time: 400.10
# Step 400, Crack depth: 0.648918, time: 400.60
# Step 401, Crack depth: 0.64892, time: 401.10
# Step 401, Crack depth: 0.648921, time: 401.60
# Step 402, Crack depth: 0.648923, time: 402.10
# Step 402, Crack depth: 0.648924, time: 402.60
# Step 403, Crack depth: 0.648926, time: 403.10
# Step 403, Crack depth: 0.648928, time: 403.58
# Step 404, Crack depth: 0.648929, time: 404.05
# Step 404, Crack depth: 0.648931, time: 404.50
# Step 404, Crack depth: 0.648933, time: 404.93
# Step 405, Crack depth: 0.648934, time: 405.35
# Step 405, Crack depth: 0.648936, time: 405.76
# Step 406, Crack depth: 0.672359, time: 406.15
# Step 406, Crack depth: 0.672358, time: 406.65
# Step 407, Crack depth: 0.672358, time: 407.15
# Step 407, Crack depth: 0.672359, time: 407.65
# Step 408, Crack depth: 0.672359, time: 408.15
# Step 408, Crack depth: 0.672359, time: 408.65
# Step 409, Crack depth: 0.672359, time: 409.15
# Step 409, Crack depth: 0.672359, time: 409.65
# Step 410, Crack depth: 0.672359, time: 410.15
# Step 410, Crack depth: 0.672359, time: 410.65
# Step 411, Crack depth: 0.67236, time: 411.15
# Step 411, Crack depth: 0.67236, time: 411.65
# Step 412, Crack depth: 0.67236, time: 412.15
# Step 412, Crack depth: 0.67236, time: 412.65
# Step 413, Crack depth: 0.67236, time: 413.15
# Step 413, Crack depth: 0.67236, time: 413.65
# Step 414, Crack depth: 0.67236, time: 414.15
# Step 414, Crack depth: 0.672361, time: 414.65
# Step 415, Crack depth: 0.672361, time: 415.15
# Step 415, Crack depth: 0.672361, time: 415.65
# Step 416, Crack depth: 0.672361, time: 416.15
# Step 416, Crack depth: 0.672361, time: 416.65
# Step 417, Crack depth: 0.672362, time: 417.15
# Step 417, Crack depth: 0.672362, time: 417.65
# Step 418, Crack depth: 0.672362, time: 418.15
# Step 418, Crack depth: 0.672362, time: 418.65
# Step 419, Crack depth: 0.672362, time: 419.15
# Step 419, Crack depth: 0.672362, time: 419.65
# Step 420, Crack depth: 0.672363, time: 420.15
# Step 420, Crack depth: 0.672363, time: 420.65
# Step 421, Crack depth: 0.672363, time: 421.15
# Step 421, Crack depth: 0.672363, time: 421.65
# Step 422, Crack depth: 0.672363, time: 422.15
# Step 422, Crack depth: 0.672364, time: 422.65
# Step 423, Crack depth: 0.672364, time: 423.15
# Step 423, Crack depth: 0.672364, time: 423.65
# Step 424, Crack depth: 0.672364, time: 424.15
# Step 424, Crack depth: 0.672364, time: 424.65
# Step 425, Crack depth: 0.672365, time: 425.15
# Step 425, Crack depth: 0.672365, time: 425.65
# Step 426, Crack depth: 0.672365, time: 426.15
# Step 426, Crack depth: 0.672365, time: 426.65
# Step 427, Crack depth: 0.672365, time: 427.15
# Step 427, Crack depth: 0.672366, time: 427.65
# Step 428, Crack depth: 0.672366, time: 428.15
# Step 428, Crack depth: 0.672366, time: 428.65
# Step 429, Crack depth: 0.672366, time: 429.15
# Step 429, Crack depth: 0.672367, time: 429.65
# Step 430, Crack depth: 0.672367, time: 430.15
# Step 430, Crack depth: 0.672367, time: 430.65
# Step 431, Crack depth: 0.672367, time: 431.15
# Step 431, Crack depth: 0.672368, time: 431.65
# Step 432, Crack depth: 0.672368, time: 432.15
# Step 432, Crack depth: 0.672368, time: 432.65
# Step 433, Crack depth: 0.672368, time: 433.15
# Step 433, Crack depth: 0.672369, time: 433.65
# Step 434, Crack depth: 0.672369, time: 434.15
# Step 434, Crack depth: 0.672369, time: 434.65
# Step 435, Crack depth: 0.67237, time: 435.15
# Step 435, Crack depth: 0.67237, time: 435.65
# Step 436, Crack depth: 0.67237, time: 436.15
# Step 436, Crack depth: 0.67237, time: 436.65
# Step 437, Crack depth: 0.672371, time: 437.15
# Step 437, Crack depth: 0.672371, time: 437.65
# Step 438, Crack depth: 0.672371, time: 438.15
# Step 438, Crack depth: 0.672372, time: 438.65
# Step 439, Crack depth: 0.672372, time: 439.15
# Step 439, Crack depth: 0.672372, time: 439.65
# Step 440, Crack depth: 0.672373, time: 440.15
# Step 440, Crack depth: 0.672373, time: 440.65
# Step 441, Crack depth: 0.672373, time: 441.15
# Step 441, Crack depth: 0.672373, time: 441.65
# Step 442, Crack depth: 0.672374, time: 442.15
# Step 442, Crack depth: 0.672374, time: 442.65
# Step 443, Crack depth: 0.672374, time: 443.15
# Step 443, Crack depth: 0.672375, time: 443.65
# Step 444, Crack depth: 0.672375, time: 444.15
# Step 444, Crack depth: 0.672375, time: 444.65
# Step 445, Crack depth: 0.672376, time: 445.15
# Step 445, Crack depth: 0.672376, time: 445.65
# Step 446, Crack depth: 0.672377, time: 446.15
# Step 446, Crack depth: 0.672377, time: 446.65
# Step 447, Crack depth: 0.672377, time: 447.15
# Step 447, Crack depth: 0.672378, time: 447.65
# Step 448, Crack depth: 0.672378, time: 448.15
# Step 448, Crack depth: 0.672378, time: 448.65
# Step 449, Crack depth: 0.672379, time: 449.15
# Step 449, Crack depth: 0.672379, time: 449.65
# Step 450, Crack depth: 0.672379, time: 450.15
# Step 450, Crack depth: 0.67238, time: 450.65
# Step 451, Crack depth: 0.67238, time: 451.15
# Step 451, Crack depth: 0.672381, time: 451.65
# Step 452, Crack depth: 0.672381, time: 452.15
# Step 452, Crack depth: 0.672381, time: 452.65
# Step 453, Crack depth: 0.672382, time: 453.15
# Step 453, Crack depth: 0.672382, time: 453.65
# Step 454, Crack depth: 0.672383, time: 454.15
# Step 454, Crack depth: 0.672383, time: 454.65
# Step 455, Crack depth: 0.672384, time: 455.15
# Step 455, Crack depth: 0.672384, time: 455.65
# Step 456, Crack depth: 0.672385, time: 456.15
# Step 456, Crack depth: 0.672386, time: 456.65
# Step 457, Crack depth: 0.672387, time: 457.15
# Step 457, Crack depth: 0.672387, time: 457.65
# Step 458, Crack depth: 0.672388, time: 458.15
# Step 458, Crack depth: 0.672389, time: 458.65
# Step 459, Crack depth: 0.672389, time: 459.15
# Step 459, Crack depth: 0.67239, time: 459.65
# Step 460, Crack depth: 0.672391, time: 460.15
# Step 460, Crack depth: 0.672392, time: 460.65
# Step 461, Crack depth: 0.672393, time: 461.15
# Step 461, Crack depth: 0.672393, time: 461.65
# Step 462, Crack depth: 0.672394, time: 462.15
# Step 462, Crack depth: 0.672395, time: 462.65
# Step 463, Crack depth: 0.672396, time: 463.15
# Step 463, Crack depth: 0.672397, time: 463.65
# Step 464, Crack depth: 0.672397, time: 464.15
# Step 464, Crack depth: 0.672398, time: 464.65
# Step 465, Crack depth: 0.672399, time: 465.15
# Step 465, Crack depth: 0.6724, time: 465.65
# Step 466, Crack depth: 0.672401, time: 466.15
# Step 466, Crack depth: 0.672402, time: 466.65
# Step 467, Crack depth: 0.672403, time: 467.15
# Step 467, Crack depth: 0.672404, time: 467.65
# Step 468, Crack depth: 0.672405, time: 468.15
# Step 468, Crack depth: 0.672406, time: 468.65
# Step 469, Crack depth: 0.672407, time: 469.15
# Step 469, Crack depth: 0.672408, time: 469.65
# Step 470, Crack depth: 0.672409, time: 470.15
# Step 470, Crack depth: 0.67241, time: 470.65
# Step 471, Crack depth: 0.672411, time: 471.15
# Step 471, Crack depth: 0.672412, time: 471.65
# Step 472, Crack depth: 0.672413, time: 472.15
# Step 472, Crack depth: 0.672414, time: 472.65
# Step 473, Crack depth: 0.672416, time: 473.15
# Step 473, Crack depth: 0.672419, time: 473.65
# Step 474, Crack depth: 0.695953, time: 474.15
# Step 474, Crack depth: 0.695951, time: 474.65
# Step 475, Crack depth: 0.695951, time: 475.15
# Step 475, Crack depth: 0.695951, time: 475.65
# Step 476, Crack depth: 0.69595, time: 476.15
# Step 476, Crack depth: 0.69595, time: 476.65
# Step 477, Crack depth: 0.69595, time: 477.15
# Step 477, Crack depth: 0.695949, time: 477.65
# Step 478, Crack depth: 0.695949, time: 478.15
# Step 478, Crack depth: 0.695948, time: 478.65
# Step 479, Crack depth: 0.695948, time: 479.15
# Step 479, Crack depth: 0.695948, time: 479.65
# Step 480, Crack depth: 0.695947, time: 480.15

# %%
X1x, X2x = S1.tabulate_dof_coordinates().reshape((-1, nd)).T
plt.figure(figsize=(20, 5))
tem = dmg.vector().get_local()
plt.ylim(0, H - (H % 25) + 50)
plt.xlim(0, L - (L % 25) + 50)
plots = plt.tricontourf(X1x, X2x, tem, 360, cmap=rainbow )
# plots = plot(dmg)

x1, x2 = mesh.coordinates().T
tri = np.asarray([cell.entities(0) for cell in cells(mesh)])
plt.triplot(x1, x2, tri, "k-", alpha=0.5, lw=0.75)
# plt.axes().set_aspect("equal")
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size=0.25, pad=0.5)
# cbar = plt.colorbar(plots, ticks=ct, cax=cax)
# cbar.ax.tick_params(labelsize=tick_fs)
# plt.tight_layout()
plt.colorbar(plots)
plt.savefig('S1-Dmg.jpg', dpi=300)

# %%
tem = dmg.vector().get_local()

# %%
plot(dmg)

# %%
len(tem)
# Out:
# 3611

# %%
len(X1x)
# Out:
# 3611

# %%
len(X2x)
# Out:
# 3611

# %%
project(u, V, form_compiler_parameters={"quadrature_degree": 3})
# Out:
# Shapes do not match: <Argument id=140430905195016> and <Coefficient id=140431152999112>.
# ---------------------------------------------------------------------------
# UFLException                              Traceback (most recent call last)
# <ipython-input-39-d3e86721ff2e> in <module>
# ----> 1 project(u, V, form_compiler_parameters={"quadrature_degree": 3})
#
# /usr/local/lib/python3.6/dist-packages/dolfin/fem/projection.py in project(v, V, bcs, mesh, function, solver_type, preconditioner_type, form_compiler_parameters)
#     127     Pv = TrialFunction(V)
#     128     a = ufl.inner(w, Pv) * dx
# --> 129     L = ufl.inner(w, v) * dx
#     130
#     131     # Assemble linear system
#
# /usr/local/lib/python3.6/dist-packages/ufl/operators.py in inner(a, b)
#     167     if a.ufl_shape == () and b.ufl_shape == ():
#     168         return a * Conj(b)
# --> 169     return Inner(a, b)
#     170
#     171
#
# /usr/local/lib/python3.6/dist-packages/ufl/tensoralgebra.py in __new__(cls, a, b)
#     159         ash, bsh = a.ufl_shape, b.ufl_shape
#     160         if ash != bsh:
# --> 161             error("Shapes do not match: %s and %s." % (ufl_err_str(a), ufl_err_str(b)))
#     162
#     163         # Simplification
#
# /usr/local/lib/python3.6/dist-packages/ufl/log.py in error(self, *message)
#     170         "Write error message and raise an exception."
#     171         self._log.error(*message)
# --> 172         raise self._exception_type(self._format_raw(*message))
#     173
#     174     def begin(self, *message):
#
# UFLException: Shapes do not match: <Argument id=140430905195016> and <Coefficient id=140431152999112>.

# %%
t11 = project(tau[0, 0], SQ,form_compiler_parameters={"quadrature_degree": 2})

# %%
plt.figure(figsize=(20, 5))
# tem = dmg.vector().array()
plot = plt.tricontourf(XQ1, XQ2, s11, 360, cmap=rainbow)
plt.colorbar(plot)
# plt.savefig('s11_hw_00.jpg', dpi=300)

# %%
plt.figure(figsize=(20, 5))
# tem = dmg.vector().array()
plot = plt.tricontourf(XQ1, XQ2, dmgc, 360, cmap=rainbow)
plt.colorbar(plot)
# plt.savefig('s11_hw_00.jpg', dpi=300)
