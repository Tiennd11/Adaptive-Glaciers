# %%
from __future__ import division
from fenics import *
from mpi4py import MPI
import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.tri as tri
import warnings
from matplotlib import cm
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# parameters["form_compiler"]["representation"] = "quadrature"

# # (To shut off deprecation warnings)
# import warnings
# from ffc.quadrature.deprecation \
#     import QuadratureRepresentationDeprecationWarning
# warnings.simplefilter("ignore", QuadratureRepresentationDeprecationWarning)

# %%
# suppress FEniCS output to terminal
set_log_active(False)


# output directory
output_dir = ""


comm = MPI.COMM_WORLD  # MPI communications
rank = comm.Get_rank()  # number of current process
size = comm.Get_size()  # total number of processes

# %%
mesh = Mesh("mesh/notch.xml")

# %%
# mesh = Mesh()
# with XDMFFile(comm, "mesh/Mesh_x.xdmf") as infile:
#     infile.read(mesh)

# %%
# xdmf = XDMFFile(comm, "output/solution.xdmf")
# xdmf.parameters["functions_share_mesh"] = True
# xdmf.parameters["rewrite_function_mesh"] = False
# xdmf.parameters["flush_output"] = True

# %%
# xdmf = XDMFFile(comm, "output/results.xdmf")
# xdmf.parameters["flush_output"] = True
# xdmf.parameters["functions_share_mesh"] = True
# xdmf.write(mesh)

# %%
# Plot the mesh
plot(mesh,title='Mesh')
plt.show()

# %%
mesh

# %%
# # Plot the mesh
# plot(mesh,title='Mesh')
# plt.show()

# %%
nd = mesh.geometry().dim()  # mesh dimensions (2D or 3D)

# %%
mesh.num_vertices()
# Out:
# 1909

# %%
# Calculate minimum mesh size
min_mesh_size = mesh.hmin()
# Print the minimum mesh size
print("Minimum mesh size:", min_mesh_size)
# Out:
# Minimum mesh size: 2.9474919917003257

# %%
"""Material parameters."""

rho_ice = 917  # density of ice (kg/m^3)
rho_H2O = 1020  # density of seawater (kg/m^3)
grav = 9.81  # gravity acceleration (m/s**2)
temp = -10 + 273  # temperature (K)
B0 = 2.207e-3  # viscosity coefficient (kPa * yr**(1/3))
B0 *= 1e3  # convert to (Pa * yr**(1/3))
B0 *= (365*24)**(1/3)  # convert to (Pa * hour**(1/3))
BT = B0*np.exp(3155/temp - 0.16612/(273.39 - temp)**1.17)

# %%
"""Damage parameters."""

alpha = 0.21  # weight of max principal stress  in Hayhurst criterion
beta = 0.63  # weight of von Mises stress in Hayhurst criterion
r = 0.43  # damage exponent
B = 5.232e-7  # damage coefficient
k1, k2 = -2.63, 7.24  # damage rate dependency parameters
Dcr = 0.6  # critical damage
Dmax = 0.99  # maximum damage
lc = 10  # nonlocal length scale
# prec_ratio = 0.08
hs_ratio = 0 # water level in crevasse (normalized with crevasse height)
hw_ratio = 0 # water level at right terminus (normalized with glacier thickness)
prec_ratio = 0.08 # depth of pre-crack (

# %%
"""Set simulation time and timestepping options."""

t_total = 480  # total time (hours)
t_elapsed = 0  # current elapsed time (hours)
t_delay_dmg = 0  # delay damage (hours)
max_Delta_t = 0.5  # max time increment (hours)
max_Delta_D = 0.1  # max damage increment
output_increment = 10  # number of steps between output
time_counter = 0  # current time step

# %%
"""Mesh details."""
# L, H = 500, 125  # domain dimensions
hs = 0  # water level in crevasse (normalized with crevasse height)
hw = 0  # water level at terminus (absolute height)
# mesh = load_mesh(output_dir + "mesh/hdf5/notch.h5")
# nd = mesh.geometry().dim()  # mesh dimensions (2D or 3D)

# %%
"""Define function spaces."""
S1 = FunctionSpace(mesh, "CG", 1)  # first order scalar space
S2 = FunctionSpace(mesh, "CG", 2)  # second order scalar space
V1 = VectorFunctionSpace(mesh, "CG", 1)  # first order vector space
V2 = VectorFunctionSpace(mesh, "CG", 2)  # second order vector space
P1 = FiniteElement("CG", mesh.ufl_cell(), 1)  # first order scalar element
P2 = VectorElement("CG", mesh.ufl_cell(), 2)  # second order vector element
V = FunctionSpace(mesh, MixedElement([P2, P1]))  # mixed finite element

# %%
"""Quadrature elements and function spaces."""

# deg_quad = 2
# scalar_quad = FiniteElement("Quadrature", cell=mesh.ufl_cell(),
#                             degree=deg_quad, quad_scheme="default")
# vector_quad = VectorElement("Quadrature", cell=mesh.ufl_cell(),
#                             degree=deg_quad, quad_scheme="default")
# SQ = FunctionSpace(mesh, scalar_quad)  # quadrature points in scalar space
# VQ = FunctionSpace(mesh, vector_quad)  # quadrature points in vector space
# form_params = {"quadrature_degree": deg_quad}


"""Coordinates of nodes on initial mesh configuration."""

X1, X2 = S1.tabulate_dof_coordinates().reshape((-1, nd)).T  # coordinates
n_local = len(X1)  # number of coordinates on local process
n_global = S1.dim()  # number of coordinates in global system

# %%
L,H= max(X1),max(X2)

# %%
L
# Out:
# 500.0

# %%
H
# Out:
# 125.0

# %%
def mwrite(filename, my_list):
    MPI.barrier(comm)
    if rank == 0:
        with open(filename, "w") as f:
            for item in my_list:
                f.write("%s" % item)


def mprint(*argv):
    if rank == 0:
        out = ""
        for arg in argv:
            out = out + str(arg)
        # this forces program to output when run in parallel
        print(out, flush=True)

# %%
mprint("Number of vertices      : {}".format(S1.dim()))
mprint("Number of cells         : {}".format(V1.dim()))
mprint("Number of DoF           : {}".format(V1.dim()))
mprint("Number of processes     : {}".format(size))
mprint("Number of DoF/process   : {}".format(int(V.dim() / size)))
mprint("-----------------------------------------------------")
# Out:
# Number of vertices      : 1909
# Number of cells         : 3818
# Number of DoF           : 3818
# Number of processes     : 1
# Number of DoF/process   : 16689
# -----------------------------------------------------

# %% [markdown]
# Number of vertices      : 10719
# Number of cells         : 21438
#
# Number of vertices      : 3573
# Number of cells         : 7146
#
# Number of vertices      : 1909
# Number of cells         : 3818
#
# Number of vertices      : 7390
# Number of cells         : 14780

# %%
class left_edge(SubDomain):
    """Boundary on the left domain edge."""
    def inside(self, x, on_boundary): return near(x[0], 0) and on_boundary


class right_edge(SubDomain):
    """Boundary on the right domain edge."""
    def inside(self, x, on_boundary): return near(x[0], L) and on_boundary


class bottom_edge(SubDomain):
    """Boundary on the bottom domain edge."""
    def inside(self, x, on_boundary): return near(x[1], 0) and on_boundary


class top_edge(SubDomain):
    """Boundary on the top domain edge."""
    def inside(self, x, on_boundary): return near(x[1], H) and on_boundary


""" Define boundaries and boundary conditions. """

left = left_edge()
right = right_edge()
bottom = bottom_edge()
top = top_edge()

boundaries = MeshFunction("size_t", mesh, mesh.topology().dim() - 1)
left.mark(boundaries, 1)
right.mark(boundaries, 2)
bottom.mark(boundaries, 3)
top.mark(boundaries, 4)
ds = Measure("ds", subdomain_data=boundaries)

free_slip_left = DirichletBC(V.sub(0).sub(0), Constant(0), left)
free_slip_bottom = DirichletBC(V.sub(0).sub(1), Constant(0), bottom)
BC = [free_slip_left, free_slip_bottom]

# %%
"""define functions that are required to solve the problem"""

def bodyforce(dmg, y, h=0):
    """Gravity loading as a body force. Fully failed points have
        no density unless they are filled with water. Then they
        have the same density as water.
    """
    Dcr = 0.6
    b = Function(V1)  # body force as vector function
    by = Function(S1)  # y-component of vector function
    for i in range(n_local):
        if dmg.vector()[i] < Dcr:
            by.vector()[i] = -rho_ice*grav
        if (dmg.vector()[i] >= Dcr)*(y[i] <= h):
            by.vector()[i] = -rho_H2O*grav
    assign(b.sub(1), by)
    return b

def hydrostatic(h):
    h_expression = Expression(("(h - x[1] > 0 ?-rho_H2O * grav*(h - x[1]) : 0)",0), h=hw, rho_H2O=rho_H2O, grav=grav, degree=1)
    return h_expression

def pore_pressure(dmg, x, y, h):
	"""Hydraulic pressure from poro-mechanics formulation."""
	Dcr = 0.6
	b_poro = Function(S1)
	dmg_local = dmg.vector().get_local()
	for i in range(n_local):
		if dmg_local[i] >= Dcr:
			b_poro.vector()[i] = rho_H2O*grav*np.fmax(h - y[i], 0)*dmg_local[i]
	return b_poro


def surface_crevasse_level(dmg, y, hsr, pr):
    """dynamically compute water level in the surface crevasse"""
    crevasse_depth = 0
    crevasse_surface = 0
    if hsr > 0:
        for i in range(n_local):  # Fix: Use 'range' and correct the syntax
            if dmg.vector()[i] > Dcr:
                x2_dmg = y[i]
                if len(x2_dmg) > 0:
                    x2_dmg_local_max = min(max(x2_dmg), H)
                    x2_dmg_local_min = max(min(x2_dmg), 0)
                else:
                    x2_dmg_local_max = H
                    x2_dmg_local_min = 0
                x2_dmg_max = comm.allreduce(x2_dmg_local_max, op=MPI.MAX)
                x2_dmg_min = comm.allreduce(x2_dmg_local_min, op=MPI.MIN)
                crevasse_depth = float(x2_dmg_max - x2_dmg_min)
                crevasse_surface = crevasse_depth * hsr + x2_dmg_min
    return crevasse_depth, crevasse_surface

# %%
"""Define constitutive and kinematic relationships."""


def D(u):
    """Symmetric gradient operator."""
    return sym(nabla_grad(u))


def DII(u):
    """Second strain invariant."""
    return (0.5*(D(u)[0, 0]**2 + D(u)[1, 1]**2) + D(u)[0, 1]**2)


def eta1(u, n=3, gam=1e-14):
    """Nonlinear viscosity."""
    return 0.5*BT*(DII(u) + gam)**((1 - n)/2/n)

def c_bar(dmg=None):
    """Implicit gradient damage constant term."""
    c = Function(S1)
#     dmg_local = dmg.vector().get_local()
    if dmg:
        for i in range(n_local):
            if dmg.vector()[i] < Dcr:
                c.vector()[i] = 0.5*(lc**2)
    else:
        c.vector()[:] = 0.5*(lc**2)
    return c


def update_psi(dmg):
    """Function for enforcing incompressibility."""
    psi = Function(S1)
    psi.vector()[:] = 1
    for i in range(n_local):
    #failed_points = dmg.vector()[:] > Dcr  # failed material points
        if dmg.vector()[i] > Dcr:
            psi.vector()[i] = 1e-32
#     psi.vector()[failed_points] = 1e-32
    return psi


def np_array(x):
    """converts x in to a vector format computed at the nodes"""
    return x.vector().get_local()


def mac(x):
    """Macaulay's bracket"""
    return (x+abs(x))/2

# %%
"Define damage function."""

dmg = Function(S1)
# deg = Function(S2)

# dmg.vector()[(L/2 - 2*lc < XQ1)*(XQ1 < L/2 + 2*lc)*(H*(1-0.08) < XQ2)] = Dmax
# # dmg.vector()[(L/2 - 5 < X1)*(X1 < L/2 + 5)*(H - 10 < X2)] = Dmax

"""define pre-crack zone"""
for i in range(n_local):
    if ((L - lc)/2 < X1[i])*(X1[i] < (L + lc)/2)*(X2[i] > H*(1 - 0.08)):
        dmg.vector()[i] = Dmax
#     else:
#         dmg.vector()[i] = 0

# %%
jet = cm.jet
rainbow = cm.rainbow
redblue = cm.coolwarm
viridis = cm.viridis
plasma = cm.plasma
magma = cm.magma

# %%
plt.figure(figsize=(20, 5))
tem = dmg.vector().get_local()
plot12 = plt.tricontourf(X1, X2, tem)
plt.colorbar(plot12)

# %%
"""Initial guess for Picard iterations."""

uk = Function(V2)  # velocity
pk = Function(S1)  # pressure


comm.Barrier()

# %%
"""define crack tip coordinate"""
cracktip_coor = H*(1-0.08)

# %%
# a = np.array([1, -1, -3])
# abs(a)/1e6

# %%
min(1, 2)
# Out:
# 1

# %%
"""Main time loop."""
#t_total t_elapsed
while t_elapsed < t_total:

    time_counter += 1
    # get current configuration coordinates
    x1, x2 = S1.tabulate_dof_coordinates().reshape((-1, nd)).T
    """Extract boundaries."""
    L,H= max(x1),max(x2) 
    n_local = len(x1)  # number of coordinates on local process
    n_global = S1.dim()  # number of coordinates in global system


    u, p = TrialFunctions(V)  # trial functions in (V2, S1) space
    v, q = TestFunctions(V)  # test functions in (V2, S1) space

    # hydraulic pressure in surface crevasse
    cdepth, csurfx2 = surface_crevasse_level(dmg=dmg, y=x2, hsr=hs_ratio, pr=prec_ratio)  # height of water column
    b_poro = pore_pressure(dmg=dmg, x=x1, y=x2, h=csurfx2)  # hydraulic pressure
    # pHD = pore_pressure(dmg=dmg, y=xQ2, h=cs)  # hydraulic pressure


    # define loading terms
    b_grav = bodyforce(dmg=dmg, y=x2, h=csurfx2) # gravity for ice and water
    b_hw = hydrostatic(h=hw)  # terminus pressure

    # normal function to mesh
    nhat = FacetNormal(mesh)

  # incompressibility terms

    penalty = False

    psi = update_psi(dmg)
     ### update degradation function with damage value from previous step

    # define variational form
    LHS = (inner(D(v), 2*(1-dmg)*eta1(uk)*D(u)) - (1-dmg)*div(v)*p
           + psi*q*div(u))*dx
    if penalty:
        LHS += 1e12*inner(nabla_div(u), psi*div(v))*dx  # penalty term
    # RHS = (1-dmg)*inner(v, b_grav)*dx  # ice and water gravity
    RHS = inner(v, b_grav)*dx  # ice and water gravity
    if hs > 0:
        RHS += inner(nabla_div(v), b_poro)*dx  # hydraulic pressure in damage zone
    if hw > 0:
        RHS += inner(v, b_hw)*ds(2)  # terminus pressure

    """ Picard iterations. """

    eps_local = 1  # local error norm
    eps_global = 1  # global error norm
    tol = 1e-4  # error tolerance
    picard_count = 0  # iteration count
    picard_max = 50  # maximum iterations
    w = Function(V)  # empty function to dump solution

    while (abs(eps_global) > tol) and (picard_count < picard_max):

        # solve the variational form
        solve(LHS == RHS, w, BC)
        u, p = w.split(deepcopy=True)
        u1, u2 = u.split(deepcopy=True)

        # compute error norms
        u1k, u2k = uk.split(deepcopy=True)
        diff1 = u1.vector().get_local() - u1k.vector().get_local()
        diff2 = u2.vector().get_local() - u2k.vector().get_local()
        diffp = p.vector().get_local() - pk.vector().get_local()
        eps1 = np.linalg.norm(diff1)/np.linalg.norm(u1.vector().get_local())
        eps2 = np.linalg.norm(diff2)/np.linalg.norm(u2.vector().get_local())
        epsp = np.linalg.norm(diffp)/np.linalg.norm(p.vector().get_local())

        # update solution for next iteration
        assign(uk, u)
        assign(pk, p)

        comm.Barrier()

        # obtain the max error on the local process
        eps_local = max(eps1, eps2, epsp)
        # obtain the max error on all processes
        eps_global = comm.allreduce(eps_local, op=MPI.MAX)

        # update iteration count
        picard_count += 1
#     print(" Steps, eps1, eps2, eps3, epslocal: %d, %9f, %9f, %9f",picard_count, eps1, eps2, epsp, eps_local )
#     """ Generate numpy arrays from output. """

    # build effective deviatoric stress tensor
    tau = 2*eta1(u)*D(u)
    t11 = project(tau[0, 0], S1).vector().get_local()
    t22 = project(tau[1, 1], S1).vector().get_local()
    t33 = np.zeros(n_local)
    t12 = project(tau[0, 1], S1).vector().get_local()

    dmg0 = dmg.vector().get_local()# damage from previous time step
    prs = interpolate(p, S1).vector().get_local()# effective pressure

    t23 = np.zeros(n_local)

    t13 = np.zeros(n_local)

 
    # effective Cauchy stress
    s11, s22, s33, s12, s23, s13 = t11 - prs, t22 - prs, t33 - prs, t12, t23, t13
    
    I1 = s11 + s22 + s33  # effective I1 invariant
    I1_true = (1 - dmg0)*I1 - 3*b_poro.vector().get_local()  # true I1 invariant
#     I1_true = (1 - dmg0)*I1  # true I1 invariant

    J2 = 0.5*(t11**2 + t22**2 + t33**2) + t12**2  # effective J2 invariant
    vms = np.sqrt(3*J2)  # effective von Mises stress

    lam1 = s33
    lam2 = 0.5*(s11 + s22 + np.sqrt(s11**2 - 2*s11*s22 + 4*(s12**2) + s22**2))
    mps = np.fmax(lam1, lam2)  # effective max principal stress

    # effective Hayhurst stress
    chi = alpha*mps + beta*vms + (1 - alpha - beta)*I1

    
    
    """ Compute the local damage rate and increment. """

    # local damage rate
    dDloc_dt = np.zeros(n_local)
    for i in range(n_local):
        if (I1[i] > 0 and chi[i] > 0 and dmg0[i] < Dcr):
            k = min(k1 + k2*abs(I1_true[i]/1e6), 30)
            dDloc_dt[i] = B*((chi[i]/1e6)**r)/((1 - dmg0[i])**k)

    # select time increment on each local process
    if max(dDloc_dt) > 0:
        Delta_t_local = float(max_Delta_D/max(dDloc_dt))
        Delta_t_local = min(max_Delta_t*3600, Delta_t_local)
    else:
        Delta_t_local = max_Delta_t*3600

    # obtain the minimum time increment from all processes
    comm.Barrier()
    Delta_t = comm.allreduce(Delta_t_local, op=MPI.MIN)

    # compute the damage increment
    Delta_Dloc = Function(S1)
    Delta_Dloc.vector()[:] = dDloc_dt*Delta_t

    """ Compute the nonlocal damage increment using implicit gradient. """

    # trial and test functions
    Delta_D = TrialFunction(S1)
    z = TestFunction(S1)

    # define variational form
    LHS = (inner(z, Delta_D) + c_bar(dmg)*inner(nabla_grad(z), nabla_grad(Delta_D)))*dx
    RHS = inner(z, Delta_Dloc)*dx

    # solve for the nonlocal damage increment
    w = Function(S1)  # empty function to dump solution
    solve(LHS == RHS, w)

    # interpolate nonlocal damage increment at quadrature points
    wq = np.clip(interpolate(w, S1).vector().get_local(), 0, max_Delta_D)

    # update damage and psi UFL functions
    dmg = Function(S1)
    dmgv = np.zeros(n_local)

    if t_elapsed >= t_delay_dmg:
#         dmgv = np.clip(dmg0+wq, 0, Dmax)  # 0 < damage < Dmax
        for i in range(n_local):
            dmgv[i] = max(0, min(dmg0[i] + wq[i], Dmax))
            if dmgv[i] > Dcr:
                dmgv[i] = Dmax
            dmg.vector()[i] = dmgv[i]

    """ Output data to mesh file. """

    Delta_t /= 3600  # convert time increment to hours
    
#     """ Save data """
#     N11 = Function(S1)
#     H11 = Function(S1)
#     V11 = Function(S1)

#     # Assuming s11, chi, and vms are NumPy arrays or similar
#     N11.vector()[:] = s11
#     H11.vector()[:] = chi
#     V11.vector()[:] = vms

#     xdmf.write(N11, time_counter, name="stress11")
#     xdmf.write(V11, time_counter, name="Von")
#     xdmf.write(H11, time_counter, name="Hau")
#     xdmf.write(dmg, time_counter, name="damage")

    """ Updated Lagrangian implementation. """

    # split velocity into components in S1 space
    u1, u2 = u.split(deepcopy=True)
    u1 = interpolate(u1, S1).vector().get_local()
    u2 = interpolate(u2, S1).vector().get_local()

    # compute the displacement increment vector Delta_u
    Delta_u1 = Function(S1)
    Delta_u2 = Function(S1)
#     ind1 = x1 > 0  # indices of coordinates where x1 > 0
#     ind2 = x2 > 0  # indices of coordinates where x2 > 0
#     Delta_u1.vector()[ind1] = u1[ind1]*Delta_t
#     Delta_u2.vector()[ind2] = u2[ind2]*Delta_t
    """define pre-crack zone"""
    for i in range(n_local):
        if x1[i] > 0:
            Delta_u1.vector()[i] = u1[i]*Delta_t
        elif x2[i] >0:
            Delta_u2.vector()[i] = u2[i]*Delta_t
    Delta_u = Function(V1)
    assign(Delta_u.sub(0), Delta_u1)
    assign(Delta_u.sub(1), Delta_u2)
    
#     Delta_u = interpolate(Delta_u, V1)
    # move the mesh, update coordinates
    ALE.move(mesh, Delta_u)

    # update elapsed time
    t_elapsed += Delta_t
#     xdmf.write(unew, time_counter)
#     xdmf.write(dmg, time_counter)
#     mprint(
#         "step: {0:3}, cracktip_ratio: {1:6.3f}, time: {2:6.0f}".format(
#             time_counter,
#             1 - cracktip_coor / H,
#             time.time() - start,
#         )
#     )


    dmgc = dmg.vector().get_local()
    for i in range(n_local):
        # if dmgc[i] >= 0.99:
        if dmgc[i] >= Dcr:
            if x2[i] < cracktip_coor:
                cracktip_coor = x2[i]
    print("Step %d, Crack depth: %g, time: %0.2f" % (t_elapsed,1-cracktip_coor/H,t_elapsed ))
# Out:
# Step 0, Crack depth: 0.08, time: 0.50
# Step 1, Crack depth: 0.08, time: 1.00
# Step 1, Crack depth: 0.08, time: 1.50
# Step 2, Crack depth: 0.08, time: 2.00
# Step 2, Crack depth: 0.08, time: 2.50
# Step 3, Crack depth: 0.08, time: 3.00
# Step 3, Crack depth: 0.08, time: 3.50
# Step 4, Crack depth: 0.08, time: 4.00
# Step 4, Crack depth: 0.08, time: 4.50
# Step 5, Crack depth: 0.08, time: 5.00
# Step 5, Crack depth: 0.08, time: 5.50
# Step 6, Crack depth: 0.08, time: 6.00
# Step 6, Crack depth: 0.08, time: 6.50
# Step 7, Crack depth: 0.08, time: 7.00
# Step 7, Crack depth: 0.08, time: 7.50
# Step 8, Crack depth: 0.08, time: 8.00
# Step 8, Crack depth: 0.08, time: 8.50
# Step 9, Crack depth: 0.08, time: 9.00
# Step 9, Crack depth: 0.08, time: 9.50
# Step 10, Crack depth: 0.08, time: 10.00
# Step 10, Crack depth: 0.08, time: 10.50
# Step 11, Crack depth: 0.08, time: 11.00
# Step 11, Crack depth: 0.08, time: 11.50
# Step 12, Crack depth: 0.08, time: 12.00
# Step 12, Crack depth: 0.08, time: 12.50
# Step 13, Crack depth: 0.08, time: 13.00
# Step 13, Crack depth: 0.08, time: 13.50
# Step 14, Crack depth: 0.08, time: 14.00
# Step 14, Crack depth: 0.08, time: 14.50
# Step 15, Crack depth: 0.08, time: 15.00
# Step 15, Crack depth: 0.08, time: 15.50
# Step 16, Crack depth: 0.08, time: 16.00
# Step 16, Crack depth: 0.08, time: 16.50
# Step 17, Crack depth: 0.08, time: 17.00
# Step 17, Crack depth: 0.08, time: 17.50
# Step 18, Crack depth: 0.08, time: 18.00
# Step 18, Crack depth: 0.08, time: 18.50
# Step 19, Crack depth: 0.08, time: 19.00
# Step 19, Crack depth: 0.08, time: 19.50
# Step 20, Crack depth: 0.08, time: 20.00
# Step 20, Crack depth: 0.08, time: 20.50
# Step 21, Crack depth: 0.08, time: 21.00
# Step 21, Crack depth: 0.08, time: 21.50
# Step 22, Crack depth: 0.08, time: 22.00
# Step 22, Crack depth: 0.08, time: 22.50
# Step 23, Crack depth: 0.08, time: 23.00
# Step 23, Crack depth: 0.08, time: 23.50
# Step 24, Crack depth: 0.08, time: 24.00
# Step 24, Crack depth: 0.08, time: 24.50
# Step 25, Crack depth: 0.08, time: 25.00
# Step 25, Crack depth: 0.08, time: 25.50
# Step 26, Crack depth: 0.08, time: 26.00
# Step 26, Crack depth: 0.08, time: 26.50
# Step 27, Crack depth: 0.08, time: 27.00
# Step 27, Crack depth: 0.08, time: 27.50
# Step 28, Crack depth: 0.08, time: 28.00
# Step 28, Crack depth: 0.08, time: 28.50
# Step 29, Crack depth: 0.08, time: 29.00
# Step 29, Crack depth: 0.08, time: 29.50
# Step 30, Crack depth: 0.08, time: 30.00
# Step 30, Crack depth: 0.08, time: 30.50
# Step 31, Crack depth: 0.08, time: 31.00
# Step 31, Crack depth: 0.08, time: 31.50
# Step 32, Crack depth: 0.08, time: 32.00
# Step 32, Crack depth: 0.08, time: 32.50
# Step 33, Crack depth: 0.08, time: 33.00
# Step 33, Crack depth: 0.08, time: 33.50
# Step 34, Crack depth: 0.08, time: 34.00
# Step 34, Crack depth: 0.08, time: 34.50
# Step 35, Crack depth: 0.08, time: 35.00
# Step 35, Crack depth: 0.08, time: 35.50
# Step 36, Crack depth: 0.08, time: 36.00
# Step 36, Crack depth: 0.08, time: 36.50
# Step 37, Crack depth: 0.08, time: 37.00
# Step 37, Crack depth: 0.08, time: 37.50
# Step 38, Crack depth: 0.08, time: 38.00
# Step 38, Crack depth: 0.08, time: 38.50
# Step 39, Crack depth: 0.08, time: 39.00
# Step 39, Crack depth: 0.08, time: 39.50
# Step 40, Crack depth: 0.08, time: 40.00
# Step 40, Crack depth: 0.08, time: 40.50
# Step 41, Crack depth: 0.08, time: 41.00
# Step 41, Crack depth: 0.08, time: 41.50
# Step 42, Crack depth: 0.08, time: 42.00
# Step 42, Crack depth: 0.08, time: 42.50
# Step 43, Crack depth: 0.08, time: 43.00
# Step 43, Crack depth: 0.08, time: 43.50
# Step 44, Crack depth: 0.08, time: 44.00
# Step 44, Crack depth: 0.08, time: 44.50
# Step 45, Crack depth: 0.08, time: 45.00
# Step 45, Crack depth: 0.08, time: 45.50
# Step 46, Crack depth: 0.08, time: 46.00
# Step 46, Crack depth: 0.08, time: 46.50
# Step 47, Crack depth: 0.08, time: 47.00
# Step 47, Crack depth: 0.08, time: 47.50
# Step 48, Crack depth: 0.08, time: 48.00
# Step 48, Crack depth: 0.08, time: 48.50
# Step 49, Crack depth: 0.08, time: 49.00
# Step 49, Crack depth: 0.08, time: 49.50
# Step 50, Crack depth: 0.08, time: 50.00
# Step 50, Crack depth: 0.08, time: 50.50
# Step 51, Crack depth: 0.08, time: 51.00
# Step 51, Crack depth: 0.08, time: 51.50
# Step 52, Crack depth: 0.08, time: 52.00
# Step 52, Crack depth: 0.08, time: 52.50
# Step 53, Crack depth: 0.08, time: 53.00
# Step 53, Crack depth: 0.08, time: 53.50
# Step 54, Crack depth: 0.08, time: 54.00
# Step 54, Crack depth: 0.08, time: 54.50
# Step 55, Crack depth: 0.08, time: 55.00
# Step 55, Crack depth: 0.08, time: 55.50
# Step 56, Crack depth: 0.08, time: 56.00
# Step 56, Crack depth: 0.08, time: 56.50
# Step 57, Crack depth: 0.08, time: 57.00
# Step 57, Crack depth: 0.08, time: 57.50
# Step 58, Crack depth: 0.08, time: 58.00
# Step 58, Crack depth: 0.08, time: 58.50
# Step 59, Crack depth: 0.08, time: 59.00
# Step 59, Crack depth: 0.08, time: 59.50
# Step 60, Crack depth: 0.08, time: 60.00
# Step 60, Crack depth: 0.08, time: 60.50
# Step 61, Crack depth: 0.08, time: 61.00
# Step 61, Crack depth: 0.08, time: 61.50
# Step 62, Crack depth: 0.08, time: 62.00
# Step 62, Crack depth: 0.08, time: 62.50
# Step 63, Crack depth: 0.08, time: 63.00
# Step 63, Crack depth: 0.08, time: 63.50
# Step 64, Crack depth: 0.08, time: 64.00
# Step 64, Crack depth: 0.08, time: 64.50
# Step 65, Crack depth: 0.08, time: 65.00
# Step 65, Crack depth: 0.08, time: 65.50
# Step 66, Crack depth: 0.08, time: 66.00
# Step 66, Crack depth: 0.08, time: 66.50
# Step 67, Crack depth: 0.08, time: 67.00
# Step 67, Crack depth: 0.08, time: 67.50
# Step 68, Crack depth: 0.08, time: 68.00
# Step 68, Crack depth: 0.08, time: 68.50
# Step 69, Crack depth: 0.08, time: 69.00
# Step 69, Crack depth: 0.08, time: 69.50
# Step 70, Crack depth: 0.08, time: 70.00
# Step 70, Crack depth: 0.08, time: 70.50
# Step 71, Crack depth: 0.08, time: 71.00
# Step 71, Crack depth: 0.08, time: 71.50
# Step 72, Crack depth: 0.08, time: 72.00
# Step 72, Crack depth: 0.08, time: 72.50
# Step 73, Crack depth: 0.08, time: 73.00
# Step 73, Crack depth: 0.08, time: 73.50
# Step 74, Crack depth: 0.08, time: 74.00
# Step 74, Crack depth: 0.08, time: 74.50
# Step 75, Crack depth: 0.08, time: 75.00
# Step 75, Crack depth: 0.08, time: 75.50
# Step 76, Crack depth: 0.08, time: 76.00
# Step 76, Crack depth: 0.08, time: 76.50
# Step 77, Crack depth: 0.08, time: 77.00
# Step 77, Crack depth: 0.08, time: 77.50
# Step 78, Crack depth: 0.08, time: 78.00
# Step 78, Crack depth: 0.08, time: 78.50
# Step 79, Crack depth: 0.08, time: 79.00
# Step 79, Crack depth: 0.08, time: 79.50
# Step 80, Crack depth: 0.08, time: 80.00
# Step 80, Crack depth: 0.08, time: 80.50
# Step 81, Crack depth: 0.08, time: 81.00
# Step 81, Crack depth: 0.08, time: 81.50
# Step 82, Crack depth: 0.08, time: 82.00
# Step 82, Crack depth: 0.08, time: 82.50
# Step 83, Crack depth: 0.08, time: 83.00
# Step 83, Crack depth: 0.08, time: 83.50
# Step 84, Crack depth: 0.08, time: 84.00
# Step 84, Crack depth: 0.08, time: 84.50
# Step 85, Crack depth: 0.08, time: 85.00
# Step 85, Crack depth: 0.08, time: 85.50
# Step 86, Crack depth: 0.08, time: 86.00
# Step 86, Crack depth: 0.08, time: 86.50
# Step 87, Crack depth: 0.08, time: 87.00
# Step 87, Crack depth: 0.08, time: 87.50
# Step 88, Crack depth: 0.08, time: 88.00
# Step 88, Crack depth: 0.08, time: 88.50
# Step 89, Crack depth: 0.08, time: 89.00
# Step 89, Crack depth: 0.08, time: 89.50
# Step 90, Crack depth: 0.08, time: 90.00
# Step 90, Crack depth: 0.08, time: 90.50
# Step 91, Crack depth: 0.08, time: 91.00
# Step 91, Crack depth: 0.08, time: 91.50
# Step 92, Crack depth: 0.08, time: 92.00
# Step 92, Crack depth: 0.08, time: 92.50
# Step 93, Crack depth: 0.08, time: 93.00
# Step 93, Crack depth: 0.08, time: 93.50
# Step 94, Crack depth: 0.08, time: 94.00
# Step 94, Crack depth: 0.08, time: 94.50
# Step 95, Crack depth: 0.08, time: 95.00
# Step 95, Crack depth: 0.08, time: 95.50
# Step 96, Crack depth: 0.08, time: 96.00
# Step 96, Crack depth: 0.08, time: 96.50
# Step 97, Crack depth: 0.08, time: 97.00
# Step 97, Crack depth: 0.08, time: 97.50
# Step 98, Crack depth: 0.08, time: 98.00
# Step 98, Crack depth: 0.08, time: 98.50
# Step 99, Crack depth: 0.08, time: 99.00
# Step 99, Crack depth: 0.08, time: 99.50
# Step 100, Crack depth: 0.08, time: 100.00
# Step 100, Crack depth: 0.08, time: 100.50
# Step 101, Crack depth: 0.08, time: 101.00
# Step 101, Crack depth: 0.08, time: 101.50
# Step 102, Crack depth: 0.08, time: 102.00
# Step 102, Crack depth: 0.08, time: 102.50
# Step 103, Crack depth: 0.08, time: 103.00
# Step 103, Crack depth: 0.08, time: 103.50
# Step 104, Crack depth: 0.08, time: 104.00
# Step 104, Crack depth: 0.08, time: 104.50
# Step 105, Crack depth: 0.08, time: 105.00
# Step 105, Crack depth: 0.08, time: 105.50
# Step 106, Crack depth: 0.08, time: 106.00
# Step 106, Crack depth: 0.08, time: 106.50
# Step 107, Crack depth: 0.08, time: 107.00
# Step 107, Crack depth: 0.08, time: 107.50
# Step 108, Crack depth: 0.08, time: 108.00
# Step 108, Crack depth: 0.08, time: 108.50
# Step 109, Crack depth: 0.08, time: 109.00
# Step 109, Crack depth: 0.08, time: 109.50
# Step 110, Crack depth: 0.08, time: 110.00
# Step 110, Crack depth: 0.08, time: 110.50
# Step 111, Crack depth: 0.08, time: 111.00
# Step 111, Crack depth: 0.08, time: 111.50
# Step 112, Crack depth: 0.08, time: 112.00
# Step 112, Crack depth: 0.08, time: 112.50
# Step 113, Crack depth: 0.08, time: 113.00
# Step 113, Crack depth: 0.08, time: 113.50
# Step 114, Crack depth: 0.08, time: 114.00
# Step 114, Crack depth: 0.08, time: 114.50
# Step 115, Crack depth: 0.08, time: 115.00
# Step 115, Crack depth: 0.08, time: 115.50
# Step 116, Crack depth: 0.08, time: 116.00
# Step 116, Crack depth: 0.08, time: 116.50
# Step 117, Crack depth: 0.08, time: 117.00
# Step 117, Crack depth: 0.08, time: 117.50
# Step 118, Crack depth: 0.08, time: 118.00
# Step 118, Crack depth: 0.08, time: 118.50
# Step 119, Crack depth: 0.08, time: 119.00
# Step 119, Crack depth: 0.08, time: 119.50
# Step 120, Crack depth: 0.08, time: 120.00
# Step 120, Crack depth: 0.08, time: 120.50
# Step 121, Crack depth: 0.08, time: 121.00
# Step 121, Crack depth: 0.08, time: 121.50
# Step 122, Crack depth: 0.08, time: 122.00
# Step 122, Crack depth: 0.08, time: 122.50
# Step 123, Crack depth: 0.08, time: 123.00
# Step 123, Crack depth: 0.08, time: 123.50
# Step 124, Crack depth: 0.08, time: 124.00
# Step 124, Crack depth: 0.08, time: 124.50
# Step 125, Crack depth: 0.08, time: 125.00
# Step 125, Crack depth: 0.08, time: 125.50
# Step 126, Crack depth: 0.08, time: 126.00
# Step 126, Crack depth: 0.08, time: 126.50
# Step 127, Crack depth: 0.08, time: 127.00
# Step 127, Crack depth: 0.08, time: 127.50
# Step 128, Crack depth: 0.08, time: 128.00
# Step 128, Crack depth: 0.08, time: 128.50
# Step 129, Crack depth: 0.08, time: 129.00
# Step 129, Crack depth: 0.08, time: 129.50
# Step 130, Crack depth: 0.08, time: 130.00
# Step 130, Crack depth: 0.08, time: 130.50
# Step 131, Crack depth: 0.08, time: 131.00
# Step 131, Crack depth: 0.08, time: 131.50
# Step 132, Crack depth: 0.08, time: 132.00
# Step 132, Crack depth: 0.08, time: 132.50
# Step 133, Crack depth: 0.08, time: 133.00
# Step 133, Crack depth: 0.08, time: 133.50
# Step 134, Crack depth: 0.08, time: 134.00
# Step 134, Crack depth: 0.08, time: 134.50
# Step 135, Crack depth: 0.08, time: 135.00
# Step 135, Crack depth: 0.08, time: 135.50
# Step 136, Crack depth: 0.08, time: 136.00
# Step 136, Crack depth: 0.08, time: 136.49
# Step 136, Crack depth: 0.08, time: 136.94
# Step 137, Crack depth: 0.08, time: 137.36
# Step 137, Crack depth: 0.08, time: 137.74
# Step 138, Crack depth: 0.08, time: 138.08
# Step 138, Crack depth: 0.08, time: 138.40
# Step 138, Crack depth: 0.08, time: 138.70
# Step 138, Crack depth: 0.08, time: 138.97
# Step 139, Crack depth: 0.08, time: 139.23
# Step 139, Crack depth: 0.08, time: 139.46
# Step 139, Crack depth: 0.08, time: 139.68
# Step 139, Crack depth: 0.08, time: 139.89
# Step 140, Crack depth: 0.08, time: 140.07
# Step 140, Crack depth: 0.08, time: 140.25
# Step 140, Crack depth: 0.08, time: 140.42
# Step 140, Crack depth: 0.08, time: 140.57
# Step 140, Crack depth: 0.08, time: 140.71
# Step 140, Crack depth: 0.08, time: 140.85
# Step 140, Crack depth: 0.1, time: 140.98
# Step 141, Crack depth: 0.1, time: 141.22
# Step 141, Crack depth: 0.1, time: 141.44
# Step 141, Crack depth: 0.1, time: 141.64
# Step 141, Crack depth: 0.1, time: 141.68
# Step 141, Crack depth: 0.1, time: 141.71
# Step 141, Crack depth: 0.1, time: 141.74
# Step 141, Crack depth: 0.1, time: 141.76
# Step 141, Crack depth: 0.1, time: 141.79
# Step 141, Crack depth: 0.1, time: 141.81
# Step 141, Crack depth: 0.1, time: 141.83
# Step 141, Crack depth: 0.1, time: 141.85
# Step 141, Crack depth: 0.12, time: 141.87
# Step 142, Crack depth: 0.12, time: 142.37
# Step 142, Crack depth: 0.12, time: 142.53
# Step 142, Crack depth: 0.12, time: 142.69
# Step 142, Crack depth: 0.12, time: 142.83
# Step 142, Crack depth: 0.12, time: 142.97
# Step 143, Crack depth: 0.12, time: 143.10
# Step 143, Crack depth: 0.12, time: 143.22
# Step 143, Crack depth: 0.12, time: 143.34
# Step 143, Crack depth: 0.12, time: 143.54
# Step 143, Crack depth: 0.12, time: 143.72
# Step 143, Crack depth: 0.12, time: 143.90
# Step 144, Crack depth: 0.12, time: 144.07
# Step 144, Crack depth: 0.12, time: 144.22
# Step 144, Crack depth: 0.12, time: 144.37
# Step 144, Crack depth: 0.12, time: 144.51
# Step 144, Crack depth: 0.12, time: 144.64
# Step 144, Crack depth: 0.12, time: 144.76
# Step 144, Crack depth: 0.12, time: 144.87
# Step 144, Crack depth: 0.12, time: 144.98
# Step 145, Crack depth: 0.12, time: 145.08
# Step 145, Crack depth: 0.12, time: 145.18
# Step 145, Crack depth: 0.12, time: 145.27
# Step 145, Crack depth: 0.12, time: 145.36
# Step 145, Crack depth: 0.12, time: 145.44
# Step 145, Crack depth: 0.14, time: 145.69
# Step 145, Crack depth: 0.14, time: 145.76
# Step 145, Crack depth: 0.14, time: 145.83
# Step 145, Crack depth: 0.14, time: 145.89
# Step 145, Crack depth: 0.14, time: 145.95
# Step 146, Crack depth: 0.14, time: 146.01
# Step 146, Crack depth: 0.14, time: 146.06
# Step 146, Crack depth: 0.14, time: 146.10
# Step 146, Crack depth: 0.14, time: 146.14
# Step 146, Crack depth: 0.14, time: 146.18
# Step 146, Crack depth: 0.14, time: 146.22
# Step 146, Crack depth: 0.14, time: 146.26
# Step 146, Crack depth: 0.14, time: 146.29
# Step 146, Crack depth: 0.14, time: 146.32
# Step 146, Crack depth: 0.14, time: 146.35
# Step 146, Crack depth: 0.14, time: 146.37
# Step 146, Crack depth: 0.14, time: 146.40
# Step 146, Crack depth: 0.14, time: 146.42
# Step 146, Crack depth: 0.14, time: 146.53
# Step 146, Crack depth: 0.16, time: 146.63
# Step 146, Crack depth: 0.16, time: 146.78
# Step 147, Crack depth: 0.16, time: 147.03
# Step 147, Crack depth: 0.16, time: 147.27
# Step 147, Crack depth: 0.16, time: 147.49
# Step 147, Crack depth: 0.16, time: 147.70
# Step 147, Crack depth: 0.16, time: 147.90
# Step 148, Crack depth: 0.16, time: 148.08
# Step 148, Crack depth: 0.16, time: 148.25
# Step 148, Crack depth: 0.16, time: 148.42
# Step 148, Crack depth: 0.16, time: 148.57
# Step 148, Crack depth: 0.16, time: 148.71
# Step 148, Crack depth: 0.16, time: 148.85
# Step 148, Crack depth: 0.16, time: 148.97
# Step 149, Crack depth: 0.16, time: 149.09
# Step 149, Crack depth: 0.16, time: 149.21
# Step 149, Crack depth: 0.16, time: 149.31
# Step 149, Crack depth: 0.16, time: 149.41
# Step 149, Crack depth: 0.16, time: 149.51
# Step 149, Crack depth: 0.16, time: 149.60
# Step 149, Crack depth: 0.16, time: 149.68
# Step 149, Crack depth: 0.16, time: 149.76
# Step 149, Crack depth: 0.16, time: 149.84
# Step 149, Crack depth: 0.16, time: 149.91
# Step 149, Crack depth: 0.16, time: 149.98
# Step 150, Crack depth: 0.16, time: 150.21
# Step 150, Crack depth: 0.18, time: 150.43
# Step 150, Crack depth: 0.18, time: 150.49
# Step 150, Crack depth: 0.18, time: 150.54
# Step 150, Crack depth: 0.18, time: 150.60
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-183-4db3b9cb4bb7> in <module>
#      60
#      61         # solve the variational form
# ---> 62         solve(LHS == RHS, w, BC)
#      63         u, p = w.split(deepcopy=True)
#      64         u1, u2 = u.split(deepcopy=True)
#
# /usr/local/lib/python3.6/dist-packages/dolfin/fem/solving.py in solve(*args, **kwargs)
#     218     # tolerance)
#     219     elif isinstance(args[0], ufl.classes.Equation):
# --> 220         _solve_varproblem(*args, **kwargs)
#     221
#     222     # Default case, just call the wrapped C++ solve function
#
# /usr/local/lib/python3.6/dist-packages/dolfin/fem/solving.py in _solve_varproblem(*args, **kwargs)
#     245         solver = LinearVariationalSolver(problem)
#     246         solver.parameters.update(solver_parameters)
# --> 247         solver.solve()
#     248
#     249     # Solve nonlinear variational problem
#
# KeyboardInterrupt:

# %%
plot(V11)

# %%
N11x = Function(S1)
H11x = Function(S1)
V11x = Function(S1)
N11x.assign(N11)
xdmf.write(N11x, time_counter, name="stress11")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-d37c28416a43> in <module>
#       4 V11x = Function(S1)
#       5 N11x.assign(N11)
# ----> 6 xdmf.write(N11x, time_counter, name="stress11")
#
# TypeError: write(): incompatible function arguments. The following argument types are supported:
#     1. (self: dolfin.cpp.io.XDMFFile, u: dolfin.cpp.function.Function, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     2. (self: dolfin.cpp.io.XDMFFile, u: dolfin.cpp.function.Function, t: float, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     3. (self: dolfin.cpp.io.XDMFFile, mesh: dolfin.cpp.mesh.Mesh, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     4. (self: dolfin.cpp.io.XDMFFile, mvc: dolfin.cpp.mesh.MeshFunctionBool, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     5. (self: dolfin.cpp.io.XDMFFile, mvc: dolfin.cpp.mesh.MeshFunctionSizet, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     6. (self: dolfin.cpp.io.XDMFFile, mvc: dolfin.cpp.mesh.MeshFunctionInt, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     7. (self: dolfin.cpp.io.XDMFFile, mvc: dolfin.cpp.mesh.MeshFunctionDouble, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     8. (self: dolfin.cpp.io.XDMFFile, mvc: dolfin.cpp.mesh.MeshValueCollection_bool, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     9. (self: dolfin.cpp.io.XDMFFile, mvc: dolfin.cpp.mesh.MeshValueCollection_sizet, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     10. (self: dolfin.cpp.io.XDMFFile, mvc: dolfin.cpp.mesh.MeshValueCollection_int, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     11. (self: dolfin.cpp.io.XDMFFile, mvc: dolfin.cpp.mesh.MeshValueCollection_double, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     12. (self: dolfin.cpp.io.XDMFFile, points: list, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     13. (self: dolfin.cpp.io.XDMFFile, points: list, values: List[float], encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     14. (self: dolfin.cpp.io.XDMFFile, u: object, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#     15. (self: dolfin.cpp.io.XDMFFile, u: object, t: float, encoding: dolfin.cpp.io.XDMFFile.Encoding=Encoding.HDF5) -> None
#
# Invoked with: <dolfin.cpp.io.XDMFFile object at 0x7fcca315dc00>, Coefficient(FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', triangle, 1), dim=2), 322), FiniteElement('Lagrange', triangle, 1)), 1691), 1; kwargs: name='stress11'

# %%
131.99

# %%
comm.Barrier()


"""Main time loop."""
#t_total t_elapsed
while t_elapsed < t_total:

    time_counter += 1
    # get current configuration coordinates
    x1, x2 = S1.tabulate_dof_coordinates().reshape((-1, nd)).T
#     xQ1, xQ2 = SQ.tabulate_dof_coordinates().reshape((-1, nd)).T
    n_local = len(x1)  # number of coordinates on local process
    n_global = S1.dim()  # number of coordinates in global system
#     nQ_local = len(xQ1)  # number of quadrature points on local process
#     nQ_global = SQ.dim()  # number of quadrature points in global system

    u, p = TrialFunctions(V)  # trial functions in (V2, S1) space
    v, q = TestFunctions(V)  # test functions in (V2, S1) space

    # hydraulic pressure in surface crevasse
    cdepth, csurfx2 = surface_crevasse_level(dmg=dmg, y=x2, hsr=hs_ratio, pr=prec_ratio)  # height of water column
    b_poro = pore_pressure(dmg=dmg, x=x1, y=x2, h=csurfx2)  # hydraulic pressure
    # pHD = pore_pressure(dmg=dmg, y=xQ2, h=cs)  # hydraulic pressure


    # define loading terms
    b_grav = bodyforce(dmg=dmg, y=x2, h=csurfx2) # gravity for ice and water
    b_hw = hydrostatic(h=hw)  # terminus pressure

    # normal function to mesh
    nhat = FacetNormal(mesh)

  # incompressibility terms

    penalty = False

    psi = update_psi(dmg)
     ### update degradation function with damage value from previous step
#     deg.vector()[:]= np.fmax(1-np_array(dmg),1e-6)

    # define variational form
    LHS = (inner(D(v), 2*(1-dmg)*eta1(uk)*D(u)) - (1-dmg)*div(v)*p
           + psi*q*div(u))*dx
    if penalty:
        LHS += 1e12*inner(nabla_div(u), psi*div(v))*dx  # penalty term
    # RHS = (1-dmg)*inner(v, b_grav)*dx  # ice and water gravity
    RHS = inner(v, b_grav)*dx  # ice and water gravity
    if hs > 0:
        RHS += inner(nabla_div(v), b_poro)*dx  # hydraulic pressure in damage zone
    if hw > 0:
        RHS += inner(v, b_hw)*ds(2)  # terminus pressure

    """ Picard iterations. """

    eps_local = 1  # local error norm
    eps_global = 1  # global error norm
    tol = 1e-4  # error tolerance
    picard_count = 0  # iteration count
    picard_max = 50  # maximum iterations
    w = Function(V)  # empty function to dump solution

    while (abs(eps_global) > tol) and (picard_count < picard_max):

        # solve the variational form
        solve(LHS == RHS, w, BC)
        u, p = w.split(deepcopy=True)
        u1, u2 = u.split(deepcopy=True)

        # compute error norms
        u1k, u2k = uk.split(deepcopy=True)
        diff1 = u1.vector().get_local() - u1k.vector().get_local()
        diff2 = u2.vector().get_local() - u2k.vector().get_local()
        diffp = p.vector().get_local() - pk.vector().get_local()
        eps1 = np.linalg.norm(diff1)/np.linalg.norm(u1.vector().get_local())
        eps2 = np.linalg.norm(diff2)/np.linalg.norm(u2.vector().get_local())
        epsp = np.linalg.norm(diffp)/np.linalg.norm(p.vector().get_local())
        # eps1 = np.linalg.norm(diff1)
        # eps2 = np.linalg.norm(diff2)
        # epsp = np.linalg.norm(diffp)

        # update solution for next iteration
        assign(uk, u)
        assign(pk, p)

        comm.Barrier()

        # obtain the max error on the local process
        eps_local = max(eps1, eps2, epsp)
        # obtain the max error on all processes
        eps_global = comm.allreduce(eps_local, op=MPI.MAX)

        # update iteration count
        picard_count += 1
#     print(" Steps, eps1, eps2, eps3, epslocal: %d, %9f, %9f, %9f",picard_count, eps1, eps2, epsp, eps_local )
#     """ Generate numpy arrays from output. """

    # build effective deviatoric stress tensor
    tau = 2*eta1(u)*D(u)
    t11 = project(tau[0, 0], S1).vector().get_local()
    t22 = project(tau[1, 1], S1).vector().get_local()
    t33 = np.zeros(n_local)
    t12 = project(tau[0, 1], S1).vector().get_local()

    dmg0 = dmg.vector().get_local()# damage from previous time step
    prs = interpolate(p, S1).vector().get_local()# effective pressure

    t23 = np.zeros(n_local)

    t13 = np.zeros(n_local)


    # effective Cauchy stress
    s11, s22, s33, s12, s23, s13 = t11 - prs, t22 - prs, t33 - prs, t12, t23, t13
    
    I1 = s11 + s22 + s33  # effective I1 invariant
    I1_true = (1 - dmg0)*I1 - 3*b_poro.vector().get_local()  # true I1 invariant
#     I1_true = (1 - dmg0)*I1  # true I1 invariant

    J2 = 0.5*(t11**2 + t22**2 + t33**2) + t12**2  # effective J2 invariant
    vms = np.sqrt(3*J2)  # effective von Mises stress

    lam1 = s33
    lam2 = 0.5*(s11 + s22 + np.sqrt(s11**2 - 2*s11*s22 + 4*(s12**2) + s22**2))
    mps = np.fmax(lam1, lam2)  # effective max principal stress

    # effective Hayhurst stress
    chi = alpha*mps + beta*vms + (1 - alpha - beta)*I1

    
    
    """ Compute the local damage rate and increment. """

    # local damage rate
    dDloc_dt = np.zeros(n_local)
    for i in range(n_local):
        if (I1[i] > 0 and chi[i] > 0 and dmg0[i] < Dcr):
            k = min(k1 + k2*abs(I1_true[i]/1e6), 30)
            dDloc_dt[i] = B*((chi[i]/1e6)**r)/((1 - dmg0[i])**k)

    # select time increment on each local process
    if max(dDloc_dt) > 0:
        Delta_t_local = float(max_Delta_D/max(dDloc_dt))
        Delta_t_local = min(max_Delta_t*3600, Delta_t_local)
    else:
        Delta_t_local = max_Delta_t*3600

    # obtain the minimum time increment from all processes
    comm.Barrier()
    Delta_t = comm.allreduce(Delta_t_local, op=MPI.MIN)

    # compute the damage increment
    Delta_Dloc = Function(S1)
    Delta_Dloc.vector()[:] = dDloc_dt*Delta_t

    """ Compute the nonlocal damage increment using implicit gradient. """

    # trial and test functions
    Delta_D = TrialFunction(S1)
    z = TestFunction(S1)

    # define variational form
    LHS = (inner(z, Delta_D)
           + c_bar(dmg)*inner(nabla_grad(z), nabla_grad(Delta_D)))*dx
    RHS = inner(z, Delta_Dloc)*dx

    # solve for the nonlocal damage increment
    w = Function(S1)  # empty function to dump solution
    solve(LHS == RHS, w)

    # interpolate nonlocal damage increment at quadrature points
    wq = np.clip(interpolate(w, S1).vector().get_local(), 0, max_Delta_D)

    # update damage and psi UFL functions
    dmg = Function(S1)
    if t_elapsed >= t_delay_dmg:
        dmgv = np.clip(dmg0+wq, 0, Dmax)  # 0 < damage < Dmax
        for i in range(n_local):
            if dmgv[i] > Dcr:
                dmgv[i] = Dmax
        dmg.vector()[:] = dmgv

    """ Output data to mesh file. """

    Delta_t /= 3600  # convert time increment to hours
    
    
    """ Updated Lagrangian implementation. """

    # split velocity into components in S1 space
    u1, u2 = u.split(deepcopy=True)
    u1 = interpolate(u1, S1).vector().get_local()
    u2 = interpolate(u2, S1).vector().get_local()

    # compute the displacement increment vector Delta_u
    Delta_u1 = Function(S1)
    Delta_u2 = Function(S1)
#     ind1 = x1 > 0  # indices of coordinates where x1 > 0
#     ind2 = x2 > 0  # indices of coordinates where x2 > 0
#     Delta_u1.vector()[ind1] = u1[ind1]*Delta_t
#     Delta_u2.vector()[ind2] = u2[ind2]*Delta_t
    """define pre-crack zone"""
    for i in range(n_local):
        if x1[i] > 0:
            Delta_u1.vector()[i] = u1[i]*Delta_t
        elif x2[i] > 0:
            Delta_u2.vector()[i] = u2[i]*Delta_t
    Delta_u = Function(V1)
    assign(Delta_u.sub(0), Delta_u1)
    assign(Delta_u.sub(1), Delta_u2)
    
#     Delta_u = interpolate(Delta_u, V1)
    # move the mesh, update coordinates
    ALE.move(mesh, Delta_u)

    # update elapsed time
    t_elapsed += Delta_t


    dmgc = dmg.vector().get_local()
    for i in range(n_local):
        # if dmgc[i] >= 0.99:
        if dmgc[i] >= Dcr:
            if x2[i] < cracktip_coor:
                cracktip_coor = x2[i]
    print("Step %d, Crack depth: %g, time: %0.2f" % (t_elapsed,1-cracktip_coor/H,t_elapsed ))

# %%
X1x, X2x = S1.tabulate_dof_coordinates().reshape((-1, nd)).T
plt.figure(figsize=(20, 5))
tem = dmg.vector().get_local()
plt.ylim(0, H - (H % 25) + 50)
plt.xlim(0, L - (L % 25) + 50)
plots = plt.tricontourf(X1x, X2x, tem, 360, cmap=rainbow )
# plots = plot(dmg)

x1, x2 = mesh.coordinates().T
tri = np.asarray([cell.entities(0) for cell in cells(mesh)])
plt.triplot(x1, x2, tri, "k-", alpha=0.5, lw=0.75)
# plt.axes().set_aspect("equal")
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size=0.25, pad=0.5)
# cbar = plt.colorbar(plots, ticks=ct, cax=cax)
# cbar.ax.tick_params(labelsize=tick_fs)
# plt.tight_layout()
plt.colorbar(plots)
plt.savefig('S1-Dmg.jpg', dpi=300)

# %%
plot(u1)
plt.colorbar(plot(u1))

# %%
plot(mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7fcca13cba90>,
#  <matplotlib.lines.Line2D at 0x7fcca16d0358>]

# %%
tem = dmg.vector().get_local()

# %%
plot(dmg)

# %%
len(tem)

# %%
len(X1x)

# %%
len(X2x)

# %%
X1x, X2x = S2.tabulate_dof_coordinates().reshape((-1, nd)).T

plt.figure(figsize=(20, 5))
# tem = dmg.vector().get_local()
plt.ylim(0, H - (H % 25) + 50)
plt.xlim(0, L - (L % 25) + 50)
plots = plt.tricontourf(X1x, X2x, dmg)
# plots = plot(dmg)

# x1, x2 = mesh.coordinates().T
# tri = np.asarray([cell.entities(0) for cell in cells(mesh)])
# plt.triplot(x1, x2, tri, "k-", alpha=0.5, lw=0.75)
# # plt.axes().set_aspect("equal")
# # divider = make_axes_locatable(ax)
# # cax = divider.append_axes("right", size=0.25, pad=0.5)
# # cbar = plt.colorbar(plots, ticks=ct, cax=cax)
# # cbar.ax.tick_params(labelsize=tick_fs)
# # plt.tight_layout()
plt.colorbar(plots)
plt.savefig('s11_hw_00.jpg', dpi=300)

# %%
project(u, V, form_compiler_parameters={"quadrature_degree": 3})

# %%
t11 = project(tau[0, 0], SQ,form_compiler_parameters={"quadrature_degree": 2})

# %%
plt.figure(figsize=(20, 5))
# tem = dmg.vector().array()
plot = plt.tricontourf(XQ1, XQ2, s11, 360, cmap=rainbow)
plt.colorbar(plot)
# plt.savefig('s11_hw_00.jpg', dpi=300)

# %%
plt.figure(figsize=(20, 5))
# tem = dmg.vector().array()
plot = plt.tricontourf(XQ1, XQ2, dmgc, 360, cmap=rainbow)
plt.colorbar(plot)
# plt.savefig('s11_hw_00.jpg', dpi=300)
