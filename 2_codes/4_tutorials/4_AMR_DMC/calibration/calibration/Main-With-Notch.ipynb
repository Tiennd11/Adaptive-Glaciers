# %%
import ufl
import matplotlib.pyplot as plt
import time
import numpy as np
from dolfin import *
import matplotlib.tri as tri
import warnings
from matplotlib import cm
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# suppress FEniCS output to terminal
set_log_active(False)


# output directory
output_dir = ""


comm = MPI.comm_world  # MPI communications
rank = comm.Get_rank()  # number of current process
size = comm.Get_size()  # total number of processes

# %%
# mesh = Mesh("mesh/notch.xml")

# %%
mesh = Mesh()
with XDMFFile(comm, "mesh/Mesh_6.xdmf") as infile:
    infile.read(mesh)

# %%
# Step 4: Define the xdmf file for writing
xdmf = XDMFFile("Damage2.xdmf")
xdmf.parameters["flush_output"] = True
xdmf.parameters["rewrite_function_mesh"] = True
xdmf.parameters["functions_share_mesh"] = True

# %%
# xdmf = XDMFFile(comm, "output/results.xdmf")
# xdmf.parameters["flush_output"] = True
# xdmf.parameters["functions_share_mesh"] = True
# xdmf.write(mesh)

# %%
# Plot the mesh
plot(mesh,title='Mesh')
plt.show()

# %%
mesh

# %%
# # Plot the mesh
# plot(mesh,title='Mesh')
# plt.show()

# %%
nd = mesh.geometry().dim()  # mesh dimensions (2D or 3D)

# %%
mesh.num_vertices()
# Out:
# 3422

# %%
# Calculate minimum mesh size
min_mesh_size = mesh.hmin()
# Print the minimum mesh size
print("Minimum mesh size:", min_mesh_size)
# Out:
# Minimum mesh size: 2.59381630700894

# %%
"""Material parameters."""

rho_ice = 917  # density of ice (kg/m^3)
rho_H2O = 1020  # density of seawater (kg/m^3)
grav = 9.81  # gravity acceleration (m/s**2)
temp = -10 + 273  # temperature (K)
B0 = 2.207e-3  # viscosity coefficient (kPa * yr**(1/3))
B0 *= 1e3  # convert to (Pa * yr**(1/3))
B0 *= (365*24)**(1/3)  # convert to (Pa * hour**(1/3))
BT = B0*np.exp(3155/temp - 0.16612/(273.39 - temp)**1.17)

# %%
"""Damage parameters."""

alpha = 0.21  # weight of max principal stress  in Hayhurst criterion
beta = 0.63  # weight of von Mises stress in Hayhurst criterion
r = 0.43  # damage exponent
B = 5.232e-7  # damage coefficient
k1, k2 = -2.63, 7.24  # damage rate dependency parameters
Dcr = 0.6  # critical damage
Dmax = 0.99  # maximum damage
lc = 10  # nonlocal length scale
# prec_ratio = 0.08
hs_ratio = 0 # water level in crevasse (normalized with crevasse height)
hw_ratio = 0 # water level at right terminus (normalized with glacier thickness)
prec_ratio = 0.08 # depth of pre-crack (

# %%
"""Set simulation time and timestepping options."""

t_total = 480  # total time (hours)
t_elapsed = 0  # current elapsed time (hours)
t_delay_dmg = 0  # delay damage (hours)
max_Delta_t = 0.5  # max time increment (hours)
max_Delta_D = 0.1  # max damage increment
output_increment = 10  # number of steps between output
time_counter = 0  # current time step

# %%
"""Mesh details."""
# L, H = 500, 125  # domain dimensions
hs = 0  # water level in crevasse (normalized with crevasse height)
hw = 0  # water level at terminus (absolute height)
# mesh = load_mesh(output_dir + "mesh/hdf5/notch.h5")
# nd = mesh.geometry().dim()  # mesh dimensions (2D or 3D)

# %%
"""Define function spaces."""
S1 = FunctionSpace(mesh, "CG", 1)  # first order scalar space
S2 = FunctionSpace(mesh, "CG", 2)  # second order scalar space
V1 = VectorFunctionSpace(mesh, "CG", 1)  # first order vector space
V2 = VectorFunctionSpace(mesh, "CG", 2)  # second order vector space
P1 = FiniteElement("CG", mesh.ufl_cell(), 1)  # first order scalar element
P2 = VectorElement("CG", mesh.ufl_cell(), 2)  # second order vector element
V = FunctionSpace(mesh, MixedElement([P2, P1]))  # mixed finite element

# %%
"""Quadrature elements and function spaces."""

# deg_quad = 2
# scalar_quad = FiniteElement("Quadrature", cell=mesh.ufl_cell(),
#                             degree=deg_quad, quad_scheme="default")
# vector_quad = VectorElement("Quadrature", cell=mesh.ufl_cell(),
#                             degree=deg_quad, quad_scheme="default")
# SQ = FunctionSpace(mesh, scalar_quad)  # quadrature points in scalar space
# VQ = FunctionSpace(mesh, vector_quad)  # quadrature points in vector space
# form_params = {"quadrature_degree": deg_quad}


"""Coordinates of nodes on initial mesh configuration."""

X1, X2 = S1.tabulate_dof_coordinates().reshape((-1, nd)).T  # coordinates
n_local = len(X1)  # number of coordinates on local process
n_global = S1.dim()  # number of coordinates in global system

# %%
L,H= max(X1),max(X2)

# %%
L
# Out:
# 500.0

# %%
H
# Out:
# 125.0

# %%
def mwrite(filename, my_list):
    MPI.barrier(comm)
    if rank == 0:
        with open(filename, "w") as f:
            for item in my_list:
                f.write("%s" % item)


def mprint(*argv):
    if rank == 0:
        out = ""
        for arg in argv:
            out = out + str(arg)
        # this forces program to output when run in parallel
        print(out, flush=True)

# %%
mprint("Number of vertices      : {}".format(S1.dim()))
mprint("Number of cells         : {}".format(V1.dim()))
mprint("Number of DoF           : {}".format(V1.dim()))
mprint("Number of processes     : {}".format(size))
mprint("Number of DoF/process   : {}".format(int(V.dim() / size)))
mprint("-----------------------------------------------------")
# Out:
# Number of vertices      : 3422
# Number of cells         : 6844
# Number of DoF           : 6844
# Number of processes     : 1
# Number of DoF/process   : 30248
# -----------------------------------------------------

# %%
class left_edge(SubDomain):
    """Boundary on the left domain edge."""
    def inside(self, x, on_boundary): return near(x[0], 0) and on_boundary


class right_edge(SubDomain):
    """Boundary on the right domain edge."""
    def inside(self, x, on_boundary): return near(x[0], L) and on_boundary


class bottom_edge(SubDomain):
    """Boundary on the bottom domain edge."""
    def inside(self, x, on_boundary): return near(x[1], 0) and on_boundary


class top_edge(SubDomain):
    """Boundary on the top domain edge."""
    def inside(self, x, on_boundary): return near(x[1], H) and on_boundary


""" Define boundaries and boundary conditions. """

left = left_edge()
right = right_edge()
bottom = bottom_edge()
top = top_edge()

boundaries = MeshFunction("size_t", mesh, mesh.topology().dim() - 1)
left.mark(boundaries, 1)
right.mark(boundaries, 2)
bottom.mark(boundaries, 3)
top.mark(boundaries, 4)
ds = Measure("ds", subdomain_data=boundaries)

free_slip_left = DirichletBC(V.sub(0).sub(0), Constant(0), left)
free_slip_bottom = DirichletBC(V.sub(0).sub(1), Constant(0), bottom)
BC = [free_slip_left, free_slip_bottom]

# %%
"""define functions that are required to solve the problem"""

def bodyforce(dmg, y, h=0):
    """Gravity loading as a body force. Fully failed points have
        no density unless they are filled with water. Then they
        have the same density as water.
    """
    Dcr = 0.6
    b = Function(V1)  # body force as vector function
    by = Function(S1)  # y-component of vector function
    for i in range(n_local):
        if dmg.vector()[i] < Dcr:
            by.vector()[i] = -rho_ice*grav
        if (dmg.vector()[i] >= Dcr)*(y[i] <= h):
            by.vector()[i] = -rho_H2O*grav
    assign(b.sub(1), by)
    return b

def hydrostatic(h):
    h_expression = Expression(("(h - x[1] > 0 ?-rho_H2O * grav*(h - x[1]) : 0)",0), h=hw, rho_H2O=rho_H2O, grav=grav, degree=1)
    return h_expression

def pore_pressure(dmg, x, y, h):
	"""Hydraulic pressure from poro-mechanics formulation."""
	Dcr = 0.6
	b_poro = Function(S1)
	dmg_local = dmg.vector().get_local()
	for i in range(n_local):
		if dmg_local[i] >= Dcr:
			b_poro.vector()[i] = rho_H2O*grav*np.fmax(h - y[i], 0)*dmg_local[i]
	return b_poro


def surface_crevasse_level(dmg, y, hsr, pr):
    """dynamically compute water level in the surface crevasse"""
    crevasse_depth = 0
    crevasse_surface = 0
    if hsr > 0:
        for i in range(n_local):  # Fix: Use 'range' and correct the syntax
            if dmg.vector()[i] > Dcr:
                x2_dmg = y[i]
                if len(x2_dmg) > 0:
                    x2_dmg_local_max = min(max(x2_dmg), H)
                    x2_dmg_local_min = max(min(x2_dmg), 0)
                else:
                    x2_dmg_local_max = H
                    x2_dmg_local_min = 0
                x2_dmg_max = comm.allreduce(x2_dmg_local_max, op=MPI.MAX)
                x2_dmg_min = comm.allreduce(x2_dmg_local_min, op=MPI.MIN)
                crevasse_depth = float(x2_dmg_max - x2_dmg_min)
                crevasse_surface = crevasse_depth * hsr + x2_dmg_min
    return crevasse_depth, crevasse_surface

# %%
"""Define constitutive and kinematic relationships."""


def D(u):
    """Symmetric gradient operator."""
    return sym(nabla_grad(u))


def DII(u):
    """Second strain invariant."""
    return (0.5*(D(u)[0, 0]**2 + D(u)[1, 1]**2) + D(u)[0, 1]**2)


def eta1(u, n=3, gam=1e-14):
    """Nonlinear viscosity."""
    return 0.5*BT*(DII(u) + gam)**((1 - n)/2/n)

def c_bar(dmg=None):
    """Implicit gradient damage constant term."""
    c = Function(S1)
#     dmg_local = dmg.vector().get_local()
    if dmg:
        for i in range(n_local):
            if dmg.vector()[i] < Dcr:
                c.vector()[i] = 0.5*(lc**2)
    else:
        c.vector()[:] = 0.5*(lc**2)
    return c


def update_psi(dmg):
    """Function for enforcing incompressibility."""
    psi = Function(S1)
    psi.vector()[:] = 1
    for i in range(n_local):
    #failed_points = dmg.vector()[:] > Dcr  # failed material points
        if dmg.vector()[i] > Dcr:
            psi.vector()[i] = 1e-32
#     psi.vector()[failed_points] = 1e-32
    return psi


def np_array(x):
    """converts x in to a vector format computed at the nodes"""
    return x.vector().get_local()


def mac(x):
    """Macaulay's bracket"""
    return (x+abs(x))/2

# %%
"Define damage function."""

dmg = Function(S1)
# deg = Function(S2)

# dmg.vector()[(L/2 - 2*lc < XQ1)*(XQ1 < L/2 + 2*lc)*(H*(1-0.08) < XQ2)] = Dmax
# # dmg.vector()[(L/2 - 5 < X1)*(X1 < L/2 + 5)*(H - 10 < X2)] = Dmax

"""define pre-crack zone"""
# for i in range(n_local):
#     if ((L - lc)/2 < X1[i])*(X1[i] < (L + lc)/2)*(X2[i] > H*(1 - 0.08)):
#         dmg.vector()[i] = Dmax
#     else:
#         dmg.vector()[i] = 0
# Out:
# 'define pre-crack zone'

# %%
jet = cm.jet
rainbow = cm.rainbow
redblue = cm.coolwarm
viridis = cm.viridis
plasma = cm.plasma
magma = cm.magma

# %%
plot(dmg)

# %%
"""Initial guess for Picard iterations."""

uk = Function(V2)  # velocity
pk = Function(S1)  # pressure


comm.Barrier()

# %%
"""define crack tip coordinate"""
cracktip_coor = H*(1-0.08)

# %%
"""Main time loop."""
#t_total t_elapsed
while t_elapsed < t_total:

    time_counter += 1
    # get current configuration coordinates
    x1, x2 = S1.tabulate_dof_coordinates().reshape((-1, nd)).T
    """Extract boundaries."""
    L,H= max(x1),max(x2) 
    n_local = len(x1)  # number of coordinates on local process
    n_global = S1.dim()  # number of coordinates in global system


    u, p = TrialFunctions(V)  # trial functions in (V2, S1) space
    v, q = TestFunctions(V)  # test functions in (V2, S1) space

    # hydraulic pressure in surface crevasse
    cdepth, csurfx2 = surface_crevasse_level(dmg=dmg, y=x2, hsr=hs_ratio, pr=prec_ratio)  # height of water column
    b_poro = pore_pressure(dmg=dmg, x=x1, y=x2, h=csurfx2)  # hydraulic pressure
    # pHD = pore_pressure(dmg=dmg, y=xQ2, h=cs)  # hydraulic pressure


    # define loading terms
    b_grav = bodyforce(dmg=dmg, y=x2, h=csurfx2) # gravity for ice and water
    b_hw = hydrostatic(h=hw)  # terminus pressure

    # normal function to mesh
    nhat = FacetNormal(mesh)

  # incompressibility terms

    penalty = False

    psi = update_psi(dmg)
     ### update degradation function with damage value from previous step

    # define variational form
    LHS = (inner(D(v), 2*(1-dmg)*eta1(uk)*D(u)) - (1-dmg)*div(v)*p
           + psi*q*div(u))*dx
    if penalty:
        LHS += 1e12*inner(nabla_div(u), psi*div(v))*dx  # penalty term
    # RHS = (1-dmg)*inner(v, b_grav)*dx  # ice and water gravity
    RHS = inner(v, b_grav)*dx  # ice and water gravity
    if hs > 0:
        RHS += inner(nabla_div(v), b_poro)*dx  # hydraulic pressure in damage zone
    if hw > 0:
        RHS += inner(v, b_hw)*ds(2)  # terminus pressure

    """ Picard iterations. """

    eps_local = 1  # local error norm
    eps_global = 1  # global error norm
    tol = 1e-4  # error tolerance
    picard_count = 0  # iteration count
    picard_max = 50  # maximum iterations
    w = Function(V)  # empty function to dump solution

    while (abs(eps_global) > tol) and (picard_count < picard_max):

        # solve the variational form
        solve(LHS == RHS, w, BC)
        u, p = w.split(deepcopy=True)
        u1, u2 = u.split(deepcopy=True)

        # compute error norms
        u1k, u2k = uk.split(deepcopy=True)
        diff1 = u1.vector().get_local() - u1k.vector().get_local()
        diff2 = u2.vector().get_local() - u2k.vector().get_local()
        diffp = p.vector().get_local() - pk.vector().get_local()
        eps1 = np.linalg.norm(diff1)/np.linalg.norm(u1.vector().get_local())
        eps2 = np.linalg.norm(diff2)/np.linalg.norm(u2.vector().get_local())
        epsp = np.linalg.norm(diffp)/np.linalg.norm(p.vector().get_local())

        # update solution for next iteration
        assign(uk, u)
        assign(pk, p)

        comm.Barrier()

        # obtain the max error on the local process
        eps_local = max(eps1, eps2, epsp)
        # obtain the max error on all processes
        eps_global = comm.allreduce(eps_local, op=MPI.max)


        # update iteration count
        picard_count += 1
    # build effective deviatoric stress tensor
    tau = 2*eta1(u)*D(u)
    t11 = project(tau[0, 0], S1).vector().get_local()
    t22 = project(tau[1, 1], S1).vector().get_local()
    t33 = np.zeros(n_local)
    t12 = project(tau[0, 1], S1).vector().get_local()

    dmg0 = dmg.vector().get_local()# damage from previous time step
    prs = interpolate(p, S1).vector().get_local()# effective pressure

    t23 = np.zeros(n_local)

    t13 = np.zeros(n_local)

 
    # effective Cauchy stress
    s11, s22, s33, s12, s23, s13 = t11 - prs, t22 - prs, t33 - prs, t12, t23, t13
    
    I1 = s11 + s22 + s33  # effective I1 invariant
    I1_true = (1 - dmg0)*I1 - 3*b_poro.vector().get_local()  # true I1 invariant
#     I1_true = (1 - dmg0)*I1  # true I1 invariant

    J2 = 0.5*(t11**2 + t22**2 + t33**2) + t12**2  # effective J2 invariant
    vms = np.sqrt(3*J2)  # effective von Mises stress

    lam1 = s33
    lam2 = 0.5*(s11 + s22 + np.sqrt(s11**2 - 2*s11*s22 + 4*(s12**2) + s22**2))
    mps = np.fmax(lam1, lam2)  # effective max principal stress

    # effective Hayhurst stress
    chi = alpha*mps + beta*vms + (1 - alpha - beta)*I1

    
    
    """ Compute the local damage rate and increment. """

    # local damage rate
    dDloc_dt = np.zeros(n_local)
    for i in range(n_local):
        if (I1[i] > 0 and chi[i] > 0 and dmg0[i] < Dcr):
            k = min(k1 + k2*abs(I1_true[i]/1e6), 30)
            dDloc_dt[i] = B*((chi[i]/1e6)**r)/((1 - dmg0[i])**k)

    # select time increment on each local process
    if max(dDloc_dt) > 0:
        Delta_t_local = float(max_Delta_D/max(dDloc_dt))
        Delta_t_local = min(max_Delta_t*3600, Delta_t_local)
    else:
        Delta_t_local = max_Delta_t*3600

    # obtain the minimum time increment from all processes
    comm.Barrier()
    Delta_t = comm.allreduce(Delta_t_local, op=MPI.min)

    # compute the damage increment
    Delta_Dloc = Function(S1)
    Delta_Dloc.vector()[:] = dDloc_dt*Delta_t

    """ Compute the nonlocal damage increment using implicit gradient. """

    # trial and test functions
    Delta_D = TrialFunction(S1)
    z = TestFunction(S1)

    # define variational form
    LHS = (inner(z, Delta_D) + c_bar(dmg)*inner(nabla_grad(z), nabla_grad(Delta_D)))*dx
    RHS = inner(z, Delta_Dloc)*dx

    # solve for the nonlocal damage increment
    w = Function(S1)  # empty function to dump solution
    solve(LHS == RHS, w)

    # interpolate nonlocal damage increment at quadrature points
    wq = np.clip(interpolate(w, S1).vector().get_local(), 0, max_Delta_D)

    # update damage and psi UFL functions
    dmg = Function(S1)
    dmgv = np.zeros(n_local)

    if t_elapsed >= t_delay_dmg:
#         dmgv = np.clip(dmg0+wq, 0, Dmax)  # 0 < damage < Dmax
        for i in range(n_local):
            dmgv[i] = max(0, min(dmg0[i] + wq[i], Dmax))
            if dmgv[i] > Dcr:
                dmgv[i] = Dmax
            dmg.vector()[i] = dmgv[i]

    """ Output data to mesh file. """

    Delta_t /= 3600  # convert time increment to hours
    
    """ Save data """
#     S2 = FunctionSpace(mesh, "CG", 1)  # first order scalar space
    
    N11 = Function(S1, name="S11")
    H11 = Function(S1, name="H11")
    V11 = Function(S1, name="V11")
    dmgx = Function(S1, name="Dmg")
    
    # Assuming s11, chi, and vms are NumPy arrays or similar
    N11.vector()[:] = s11
    H11.vector()[:] = chi
    V11.vector()[:] = vms
    dmgx.vector()[:] = dmg.vector()[:]

#     xdmf.write(mesh)
    xdmf.write(N11, t_elapsed)
    xdmf.write(V11, t_elapsed)
    xdmf.write(H11, t_elapsed)
    xdmf.write(dmgx, t_elapsed)

    """ Updated Lagrangian implementation. """

    # split velocity into components in S1 space
    u1, u2 = u.split(deepcopy=True)
    u1 = interpolate(u1, S1).vector().get_local()
    u2 = interpolate(u2, S1).vector().get_local()

    # compute the displacement increment vector Delta_u
    Delta_u1 = Function(S1)
    Delta_u2 = Function(S1)
#     ind1 = x1 >= 0  # indices of coordinates where x1 > 0
#     ind2 = x2 >= 0  # indices of coordinates where x2 > 0
    Delta_u1.vector()[:] = u1*Delta_t
    Delta_u2.vector()[:] = u2*Delta_t
#     """define pre-crack zone"""
#     for i in range(n_local):
#         if x1[i] >= 0:
#             Delta_u1.vector()[i] = u1[i]*Delta_t
#         elif x2[i] >= 0:
#             Delta_u2.vector()[i] = u2[i]*Delta_t
    Delta_u = Function(V1)
    assign(Delta_u.sub(0), Delta_u1)
    assign(Delta_u.sub(1), Delta_u2)
    
#     Delta_u = interpolate(Delta_u, V1)
    # move the mesh, update coordinates
    ALE.move(mesh, Delta_u)

    # update elapsed time
    t_elapsed += Delta_t

    dmgc = dmg.vector().get_local()
    for i in range(n_local):
        # if dmgc[i] >= 0.99:
        if dmgc[i] >= Dcr:
            if x2[i] < cracktip_coor:
                cracktip_coor = x2[i]
    print("Step %d, Crack depth: %g, time: %0.2f" % (t_elapsed,1-cracktip_coor/H,t_elapsed ))
# Out:
# Step 0, Crack depth: 0.08, time: 0.50
# Step 1, Crack depth: 0.0799867, time: 1.00
# Step 1, Crack depth: 0.0799734, time: 1.50
# Step 2, Crack depth: 0.07996, time: 2.00
# Step 2, Crack depth: 0.0799467, time: 2.50
# Step 3, Crack depth: 0.0799334, time: 3.00
# Step 3, Crack depth: 0.07992, time: 3.50
# Step 4, Crack depth: 0.0799067, time: 4.00
# Step 4, Crack depth: 0.0798934, time: 4.50
# Step 5, Crack depth: 0.0798801, time: 5.00
# Step 5, Crack depth: 0.0798667, time: 5.50
# Step 6, Crack depth: 0.0798534, time: 6.00
# Step 6, Crack depth: 0.07984, time: 6.50
# Step 7, Crack depth: 0.0798267, time: 7.00
# Step 7, Crack depth: 0.0798134, time: 7.50
# Step 8, Crack depth: 0.0798, time: 8.00
# Step 8, Crack depth: 0.0797867, time: 8.50
# Step 9, Crack depth: 0.0797733, time: 9.00
# Step 9, Crack depth: 0.07976, time: 9.50
# Step 10, Crack depth: 0.0797466, time: 10.00
# Step 10, Crack depth: 0.0797333, time: 10.50
# Step 11, Crack depth: 0.0797199, time: 11.00
# Step 11, Crack depth: 0.0797066, time: 11.50
# Step 12, Crack depth: 0.0796932, time: 12.00
# Step 12, Crack depth: 0.0796798, time: 12.50
# Step 13, Crack depth: 0.0796665, time: 13.00
# Step 13, Crack depth: 0.0796531, time: 13.50
# Step 14, Crack depth: 0.0796397, time: 14.00
# Step 14, Crack depth: 0.0796264, time: 14.50
# Step 15, Crack depth: 0.079613, time: 15.00
# Step 15, Crack depth: 0.0795996, time: 15.50
# Step 16, Crack depth: 0.0795863, time: 16.00
# Step 16, Crack depth: 0.0795729, time: 16.50
# Step 17, Crack depth: 0.0795595, time: 17.00
# Step 17, Crack depth: 0.0795461, time: 17.50
# Step 18, Crack depth: 0.0795328, time: 18.00
# Step 18, Crack depth: 0.0795194, time: 18.50
# Step 19, Crack depth: 0.079506, time: 19.00
# Step 19, Crack depth: 0.0794926, time: 19.50
# Step 20, Crack depth: 0.0794792, time: 20.00
# Step 20, Crack depth: 0.0794659, time: 20.50
# Step 21, Crack depth: 0.0794525, time: 21.00
# Step 21, Crack depth: 0.0794391, time: 21.50
# Step 22, Crack depth: 0.0794257, time: 22.00
# Step 22, Crack depth: 0.0794123, time: 22.50
# Step 23, Crack depth: 0.0793989, time: 23.00
# Step 23, Crack depth: 0.0793855, time: 23.50
# Step 24, Crack depth: 0.0793721, time: 24.00
# Step 24, Crack depth: 0.0793587, time: 24.50
# Step 25, Crack depth: 0.0793453, time: 25.00
# Step 25, Crack depth: 0.0793319, time: 25.50
# Step 26, Crack depth: 0.0793185, time: 26.00
# Step 26, Crack depth: 0.0793051, time: 26.50
# Step 27, Crack depth: 0.0792917, time: 27.00
# Step 27, Crack depth: 0.0792783, time: 27.50
# Step 28, Crack depth: 0.0792648, time: 28.00
# Step 28, Crack depth: 0.0792514, time: 28.50
# Step 29, Crack depth: 0.079238, time: 29.00
# Step 29, Crack depth: 0.0792246, time: 29.50
# Step 30, Crack depth: 0.0792112, time: 30.00
# Step 30, Crack depth: 0.0791978, time: 30.50
# Step 31, Crack depth: 0.0791843, time: 31.00
# Step 31, Crack depth: 0.0791709, time: 31.50
# Step 32, Crack depth: 0.0791575, time: 32.00
# Step 32, Crack depth: 0.079144, time: 32.50
# Step 33, Crack depth: 0.0791306, time: 33.00
# Step 33, Crack depth: 0.0791172, time: 33.50
# Step 34, Crack depth: 0.0791037, time: 34.00
# Step 34, Crack depth: 0.0790903, time: 34.50
# Step 35, Crack depth: 0.0790769, time: 35.00
# Step 35, Crack depth: 0.0790634, time: 35.50
# Step 36, Crack depth: 0.07905, time: 36.00
# Step 36, Crack depth: 0.0790365, time: 36.50
# Step 37, Crack depth: 0.0790231, time: 37.00
# Step 37, Crack depth: 0.0790097, time: 37.50
# Step 38, Crack depth: 0.0789962, time: 38.00
# Step 38, Crack depth: 0.0789828, time: 38.50
# Step 39, Crack depth: 0.0789693, time: 39.00
# Step 39, Crack depth: 0.0789558, time: 39.50
# Step 40, Crack depth: 0.0789424, time: 40.00
# Step 40, Crack depth: 0.0789289, time: 40.50
# Step 41, Crack depth: 0.0789155, time: 41.00
# Step 41, Crack depth: 0.078902, time: 41.50
# Step 42, Crack depth: 0.0788885, time: 42.00
# Step 42, Crack depth: 0.0788751, time: 42.50
# Step 43, Crack depth: 0.0788616, time: 43.00
# Step 43, Crack depth: 0.0788481, time: 43.50
# Step 44, Crack depth: 0.0788347, time: 44.00
# Step 44, Crack depth: 0.0788212, time: 44.50
# Step 45, Crack depth: 0.0788077, time: 45.00
# Step 45, Crack depth: 0.0787942, time: 45.50
# Step 46, Crack depth: 0.0787808, time: 46.00
# Step 46, Crack depth: 0.0787673, time: 46.50
# Step 47, Crack depth: 0.0787538, time: 47.00
# Step 47, Crack depth: 0.0787403, time: 47.50
# Step 48, Crack depth: 0.0787268, time: 48.00
# Step 48, Crack depth: 0.0787133, time: 48.50
# Step 49, Crack depth: 0.0786998, time: 49.00
# Step 49, Crack depth: 0.0786864, time: 49.50
# Step 50, Crack depth: 0.0786729, time: 50.00
# Step 50, Crack depth: 0.0786594, time: 50.50
# Step 51, Crack depth: 0.0786459, time: 51.00
# Step 51, Crack depth: 0.0786324, time: 51.50
# Step 52, Crack depth: 0.0786189, time: 52.00
# Step 52, Crack depth: 0.0786054, time: 52.50
# Step 53, Crack depth: 0.0785918, time: 53.00
# Step 53, Crack depth: 0.0785783, time: 53.50
# Step 54, Crack depth: 0.0785648, time: 54.00
# Step 54, Crack depth: 0.0785513, time: 54.50
# Step 55, Crack depth: 0.0785378, time: 55.00
# Step 55, Crack depth: 0.0785243, time: 55.50
# Step 56, Crack depth: 0.0785108, time: 56.00
# Step 56, Crack depth: 0.0784972, time: 56.50
# Step 57, Crack depth: 0.0784837, time: 57.00
# Step 57, Crack depth: 0.0784702, time: 57.50
# Step 58, Crack depth: 0.0784567, time: 58.00
# Step 58, Crack depth: 0.0784431, time: 58.50
# Step 59, Crack depth: 0.0784296, time: 59.00
# Step 59, Crack depth: 0.0784161, time: 59.50
# Step 60, Crack depth: 0.0784025, time: 60.00
# Step 60, Crack depth: 0.078389, time: 60.50
# Step 61, Crack depth: 0.0783755, time: 61.00
# Step 61, Crack depth: 0.0783619, time: 61.50
# Step 62, Crack depth: 0.0783484, time: 62.00
# Step 62, Crack depth: 0.0783348, time: 62.50
# Step 63, Crack depth: 0.0783213, time: 63.00
# Step 63, Crack depth: 0.0783078, time: 63.50
# Step 64, Crack depth: 0.0782942, time: 64.00
# Step 64, Crack depth: 0.0782806, time: 64.50
# Step 65, Crack depth: 0.0782671, time: 65.00
# Step 65, Crack depth: 0.0782535, time: 65.50
# Step 66, Crack depth: 0.07824, time: 66.00
# Step 66, Crack depth: 0.0782264, time: 66.50
# Step 67, Crack depth: 0.0782129, time: 67.00
# Step 67, Crack depth: 0.0781993, time: 67.50
# Step 68, Crack depth: 0.0781857, time: 68.00
# Step 68, Crack depth: 0.0781722, time: 68.50
# Step 69, Crack depth: 0.0781586, time: 69.00
# Step 69, Crack depth: 0.078145, time: 69.50
# Step 70, Crack depth: 0.0781314, time: 70.00
# Step 70, Crack depth: 0.0781179, time: 70.50
# Step 71, Crack depth: 0.0781043, time: 71.00
# Step 71, Crack depth: 0.0780907, time: 71.50
# Step 72, Crack depth: 0.0780771, time: 72.00
# Step 72, Crack depth: 0.0780635, time: 72.50
# Step 73, Crack depth: 0.07805, time: 73.00
# Step 73, Crack depth: 0.0780364, time: 73.50
# Step 74, Crack depth: 0.0780228, time: 74.00
# Step 74, Crack depth: 0.0780092, time: 74.50
# Step 75, Crack depth: 0.0779956, time: 75.00
# Step 75, Crack depth: 0.077982, time: 75.50
# Step 76, Crack depth: 0.0779684, time: 76.00
# Step 76, Crack depth: 0.0779548, time: 76.50
# Step 77, Crack depth: 0.0779412, time: 77.00
# Step 77, Crack depth: 0.0779276, time: 77.50
# Step 78, Crack depth: 0.077914, time: 78.00
# Step 78, Crack depth: 0.0779004, time: 78.50
# Step 79, Crack depth: 0.0778868, time: 79.00
# Step 79, Crack depth: 0.0778732, time: 79.50
# Step 80, Crack depth: 0.0778595, time: 80.00
# Step 80, Crack depth: 0.0778459, time: 80.50
# Step 81, Crack depth: 0.0778323, time: 81.00
# Step 81, Crack depth: 0.0778187, time: 81.50
# Step 82, Crack depth: 0.0778051, time: 82.00
# Step 82, Crack depth: 0.0777914, time: 82.50
# Step 83, Crack depth: 0.0777778, time: 83.00
# Step 83, Crack depth: 0.0777642, time: 83.50
# Step 84, Crack depth: 0.0777505, time: 84.00
# Step 84, Crack depth: 0.0777369, time: 84.50
# Step 85, Crack depth: 0.0777233, time: 85.00
# Step 85, Crack depth: 0.0777096, time: 85.50
# Step 86, Crack depth: 0.077696, time: 86.00
# Step 86, Crack depth: 0.0776824, time: 86.50
# Step 87, Crack depth: 0.0776687, time: 87.00
# Step 87, Crack depth: 0.0776551, time: 87.50
# Step 88, Crack depth: 0.0776414, time: 88.00
# Step 88, Crack depth: 0.0776278, time: 88.50
# Step 89, Crack depth: 0.0776141, time: 89.00
# Step 89, Crack depth: 0.0776005, time: 89.50
# Step 90, Crack depth: 0.0775868, time: 90.00
# Step 90, Crack depth: 0.0775732, time: 90.50
# Step 91, Crack depth: 0.0775595, time: 91.00
# Step 91, Crack depth: 0.0775458, time: 91.50
# Step 92, Crack depth: 0.0775322, time: 92.00
# Step 92, Crack depth: 0.0775185, time: 92.50
# Step 93, Crack depth: 0.0775049, time: 93.00
# Step 93, Crack depth: 0.0774912, time: 93.50
# Step 94, Crack depth: 0.0774775, time: 94.00
# Step 94, Crack depth: 0.0774638, time: 94.50
# Step 95, Crack depth: 0.0774502, time: 95.00
# Step 95, Crack depth: 0.0774365, time: 95.50
# Step 96, Crack depth: 0.0774228, time: 96.00
# Step 96, Crack depth: 0.0774091, time: 96.50
# Step 97, Crack depth: 0.0773955, time: 97.00
# Step 97, Crack depth: 0.0773818, time: 97.50
# Step 98, Crack depth: 0.0773681, time: 98.00
# Step 98, Crack depth: 0.0773544, time: 98.50
# Step 99, Crack depth: 0.0773407, time: 99.00
# Step 99, Crack depth: 0.077327, time: 99.50
# Step 100, Crack depth: 0.0773133, time: 100.00
# Step 100, Crack depth: 0.0772996, time: 100.50
# Step 101, Crack depth: 0.0772859, time: 101.00
# Step 101, Crack depth: 0.0772722, time: 101.50
# Step 102, Crack depth: 0.0772585, time: 102.00
# Step 102, Crack depth: 0.0772448, time: 102.50
# Step 103, Crack depth: 0.0772311, time: 103.00
# Step 103, Crack depth: 0.0772174, time: 103.50
# Step 104, Crack depth: 0.0772037, time: 104.00
# Step 104, Crack depth: 0.07719, time: 104.50
# Step 105, Crack depth: 0.0771763, time: 105.00
# Step 105, Crack depth: 0.0771626, time: 105.50
# Step 106, Crack depth: 0.0771489, time: 106.00
# Step 106, Crack depth: 0.0771351, time: 106.50
# Step 107, Crack depth: 0.0771214, time: 107.00
# Step 107, Crack depth: 0.0771077, time: 107.50
# Step 108, Crack depth: 0.077094, time: 108.00
# Step 108, Crack depth: 0.0770803, time: 108.50
# Step 109, Crack depth: 0.0770665, time: 109.00
# Step 109, Crack depth: 0.0770528, time: 109.50
# Step 110, Crack depth: 0.0770391, time: 110.00
# Step 110, Crack depth: 0.0770254, time: 110.50
# Step 111, Crack depth: 0.0770116, time: 111.00
# Step 111, Crack depth: 0.0769979, time: 111.50
# Step 112, Crack depth: 0.0769842, time: 112.00
# Step 112, Crack depth: 0.0769705, time: 112.50
# Step 113, Crack depth: 0.0769567, time: 113.00
# Step 113, Crack depth: 0.076943, time: 113.50
# Step 114, Crack depth: 0.0769293, time: 114.00
# Step 114, Crack depth: 0.0769155, time: 114.50
# Step 114, Crack depth: 0.0769018, time: 114.95
# Step 115, Crack depth: 0.0768894, time: 115.36
# Step 115, Crack depth: 0.0768783, time: 115.72
# Step 116, Crack depth: 0.0768682, time: 116.06
# Step 116, Crack depth: 0.076859, time: 116.36
# Step 116, Crack depth: 0.0768507, time: 116.64
# Step 116, Crack depth: 0.076843, time: 116.89
# Step 117, Crack depth: 0.076836, time: 117.13
# Step 117, Crack depth: 0.0768296, time: 117.34
# Step 117, Crack depth: 0.0768237, time: 117.54
# Step 117, Crack depth: 0.0768182, time: 117.73
# Step 117, Crack depth: 0.0768132, time: 117.90
# Step 118, Crack depth: 0.102557, time: 118.06
# Step 118, Crack depth: 0.102562, time: 118.15
# Step 118, Crack depth: 0.102564, time: 118.19
# Step 118, Crack depth: 0.102566, time: 118.23
# Step 118, Crack depth: 0.102567, time: 118.31
# Step 118, Crack depth: 0.10257, time: 118.38
# Step 118, Crack depth: 0.102572, time: 118.44
# Step 118, Crack depth: 0.102574, time: 118.50
# Step 118, Crack depth: 0.102576, time: 118.56
# Step 118, Crack depth: 0.122915, time: 118.62
# Step 118, Crack depth: 0.122917, time: 118.81
# Step 118, Crack depth: 0.122924, time: 118.98
# Step 119, Crack depth: 0.122931, time: 119.14
# Step 119, Crack depth: 0.122937, time: 119.28
# Step 119, Crack depth: 0.122943, time: 119.41
# Step 119, Crack depth: 0.122949, time: 119.53
# Step 119, Crack depth: 0.122953, time: 119.64
# Step 119, Crack depth: 0.122958, time: 119.74
# Step 119, Crack depth: 0.122962, time: 119.83
# Step 119, Crack depth: 0.122966, time: 119.92
# Step 119, Crack depth: 0.122969, time: 120.00
# Step 120, Crack depth: 0.122973, time: 120.07
# Step 120, Crack depth: 0.122975, time: 120.13
# Step 120, Crack depth: 0.122978, time: 120.19
# Step 120, Crack depth: 0.122981, time: 120.25
# Step 120, Crack depth: 0.122983, time: 120.30
# Step 120, Crack depth: 0.122985, time: 120.35
# Step 120, Crack depth: 0.122987, time: 120.39
# Step 120, Crack depth: 0.122989, time: 120.43
# Step 120, Crack depth: 0.122991, time: 120.47
# Step 120, Crack depth: 0.14388, time: 120.50
# Step 120, Crack depth: 0.143881, time: 120.90
# Step 121, Crack depth: 0.143893, time: 121.10
# Step 121, Crack depth: 0.143901, time: 121.28
# Step 121, Crack depth: 0.143908, time: 121.45
# Step 121, Crack depth: 0.143914, time: 121.60
# Step 121, Crack depth: 0.14392, time: 121.73
# Step 121, Crack depth: 0.143925, time: 121.86
# Step 121, Crack depth: 0.14393, time: 121.97
# Step 122, Crack depth: 0.143935, time: 122.08
# Step 122, Crack depth: 0.143939, time: 122.18
# Step 122, Crack depth: 0.143943, time: 122.27
# Step 122, Crack depth: 0.143947, time: 122.53
# Step 122, Crack depth: 0.143956, time: 122.78
# Step 123, Crack depth: 0.143966, time: 123.02
# Step 123, Crack depth: 0.143975, time: 123.24
# Step 123, Crack depth: 0.143983, time: 123.44
# Step 123, Crack depth: 0.143991, time: 123.63
# Step 123, Crack depth: 0.143998, time: 123.81
# Step 123, Crack depth: 0.163256, time: 123.98
# Step 124, Crack depth: 0.166827, time: 124.08
# Step 124, Crack depth: 0.16683, time: 124.29
# Step 124, Crack depth: 0.166835, time: 124.48
# Step 124, Crack depth: 0.16684, time: 124.66
# Step 124, Crack depth: 0.166845, time: 124.83
# Step 124, Crack depth: 0.16685, time: 124.98
# Step 125, Crack depth: 0.166854, time: 125.12
# Step 125, Crack depth: 0.166858, time: 125.25
# Step 125, Crack depth: 0.166862, time: 125.38
# Step 125, Crack depth: 0.166865, time: 125.49
# Step 125, Crack depth: 0.166868, time: 125.60
# Step 125, Crack depth: 0.166871, time: 125.70
# Step 125, Crack depth: 0.166874, time: 125.79
# Step 125, Crack depth: 0.166877, time: 125.88
# Step 125, Crack depth: 0.166879, time: 125.96
# Step 126, Crack depth: 0.166881, time: 126.03
# Step 126, Crack depth: 0.166883, time: 126.11
# Step 126, Crack depth: 0.166886, time: 126.17
# Step 126, Crack depth: 0.166887, time: 126.24
# Step 126, Crack depth: 0.166889, time: 126.30
# Step 126, Crack depth: 0.166891, time: 126.35
# Step 126, Crack depth: 0.166893, time: 126.41
# Step 126, Crack depth: 0.166894, time: 126.45
# Step 126, Crack depth: 0.186474, time: 126.50
# Step 126, Crack depth: 0.186475, time: 126.65
# Step 126, Crack depth: 0.18648, time: 126.79
# Step 126, Crack depth: 0.189098, time: 126.91
# Step 127, Crack depth: 0.189101, time: 127.05
# Step 127, Crack depth: 0.189104, time: 127.17
# Step 127, Crack depth: 0.189107, time: 127.29
# Step 127, Crack depth: 0.18911, time: 127.39
# Step 127, Crack depth: 0.189113, time: 127.48
# Step 127, Crack depth: 0.189115, time: 127.57
# Step 127, Crack depth: 0.189117, time: 127.64
# Step 127, Crack depth: 0.189119, time: 127.71
# Step 127, Crack depth: 0.189121, time: 127.78
# Step 127, Crack depth: 0.189123, time: 127.84
# Step 127, Crack depth: 0.189125, time: 127.89
# Step 127, Crack depth: 0.189126, time: 127.94
# Step 127, Crack depth: 0.189127, time: 127.99
# Step 128, Crack depth: 0.189129, time: 128.03
# Step 128, Crack depth: 0.18913, time: 128.07
# Step 128, Crack depth: 0.189131, time: 128.11
# Step 128, Crack depth: 0.189132, time: 128.14
# Step 128, Crack depth: 0.212028, time: 128.17
# Step 128, Crack depth: 0.212029, time: 128.43
# Step 128, Crack depth: 0.212037, time: 128.65
# Step 128, Crack depth: 0.212044, time: 128.86
# Step 129, Crack depth: 0.21205, time: 129.04
# Step 129, Crack depth: 0.212056, time: 129.20
# Step 129, Crack depth: 0.212061, time: 129.35
# Step 129, Crack depth: 0.212066, time: 129.48
# Step 129, Crack depth: 0.21207, time: 129.60
# Step 129, Crack depth: 0.212074, time: 129.70
# Step 129, Crack depth: 0.212078, time: 129.80
# Step 129, Crack depth: 0.212081, time: 129.89
# Step 129, Crack depth: 0.212084, time: 129.96
# Step 130, Crack depth: 0.212086, time: 130.03
# Step 130, Crack depth: 0.212089, time: 130.10
# Step 130, Crack depth: 0.212091, time: 130.15
# Step 130, Crack depth: 0.212093, time: 130.21
# Step 130, Crack depth: 0.212095, time: 130.25
# Step 130, Crack depth: 0.212096, time: 130.29
# Step 130, Crack depth: 0.212098, time: 130.33
# Step 130, Crack depth: 0.212099, time: 130.37
# Step 130, Crack depth: 0.2121, time: 130.40
# Step 130, Crack depth: 0.212101, time: 130.42
# Step 130, Crack depth: 0.212102, time: 130.45
# Step 130, Crack depth: 0.212103, time: 130.47
# Step 130, Crack depth: 0.212104, time: 130.49
# Step 130, Crack depth: 0.212104, time: 130.50
# Step 130, Crack depth: 0.212105, time: 130.52
# Step 130, Crack depth: 0.212106, time: 130.53
# Step 130, Crack depth: 0.212106, time: 130.55
# Step 130, Crack depth: 0.212107, time: 130.56
# Step 130, Crack depth: 0.212107, time: 130.57
# Step 130, Crack depth: 0.212107, time: 130.58
# Step 130, Crack depth: 0.212108, time: 130.59
# Step 130, Crack depth: 0.240237, time: 130.60
# Step 131, Crack depth: 0.240237, time: 131.10
# Step 131, Crack depth: 0.240248, time: 131.60
# Step 132, Crack depth: 0.24026, time: 132.10
# Step 132, Crack depth: 0.240272, time: 132.60
# Step 133, Crack depth: 0.240284, time: 133.10
# Step 133, Crack depth: 0.240295, time: 133.56
# Step 133, Crack depth: 0.240307, time: 133.82
# Step 134, Crack depth: 0.240313, time: 134.06
# Step 134, Crack depth: 0.24032, time: 134.27
# Step 134, Crack depth: 0.240325, time: 134.46
# Step 134, Crack depth: 0.24033, time: 134.64
# Step 134, Crack depth: 0.240335, time: 134.80
# Step 134, Crack depth: 0.240339, time: 134.94
# Step 135, Crack depth: 0.240343, time: 135.03
# Step 135, Crack depth: 0.240345, time: 135.11
# Step 135, Crack depth: 0.240348, time: 135.19
# Step 135, Crack depth: 0.24035, time: 135.25
# Step 135, Crack depth: 0.240351, time: 135.32
# Step 135, Crack depth: 0.240353, time: 135.37
# Step 135, Crack depth: 0.240355, time: 135.42
# Step 135, Crack depth: 0.240356, time: 135.47
# Step 135, Crack depth: 0.240358, time: 135.51
# Step 135, Crack depth: 0.240359, time: 135.55
# Step 135, Crack depth: 0.24036, time: 135.59
# Step 135, Crack depth: 0.240361, time: 135.61
# Step 135, Crack depth: 0.240362, time: 135.64
# Step 135, Crack depth: 0.240362, time: 135.66
# Step 135, Crack depth: 0.240363, time: 135.68
# Step 135, Crack depth: 0.240364, time: 135.70
# Step 135, Crack depth: 0.240364, time: 135.76
# Step 135, Crack depth: 0.240366, time: 135.80
# Step 135, Crack depth: 0.240368, time: 135.85
# Step 135, Crack depth: 0.24037, time: 135.89
# Step 135, Crack depth: 0.265733, time: 135.93
# Step 136, Crack depth: 0.265733, time: 136.28
# Step 136, Crack depth: 0.265741, time: 136.59
# Step 136, Crack depth: 0.265749, time: 136.87
# Step 137, Crack depth: 0.265755, time: 137.12
# Step 137, Crack depth: 0.265761, time: 137.35
# Step 137, Crack depth: 0.265767, time: 137.56
# Step 137, Crack depth: 0.265772, time: 137.74
# Step 137, Crack depth: 0.265776, time: 137.91
# Step 138, Crack depth: 0.265781, time: 138.07
# Step 138, Crack depth: 0.265784, time: 138.21
# Step 138, Crack depth: 0.265788, time: 138.34
# Step 138, Crack depth: 0.265791, time: 138.45
# Step 138, Crack depth: 0.265794, time: 138.56
# Step 138, Crack depth: 0.265797, time: 138.65
# Step 138, Crack depth: 0.265799, time: 138.74
# Step 138, Crack depth: 0.265801, time: 138.82
# Step 138, Crack depth: 0.265803, time: 138.89
# Step 138, Crack depth: 0.265805, time: 138.95
# Step 139, Crack depth: 0.265807, time: 139.01
# Step 139, Crack depth: 0.265808, time: 139.07
# Step 139, Crack depth: 0.26581, time: 139.10
# Step 139, Crack depth: 0.265811, time: 139.14
# Step 139, Crack depth: 0.265812, time: 139.17
# Step 139, Crack depth: 0.265813, time: 139.20
# Step 139, Crack depth: 0.265813, time: 139.26
# Step 139, Crack depth: 0.265816, time: 139.32
# Step 139, Crack depth: 0.265818, time: 139.38
# Step 139, Crack depth: 0.265819, time: 139.44
# Step 139, Crack depth: 0.265821, time: 139.49
# Step 139, Crack depth: 0.265823, time: 139.53
# Step 139, Crack depth: 0.265825, time: 139.58
# Step 139, Crack depth: 0.265826, time: 139.62
# Step 139, Crack depth: 0.265828, time: 139.66
# Step 139, Crack depth: 0.265829, time: 139.70
# Step 139, Crack depth: 0.26583, time: 139.73
# Step 139, Crack depth: 0.29088, time: 139.76
# Step 140, Crack depth: 0.29088, time: 140.10
# Step 140, Crack depth: 0.290888, time: 140.40
# Step 140, Crack depth: 0.290894, time: 140.68
# Step 140, Crack depth: 0.2909, time: 140.93
# Step 141, Crack depth: 0.290906, time: 141.15
# Step 141, Crack depth: 0.290911, time: 141.36
# Step 141, Crack depth: 0.290916, time: 141.54
# Step 141, Crack depth: 0.29092, time: 141.71
# Step 141, Crack depth: 0.290924, time: 141.86
# Step 142, Crack depth: 0.290927, time: 142.00
# Step 142, Crack depth: 0.290931, time: 142.13
# Step 142, Crack depth: 0.290933, time: 142.24
# Step 142, Crack depth: 0.290936, time: 142.35
# Step 142, Crack depth: 0.290939, time: 142.44
# Step 142, Crack depth: 0.290941, time: 142.53
# Step 142, Crack depth: 0.290943, time: 142.61
# Step 142, Crack depth: 0.290945, time: 142.68
# Step 142, Crack depth: 0.290947, time: 142.75
# Step 142, Crack depth: 0.290948, time: 142.81
# Step 142, Crack depth: 0.29095, time: 142.86
# Step 142, Crack depth: 0.290951, time: 142.91
# Step 142, Crack depth: 0.290952, time: 142.95
# Step 142, Crack depth: 0.290953, time: 142.98
# Step 143, Crack depth: 0.290954, time: 143.06
# Step 143, Crack depth: 0.290956, time: 143.13
# Step 143, Crack depth: 0.290959, time: 143.20
# Step 143, Crack depth: 0.290961, time: 143.27
# Step 143, Crack depth: 0.290963, time: 143.33
# Step 143, Crack depth: 0.290965, time: 143.38
# Step 143, Crack depth: 0.290967, time: 143.44
# Step 143, Crack depth: 0.290968, time: 143.49
# Step 143, Crack depth: 0.29097, time: 143.53
# Step 143, Crack depth: 0.290971, time: 143.58
# Step 143, Crack depth: 0.290973, time: 143.62
# Step 143, Crack depth: 0.290974, time: 143.66
# Step 143, Crack depth: 0.290976, time: 143.70
# Step 143, Crack depth: 0.314747, time: 143.73
# Step 144, Crack depth: 0.314747, time: 144.09
# Step 144, Crack depth: 0.314755, time: 144.42
# Step 144, Crack depth: 0.314761, time: 144.71
# Step 144, Crack depth: 0.314767, time: 144.97
# Step 145, Crack depth: 0.314773, time: 145.21
# Step 145, Crack depth: 0.314778, time: 145.43
# Step 145, Crack depth: 0.314783, time: 145.63
# Step 145, Crack depth: 0.314787, time: 145.81
# Step 145, Crack depth: 0.314791, time: 145.97
# Step 146, Crack depth: 0.314794, time: 146.12
# Step 146, Crack depth: 0.314798, time: 146.25
# Step 146, Crack depth: 0.314801, time: 146.37
# Step 146, Crack depth: 0.314803, time: 146.48
# Step 146, Crack depth: 0.314806, time: 146.58
# Step 146, Crack depth: 0.314808, time: 146.67
# Step 146, Crack depth: 0.31481, time: 146.76
# Step 146, Crack depth: 0.314812, time: 146.83
# Step 146, Crack depth: 0.314814, time: 146.90
# Step 146, Crack depth: 0.314815, time: 146.97
# Step 147, Crack depth: 0.314817, time: 147.02
# Step 147, Crack depth: 0.314818, time: 147.08
# Step 147, Crack depth: 0.314819, time: 147.12
# Step 147, Crack depth: 0.31482, time: 147.17
# Step 147, Crack depth: 0.314822, time: 147.20
# Step 147, Crack depth: 0.314822, time: 147.24
# Step 147, Crack depth: 0.314823, time: 147.27
# Step 147, Crack depth: 0.314824, time: 147.34
# Step 147, Crack depth: 0.314826, time: 147.40
# Step 147, Crack depth: 0.314828, time: 147.46
# Step 147, Crack depth: 0.31483, time: 147.52
# Step 147, Crack depth: 0.314832, time: 147.58
# Step 147, Crack depth: 0.314833, time: 147.63
# Step 147, Crack depth: 0.314835, time: 147.67
# Step 147, Crack depth: 0.314837, time: 147.72
# Step 147, Crack depth: 0.314838, time: 147.76
# Step 147, Crack depth: 0.314839, time: 147.80
# Step 147, Crack depth: 0.314841, time: 147.84
# Step 147, Crack depth: 0.314842, time: 147.88
# Step 147, Crack depth: 0.339047, time: 147.91
# Step 148, Crack depth: 0.339047, time: 148.24
# Step 148, Crack depth: 0.339053, time: 148.54
# Step 148, Crack depth: 0.339059, time: 148.81
# Step 149, Crack depth: 0.339065, time: 149.06
# Step 149, Crack depth: 0.339069, time: 149.28
# Step 149, Crack depth: 0.339074, time: 149.48
# Step 149, Crack depth: 0.339078, time: 149.67
# Step 149, Crack depth: 0.339082, time: 149.84
# Step 149, Crack depth: 0.339085, time: 149.99
# Step 150, Crack depth: 0.339088, time: 150.13
# Step 150, Crack depth: 0.339091, time: 150.25
# Step 150, Crack depth: 0.339094, time: 150.37
# Step 150, Crack depth: 0.339096, time: 150.47
# Step 150, Crack depth: 0.339098, time: 150.57
# Step 150, Crack depth: 0.3391, time: 150.65
# Step 150, Crack depth: 0.339102, time: 150.73
# Step 150, Crack depth: 0.339104, time: 150.81
# Step 150, Crack depth: 0.339105, time: 150.87
# Step 150, Crack depth: 0.339107, time: 150.93
# Step 150, Crack depth: 0.339108, time: 150.99
# Step 151, Crack depth: 0.339109, time: 151.04
# Step 151, Crack depth: 0.33911, time: 151.08
# Step 151, Crack depth: 0.339111, time: 151.13
# Step 151, Crack depth: 0.339112, time: 151.16
# Step 151, Crack depth: 0.339113, time: 151.20
# Step 151, Crack depth: 0.339114, time: 151.23
# Step 151, Crack depth: 0.339114, time: 151.26
# Step 151, Crack depth: 0.339115, time: 151.29
# Step 151, Crack depth: 0.339116, time: 151.31
# Step 151, Crack depth: 0.339116, time: 151.33
# Step 151, Crack depth: 0.339117, time: 151.35
# Step 151, Crack depth: 0.339117, time: 151.37
# Step 151, Crack depth: 0.339118, time: 151.39
# Step 151, Crack depth: 0.339118, time: 151.44
# Step 151, Crack depth: 0.33912, time: 151.49
# Step 151, Crack depth: 0.339121, time: 151.53
# Step 151, Crack depth: 0.339123, time: 151.57
# Step 151, Crack depth: 0.339124, time: 151.61
# Step 151, Crack depth: 0.339125, time: 151.65
# Step 151, Crack depth: 0.362615, time: 151.68
# Step 152, Crack depth: 0.362616, time: 152.04
# Step 152, Crack depth: 0.362622, time: 152.36
# Step 152, Crack depth: 0.362628, time: 152.65
# Step 152, Crack depth: 0.362633, time: 152.92
# Step 153, Crack depth: 0.362638, time: 153.16
# Step 153, Crack depth: 0.362643, time: 153.38
# Step 153, Crack depth: 0.362647, time: 153.58
# Step 153, Crack depth: 0.362651, time: 153.76
# Step 153, Crack depth: 0.362654, time: 153.92
# Step 154, Crack depth: 0.362657, time: 154.07
# Step 154, Crack depth: 0.36266, time: 154.20
# Step 154, Crack depth: 0.362663, time: 154.33
# Step 154, Crack depth: 0.362665, time: 154.44
# Step 154, Crack depth: 0.362667, time: 154.54
# Step 154, Crack depth: 0.362669, time: 154.64
# Step 154, Crack depth: 0.362671, time: 154.72
# Step 154, Crack depth: 0.362673, time: 154.80
# Step 154, Crack depth: 0.362674, time: 154.87
# Step 154, Crack depth: 0.362676, time: 154.94
# Step 154, Crack depth: 0.362677, time: 154.99
# Step 155, Crack depth: 0.362678, time: 155.05
# Step 155, Crack depth: 0.362679, time: 155.10
# Step 155, Crack depth: 0.36268, time: 155.14
# Step 155, Crack depth: 0.362681, time: 155.18
# Step 155, Crack depth: 0.362682, time: 155.22
# Step 155, Crack depth: 0.362683, time: 155.26
# Step 155, Crack depth: 0.362684, time: 155.29
# Step 155, Crack depth: 0.362684, time: 155.32
# Step 155, Crack depth: 0.362685, time: 155.34
# Step 155, Crack depth: 0.362685, time: 155.37
# Step 155, Crack depth: 0.362686, time: 155.39
# Step 155, Crack depth: 0.362687, time: 155.41
# Step 155, Crack depth: 0.362687, time: 155.43
# Step 155, Crack depth: 0.362688, time: 155.45
# Step 155, Crack depth: 0.362688, time: 155.47
# Step 155, Crack depth: 0.362688, time: 155.52
# Step 155, Crack depth: 0.36269, time: 155.56
# Step 155, Crack depth: 0.362691, time: 155.60
# Step 155, Crack depth: 0.362692, time: 155.64
# Step 155, Crack depth: 0.362693, time: 155.68
# Step 155, Crack depth: 0.386321, time: 155.72
# Step 156, Crack depth: 0.386321, time: 156.10
# Step 156, Crack depth: 0.386328, time: 156.46
# Step 156, Crack depth: 0.386334, time: 156.78
# Step 157, Crack depth: 0.386339, time: 157.07
# Step 157, Crack depth: 0.386344, time: 157.33
# Step 157, Crack depth: 0.386348, time: 157.57
# Step 157, Crack depth: 0.386353, time: 157.79
# Step 157, Crack depth: 0.386356, time: 157.98
# Step 158, Crack depth: 0.38636, time: 158.16
# Step 158, Crack depth: 0.386363, time: 158.33
# Step 158, Crack depth: 0.386366, time: 158.48
# Step 158, Crack depth: 0.386369, time: 158.62
# Step 158, Crack depth: 0.386371, time: 158.74
# Step 158, Crack depth: 0.386373, time: 158.85
# Step 158, Crack depth: 0.386375, time: 158.96
# Step 159, Crack depth: 0.386377, time: 159.05
# Step 159, Crack depth: 0.386379, time: 159.14
# Step 159, Crack depth: 0.386381, time: 159.22
# Step 159, Crack depth: 0.386382, time: 159.29
# Step 159, Crack depth: 0.386383, time: 159.36
# Step 159, Crack depth: 0.386385, time: 159.42
# Step 159, Crack depth: 0.386386, time: 159.47
# Step 159, Crack depth: 0.386387, time: 159.52
# Step 159, Crack depth: 0.386388, time: 159.57
# Step 159, Crack depth: 0.386389, time: 159.61
# Step 159, Crack depth: 0.386389, time: 159.65
# Step 159, Crack depth: 0.38639, time: 159.69
# Step 159, Crack depth: 0.386391, time: 159.72
# Step 159, Crack depth: 0.386392, time: 159.75
# Step 159, Crack depth: 0.386392, time: 159.77
# Step 159, Crack depth: 0.386393, time: 159.80
# Step 159, Crack depth: 0.386393, time: 159.82
# Step 159, Crack depth: 0.386394, time: 159.85
# Step 159, Crack depth: 0.386394, time: 159.87
# Step 159, Crack depth: 0.386395, time: 159.89
# Step 159, Crack depth: 0.386395, time: 159.91
# Step 159, Crack depth: 0.386396, time: 159.95
# Step 160, Crack depth: 0.386397, time: 160.00
# Step 160, Crack depth: 0.386398, time: 160.04
# Step 160, Crack depth: 0.386399, time: 160.09
# Step 160, Crack depth: 0.410061, time: 160.12
# Step 160, Crack depth: 0.410061, time: 160.56
# Step 160, Crack depth: 0.410068, time: 160.95
# Step 161, Crack depth: 0.410074, time: 161.31
# Step 161, Crack depth: 0.410079, time: 161.63
# Step 161, Crack depth: 0.410084, time: 161.92
# Step 162, Crack depth: 0.410089, time: 162.19
# Step 162, Crack depth: 0.410093, time: 162.43
# Step 162, Crack depth: 0.410097, time: 162.65
# Step 162, Crack depth: 0.410101, time: 162.85
# Step 163, Crack depth: 0.410104, time: 163.04
# Step 163, Crack depth: 0.410107, time: 163.20
# Step 163, Crack depth: 0.410109, time: 163.36
# Step 163, Crack depth: 0.410112, time: 163.50
# Step 163, Crack depth: 0.410114, time: 163.62
# Step 163, Crack depth: 0.410116, time: 163.74
# Step 163, Crack depth: 0.410118, time: 163.84
# Step 163, Crack depth: 0.41012, time: 163.94
# Step 164, Crack depth: 0.410122, time: 164.03
# Step 164, Crack depth: 0.410123, time: 164.11
# Step 164, Crack depth: 0.410125, time: 164.18
# Step 164, Crack depth: 0.410126, time: 164.25
# Step 164, Crack depth: 0.410127, time: 164.31
# Step 164, Crack depth: 0.410128, time: 164.37
# Step 164, Crack depth: 0.410129, time: 164.42
# Step 164, Crack depth: 0.41013, time: 164.47
# Step 164, Crack depth: 0.410131, time: 164.51
# Step 164, Crack depth: 0.410132, time: 164.55
# Step 164, Crack depth: 0.410132, time: 164.59
# Step 164, Crack depth: 0.410133, time: 164.62
# Step 164, Crack depth: 0.410134, time: 164.65
# Step 164, Crack depth: 0.410134, time: 164.68
# Step 164, Crack depth: 0.410135, time: 164.71
# Step 164, Crack depth: 0.410135, time: 164.73
# Step 164, Crack depth: 0.410136, time: 164.76
# Step 164, Crack depth: 0.410136, time: 164.78
# Step 164, Crack depth: 0.410137, time: 164.80
# Step 164, Crack depth: 0.410137, time: 164.82
# Step 164, Crack depth: 0.410138, time: 164.87
# Step 164, Crack depth: 0.410139, time: 164.92
# Step 164, Crack depth: 0.41014, time: 164.97
# Step 165, Crack depth: 0.433722, time: 165.01
# Step 165, Crack depth: 0.433722, time: 165.51
# Step 165, Crack depth: 0.433729, time: 166.00
# Step 166, Crack depth: 0.433736, time: 166.44
# Step 166, Crack depth: 0.433742, time: 166.85
# Step 167, Crack depth: 0.433748, time: 167.21
# Step 167, Crack depth: 0.433753, time: 167.55
# Step 167, Crack depth: 0.433758, time: 167.85
# Step 168, Crack depth: 0.433763, time: 168.13
# Step 168, Crack depth: 0.433767, time: 168.38
# Step 168, Crack depth: 0.433771, time: 168.61
# Step 168, Crack depth: 0.433774, time: 168.82
# Step 169, Crack depth: 0.433777, time: 169.01
# Step 169, Crack depth: 0.43378, time: 169.19
# Step 169, Crack depth: 0.433783, time: 169.35
# Step 169, Crack depth: 0.433785, time: 169.49
# Step 169, Crack depth: 0.433788, time: 169.63
# Step 169, Crack depth: 0.43379, time: 169.75
# Step 169, Crack depth: 0.433792, time: 169.86
# Step 169, Crack depth: 0.433793, time: 169.97
# Step 170, Crack depth: 0.433795, time: 170.06
# Step 170, Crack depth: 0.433796, time: 170.15
# Step 170, Crack depth: 0.433798, time: 170.23
# Step 170, Crack depth: 0.433799, time: 170.30
# Step 170, Crack depth: 0.4338, time: 170.37
# Step 170, Crack depth: 0.433801, time: 170.43
# Step 170, Crack depth: 0.433802, time: 170.48
# Step 170, Crack depth: 0.433803, time: 170.53
# Step 170, Crack depth: 0.433804, time: 170.58
# Step 170, Crack depth: 0.433805, time: 170.62
# Step 170, Crack depth: 0.433806, time: 170.66
# Step 170, Crack depth: 0.433806, time: 170.70
# Step 170, Crack depth: 0.433807, time: 170.73
# Step 170, Crack depth: 0.433808, time: 170.76
# Step 170, Crack depth: 0.433808, time: 170.79
# Step 170, Crack depth: 0.433809, time: 170.82
# Step 170, Crack depth: 0.433809, time: 170.85
# Step 170, Crack depth: 0.43381, time: 170.87
# Step 170, Crack depth: 0.43381, time: 170.89
# Step 170, Crack depth: 0.433811, time: 170.95
# Step 171, Crack depth: 0.433812, time: 171.00
# Step 171, Crack depth: 0.433813, time: 171.05
# Step 171, Crack depth: 0.458103, time: 171.10
# Step 171, Crack depth: 0.458103, time: 171.60
# Step 172, Crack depth: 0.458109, time: 172.10
# Step 172, Crack depth: 0.458115, time: 172.56
# Step 172, Crack depth: 0.458121, time: 172.97
# Step 173, Crack depth: 0.458126, time: 173.35
# Step 173, Crack depth: 0.458131, time: 173.70
# Step 174, Crack depth: 0.458136, time: 174.01
# Step 174, Crack depth: 0.45814, time: 174.30
# Step 174, Crack depth: 0.458144, time: 174.57
# Step 174, Crack depth: 0.458147, time: 174.81
# Step 175, Crack depth: 0.45815, time: 175.03
# Step 175, Crack depth: 0.458153, time: 175.23
# Step 175, Crack depth: 0.458156, time: 175.42
# Step 175, Crack depth: 0.458158, time: 175.59
# Step 175, Crack depth: 0.458161, time: 175.75
# Step 175, Crack depth: 0.458163, time: 175.89
# Step 176, Crack depth: 0.458165, time: 176.02
# Step 176, Crack depth: 0.458167, time: 176.14
# Step 176, Crack depth: 0.458168, time: 176.25
# Step 176, Crack depth: 0.45817, time: 176.36
# Step 176, Crack depth: 0.458171, time: 176.45
# Step 176, Crack depth: 0.458173, time: 176.54
# Step 176, Crack depth: 0.458174, time: 176.62
# Step 176, Crack depth: 0.458175, time: 176.69
# Step 176, Crack depth: 0.458176, time: 176.76
# Step 176, Crack depth: 0.458177, time: 176.82
# Step 176, Crack depth: 0.458178, time: 176.87
# Step 176, Crack depth: 0.458179, time: 176.93
# Step 176, Crack depth: 0.45818, time: 176.97
# Step 177, Crack depth: 0.45818, time: 177.02
# Step 177, Crack depth: 0.458181, time: 177.06
# Step 177, Crack depth: 0.458182, time: 177.10
# Step 177, Crack depth: 0.458182, time: 177.13
# Step 177, Crack depth: 0.458183, time: 177.17
# Step 177, Crack depth: 0.458183, time: 177.20
# Step 177, Crack depth: 0.458184, time: 177.23
# Step 177, Crack depth: 0.458185, time: 177.25
# Step 177, Crack depth: 0.458185, time: 177.28
# Step 177, Crack depth: 0.458186, time: 177.34
# Step 177, Crack depth: 0.458187, time: 177.41
# Step 177, Crack depth: 0.481575, time: 177.47
# Step 177, Crack depth: 0.481575, time: 177.97
# Step 178, Crack depth: 0.481581, time: 178.47
# Step 178, Crack depth: 0.481587, time: 178.97
# Step 179, Crack depth: 0.481592, time: 179.47
# Step 179, Crack depth: 0.481598, time: 179.97
# Step 180, Crack depth: 0.481604, time: 180.43
# Step 180, Crack depth: 0.481609, time: 180.86
# Step 181, Crack depth: 0.481614, time: 181.25
# Step 181, Crack depth: 0.481619, time: 181.60
# Step 181, Crack depth: 0.481623, time: 181.93
# Step 182, Crack depth: 0.481627, time: 182.23
# Step 182, Crack depth: 0.48163, time: 182.50
# Step 182, Crack depth: 0.481634, time: 182.75
# Step 182, Crack depth: 0.481637, time: 182.98
# Step 183, Crack depth: 0.48164, time: 183.20
# Step 183, Crack depth: 0.481642, time: 183.39
# Step 183, Crack depth: 0.481645, time: 183.57
# Step 183, Crack depth: 0.481647, time: 183.74
# Step 183, Crack depth: 0.481649, time: 183.89
# Step 184, Crack depth: 0.481651, time: 184.03
# Step 184, Crack depth: 0.481653, time: 184.16
# Step 184, Crack depth: 0.481654, time: 184.28
# Step 184, Crack depth: 0.481656, time: 184.39
# Step 184, Crack depth: 0.481657, time: 184.49
# Step 184, Crack depth: 0.481659, time: 184.58
# Step 184, Crack depth: 0.48166, time: 184.67
# Step 184, Crack depth: 0.481661, time: 184.74
# Step 184, Crack depth: 0.481662, time: 184.82
# Step 184, Crack depth: 0.481663, time: 184.89
# Step 184, Crack depth: 0.481664, time: 184.95
# Step 185, Crack depth: 0.481665, time: 185.00
# Step 185, Crack depth: 0.481666, time: 185.06
# Step 185, Crack depth: 0.481666, time: 185.11
# Step 185, Crack depth: 0.481667, time: 185.15
# Step 185, Crack depth: 0.481668, time: 185.19
# Step 185, Crack depth: 0.481668, time: 185.23
# Step 185, Crack depth: 0.481669, time: 185.27
# Step 185, Crack depth: 0.48167, time: 185.30
# Step 185, Crack depth: 0.48167, time: 185.33
# Step 185, Crack depth: 0.481671, time: 185.41
# Step 185, Crack depth: 0.481672, time: 185.49
# Step 185, Crack depth: 0.505768, time: 185.56
# Step 186, Crack depth: 0.505769, time: 186.06
# Step 186, Crack depth: 0.505773, time: 186.56
# Step 187, Crack depth: 0.505778, time: 187.06
# Step 187, Crack depth: 0.505783, time: 187.56
# Step 188, Crack depth: 0.505788, time: 188.06
# Step 188, Crack depth: 0.505793, time: 188.56
# Step 189, Crack depth: 0.505798, time: 189.06
# Step 189, Crack depth: 0.505803, time: 189.54
# Step 189, Crack depth: 0.505808, time: 189.97
# Step 190, Crack depth: 0.505812, time: 190.37
# Step 190, Crack depth: 0.505816, time: 190.74
# Step 191, Crack depth: 0.50582, time: 191.08
# Step 191, Crack depth: 0.505823, time: 191.39
# Step 191, Crack depth: 0.505827, time: 191.67
# Step 191, Crack depth: 0.50583, time: 191.94
# Step 192, Crack depth: 0.505833, time: 192.18
# Step 192, Crack depth: 0.505835, time: 192.40
# Step 192, Crack depth: 0.505838, time: 192.61
# Step 192, Crack depth: 0.50584, time: 192.80
# Step 192, Crack depth: 0.505842, time: 192.98
# Step 193, Crack depth: 0.505844, time: 193.14
# Step 193, Crack depth: 0.505846, time: 193.29
# Step 193, Crack depth: 0.505847, time: 193.43
# Step 193, Crack depth: 0.505849, time: 193.56
# Step 193, Crack depth: 0.50585, time: 193.67
# Step 193, Crack depth: 0.505852, time: 193.78
# Step 193, Crack depth: 0.505853, time: 193.89
# Step 193, Crack depth: 0.505854, time: 193.98
# Step 194, Crack depth: 0.505855, time: 194.07
# Step 194, Crack depth: 0.505856, time: 194.15
# Step 194, Crack depth: 0.505857, time: 194.22
# Step 194, Crack depth: 0.505858, time: 194.29
# Step 194, Crack depth: 0.505859, time: 194.35
# Step 194, Crack depth: 0.50586, time: 194.41
# Step 194, Crack depth: 0.505861, time: 194.46
# Step 194, Crack depth: 0.505861, time: 194.51
# Step 194, Crack depth: 0.505862, time: 194.55
# Step 194, Crack depth: 0.505863, time: 194.59
# Step 194, Crack depth: 0.505863, time: 194.63
# Step 194, Crack depth: 0.505864, time: 194.67
# Step 194, Crack depth: 0.505864, time: 194.76
# Step 194, Crack depth: 0.529367, time: 194.85
# Step 195, Crack depth: 0.529367, time: 195.35
# Step 195, Crack depth: 0.529371, time: 195.85
# Step 196, Crack depth: 0.529376, time: 196.35
# Step 196, Crack depth: 0.52938, time: 196.85
# Step 197, Crack depth: 0.529384, time: 197.35
# Step 197, Crack depth: 0.529388, time: 197.85
# Step 198, Crack depth: 0.529393, time: 198.35
# Step 198, Crack depth: 0.529397, time: 198.85
# Step 199, Crack depth: 0.529401, time: 199.35
# Step 199, Crack depth: 0.529406, time: 199.85
# Step 200, Crack depth: 0.52941, time: 200.35
# Step 200, Crack depth: 0.529414, time: 200.85
# Step 201, Crack depth: 0.529419, time: 201.35
# Step 201, Crack depth: 0.529423, time: 201.85
# Step 202, Crack depth: 0.529428, time: 202.34
# Step 202, Crack depth: 0.529432, time: 202.80
# Step 203, Crack depth: 0.529436, time: 203.22
# Step 203, Crack depth: 0.52944, time: 203.61
# Step 203, Crack depth: 0.529444, time: 203.97
# Step 204, Crack depth: 0.529447, time: 204.30
# Step 204, Crack depth: 0.52945, time: 204.60
# Step 204, Crack depth: 0.529453, time: 204.89
# Step 205, Crack depth: 0.529456, time: 205.15
# Step 205, Crack depth: 0.529458, time: 205.39
# Step 205, Crack depth: 0.529461, time: 205.61
# Step 205, Crack depth: 0.529463, time: 205.82
# Step 206, Crack depth: 0.529465, time: 206.01
# Step 206, Crack depth: 0.529467, time: 206.19
# Step 206, Crack depth: 0.529469, time: 206.36
# Step 206, Crack depth: 0.52947, time: 206.51
# Step 206, Crack depth: 0.529472, time: 206.65
# Step 206, Crack depth: 0.529474, time: 206.79
# Step 206, Crack depth: 0.529475, time: 206.91
# Step 207, Crack depth: 0.529476, time: 207.02
# Step 207, Crack depth: 0.529477, time: 207.13
# Step 207, Crack depth: 0.529478, time: 207.23
# Step 207, Crack depth: 0.52948, time: 207.30
# Step 207, Crack depth: 0.52948, time: 207.37
# Step 207, Crack depth: 0.529481, time: 207.44
# Step 207, Crack depth: 0.529482, time: 207.50
# Step 207, Crack depth: 0.529483, time: 207.56
# Step 207, Crack depth: 0.529484, time: 207.69
# Step 207, Crack depth: 0.529486, time: 207.81
# Step 207, Crack depth: 0.529488, time: 207.93
# Step 208, Crack depth: 0.52949, time: 208.04
# Step 208, Crack depth: 0.55392, time: 208.15
# Step 208, Crack depth: 0.55392, time: 208.65
# Step 209, Crack depth: 0.553924, time: 209.15
# Step 209, Crack depth: 0.553927, time: 209.65
# Step 210, Crack depth: 0.553931, time: 210.15
# Step 210, Crack depth: 0.553934, time: 210.65
# Step 211, Crack depth: 0.553937, time: 211.15
# Step 211, Crack depth: 0.553941, time: 211.65
# Step 212, Crack depth: 0.553944, time: 212.15
# Step 212, Crack depth: 0.553948, time: 212.65
# Step 213, Crack depth: 0.553951, time: 213.15
# Step 213, Crack depth: 0.553955, time: 213.65
# Step 214, Crack depth: 0.553958, time: 214.15
# Step 214, Crack depth: 0.553962, time: 214.65
# Step 215, Crack depth: 0.553966, time: 215.15
# Step 215, Crack depth: 0.553969, time: 215.65
# Step 216, Crack depth: 0.553973, time: 216.15
# Step 216, Crack depth: 0.553976, time: 216.65
# Step 217, Crack depth: 0.55398, time: 217.15
# Step 217, Crack depth: 0.553984, time: 217.65
# Step 218, Crack depth: 0.553988, time: 218.13
# Step 218, Crack depth: 0.553991, time: 218.57
# Step 218, Crack depth: 0.553994, time: 218.98
# Step 219, Crack depth: 0.553998, time: 219.36
# Step 219, Crack depth: 0.554001, time: 219.71
# Step 220, Crack depth: 0.554003, time: 220.04
# Step 220, Crack depth: 0.554006, time: 220.35
# Step 220, Crack depth: 0.554008, time: 220.63
# Step 220, Crack depth: 0.554011, time: 220.90
# Step 221, Crack depth: 0.554013, time: 221.14
# Step 221, Crack depth: 0.554015, time: 221.37
# Step 221, Crack depth: 0.554017, time: 221.59
# Step 221, Crack depth: 0.554018, time: 221.79
# Step 221, Crack depth: 0.55402, time: 221.97
# Step 222, Crack depth: 0.554022, time: 222.15
# Step 222, Crack depth: 0.554023, time: 222.31
# Step 222, Crack depth: 0.554025, time: 222.42
# Step 222, Crack depth: 0.554026, time: 222.53
# Step 222, Crack depth: 0.554027, time: 222.63
# Step 222, Crack depth: 0.554028, time: 222.72
# Step 222, Crack depth: 0.554029, time: 222.82
# Step 223, Crack depth: 0.55403, time: 223.01
# Step 223, Crack depth: 0.554033, time: 223.19
# Step 223, Crack depth: 0.554035, time: 223.37
# Step 223, Crack depth: 0.554038, time: 223.53
# Step 223, Crack depth: 0.55404, time: 223.70
# Step 223, Crack depth: 0.554043, time: 223.85
# Step 224, Crack depth: 0.577548, time: 224.00
# Step 224, Crack depth: 0.577548, time: 224.50
# Step 225, Crack depth: 0.577551, time: 225.00
# Step 225, Crack depth: 0.577553, time: 225.50
# Step 226, Crack depth: 0.577556, time: 226.00
# Step 226, Crack depth: 0.577559, time: 226.50
# Step 227, Crack depth: 0.577562, time: 227.00
# Step 227, Crack depth: 0.577564, time: 227.50
# Step 228, Crack depth: 0.577567, time: 228.00
# Step 228, Crack depth: 0.57757, time: 228.50
# Step 229, Crack depth: 0.577573, time: 229.00
# Step 229, Crack depth: 0.577576, time: 229.50
# Step 230, Crack depth: 0.577579, time: 230.00
# Step 230, Crack depth: 0.577581, time: 230.50
# Step 231, Crack depth: 0.577584, time: 231.00
# Step 231, Crack depth: 0.577587, time: 231.50
# Step 232, Crack depth: 0.57759, time: 232.00
# Step 232, Crack depth: 0.577593, time: 232.50
# Step 233, Crack depth: 0.577596, time: 233.00
# Step 233, Crack depth: 0.577599, time: 233.50
# Step 234, Crack depth: 0.577602, time: 234.00
# Step 234, Crack depth: 0.577605, time: 234.50
# Step 235, Crack depth: 0.577608, time: 235.00
# Step 235, Crack depth: 0.577611, time: 235.50
# Step 236, Crack depth: 0.577614, time: 236.00
# Step 236, Crack depth: 0.577617, time: 236.50
# Step 237, Crack depth: 0.57762, time: 237.00
# Step 237, Crack depth: 0.577623, time: 237.50
# Step 238, Crack depth: 0.577626, time: 238.00
# Step 238, Crack depth: 0.577629, time: 238.50
# Step 238, Crack depth: 0.577633, time: 238.96
# Step 239, Crack depth: 0.577636, time: 239.38
# Step 239, Crack depth: 0.577638, time: 239.78
# Step 240, Crack depth: 0.577641, time: 240.16
# Step 240, Crack depth: 0.577644, time: 240.51
# Step 240, Crack depth: 0.577646, time: 240.83
# Step 241, Crack depth: 0.577648, time: 241.14
# Step 241, Crack depth: 0.57765, time: 241.42
# Step 241, Crack depth: 0.577652, time: 241.69
# Step 241, Crack depth: 0.577654, time: 241.87
# Step 242, Crack depth: 0.577656, time: 242.05
# Step 242, Crack depth: 0.577657, time: 242.21
# Step 242, Crack depth: 0.577658, time: 242.37
# Step 242, Crack depth: 0.57766, time: 242.51
# Step 242, Crack depth: 0.577661, time: 242.65
# Step 242, Crack depth: 0.577662, time: 242.78
# Step 243, Crack depth: 0.577663, time: 243.05
# Step 243, Crack depth: 0.577667, time: 243.30
# Step 243, Crack depth: 0.57767, time: 243.55
# Step 243, Crack depth: 0.577673, time: 243.78
# Step 244, Crack depth: 0.577676, time: 244.01
# Step 244, Crack depth: 0.601726, time: 244.23
# Step 244, Crack depth: 0.601726, time: 244.73
# Step 245, Crack depth: 0.601728, time: 245.23
# Step 245, Crack depth: 0.60173, time: 245.73
# Step 246, Crack depth: 0.601732, time: 246.23
# Step 246, Crack depth: 0.601734, time: 246.73
# Step 247, Crack depth: 0.601736, time: 247.23
# Step 247, Crack depth: 0.601738, time: 247.73
# Step 248, Crack depth: 0.60174, time: 248.23
# Step 248, Crack depth: 0.601742, time: 248.73
# Step 249, Crack depth: 0.601744, time: 249.23
# Step 249, Crack depth: 0.601746, time: 249.73
# Step 250, Crack depth: 0.601748, time: 250.23
# Step 250, Crack depth: 0.601751, time: 250.73
# Step 251, Crack depth: 0.601753, time: 251.23
# Step 251, Crack depth: 0.601755, time: 251.73
# Step 252, Crack depth: 0.601757, time: 252.23
# Step 252, Crack depth: 0.601759, time: 252.73
# Step 253, Crack depth: 0.601761, time: 253.23
# Step 253, Crack depth: 0.601763, time: 253.73
# Step 254, Crack depth: 0.601766, time: 254.23
# Step 254, Crack depth: 0.601768, time: 254.73
# Step 255, Crack depth: 0.60177, time: 255.23
# Step 255, Crack depth: 0.601772, time: 255.73
# Step 256, Crack depth: 0.601775, time: 256.23
# Step 256, Crack depth: 0.601777, time: 256.73
# Step 257, Crack depth: 0.601779, time: 257.23
# Step 257, Crack depth: 0.601781, time: 257.73
# Step 258, Crack depth: 0.601784, time: 258.23
# Step 258, Crack depth: 0.601786, time: 258.73
# Step 259, Crack depth: 0.601788, time: 259.23
# Step 259, Crack depth: 0.601791, time: 259.73
# Step 260, Crack depth: 0.601793, time: 260.23
# Step 260, Crack depth: 0.601795, time: 260.73
# Step 261, Crack depth: 0.601798, time: 261.23
# Step 261, Crack depth: 0.6018, time: 261.73
# Step 262, Crack depth: 0.601802, time: 262.23
# Step 262, Crack depth: 0.601805, time: 262.73
# Step 263, Crack depth: 0.601807, time: 263.23
# Step 263, Crack depth: 0.60181, time: 263.73
# Step 264, Crack depth: 0.601812, time: 264.23
# Step 264, Crack depth: 0.601815, time: 264.73
# Step 265, Crack depth: 0.601817, time: 265.21
# Step 265, Crack depth: 0.60182, time: 265.66
# Step 266, Crack depth: 0.601822, time: 266.09
# Step 266, Crack depth: 0.601824, time: 266.36
# Step 266, Crack depth: 0.601826, time: 266.62
# Step 266, Crack depth: 0.601828, time: 266.87
# Step 267, Crack depth: 0.601829, time: 267.10
# Step 267, Crack depth: 0.601831, time: 267.32
# Step 267, Crack depth: 0.601832, time: 267.53
# Step 267, Crack depth: 0.601834, time: 267.73
# Step 267, Crack depth: 0.601835, time: 267.92
# Step 268, Crack depth: 0.601837, time: 268.11
# Step 268, Crack depth: 0.601838, time: 268.28
# Step 268, Crack depth: 0.601839, time: 268.44
# Step 268, Crack depth: 0.60184, time: 268.60
# Step 268, Crack depth: 0.601841, time: 268.75
# Step 269, Crack depth: 0.601843, time: 269.07
# Step 269, Crack depth: 0.601846, time: 269.38
# Step 269, Crack depth: 0.625285, time: 269.67
# ...
# Step 307, Crack depth: 0.648921, time: 307.50
# Step 307, Crack depth: 0.648922, time: 308.00
# Step 308, Crack depth: 0.648922, time: 308.50
# Step 308, Crack depth: 0.648923, time: 309.00
# Step 309, Crack depth: 0.648924, time: 309.50
# Step 309, Crack depth: 0.648925, time: 310.00
# Step 310, Crack depth: 0.648926, time: 310.50
# Step 310, Crack depth: 0.648926, time: 311.00
# Step 311, Crack depth: 0.648927, time: 311.50
# Step 311, Crack depth: 0.648928, time: 312.00
# Step 312, Crack depth: 0.648929, time: 312.50
# Step 312, Crack depth: 0.64893, time: 313.00
# Step 313, Crack depth: 0.64893, time: 313.50
# Step 313, Crack depth: 0.648931, time: 314.00
# Step 314, Crack depth: 0.648932, time: 314.50
# Step 314, Crack depth: 0.648933, time: 315.00
# Step 315, Crack depth: 0.648934, time: 315.50
# Step 315, Crack depth: 0.648935, time: 316.00
# Step 316, Crack depth: 0.648935, time: 316.50
# Step 316, Crack depth: 0.648936, time: 317.00
# Step 317, Crack depth: 0.648937, time: 317.50
# Step 317, Crack depth: 0.648938, time: 318.00
# Step 318, Crack depth: 0.648939, time: 318.50
# Step 318, Crack depth: 0.64894, time: 319.00
# Step 319, Crack depth: 0.648941, time: 319.50
# Step 319, Crack depth: 0.648942, time: 320.00
# Step 320, Crack depth: 0.648942, time: 320.50
# Step 320, Crack depth: 0.648943, time: 321.00
# Step 321, Crack depth: 0.648944, time: 321.50
# Step 321, Crack depth: 0.648945, time: 322.00
# Step 322, Crack depth: 0.648946, time: 322.50
# Step 322, Crack depth: 0.648947, time: 323.00
# Step 323, Crack depth: 0.648948, time: 323.50
# Step 323, Crack depth: 0.648949, time: 324.00
# Step 324, Crack depth: 0.64895, time: 324.50
# Step 324, Crack depth: 0.648951, time: 325.00
# Step 325, Crack depth: 0.648952, time: 325.50
# Step 325, Crack depth: 0.648953, time: 326.00
# Step 326, Crack depth: 0.648954, time: 326.50
# Step 326, Crack depth: 0.648955, time: 327.00
# Step 327, Crack depth: 0.648956, time: 327.50
# Step 327, Crack depth: 0.648957, time: 328.00
# Step 328, Crack depth: 0.648958, time: 328.50
# Step 328, Crack depth: 0.648959, time: 329.00
# Step 329, Crack depth: 0.64896, time: 329.50
# Step 329, Crack depth: 0.648961, time: 330.00
# Step 330, Crack depth: 0.648962, time: 330.50
# Step 330, Crack depth: 0.648963, time: 331.00
# Step 331, Crack depth: 0.648964, time: 331.50
# Step 331, Crack depth: 0.648965, time: 332.00
# Step 332, Crack depth: 0.648966, time: 332.50
# Step 332, Crack depth: 0.648968, time: 333.00
# Step 333, Crack depth: 0.648969, time: 333.50
# Step 333, Crack depth: 0.64897, time: 334.00
# Step 334, Crack depth: 0.648971, time: 334.50
# Step 334, Crack depth: 0.648972, time: 335.00
# Step 335, Crack depth: 0.648973, time: 335.50
# Step 335, Crack depth: 0.648975, time: 336.00
# Step 336, Crack depth: 0.648976, time: 336.50
# Step 336, Crack depth: 0.648977, time: 337.00
# Step 337, Crack depth: 0.648978, time: 337.50
# Step 337, Crack depth: 0.648979, time: 338.00
# Step 338, Crack depth: 0.648981, time: 338.50
# Step 338, Crack depth: 0.648983, time: 339.00
# Step 339, Crack depth: 0.648984, time: 339.50
# Step 339, Crack depth: 0.648986, time: 340.00
# Step 340, Crack depth: 0.648988, time: 340.50
# Step 340, Crack depth: 0.648989, time: 340.97
# Step 341, Crack depth: 0.648991, time: 341.43
# Step 341, Crack depth: 0.648993, time: 341.87
# Step 342, Crack depth: 0.648994, time: 342.29
# Step 342, Crack depth: 0.648996, time: 342.69
# Step 343, Crack depth: 0.648997, time: 343.08
# Step 343, Crack depth: 0.648999, time: 343.45
# Step 343, Crack depth: 0.649, time: 343.81
# Step 344, Crack depth: 0.649002, time: 344.31
# Step 344, Crack depth: 0.649005, time: 344.81
# Step 345, Crack depth: 0.649009, time: 345.31
# Step 345, Crack depth: 0.649012, time: 345.81
# Step 346, Crack depth: 0.649015, time: 346.31
# Step 346, Crack depth: 0.672534, time: 346.81
# Step 347, Crack depth: 0.672532, time: 347.31
# Step 347, Crack depth: 0.672533, time: 347.81
# Step 348, Crack depth: 0.672533, time: 348.31
# Step 348, Crack depth: 0.672533, time: 348.81
# Step 349, Crack depth: 0.672533, time: 349.31
# Step 349, Crack depth: 0.672534, time: 349.81
# Step 350, Crack depth: 0.672534, time: 350.31
# Step 350, Crack depth: 0.672534, time: 350.81
# Step 351, Crack depth: 0.672534, time: 351.31
# Step 351, Crack depth: 0.672535, time: 351.81
# Step 352, Crack depth: 0.672535, time: 352.31
# Step 352, Crack depth: 0.672535, time: 352.81
# Step 353, Crack depth: 0.672536, time: 353.31
# Step 353, Crack depth: 0.672536, time: 353.81
# Step 354, Crack depth: 0.672536, time: 354.31
# Step 354, Crack depth: 0.672536, time: 354.81
# Step 355, Crack depth: 0.672537, time: 355.31
# Step 355, Crack depth: 0.672537, time: 355.81
# Step 356, Crack depth: 0.672537, time: 356.31
# Step 356, Crack depth: 0.672538, time: 356.81
# Step 357, Crack depth: 0.672538, time: 357.31
# Step 357, Crack depth: 0.672538, time: 357.81
# Step 358, Crack depth: 0.672539, time: 358.31
# Step 358, Crack depth: 0.672539, time: 358.81
# Step 359, Crack depth: 0.672539, time: 359.31
# Step 359, Crack depth: 0.67254, time: 359.81
# Step 360, Crack depth: 0.67254, time: 360.31
# Step 360, Crack depth: 0.67254, time: 360.81
# Step 361, Crack depth: 0.672541, time: 361.31
# Step 361, Crack depth: 0.672541, time: 361.81
# Step 362, Crack depth: 0.672541, time: 362.31
# Step 362, Crack depth: 0.672542, time: 362.81
# Step 363, Crack depth: 0.672542, time: 363.31
# Step 363, Crack depth: 0.672542, time: 363.81
# Step 364, Crack depth: 0.672543, time: 364.31
# Step 364, Crack depth: 0.672543, time: 364.81
# Step 365, Crack depth: 0.672543, time: 365.31
# Step 365, Crack depth: 0.672544, time: 365.81
# Step 366, Crack depth: 0.672544, time: 366.31
# Step 366, Crack depth: 0.672544, time: 366.81
# Step 367, Crack depth: 0.672545, time: 367.31
# Step 367, Crack depth: 0.672545, time: 367.81
# Step 368, Crack depth: 0.672546, time: 368.31
# Step 368, Crack depth: 0.672546, time: 368.81
# Step 369, Crack depth: 0.672546, time: 369.31
# Step 369, Crack depth: 0.672547, time: 369.81
# Step 370, Crack depth: 0.672547, time: 370.31
# Step 370, Crack depth: 0.672547, time: 370.81
# Step 371, Crack depth: 0.672548, time: 371.31
# Step 371, Crack depth: 0.672548, time: 371.81
# Step 372, Crack depth: 0.672549, time: 372.31
# Step 372, Crack depth: 0.672549, time: 372.81
# Step 373, Crack depth: 0.672549, time: 373.31
# Step 373, Crack depth: 0.67255, time: 373.81
# Step 374, Crack depth: 0.67255, time: 374.31
# Step 374, Crack depth: 0.672551, time: 374.81
# Step 375, Crack depth: 0.672551, time: 375.31
# Step 375, Crack depth: 0.672552, time: 375.81
# Step 376, Crack depth: 0.672552, time: 376.31
# Step 376, Crack depth: 0.672552, time: 376.81
# Step 377, Crack depth: 0.672553, time: 377.31
# Step 377, Crack depth: 0.672553, time: 377.81
# Step 378, Crack depth: 0.672554, time: 378.31
# Step 378, Crack depth: 0.672554, time: 378.81
# Step 379, Crack depth: 0.672555, time: 379.31
# Step 379, Crack depth: 0.672555, time: 379.81
# Step 380, Crack depth: 0.672556, time: 380.31
# Step 380, Crack depth: 0.672556, time: 380.81
# Step 381, Crack depth: 0.672557, time: 381.31
# Step 381, Crack depth: 0.672557, time: 381.81
# Step 382, Crack depth: 0.672558, time: 382.31
# Step 382, Crack depth: 0.672558, time: 382.81
# Step 383, Crack depth: 0.672559, time: 383.31
# Step 383, Crack depth: 0.672559, time: 383.81
# Step 384, Crack depth: 0.67256, time: 384.31
# Step 384, Crack depth: 0.67256, time: 384.81
# Step 385, Crack depth: 0.672561, time: 385.31
# Step 385, Crack depth: 0.672561, time: 385.81
# Step 386, Crack depth: 0.672562, time: 386.31
# Step 386, Crack depth: 0.672562, time: 386.81
# Step 387, Crack depth: 0.672563, time: 387.31
# Step 387, Crack depth: 0.672563, time: 387.81
# Step 388, Crack depth: 0.672564, time: 388.31
# Step 388, Crack depth: 0.672564, time: 388.81
# Step 389, Crack depth: 0.672565, time: 389.31
# Step 389, Crack depth: 0.672566, time: 389.81
# Step 390, Crack depth: 0.672566, time: 390.31
# Step 390, Crack depth: 0.672567, time: 390.81
# Step 391, Crack depth: 0.672567, time: 391.31
# Step 391, Crack depth: 0.672568, time: 391.81
# Step 392, Crack depth: 0.672569, time: 392.31
# Step 392, Crack depth: 0.67257, time: 392.81
# Step 393, Crack depth: 0.672571, time: 393.31
# Step 393, Crack depth: 0.672572, time: 393.81
# Step 394, Crack depth: 0.672573, time: 394.31
# Step 394, Crack depth: 0.672574, time: 394.81
# Step 395, Crack depth: 0.672575, time: 395.31
# Step 395, Crack depth: 0.672576, time: 395.81
# Step 396, Crack depth: 0.672577, time: 396.31
# Step 396, Crack depth: 0.672578, time: 396.81
# Step 397, Crack depth: 0.672579, time: 397.31
# Step 397, Crack depth: 0.67258, time: 397.81
# Step 398, Crack depth: 0.672581, time: 398.31
# Step 398, Crack depth: 0.672582, time: 398.81
# Step 399, Crack depth: 0.672583, time: 399.31
# Step 399, Crack depth: 0.672584, time: 399.81
# Step 400, Crack depth: 0.672586, time: 400.31
# Step 400, Crack depth: 0.672587, time: 400.81
# Step 401, Crack depth: 0.672588, time: 401.31
# Step 401, Crack depth: 0.672589, time: 401.81
# Step 402, Crack depth: 0.672592, time: 402.31
# Step 402, Crack depth: 0.672594, time: 402.81
# Step 403, Crack depth: 0.672596, time: 403.31
# Step 403, Crack depth: 0.672599, time: 403.81
# Step 404, Crack depth: 0.672601, time: 404.31
# Step 404, Crack depth: 0.672604, time: 404.81
# Step 405, Crack depth: 0.672606, time: 405.31
# Step 405, Crack depth: 0.672609, time: 405.81
# Step 406, Crack depth: 0.672611, time: 406.31
# Step 406, Crack depth: 0.672614, time: 406.81
# Step 407, Crack depth: 0.696079, time: 407.31
# Step 407, Crack depth: 0.696078, time: 407.81
# Step 408, Crack depth: 0.696077, time: 408.31
# Step 408, Crack depth: 0.696077, time: 408.81
# Step 409, Crack depth: 0.696077, time: 409.31
# Step 409, Crack depth: 0.696077, time: 409.81
# Step 410, Crack depth: 0.696076, time: 410.31
# Step 410, Crack depth: 0.696076, time: 410.81
# Step 411, Crack depth: 0.696076, time: 411.31
# Step 411, Crack depth: 0.696076, time: 411.81
# Step 412, Crack depth: 0.696075, time: 412.31
# Step 412, Crack depth: 0.696075, time: 412.81
# Step 413, Crack depth: 0.696075, time: 413.31
# Step 413, Crack depth: 0.696075, time: 413.81
# Step 414, Crack depth: 0.696074, time: 414.31
# Step 414, Crack depth: 0.696074, time: 414.81
# Step 415, Crack depth: 0.696074, time: 415.31
# Step 415, Crack depth: 0.696074, time: 415.81
# Step 416, Crack depth: 0.696073, time: 416.31
# Step 416, Crack depth: 0.696073, time: 416.81
# Step 417, Crack depth: 0.696073, time: 417.31
# Step 417, Crack depth: 0.696073, time: 417.81
# Step 418, Crack depth: 0.696072, time: 418.31
# Step 418, Crack depth: 0.696072, time: 418.81
# Step 419, Crack depth: 0.696072, time: 419.31
# Step 419, Crack depth: 0.696072, time: 419.81
# Step 420, Crack depth: 0.696072, time: 420.31
# Step 420, Crack depth: 0.696071, time: 420.81
# Step 421, Crack depth: 0.696071, time: 421.31
# Step 421, Crack depth: 0.696071, time: 421.81
# Step 422, Crack depth: 0.696071, time: 422.31
# Step 422, Crack depth: 0.69607, time: 422.81
# Step 423, Crack depth: 0.69607, time: 423.31
# Step 423, Crack depth: 0.69607, time: 423.81
# Step 424, Crack depth: 0.69607, time: 424.31
# Step 424, Crack depth: 0.69607, time: 424.81
# Step 425, Crack depth: 0.696069, time: 425.31
# Step 425, Crack depth: 0.696069, time: 425.81
# Step 426, Crack depth: 0.696069, time: 426.31
# Step 426, Crack depth: 0.696069, time: 426.81
# Step 427, Crack depth: 0.696069, time: 427.31
# Step 427, Crack depth: 0.696068, time: 427.81
# Step 428, Crack depth: 0.696068, time: 428.31
# Step 428, Crack depth: 0.696068, time: 428.81
# Step 429, Crack depth: 0.696068, time: 429.31
# Step 429, Crack depth: 0.696068, time: 429.81
# Step 430, Crack depth: 0.696067, time: 430.31
# Step 430, Crack depth: 0.696067, time: 430.81
# Step 431, Crack depth: 0.696067, time: 431.31
# Step 431, Crack depth: 0.696067, time: 431.81
# Step 432, Crack depth: 0.696067, time: 432.31
# Step 432, Crack depth: 0.696067, time: 432.81
# Step 433, Crack depth: 0.696066, time: 433.31
# Step 433, Crack depth: 0.696066, time: 433.81
# Step 434, Crack depth: 0.696066, time: 434.31
# Step 434, Crack depth: 0.696066, time: 434.81
# Step 435, Crack depth: 0.696066, time: 435.31
# Step 435, Crack depth: 0.696066, time: 435.81
# Step 436, Crack depth: 0.696065, time: 436.31
# Step 436, Crack depth: 0.696065, time: 436.81
# Step 437, Crack depth: 0.696065, time: 437.31
# Step 437, Crack depth: 0.696065, time: 437.81
# Step 438, Crack depth: 0.696065, time: 438.31
# Step 438, Crack depth: 0.696065, time: 438.81
# Step 439, Crack depth: 0.696064, time: 439.31
# Step 439, Crack depth: 0.696064, time: 439.81
# Step 440, Crack depth: 0.696064, time: 440.31
# Step 440, Crack depth: 0.696064, time: 440.81
# Step 441, Crack depth: 0.696064, time: 441.31
# Step 441, Crack depth: 0.696064, time: 441.81
# Step 442, Crack depth: 0.696064, time: 442.31
# Step 442, Crack depth: 0.696063, time: 442.81
# Step 443, Crack depth: 0.696063, time: 443.31
# Step 443, Crack depth: 0.696063, time: 443.81
# Step 444, Crack depth: 0.696063, time: 444.31
# Step 444, Crack depth: 0.696063, time: 444.81
# Step 445, Crack depth: 0.696063, time: 445.31
# Step 445, Crack depth: 0.696063, time: 445.81
# Step 446, Crack depth: 0.696062, time: 446.31
# Step 446, Crack depth: 0.696062, time: 446.81
# Step 447, Crack depth: 0.696062, time: 447.31
# Step 447, Crack depth: 0.696062, time: 447.81
# Step 448, Crack depth: 0.696062, time: 448.31
# Step 448, Crack depth: 0.696062, time: 448.81
# Step 449, Crack depth: 0.696062, time: 449.31
# Step 449, Crack depth: 0.696062, time: 449.81
# Step 450, Crack depth: 0.696061, time: 450.31
# Step 450, Crack depth: 0.696061, time: 450.81
# Step 451, Crack depth: 0.696061, time: 451.31
# Step 451, Crack depth: 0.696061, time: 451.81
# Step 452, Crack depth: 0.696061, time: 452.31
# Step 452, Crack depth: 0.696061, time: 452.81
# Step 453, Crack depth: 0.696061, time: 453.31
# Step 453, Crack depth: 0.696061, time: 453.81
# Step 454, Crack depth: 0.696061, time: 454.31
# Step 454, Crack depth: 0.69606, time: 454.81
# Step 455, Crack depth: 0.69606, time: 455.31
# Step 455, Crack depth: 0.69606, time: 455.81
# Step 456, Crack depth: 0.69606, time: 456.31
# Step 456, Crack depth: 0.69606, time: 456.81
# Step 457, Crack depth: 0.69606, time: 457.31
# Step 457, Crack depth: 0.69606, time: 457.81
# Step 458, Crack depth: 0.69606, time: 458.31
# Step 458, Crack depth: 0.69606, time: 458.81
# Step 459, Crack depth: 0.69606, time: 459.31
# Step 459, Crack depth: 0.69606, time: 459.81
# Step 460, Crack depth: 0.69606, time: 460.31
# Step 460, Crack depth: 0.69606, time: 460.81
# Step 461, Crack depth: 0.69606, time: 461.31
# Step 461, Crack depth: 0.69606, time: 461.81
# Step 462, Crack depth: 0.69606, time: 462.31
# Step 462, Crack depth: 0.696061, time: 462.81
# Step 463, Crack depth: 0.696061, time: 463.31
# Step 463, Crack depth: 0.696061, time: 463.81
# Step 464, Crack depth: 0.696061, time: 464.31
# Step 464, Crack depth: 0.696061, time: 464.81
# Step 465, Crack depth: 0.696062, time: 465.31
# Step 465, Crack depth: 0.696062, time: 465.81
# Step 466, Crack depth: 0.696062, time: 466.31
# Step 466, Crack depth: 0.696062, time: 466.81
# Step 467, Crack depth: 0.696062, time: 467.31
# Step 467, Crack depth: 0.696063, time: 467.81
# Step 468, Crack depth: 0.696063, time: 468.31
# Step 468, Crack depth: 0.696063, time: 468.81
# Step 469, Crack depth: 0.696063, time: 469.31
# Step 469, Crack depth: 0.696064, time: 469.81
# Step 470, Crack depth: 0.696064, time: 470.31
# Step 470, Crack depth: 0.696064, time: 470.81
# Step 471, Crack depth: 0.696065, time: 471.31
# Step 471, Crack depth: 0.696065, time: 471.81
# Step 472, Crack depth: 0.696065, time: 472.31
# Step 472, Crack depth: 0.696066, time: 472.81
# Step 473, Crack depth: 0.696066, time: 473.31
# Step 473, Crack depth: 0.696066, time: 473.81
# Step 474, Crack depth: 0.696067, time: 474.31
# Step 474, Crack depth: 0.696067, time: 474.81
# Step 475, Crack depth: 0.696067, time: 475.31
# Step 475, Crack depth: 0.696068, time: 475.81
# Step 476, Crack depth: 0.696068, time: 476.31
# Step 476, Crack depth: 0.696068, time: 476.81
# Step 477, Crack depth: 0.696069, time: 477.31
# Step 477, Crack depth: 0.696069, time: 477.81
# Step 478, Crack depth: 0.696069, time: 478.31
# Step 478, Crack depth: 0.69607, time: 478.81
# Step 479, Crack depth: 0.69607, time: 479.31
# Step 479, Crack depth: 0.696071, time: 479.81
# Step 480, Crack depth: 0.696071, time: 480.31

# %%
X1x, X2x = S1.tabulate_dof_coordinates().reshape((-1, nd)).T
plt.figure(figsize=(20, 5))
tem = dmg.vector().get_local()
plt.ylim(0, H - (H % 25) + 50)
plt.xlim(0, L - (L % 25) + 50)
plots = plt.tricontourf(X1x, X2x, tem, 360, cmap=rainbow )
# plots = plot(dmg)

x1, x2 = mesh.coordinates().T
tri = np.asarray([cell.entities(0) for cell in cells(mesh)])
plt.triplot(x1, x2, tri, "k-", alpha=0.5, lw=0.75)
# plt.axes().set_aspect("equal")
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size=0.25, pad=0.5)
# cbar = plt.colorbar(plots, ticks=ct, cax=cax)
# cbar.ax.tick_params(labelsize=tick_fs)
# plt.tight_layout()
plt.colorbar(plots)
plt.savefig('S1-Dmg.jpg', dpi=300)

# %%
tem = dmg.vector().get_local()

# %%
plot(dmg)

# %%
len(tem)
# Out:
# 3422

# %%
len(X1x)
# Out:
# 3422

# %%
len(X2x)
# Out:
# 3422

# %%
X1x, X2x = S2.tabulate_dof_coordinates().reshape((-1, nd)).T

plt.figure(figsize=(20, 5))
# tem = dmg.vector().get_local()
plt.ylim(0, H - (H % 25) + 50)
plt.xlim(0, L - (L % 25) + 50)
plots = plt.tricontourf(X1x, X2x, dmg)
# plots = plot(dmg)

# x1, x2 = mesh.coordinates().T
# tri = np.asarray([cell.entities(0) for cell in cells(mesh)])
# plt.triplot(x1, x2, tri, "k-", alpha=0.5, lw=0.75)
# # plt.axes().set_aspect("equal")
# # divider = make_axes_locatable(ax)
# # cax = divider.append_axes("right", size=0.25, pad=0.5)
# # cbar = plt.colorbar(plots, ticks=ct, cax=cax)
# # cbar.ax.tick_params(labelsize=tick_fs)
# # plt.tight_layout()
plt.colorbar(plots)
plt.savefig('s11_hw_00.jpg', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-45a5ce6b0daf> in <module>
#       5 plt.ylim(0, H - (H % 25) + 50)
#       6 plt.xlim(0, L - (L % 25) + 50)
# ----> 7 plots = plt.tricontourf(X1x, X2x, dmg)
#       8 # plots = plot(dmg)
#       9
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in tricontourf(*args, **kwargs)
#    2992 @_autogen_docstring(Axes.tricontourf)
#    2993 def tricontourf(*args, **kwargs):
# -> 2994     __ret = gca().tricontourf(*args, **kwargs)
#    2995     if __ret._A is not None: sci(__ret)  # noqa
#    2996     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in tricontourf(self, *args, **kwargs)
#    8101
#    8102     def tricontourf(self, *args, **kwargs):
# -> 8103         return mtri.tricontourf(self, *args, **kwargs)
#    8104     tricontourf.__doc__ = mtri.tricontour.__doc__
#    8105
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/tri/tricontour.py in tricontourf(ax, *args, **kwargs)
#     270 def tricontourf(ax, *args, **kwargs):
#     271     kwargs['filled'] = True
# --> 272     return TriContourSet(ax, *args, **kwargs)
#     273
#     274
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/tri/tricontour.py in __init__(self, ax, *args, **kwargs)
#      34         are described in the docstring of `tricontour`.
#      35         """
# ---> 36         ContourSet.__init__(self, ax, *args, **kwargs)
#      37
#      38     def _process_args(self, *args, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     885         self._transform = kwargs.pop('transform', None)
#     886
# --> 887         kwargs = self._process_args(*args, **kwargs)
#     888         self._process_levels()
#     889
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/tri/tricontour.py in _process_args(self, *args, **kwargs)
#      45                 self.levels = args[0].levels
#      46         else:
# ---> 47             tri, z = self._contour_args(args, kwargs)
#      48             C = _tri.TriContourGenerator(tri.get_cpp_triangulation(), z)
#      49             self._mins = [tri.x.min(), tri.y.min()]
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/tri/tricontour.py in _contour_args(self, args, kwargs)
#      82         z = np.asarray(args[0])
#      83         if z.shape != tri.x.shape:
# ---> 84             raise ValueError('z array must have same length as triangulation x'
#      85                              ' and y arrays')
#      86         self.zmax = z.max()
#
# ValueError: z array must have same length as triangulation x and y arrays

# %%
project(u, V, form_compiler_parameters={"quadrature_degree": 3})

# %%
t11 = project(tau[0, 0], SQ,form_compiler_parameters={"quadrature_degree": 2})

# %%
plt.figure(figsize=(20, 5))
# tem = dmg.vector().array()
plot = plt.tricontourf(XQ1, XQ2, s11, 360, cmap=rainbow)
plt.colorbar(plot)
# plt.savefig('s11_hw_00.jpg', dpi=300)

# %%
plt.figure(figsize=(20, 5))
# tem = dmg.vector().array()
plot = plt.tricontourf(XQ1, XQ2, dmgc, 360, cmap=rainbow)
plt.colorbar(plot)
# plt.savefig('s11_hw_00.jpg', dpi=300)
