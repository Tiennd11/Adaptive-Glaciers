# %%
import ufl
import matplotlib.pyplot as plt
import time
import numpy as np
from dolfin import *
import matplotlib.tri as tri
import warnings
from matplotlib import cm
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# suppress FEniCS output to terminal
set_log_active(False)


# output directory
output_dir = ""


comm = MPI.comm_world  # MPI communications
rank = comm.Get_rank()  # number of current process
size = comm.Get_size()  # total number of processes

# %%
# mesh = Mesh("mesh/notch.xml")

# %%
mesh = Mesh()
with XDMFFile(comm, "mesh/Mesh_x.xdmf") as infile:
    infile.read(mesh)

# %%
# Step 4: Define the xdmf file for writing
xdmf = XDMFFile("3ddata.xdmf")
xdmf.parameters["flush_output"] = True
xdmf.parameters["rewrite_function_mesh"] = True
xdmf.parameters["functions_share_mesh"] = True

# %%
# xdmf = XDMFFile(comm, "output/results.xdmf")
# xdmf.parameters["flush_output"] = True
# xdmf.parameters["functions_share_mesh"] = True
# xdmf.write(mesh)

# %%
# Plot the mesh
plot(mesh,title='Mesh')
plt.show()

# %%
mesh

# %%
# # Plot the mesh
# plot(mesh,title='Mesh')
# plt.show()

# %%
nd = mesh.geometry().dim()  # mesh dimensions (2D or 3D)

# %%
mesh.num_vertices()
# Out:
# 3611

# %%
# Calculate minimum mesh size
min_mesh_size = mesh.hmin()
# Print the minimum mesh size
print("Minimum mesh size:", min_mesh_size)
# Out:
# Minimum mesh size: 2.633498603971342

# %%
"""Material parameters."""

rho_ice = 917  # density of ice (kg/m^3)
rho_H2O = 1020  # density of seawater (kg/m^3)
grav = 9.81  # gravity acceleration (m/s**2)
temp = -10 + 273  # temperature (K)
B0 = 2.207e-3  # viscosity coefficient (kPa * yr**(1/3))
B0 *= 1e3  # convert to (Pa * yr**(1/3))
B0 *= (365*24)**(1/3)  # convert to (Pa * hour**(1/3))
BT = B0*np.exp(3155/temp - 0.16612/(273.39 - temp)**1.17)

# %%
"""Damage parameters."""

alpha = 0.21  # weight of max principal stress  in Hayhurst criterion
beta = 0.63  # weight of von Mises stress in Hayhurst criterion
r = 0.43  # damage exponent
B = 5.232e-7  # damage coefficient
k1, k2 = -2.63, 7.24  # damage rate dependency parameters
Dcr = 0.6  # critical damage
Dmax = 0.99  # maximum damage
lc = 10  # nonlocal length scale
# prec_ratio = 0.08
hs_ratio = 0 # water level in crevasse (normalized with crevasse height)
hw_ratio = 0 # water level at right terminus (normalized with glacier thickness)
prec_ratio = 0.08 # depth of pre-crack (

# %%
"""Set simulation time and timestepping options."""

t_total = 480  # total time (hours)
t_elapsed = 0  # current elapsed time (hours)
t_delay_dmg = 0  # delay damage (hours)
max_Delta_t = 0.5  # max time increment (hours)
max_Delta_D = 0.1  # max damage increment
output_increment = 10  # number of steps between output
time_counter = 0  # current time step

# %%
"""Mesh details."""
# L, H = 500, 125  # domain dimensions
hs = 0  # water level in crevasse (normalized with crevasse height)
hw = 0  # water level at terminus (absolute height)
# mesh = load_mesh(output_dir + "mesh/hdf5/notch.h5")
# nd = mesh.geometry().dim()  # mesh dimensions (2D or 3D)

# %%
"""Define function spaces."""
S1 = FunctionSpace(mesh, "CG", 1)  # first order scalar space
S2 = FunctionSpace(mesh, "CG", 2)  # second order scalar space
V1 = VectorFunctionSpace(mesh, "CG", 1)  # first order vector space
V2 = VectorFunctionSpace(mesh, "CG", 2)  # second order vector space
P1 = FiniteElement("CG", mesh.ufl_cell(), 1)  # first order scalar element
P2 = VectorElement("CG", mesh.ufl_cell(), 2)  # second order vector element
V = FunctionSpace(mesh, MixedElement([P2, P1]))  # mixed finite element

# %%
"""Quadrature elements and function spaces."""

# deg_quad = 2
# scalar_quad = FiniteElement("Quadrature", cell=mesh.ufl_cell(),
#                             degree=deg_quad, quad_scheme="default")
# vector_quad = VectorElement("Quadrature", cell=mesh.ufl_cell(),
#                             degree=deg_quad, quad_scheme="default")
# SQ = FunctionSpace(mesh, scalar_quad)  # quadrature points in scalar space
# VQ = FunctionSpace(mesh, vector_quad)  # quadrature points in vector space
# form_params = {"quadrature_degree": deg_quad}


"""Coordinates of nodes on initial mesh configuration."""

X1, X2 = S1.tabulate_dof_coordinates().reshape((-1, nd)).T  # coordinates
n_local = len(X1)  # number of coordinates on local process
n_global = S1.dim()  # number of coordinates in global system

# %%
L,H= max(X1),max(X2)

# %%
L
# Out:
# 500.0

# %%
H
# Out:
# 125.0

# %%
def mwrite(filename, my_list):
    MPI.barrier(comm)
    if rank == 0:
        with open(filename, "w") as f:
            for item in my_list:
                f.write("%s" % item)


def mprint(*argv):
    if rank == 0:
        out = ""
        for arg in argv:
            out = out + str(arg)
        # this forces program to output when run in parallel
        print(out, flush=True)

# %%
mprint("Number of vertices      : {}".format(S1.dim()))
mprint("Number of cells         : {}".format(V1.dim()))
mprint("Number of DoF           : {}".format(V1.dim()))
mprint("Number of processes     : {}".format(size))
mprint("Number of DoF/process   : {}".format(int(V.dim() / size)))
mprint("-----------------------------------------------------")
# Out:
# Number of vertices      : 3611
# Number of cells         : 7222
# Number of DoF           : 7222
# Number of processes     : 1
# Number of DoF/process   : 31929
# -----------------------------------------------------

# %%
class left_edge(SubDomain):
    """Boundary on the left domain edge."""
    def inside(self, x, on_boundary): return near(x[0], 0) and on_boundary


class right_edge(SubDomain):
    """Boundary on the right domain edge."""
    def inside(self, x, on_boundary): return near(x[0], L) and on_boundary


class bottom_edge(SubDomain):
    """Boundary on the bottom domain edge."""
    def inside(self, x, on_boundary): return near(x[1], 0) and on_boundary


class top_edge(SubDomain):
    """Boundary on the top domain edge."""
    def inside(self, x, on_boundary): return near(x[1], H) and on_boundary


""" Define boundaries and boundary conditions. """

left = left_edge()
right = right_edge()
bottom = bottom_edge()
top = top_edge()

boundaries = MeshFunction("size_t", mesh, mesh.topology().dim() - 1)
left.mark(boundaries, 1)
right.mark(boundaries, 2)
bottom.mark(boundaries, 3)
top.mark(boundaries, 4)
ds = Measure("ds", subdomain_data=boundaries)

free_slip_left = DirichletBC(V.sub(0).sub(0), Constant(0), left)
free_slip_bottom = DirichletBC(V.sub(0).sub(1), Constant(0), bottom)
BC = [free_slip_left, free_slip_bottom]

# %%
"""define functions that are required to solve the problem"""

def bodyforce(dmg, y, h=0):
    """Gravity loading as a body force. Fully failed points have
        no density unless they are filled with water. Then they
        have the same density as water.
    """
    Dcr = 0.6
    b = Function(V1)  # body force as vector function
    by = Function(S1)  # y-component of vector function
    for i in range(n_local):
        if dmg.vector()[i] < Dcr:
            by.vector()[i] = -rho_ice*grav
        if (dmg.vector()[i] >= Dcr)*(y[i] <= h):
            by.vector()[i] = -rho_H2O*grav
    assign(b.sub(1), by)
    return b

def hydrostatic(h):
    h_expression = Expression(("(h - x[1] > 0 ?-rho_H2O * grav*(h - x[1]) : 0)",0), h=hw, rho_H2O=rho_H2O, grav=grav, degree=1)
    return h_expression

def pore_pressure(dmg, x, y, h):
	"""Hydraulic pressure from poro-mechanics formulation."""
	Dcr = 0.6
	b_poro = Function(S1)
	dmg_local = dmg.vector().get_local()
	for i in range(n_local):
		if dmg_local[i] >= Dcr:
			b_poro.vector()[i] = rho_H2O*grav*np.fmax(h - y[i], 0)*dmg_local[i]
	return b_poro


def surface_crevasse_level(dmg, y, hsr, pr):
    """dynamically compute water level in the surface crevasse"""
    crevasse_depth = 0
    crevasse_surface = 0
    if hsr > 0:
        for i in range(n_local):  # Fix: Use 'range' and correct the syntax
            if dmg.vector()[i] > Dcr:
                x2_dmg = y[i]
                if len(x2_dmg) > 0:
                    x2_dmg_local_max = min(max(x2_dmg), H)
                    x2_dmg_local_min = max(min(x2_dmg), 0)
                else:
                    x2_dmg_local_max = H
                    x2_dmg_local_min = 0
                x2_dmg_max = comm.allreduce(x2_dmg_local_max, op=MPI.MAX)
                x2_dmg_min = comm.allreduce(x2_dmg_local_min, op=MPI.MIN)
                crevasse_depth = float(x2_dmg_max - x2_dmg_min)
                crevasse_surface = crevasse_depth * hsr + x2_dmg_min
    return crevasse_depth, crevasse_surface

# %%
"""Define constitutive and kinematic relationships."""


def D(u):
    """Symmetric gradient operator."""
    return sym(nabla_grad(u))


def DII(u):
    """Second strain invariant."""
    return (0.5*(D(u)[0, 0]**2 + D(u)[1, 1]**2) + D(u)[0, 1]**2)


def eta1(u, n=3, gam=1e-14):
    """Nonlinear viscosity."""
    return 0.5*BT*(DII(u) + gam)**((1 - n)/2/n)

def c_bar(dmg=None):
    """Implicit gradient damage constant term."""
    c = Function(S1)
#     dmg_local = dmg.vector().get_local()
    if dmg:
        for i in range(n_local):
            if dmg.vector()[i] < Dcr:
                c.vector()[i] = 0.5*(lc**2)
    else:
        c.vector()[:] = 0.5*(lc**2)
    return c


def update_psi(dmg):
    """Function for enforcing incompressibility."""
    psi = Function(S1)
    psi.vector()[:] = 1
    for i in range(n_local):
    #failed_points = dmg.vector()[:] > Dcr  # failed material points
        if dmg.vector()[i] > Dcr:
            psi.vector()[i] = 1e-32
#     psi.vector()[failed_points] = 1e-32
    return psi


def np_array(x):
    """converts x in to a vector format computed at the nodes"""
    return x.vector().get_local()


def mac(x):
    """Macaulay's bracket"""
    return (x+abs(x))/2

# %%
"Define damage function."""

dmg = Function(S1)
# deg = Function(S2)

# dmg.vector()[(L/2 - 2*lc < XQ1)*(XQ1 < L/2 + 2*lc)*(H*(1-0.08) < XQ2)] = Dmax
# # dmg.vector()[(L/2 - 5 < X1)*(X1 < L/2 + 5)*(H - 10 < X2)] = Dmax

"""define pre-crack zone"""
# for i in range(n_local):
#     if ((L - lc)/2 < X1[i])*(X1[i] < (L + lc)/2)*(X2[i] > H*(1 - 0.08)):
#         dmg.vector()[i] = Dmax
#     else:
#         dmg.vector()[i] = 0
# Out:
# 'define pre-crack zone'

# %%
jet = cm.jet
rainbow = cm.rainbow
redblue = cm.coolwarm
viridis = cm.viridis
plasma = cm.plasma
magma = cm.magma

# %%
plot(dmg)

# %%
"""Initial guess for Picard iterations."""

uk = Function(V2)  # velocity
pk = Function(S1)  # pressure


comm.Barrier()

# %%
"""define crack tip coordinate"""
cracktip_coor = H*(1-0.08)

# %%
"""Main time loop."""
#t_total t_elapsed
while t_elapsed < t_total:

    time_counter += 1
    # get current configuration coordinates
    x1, x2 = S1.tabulate_dof_coordinates().reshape((-1, nd)).T
    """Extract boundaries."""
    L,H= max(x1),max(x2) 
    n_local = len(x1)  # number of coordinates on local process
    n_global = S1.dim()  # number of coordinates in global system


    u, p = TrialFunctions(V)  # trial functions in (V2, S1) space
    v, q = TestFunctions(V)  # test functions in (V2, S1) space

    # hydraulic pressure in surface crevasse
    cdepth, csurfx2 = surface_crevasse_level(dmg=dmg, y=x2, hsr=hs_ratio, pr=prec_ratio)  # height of water column
    b_poro = pore_pressure(dmg=dmg, x=x1, y=x2, h=csurfx2)  # hydraulic pressure
    # pHD = pore_pressure(dmg=dmg, y=xQ2, h=cs)  # hydraulic pressure


    # define loading terms
    b_grav = bodyforce(dmg=dmg, y=x2, h=csurfx2) # gravity for ice and water
    b_hw = hydrostatic(h=hw)  # terminus pressure

    # normal function to mesh
    nhat = FacetNormal(mesh)

  # incompressibility terms

    penalty = False

    psi = update_psi(dmg)
     ### update degradation function with damage value from previous step

    # define variational form
    LHS = (inner(D(v), 2*(1-dmg)*eta1(uk)*D(u)) - (1-dmg)*div(v)*p
           + psi*q*div(u))*dx
    if penalty:
        LHS += 1e12*inner(nabla_div(u), psi*div(v))*dx  # penalty term
    # RHS = (1-dmg)*inner(v, b_grav)*dx  # ice and water gravity
    RHS = inner(v, b_grav)*dx  # ice and water gravity
#     if hs > 0:
#         RHS += inner(nabla_div(v), b_poro)*dx  # hydraulic pressure in damage zone
#     if hw > 0:
#         RHS += inner(v, b_hw)*ds(2)  # terminus pressure

    """ Picard iterations. """

    eps_local = 1  # local error norm
    eps_global = 1  # global error norm
    tol = 1e-4  # error tolerance
    picard_count = 0  # iteration count
    picard_max = 50  # maximum iterations
    w = Function(V)  # empty function to dump solution

    while (abs(eps_global) > tol) and (picard_count < picard_max):

        # solve the variational form
        solve(LHS == RHS, w, BC)
        u, p = w.split(deepcopy=True)
        u1, u2 = u.split(deepcopy=True)

        # compute error norms
        u1k, u2k = uk.split(deepcopy=True)
        diff1 = u1.vector().get_local() - u1k.vector().get_local()
        diff2 = u2.vector().get_local() - u2k.vector().get_local()
        diffp = p.vector().get_local() - pk.vector().get_local()
        eps1 = np.linalg.norm(diff1)/np.linalg.norm(u1.vector().get_local())
        eps2 = np.linalg.norm(diff2)/np.linalg.norm(u2.vector().get_local())
        epsp = np.linalg.norm(diffp)/np.linalg.norm(p.vector().get_local())

        # update solution for next iteration
        assign(uk, u)
        assign(pk, p)

        comm.Barrier()

        # obtain the max error on the local process
        eps_local = max(eps1, eps2, epsp)
        # obtain the max error on all processes
        eps_global = comm.allreduce(eps_local, op=MPI.max)


        # update iteration count
        picard_count += 1
    # build effective deviatoric stress tensor
    tau = 2*eta1(u)*D(u)
    t11 = project(tau[0, 0], S1).vector().get_local()
    t22 = project(tau[1, 1], S1).vector().get_local()
    t33 = np.zeros(n_local)
    t12 = project(tau[0, 1], S1).vector().get_local()

    dmg0 = dmg.vector().get_local()# damage from previous time step
    prs = interpolate(p, S1).vector().get_local()# effective pressure

    t23 = np.zeros(n_local)

    t13 = np.zeros(n_local)

 
    # effective Cauchy stress
    s11, s22, s33, s12, s23, s13 = t11 - prs, t22 - prs, t33 - prs, t12, t23, t13
    
    I1 = s11 + s22 + s33  # effective I1 invariant
    I1_true = (1 - dmg0)*I1 - 3*b_poro.vector().get_local()  # true I1 invariant
#     I1_true = (1 - dmg0)*I1  # true I1 invariant

    J2 = 0.5*(t11**2 + t22**2 + t33**2) + t12**2  # effective J2 invariant
    vms = np.sqrt(3*J2)  # effective von Mises stress

    lam1 = s33
    lam2 = 0.5*(s11 + s22 + np.sqrt(s11**2 - 2*s11*s22 + 4*(s12**2) + s22**2))
    mps = np.fmax(lam1, lam2)  # effective max principal stress

    # effective Hayhurst stress
    chi = alpha*mps + beta*vms + (1 - alpha - beta)*I1

    
    
    """ Compute the local damage rate and increment. """

    # local damage rate
    dDloc_dt = np.zeros(n_local)
    for i in range(n_local):
        if (I1[i] > 0 and chi[i] > 0 and dmg0[i] < Dcr):
            k = min(k1 + k2*abs(I1_true[i]/1e6), 30)
            dDloc_dt[i] = B*((chi[i]/1e6)**r)/((1 - dmg0[i])**k)

    # select time increment on each local process
    if max(dDloc_dt) > 0:
        Delta_t_local = float(max_Delta_D/max(dDloc_dt))
        Delta_t_local = min(max_Delta_t*3600, Delta_t_local)
    else:
        Delta_t_local = max_Delta_t*3600

    # obtain the minimum time increment from all processes
    comm.Barrier()
    Delta_t = comm.allreduce(Delta_t_local, op=MPI.min)

    # compute the damage increment
    Delta_Dloc = Function(S1)
    Delta_Dloc.vector()[:] = dDloc_dt*Delta_t

    """ Compute the nonlocal damage increment using implicit gradient. """

#     # trial and test functions
    Delta_D = TrialFunction(S1)
    z = TestFunction(S1)

    # define variational form
    LHS = (inner(z, Delta_D) + c_bar(dmg)*inner(nabla_grad(z), nabla_grad(Delta_D)))*dx
    RHS = inner(z, Delta_Dloc)*dx

    # solve for the nonlocal damage increment
    w = Function(S1)  # empty function to dump solution
    solve(LHS == RHS, w)

    # interpolate nonlocal damage increment at quadrature points
    wq = np.clip(interpolate(w, S1).vector().get_local(), 0, max_Delta_D)

    # update damage and psi UFL functions
    dmg = Function(S1)
    dmgv = np.zeros(n_local)

    if t_elapsed >= t_delay_dmg:
#         dmgv = np.clip(dmg0+wq, 0, Dmax)  # 0 < damage < Dmax
        for i in range(n_local):
            dmgv[i] = max(0, min(dmg0[i] + wq[i], Dmax))
            if dmgv[i] > Dcr:
                dmgv[i] = Dmax
            dmg.vector()[i] = dmgv[i]

    """ Output data to mesh file. """

    Delta_t /= 3600  # convert time increment to hours
    
    """ Save data """
#     S2 = FunctionSpace(mesh, "CG", 1)  # first order scalar space
    
    N11 = Function(S1, name="S11")
    H11 = Function(S1, name="H11")
    V11 = Function(S1, name="V11")
    dmgx = Function(S1, name="Dmg")
    
    # Assuming s11, chi, and vms are NumPy arrays or similar
    N11.vector()[:] = s11
    H11.vector()[:] = chi
    V11.vector()[:] = vms
    dmgx.vector()[:] = dmg.vector()[:]

#     xdmf.write(mesh)
    xdmf.write(N11, t_elapsed)
    xdmf.write(V11, t_elapsed)
    xdmf.write(H11, t_elapsed)
    xdmf.write(dmgx, t_elapsed)

    """ Updated Lagrangian implementation. """

    # split velocity into components in S1 space
    u1, u2 = u.split(deepcopy=True)
    u1 = interpolate(u1, S1).vector().get_local()
    u2 = interpolate(u2, S1).vector().get_local()

    # compute the displacement increment vector Delta_u
    Delta_u1 = Function(S1)
    Delta_u2 = Function(S1)
#     ind1 = x1 >= 0  # indices of coordinates where x1 > 0
#     ind2 = x2 >= 0  # indices of coordinates where x2 > 0
    Delta_u1.vector()[:] = u1*Delta_t
    Delta_u2.vector()[:] = u2*Delta_t
#     """define pre-crack zone"""
#     for i in range(n_local):
#         if x1[i] >= 0:
#             Delta_u1.vector()[i] = u1[i]*Delta_t
#         elif x2[i] >= 0:
#             Delta_u2.vector()[i] = u2[i]*Delta_t
    Delta_u = Function(V1)
    assign(Delta_u.sub(0), Delta_u1)
    assign(Delta_u.sub(1), Delta_u2)
    
#     Delta_u = interpolate(Delta_u, V1)
    # move the mesh, update coordinates
    ALE.move(mesh, Delta_u)

    # update elapsed time
    t_elapsed += Delta_t

    dmgc = dmg.vector().get_local()
    for i in range(n_local):
        # if dmgc[i] >= 0.99:
        if dmgc[i] >= Dcr:
            if x2[i] < cracktip_coor:
                cracktip_coor = x2[i]
    print("Step %d, Crack depth: %g, time: %0.2f" % (t_elapsed,1-cracktip_coor/H,t_elapsed ))
# Out:
# Step 0, Crack depth: 0.08, time: 0.50
# Step 1, Crack depth: 0.0799866, time: 1.00
# Step 1, Crack depth: 0.0799732, time: 1.50
# Step 2, Crack depth: 0.0799597, time: 2.00
# Step 2, Crack depth: 0.0799463, time: 2.50
# Step 3, Crack depth: 0.0799329, time: 3.00
# Step 3, Crack depth: 0.0799195, time: 3.50
# Step 4, Crack depth: 0.0799061, time: 4.00
# Step 4, Crack depth: 0.0798927, time: 4.50
# Step 5, Crack depth: 0.0798792, time: 5.00
# Step 5, Crack depth: 0.0798658, time: 5.50
# Step 6, Crack depth: 0.0798524, time: 6.00
# Step 6, Crack depth: 0.079839, time: 6.50
# Step 7, Crack depth: 0.0798256, time: 7.00
# Step 7, Crack depth: 0.0798122, time: 7.50
# Step 8, Crack depth: 0.0797988, time: 8.00
# Step 8, Crack depth: 0.0797854, time: 8.50
# Step 9, Crack depth: 0.079772, time: 9.00
# Step 9, Crack depth: 0.0797586, time: 9.50
# Step 10, Crack depth: 0.0797452, time: 10.00
# Step 10, Crack depth: 0.0797318, time: 10.50
# Step 11, Crack depth: 0.0797184, time: 11.00
# Step 11, Crack depth: 0.079705, time: 11.50
# Step 12, Crack depth: 0.0796916, time: 12.00
# Step 12, Crack depth: 0.0796783, time: 12.50
# Step 13, Crack depth: 0.0796649, time: 13.00
# Step 13, Crack depth: 0.0796515, time: 13.50
# Step 14, Crack depth: 0.0796381, time: 14.00
# Step 14, Crack depth: 0.0796247, time: 14.50
# Step 15, Crack depth: 0.0796113, time: 15.00
# Step 15, Crack depth: 0.0795979, time: 15.50
# Step 16, Crack depth: 0.0795846, time: 16.00
# Step 16, Crack depth: 0.0795712, time: 16.50
# Step 17, Crack depth: 0.0795578, time: 17.00
# Step 17, Crack depth: 0.0795444, time: 17.50
# Step 18, Crack depth: 0.0795311, time: 18.00
# Step 18, Crack depth: 0.0795177, time: 18.50
# Step 19, Crack depth: 0.0795043, time: 19.00
# Step 19, Crack depth: 0.079491, time: 19.50
# Step 20, Crack depth: 0.0794776, time: 20.00
# Step 20, Crack depth: 0.0794642, time: 20.50
# Step 21, Crack depth: 0.0794509, time: 21.00
# Step 21, Crack depth: 0.0794375, time: 21.50
# Step 22, Crack depth: 0.0794241, time: 22.00
# Step 22, Crack depth: 0.0794108, time: 22.50
# Step 23, Crack depth: 0.0793974, time: 23.00
# Step 23, Crack depth: 0.0793841, time: 23.50
# Step 24, Crack depth: 0.0793707, time: 24.00
# Step 24, Crack depth: 0.0793574, time: 24.50
# Step 25, Crack depth: 0.079344, time: 25.00
# Step 25, Crack depth: 0.0793306, time: 25.50
# Step 26, Crack depth: 0.0793173, time: 26.00
# Step 26, Crack depth: 0.079304, time: 26.50
# Step 27, Crack depth: 0.0792906, time: 27.00
# Step 27, Crack depth: 0.0792773, time: 27.50
# Step 28, Crack depth: 0.0792639, time: 28.00
# Step 28, Crack depth: 0.0792506, time: 28.50
# Step 29, Crack depth: 0.0792372, time: 29.00
# Step 29, Crack depth: 0.0792239, time: 29.50
# Step 30, Crack depth: 0.0792106, time: 30.00
# Step 30, Crack depth: 0.0791972, time: 30.50
# Step 31, Crack depth: 0.0791839, time: 31.00
# Step 31, Crack depth: 0.0791705, time: 31.50
# Step 32, Crack depth: 0.0791572, time: 32.00
# Step 32, Crack depth: 0.0791439, time: 32.50
# Step 33, Crack depth: 0.0791306, time: 33.00
# Step 33, Crack depth: 0.0791172, time: 33.50
# Step 34, Crack depth: 0.0791039, time: 34.00
# Step 34, Crack depth: 0.0790906, time: 34.50
# Step 35, Crack depth: 0.0790772, time: 35.00
# Step 35, Crack depth: 0.0790639, time: 35.50
# Step 36, Crack depth: 0.0790506, time: 36.00
# Step 36, Crack depth: 0.0790373, time: 36.50
# Step 37, Crack depth: 0.079024, time: 37.00
# Step 37, Crack depth: 0.0790106, time: 37.50
# Step 38, Crack depth: 0.0789973, time: 38.00
# Step 38, Crack depth: 0.078984, time: 38.50
# Step 39, Crack depth: 0.0789707, time: 39.00
# Step 39, Crack depth: 0.0789574, time: 39.50
# Step 40, Crack depth: 0.0789441, time: 40.00
# Step 40, Crack depth: 0.0789308, time: 40.50
# Step 41, Crack depth: 0.0789175, time: 41.00
# Step 41, Crack depth: 0.0789042, time: 41.50
# Step 42, Crack depth: 0.0788909, time: 42.00
# Step 42, Crack depth: 0.0788775, time: 42.50
# Step 43, Crack depth: 0.0788642, time: 43.00
# Step 43, Crack depth: 0.0788509, time: 43.50
# Step 44, Crack depth: 0.0788376, time: 44.00
# Step 44, Crack depth: 0.0788243, time: 44.50
# Step 45, Crack depth: 0.0788111, time: 45.00
# Step 45, Crack depth: 0.0787978, time: 45.50
# Step 46, Crack depth: 0.0787845, time: 46.00
# Step 46, Crack depth: 0.0787712, time: 46.50
# Step 47, Crack depth: 0.0787579, time: 47.00
# Step 47, Crack depth: 0.0787446, time: 47.50
# Step 48, Crack depth: 0.0787313, time: 48.00
# Step 48, Crack depth: 0.078718, time: 48.50
# Step 49, Crack depth: 0.0787047, time: 49.00
# Step 49, Crack depth: 0.0786914, time: 49.50
# Step 50, Crack depth: 0.0786782, time: 50.00
# Step 50, Crack depth: 0.0786649, time: 50.50
# Step 51, Crack depth: 0.0786516, time: 51.00
# Step 51, Crack depth: 0.0786383, time: 51.50
# Step 52, Crack depth: 0.078625, time: 52.00
# Step 52, Crack depth: 0.0786118, time: 52.50
# Step 53, Crack depth: 0.0785985, time: 53.00
# Step 53, Crack depth: 0.0785852, time: 53.50
# Step 54, Crack depth: 0.0785719, time: 54.00
# Step 54, Crack depth: 0.0785587, time: 54.50
# Step 55, Crack depth: 0.0785454, time: 55.00
# Step 55, Crack depth: 0.0785321, time: 55.50
# Step 56, Crack depth: 0.0785189, time: 56.00
# Step 56, Crack depth: 0.0785056, time: 56.50
# Step 57, Crack depth: 0.0784923, time: 57.00
# Step 57, Crack depth: 0.0784791, time: 57.50
# Step 58, Crack depth: 0.0784658, time: 58.00
# Step 58, Crack depth: 0.0784526, time: 58.50
# Step 59, Crack depth: 0.0784393, time: 59.00
# Step 59, Crack depth: 0.078426, time: 59.50
# Step 60, Crack depth: 0.0784128, time: 60.00
# Step 60, Crack depth: 0.0783995, time: 60.50
# Step 61, Crack depth: 0.0783863, time: 61.00
# Step 61, Crack depth: 0.078373, time: 61.50
# Step 62, Crack depth: 0.0783598, time: 62.00
# Step 62, Crack depth: 0.0783465, time: 62.50
# Step 63, Crack depth: 0.0783333, time: 63.00
# Step 63, Crack depth: 0.07832, time: 63.50
# Step 64, Crack depth: 0.0783068, time: 64.00
# Step 64, Crack depth: 0.0782935, time: 64.50
# Step 65, Crack depth: 0.0782803, time: 65.00
# Step 65, Crack depth: 0.0782671, time: 65.50
# Step 66, Crack depth: 0.0782538, time: 66.00
# Step 66, Crack depth: 0.0782406, time: 66.50
# Step 67, Crack depth: 0.0782273, time: 67.00
# Step 67, Crack depth: 0.0782141, time: 67.50
# Step 68, Crack depth: 0.0782009, time: 68.00
# Step 68, Crack depth: 0.0781876, time: 68.50
# Step 69, Crack depth: 0.0781744, time: 69.00
# Step 69, Crack depth: 0.0781612, time: 69.50
# Step 70, Crack depth: 0.0781479, time: 70.00
# Step 70, Crack depth: 0.0781347, time: 70.50
# Step 71, Crack depth: 0.0781215, time: 71.00
# Step 71, Crack depth: 0.0781083, time: 71.50
# Step 72, Crack depth: 0.078095, time: 72.00
# Step 72, Crack depth: 0.0780818, time: 72.50
# Step 73, Crack depth: 0.0780686, time: 73.00
# Step 73, Crack depth: 0.0780554, time: 73.50
# Step 74, Crack depth: 0.0780421, time: 74.00
# Step 74, Crack depth: 0.0780289, time: 74.50
# Step 75, Crack depth: 0.0780157, time: 75.00
# Step 75, Crack depth: 0.0780025, time: 75.50
# Step 76, Crack depth: 0.0779893, time: 76.00
# Step 76, Crack depth: 0.0779761, time: 76.50
# Step 77, Crack depth: 0.0779628, time: 77.00
# Step 77, Crack depth: 0.0779496, time: 77.50
# Step 78, Crack depth: 0.0779364, time: 78.00
# Step 78, Crack depth: 0.0779232, time: 78.50
# Step 79, Crack depth: 0.07791, time: 79.00
# Step 79, Crack depth: 0.0778968, time: 79.50
# Step 80, Crack depth: 0.0778836, time: 80.00
# Step 80, Crack depth: 0.0778704, time: 80.50
# Step 81, Crack depth: 0.0778572, time: 81.00
# Step 81, Crack depth: 0.077844, time: 81.50
# Step 82, Crack depth: 0.0778308, time: 82.00
# Step 82, Crack depth: 0.0778176, time: 82.50
# Step 83, Crack depth: 0.0778044, time: 83.00
# Step 83, Crack depth: 0.0777912, time: 83.50
# Step 84, Crack depth: 0.077778, time: 84.00
# Step 84, Crack depth: 0.0777648, time: 84.50
# Step 85, Crack depth: 0.0777516, time: 85.00
# Step 85, Crack depth: 0.0777384, time: 85.50
# Step 86, Crack depth: 0.0777252, time: 86.00
# Step 86, Crack depth: 0.0777121, time: 86.50
# Step 87, Crack depth: 0.0776989, time: 87.00
# Step 87, Crack depth: 0.0776857, time: 87.50
# Step 88, Crack depth: 0.0776725, time: 88.00
# Step 88, Crack depth: 0.0776593, time: 88.50
# Step 89, Crack depth: 0.0776461, time: 89.00
# Step 89, Crack depth: 0.0776329, time: 89.50
# Step 90, Crack depth: 0.0776198, time: 90.00
# Step 90, Crack depth: 0.0776066, time: 90.50
# Step 91, Crack depth: 0.0775934, time: 91.00
# Step 91, Crack depth: 0.0775802, time: 91.50
# Step 92, Crack depth: 0.0775671, time: 92.00
# Step 92, Crack depth: 0.0775539, time: 92.50
# Step 93, Crack depth: 0.0775407, time: 93.00
# Step 93, Crack depth: 0.0775275, time: 93.50
# Step 94, Crack depth: 0.0775144, time: 94.00
# Step 94, Crack depth: 0.0775012, time: 94.50
# Step 95, Crack depth: 0.077488, time: 95.00
# Step 95, Crack depth: 0.0774749, time: 95.50
# Step 96, Crack depth: 0.0774617, time: 96.00
# Step 96, Crack depth: 0.0774485, time: 96.50
# Step 97, Crack depth: 0.0774354, time: 97.00
# Step 97, Crack depth: 0.0774222, time: 97.50
# Step 98, Crack depth: 0.0774091, time: 98.00
# Step 98, Crack depth: 0.0773959, time: 98.50
# Step 99, Crack depth: 0.0773827, time: 99.00
# Step 99, Crack depth: 0.0773696, time: 99.50
# Step 100, Crack depth: 0.0773564, time: 100.00
# Step 100, Crack depth: 0.0773433, time: 100.50
# Step 101, Crack depth: 0.0773301, time: 101.00
# Step 101, Crack depth: 0.077317, time: 101.50
# Step 102, Crack depth: 0.0773038, time: 102.00
# Step 102, Crack depth: 0.0772907, time: 102.50
# Step 103, Crack depth: 0.0772775, time: 103.00
# Step 103, Crack depth: 0.0772644, time: 103.50
# Step 104, Crack depth: 0.0772512, time: 104.00
# Step 104, Crack depth: 0.0772381, time: 104.50
# Step 105, Crack depth: 0.0772249, time: 105.00
# Step 105, Crack depth: 0.0772118, time: 105.50
# Step 106, Crack depth: 0.0771986, time: 106.00
# Step 106, Crack depth: 0.0771855, time: 106.50
# Step 107, Crack depth: 0.0771724, time: 107.00
# Step 107, Crack depth: 0.0771592, time: 107.50
# Step 108, Crack depth: 0.0771461, time: 108.00
# Step 108, Crack depth: 0.077133, time: 108.50
# Step 109, Crack depth: 0.0771198, time: 109.00
# Step 109, Crack depth: 0.0771067, time: 109.50
# Step 110, Crack depth: 0.0770936, time: 110.00
# Step 110, Crack depth: 0.0770804, time: 110.50
# Step 111, Crack depth: 0.0770673, time: 111.00
# Step 111, Crack depth: 0.0770542, time: 111.50
# Step 112, Crack depth: 0.077041, time: 112.00
# Step 112, Crack depth: 0.0770279, time: 112.50
# Step 113, Crack depth: 0.0770148, time: 113.00
# Step 113, Crack depth: 0.0770017, time: 113.50
# Step 114, Crack depth: 0.0769885, time: 114.00
# Step 114, Crack depth: 0.0769754, time: 114.50
# Step 115, Crack depth: 0.0769623, time: 115.00
# Step 115, Crack depth: 0.0769492, time: 115.50
# Step 116, Crack depth: 0.0769361, time: 116.00
# Step 116, Crack depth: 0.0769229, time: 116.50
# Step 117, Crack depth: 0.0769098, time: 117.00
# Step 117, Crack depth: 0.0768967, time: 117.50
# Step 118, Crack depth: 0.0768836, time: 118.00
# Step 118, Crack depth: 0.0768705, time: 118.50
# Step 119, Crack depth: 0.0768574, time: 119.00
# Step 119, Crack depth: 0.0768443, time: 119.50
# Step 120, Crack depth: 0.0768312, time: 120.00
# Step 120, Crack depth: 0.0768181, time: 120.50
# Step 121, Crack depth: 0.0768049, time: 121.00
# Step 121, Crack depth: 0.0767918, time: 121.50
# Step 122, Crack depth: 0.0767787, time: 122.00
# Step 122, Crack depth: 0.0767656, time: 122.50
# Step 123, Crack depth: 0.0767525, time: 123.00
# Step 123, Crack depth: 0.0767394, time: 123.50
# Step 124, Crack depth: 0.0767263, time: 124.00
# Step 124, Crack depth: 0.0767132, time: 124.50
# Step 125, Crack depth: 0.0767001, time: 125.00
# Step 125, Crack depth: 0.076687, time: 125.50
# Step 126, Crack depth: 0.0766739, time: 126.00
# Step 126, Crack depth: 0.0766608, time: 126.50
# Step 127, Crack depth: 0.0766477, time: 127.00
# Step 127, Crack depth: 0.0766347, time: 127.50
# Step 128, Crack depth: 0.0766216, time: 128.00
# Step 128, Crack depth: 0.0766085, time: 128.50
# Step 129, Crack depth: 0.0765954, time: 129.00
# Step 129, Crack depth: 0.0765823, time: 129.50
# Step 130, Crack depth: 0.0765692, time: 130.00
# Step 130, Crack depth: 0.0765561, time: 130.50
# Step 131, Crack depth: 0.076543, time: 131.00
# Step 131, Crack depth: 0.07653, time: 131.50
# Step 132, Crack depth: 0.0765169, time: 132.00
# Step 132, Crack depth: 0.0765038, time: 132.50
# Step 133, Crack depth: 0.0764907, time: 133.00
# Step 133, Crack depth: 0.0764776, time: 133.50
# Step 134, Crack depth: 0.0764646, time: 134.00
# Step 134, Crack depth: 0.0764515, time: 134.50
# Step 135, Crack depth: 0.0764384, time: 135.00
# Step 135, Crack depth: 0.0764253, time: 135.50
# Step 136, Crack depth: 0.0764123, time: 136.00
# Step 136, Crack depth: 0.0763992, time: 136.50
# Step 137, Crack depth: 0.0763861, time: 137.00
# Step 137, Crack depth: 0.076373, time: 137.50
# Step 138, Crack depth: 0.07636, time: 138.00
# Step 138, Crack depth: 0.0763469, time: 138.50
# Step 139, Crack depth: 0.0763338, time: 139.00
# Step 139, Crack depth: 0.0763208, time: 139.50
# Step 140, Crack depth: 0.0763077, time: 140.00
# Step 140, Crack depth: 0.0762946, time: 140.50
# Step 141, Crack depth: 0.0762816, time: 141.00
# Step 141, Crack depth: 0.0762685, time: 141.50
# Step 142, Crack depth: 0.0762555, time: 142.00
# Step 142, Crack depth: 0.0762424, time: 142.50
# Step 143, Crack depth: 0.0762293, time: 143.00
# Step 143, Crack depth: 0.0762163, time: 143.50
# Step 144, Crack depth: 0.0762032, time: 144.00
# Step 144, Crack depth: 0.0761902, time: 144.50
# Step 145, Crack depth: 0.0761771, time: 145.00
# Step 145, Crack depth: 0.0761641, time: 145.50
# Step 146, Crack depth: 0.076151, time: 146.00
# Step 146, Crack depth: 0.076138, time: 146.50
# Step 147, Crack depth: 0.0761249, time: 147.00
# Step 147, Crack depth: 0.0761119, time: 147.50
# Step 148, Crack depth: 0.0760988, time: 148.00
# Step 148, Crack depth: 0.0760858, time: 148.50
# Step 149, Crack depth: 0.0760727, time: 149.00
# Step 149, Crack depth: 0.0760597, time: 149.50
# Step 150, Crack depth: 0.0760466, time: 150.00
# Step 150, Crack depth: 0.0760336, time: 150.50
# Step 151, Crack depth: 0.0760206, time: 151.00
# Step 151, Crack depth: 0.0760075, time: 151.50
# Step 152, Crack depth: 0.0759945, time: 152.00
# Step 152, Crack depth: 0.0759814, time: 152.50
# Step 153, Crack depth: 0.0759684, time: 153.00
# Step 153, Crack depth: 0.0759554, time: 153.50
# Step 154, Crack depth: 0.0759423, time: 154.00
# Step 154, Crack depth: 0.0759293, time: 154.50
# Step 155, Crack depth: 0.0759163, time: 155.00
# Step 155, Crack depth: 0.0759032, time: 155.50
# Step 156, Crack depth: 0.0758902, time: 156.00
# Step 156, Crack depth: 0.0758772, time: 156.50
# Step 157, Crack depth: 0.0758641, time: 157.00
# Step 157, Crack depth: 0.0758511, time: 157.50
# Step 158, Crack depth: 0.0758381, time: 158.00
# Step 158, Crack depth: 0.0758251, time: 158.50
# Step 159, Crack depth: 0.075812, time: 159.00
# Step 159, Crack depth: 0.075799, time: 159.50
# Step 160, Crack depth: 0.075786, time: 160.00
# Step 160, Crack depth: 0.075773, time: 160.50
# Step 161, Crack depth: 0.0757599, time: 161.00
# Step 161, Crack depth: 0.0757469, time: 161.50
# Step 162, Crack depth: 0.0757339, time: 162.00
# Step 162, Crack depth: 0.0757209, time: 162.50
# Step 163, Crack depth: 0.0757079, time: 163.00
# Step 163, Crack depth: 0.0756948, time: 163.50
# Step 164, Crack depth: 0.0756818, time: 164.00
# Step 164, Crack depth: 0.0756688, time: 164.50
# Step 165, Crack depth: 0.0756558, time: 165.00
# Step 165, Crack depth: 0.0756428, time: 165.50
# Step 166, Crack depth: 0.0756298, time: 166.00
# Step 166, Crack depth: 0.0756168, time: 166.50
# Step 167, Crack depth: 0.0756038, time: 167.00
# Step 167, Crack depth: 0.0755908, time: 167.50
# Step 168, Crack depth: 0.0755777, time: 168.00
# Step 168, Crack depth: 0.0755647, time: 168.50
# Step 169, Crack depth: 0.0755517, time: 169.00
# Step 169, Crack depth: 0.0755387, time: 169.50
# Step 170, Crack depth: 0.0755257, time: 170.00
# Step 170, Crack depth: 0.0755127, time: 170.50
# Step 171, Crack depth: 0.0754997, time: 171.00
# Step 171, Crack depth: 0.0754867, time: 171.50
# Step 172, Crack depth: 0.0754737, time: 172.00
# Step 172, Crack depth: 0.0754607, time: 172.50
# Step 173, Crack depth: 0.0754477, time: 173.00
# Step 173, Crack depth: 0.0754347, time: 173.50
# Step 174, Crack depth: 0.0754217, time: 174.00
# Step 174, Crack depth: 0.0754088, time: 174.50
# Step 175, Crack depth: 0.0753958, time: 175.00
# Step 175, Crack depth: 0.0753828, time: 175.50
# Step 176, Crack depth: 0.0753698, time: 176.00
# Step 176, Crack depth: 0.0753568, time: 176.50
# Step 177, Crack depth: 0.0753438, time: 177.00
# Step 177, Crack depth: 0.0753308, time: 177.50
# Step 178, Crack depth: 0.0753178, time: 178.00
# Step 178, Crack depth: 0.0753048, time: 178.50
# Step 179, Crack depth: 0.0752918, time: 179.00
# Step 179, Crack depth: 0.0752789, time: 179.50
# Step 180, Crack depth: 0.0752659, time: 180.00
# Step 180, Crack depth: 0.0752529, time: 180.50
# Step 181, Crack depth: 0.0752399, time: 181.00
# Step 181, Crack depth: 0.0752269, time: 181.50
# Step 182, Crack depth: 0.075214, time: 182.00
# Step 182, Crack depth: 0.075201, time: 182.50
# Step 183, Crack depth: 0.075188, time: 183.00
# Step 183, Crack depth: 0.075175, time: 183.50
# Step 184, Crack depth: 0.075162, time: 184.00
# Step 184, Crack depth: 0.0751491, time: 184.50
# Step 185, Crack depth: 0.0751361, time: 185.00
# Step 185, Crack depth: 0.0751231, time: 185.50
# Step 186, Crack depth: 0.0751102, time: 186.00
# Step 186, Crack depth: 0.0750972, time: 186.50
# Step 187, Crack depth: 0.0750842, time: 187.00
# Step 187, Crack depth: 0.0750712, time: 187.50
# Step 188, Crack depth: 0.0750583, time: 188.00
# Step 188, Crack depth: 0.0750453, time: 188.50
# Step 189, Crack depth: 0.0750323, time: 189.00
# Step 189, Crack depth: 0.0750194, time: 189.50
# Step 190, Crack depth: 0.0750064, time: 190.00
# Step 190, Crack depth: 0.0749935, time: 190.50
# Step 191, Crack depth: 0.0749805, time: 191.00
# Step 191, Crack depth: 0.0749675, time: 191.50
# Step 192, Crack depth: 0.0749546, time: 192.00
# Step 192, Crack depth: 0.0749416, time: 192.50
# Step 193, Crack depth: 0.0749286, time: 193.00
# Step 193, Crack depth: 0.0749157, time: 193.50
# Step 194, Crack depth: 0.0749027, time: 194.00
# Step 194, Crack depth: 0.0748898, time: 194.50
# Step 195, Crack depth: 0.0748768, time: 195.00
# Step 195, Crack depth: 0.0748639, time: 195.50
# Step 196, Crack depth: 0.0748509, time: 196.00
# Step 196, Crack depth: 0.074838, time: 196.50
# Step 197, Crack depth: 0.074825, time: 197.00
# Step 197, Crack depth: 0.0748121, time: 197.50
# Step 198, Crack depth: 0.0747991, time: 198.00
# Step 198, Crack depth: 0.0747862, time: 198.50
# Step 199, Crack depth: 0.0747732, time: 199.00
# Step 199, Crack depth: 0.0747603, time: 199.50
# Step 200, Crack depth: 0.0747473, time: 200.00
# Step 200, Crack depth: 0.0747344, time: 200.50
# Step 201, Crack depth: 0.0747214, time: 201.00
# Step 201, Crack depth: 0.0747085, time: 201.50
# Step 202, Crack depth: 0.0746956, time: 202.00
# Step 202, Crack depth: 0.0746826, time: 202.50
# Step 203, Crack depth: 0.0746697, time: 203.00
# Step 203, Crack depth: 0.0746567, time: 203.50
# Step 204, Crack depth: 0.0746438, time: 204.00
# Step 204, Crack depth: 0.0746309, time: 204.50
# Step 205, Crack depth: 0.0746179, time: 205.00
# Step 205, Crack depth: 0.074605, time: 205.50
# Step 206, Crack depth: 0.074592, time: 206.00
# Step 206, Crack depth: 0.0745791, time: 206.50
# Step 207, Crack depth: 0.0745662, time: 207.00
# Step 207, Crack depth: 0.0745532, time: 207.50
# Step 208, Crack depth: 0.0745403, time: 208.00
# Step 208, Crack depth: 0.0745274, time: 208.50
# Step 209, Crack depth: 0.0745145, time: 209.00
# Step 209, Crack depth: 0.0745015, time: 209.50
# Step 210, Crack depth: 0.0744886, time: 210.00
# Step 210, Crack depth: 0.0744757, time: 210.50
# Step 211, Crack depth: 0.0744627, time: 211.00
# Step 211, Crack depth: 0.0744498, time: 211.50
# Step 212, Crack depth: 0.0744369, time: 212.00
# Step 212, Crack depth: 0.074424, time: 212.50
# Step 213, Crack depth: 0.0744111, time: 213.00
# Step 213, Crack depth: 0.0743981, time: 213.50
# Step 214, Crack depth: 0.0743852, time: 214.00
# Step 214, Crack depth: 0.0743723, time: 214.50
# Step 215, Crack depth: 0.0743594, time: 215.00
# Step 215, Crack depth: 0.0743465, time: 215.50
# Step 216, Crack depth: 0.0743335, time: 216.00
# Step 216, Crack depth: 0.0743206, time: 216.50
# Step 217, Crack depth: 0.0743077, time: 217.00
# Step 217, Crack depth: 0.0742948, time: 217.50
# Step 218, Crack depth: 0.0742819, time: 218.00
# Step 218, Crack depth: 0.074269, time: 218.50
# Step 219, Crack depth: 0.074256, time: 219.00
# Step 219, Crack depth: 0.0742431, time: 219.50
# Step 220, Crack depth: 0.0742302, time: 220.00
# Step 220, Crack depth: 0.0742173, time: 220.50
# Step 221, Crack depth: 0.0742044, time: 221.00
# Step 221, Crack depth: 0.0741915, time: 221.50
# Step 222, Crack depth: 0.0741786, time: 222.00
# Step 222, Crack depth: 0.0741657, time: 222.50
# Step 223, Crack depth: 0.0741528, time: 223.00
# Step 223, Crack depth: 0.0741399, time: 223.50
# Step 224, Crack depth: 0.074127, time: 224.00
# Step 224, Crack depth: 0.0741141, time: 224.50
# Step 225, Crack depth: 0.0741012, time: 225.00
# Step 225, Crack depth: 0.0740883, time: 225.50
# Step 226, Crack depth: 0.0740754, time: 226.00
# Step 226, Crack depth: 0.0740625, time: 226.50
# Step 227, Crack depth: 0.0740496, time: 227.00
# Step 227, Crack depth: 0.0740367, time: 227.50
# Step 228, Crack depth: 0.0740238, time: 228.00
# Step 228, Crack depth: 0.0740109, time: 228.50
# Step 229, Crack depth: 0.073998, time: 229.00
# Step 229, Crack depth: 0.0739851, time: 229.50
# Step 230, Crack depth: 0.0739722, time: 230.00
# Step 230, Crack depth: 0.0739593, time: 230.50
# Step 231, Crack depth: 0.0739464, time: 231.00
# Step 231, Crack depth: 0.0739335, time: 231.50
# Step 232, Crack depth: 0.0739206, time: 232.00
# Step 232, Crack depth: 0.0739077, time: 232.50
# Step 233, Crack depth: 0.0738949, time: 233.00
# Step 233, Crack depth: 0.073882, time: 233.50
# Step 234, Crack depth: 0.0738691, time: 234.00
# Step 234, Crack depth: 0.0738562, time: 234.50
# Step 235, Crack depth: 0.0738433, time: 235.00
# Step 235, Crack depth: 0.0738304, time: 235.50
# Step 236, Crack depth: 0.0738175, time: 236.00
# Step 236, Crack depth: 0.0738047, time: 236.50
# Step 237, Crack depth: 0.0737918, time: 237.00
# Step 237, Crack depth: 0.0737789, time: 237.50
# Step 238, Crack depth: 0.073766, time: 238.00
# Step 238, Crack depth: 0.0737531, time: 238.50
# Step 239, Crack depth: 0.0737403, time: 239.00
# Step 239, Crack depth: 0.0737274, time: 239.50
# Step 240, Crack depth: 0.0737145, time: 240.00
# Step 240, Crack depth: 0.0737016, time: 240.50
# Step 241, Crack depth: 0.0736887, time: 241.00
# Step 241, Crack depth: 0.0736759, time: 241.50
# Step 242, Crack depth: 0.073663, time: 242.00
# Step 242, Crack depth: 0.0736501, time: 242.50
# Step 243, Crack depth: 0.0736373, time: 243.00
# Step 243, Crack depth: 0.0736244, time: 243.50
# Step 244, Crack depth: 0.0736115, time: 244.00
# Step 244, Crack depth: 0.0735986, time: 244.50
# Step 245, Crack depth: 0.0735858, time: 245.00
# Step 245, Crack depth: 0.0735729, time: 245.50
# Step 246, Crack depth: 0.07356, time: 246.00
# Step 246, Crack depth: 0.0735472, time: 246.50
# Step 247, Crack depth: 0.0735343, time: 247.00
# Step 247, Crack depth: 0.0735214, time: 247.50
# Step 248, Crack depth: 0.0735086, time: 248.00
# Step 248, Crack depth: 0.0734957, time: 248.50
# Step 249, Crack depth: 0.0734829, time: 249.00
# Step 249, Crack depth: 0.07347, time: 249.50
# Step 250, Crack depth: 0.0734571, time: 250.00
# Step 250, Crack depth: 0.0734443, time: 250.50
# Step 251, Crack depth: 0.0734314, time: 251.00
# Step 251, Crack depth: 0.0734185, time: 251.50
# Step 252, Crack depth: 0.0734057, time: 252.00
# Step 252, Crack depth: 0.0733928, time: 252.50
# Step 253, Crack depth: 0.07338, time: 253.00
# Step 253, Crack depth: 0.0733671, time: 253.50
# Step 254, Crack depth: 0.0733543, time: 254.00
# Step 254, Crack depth: 0.0733414, time: 254.50
# Step 255, Crack depth: 0.0733286, time: 255.00
# Step 255, Crack depth: 0.0733157, time: 255.50
# Step 256, Crack depth: 0.0733029, time: 256.00
# Step 256, Crack depth: 0.07329, time: 256.50
# Step 257, Crack depth: 0.0732772, time: 257.00
# Step 257, Crack depth: 0.0732643, time: 257.50
# Step 258, Crack depth: 0.0732515, time: 258.00
# Step 258, Crack depth: 0.0732386, time: 258.50
# Step 259, Crack depth: 0.0732258, time: 259.00
# Step 259, Crack depth: 0.0732129, time: 259.50
# Step 260, Crack depth: 0.0732001, time: 260.00
# Step 260, Crack depth: 0.0731872, time: 260.50
# Step 261, Crack depth: 0.0731744, time: 261.00
# Step 261, Crack depth: 0.0731615, time: 261.50
# Step 262, Crack depth: 0.0731487, time: 262.00
# Step 262, Crack depth: 0.0731358, time: 262.50
# Step 263, Crack depth: 0.073123, time: 263.00
# Step 263, Crack depth: 0.0731102, time: 263.50
# Step 264, Crack depth: 0.0730973, time: 264.00
# Step 264, Crack depth: 0.0730845, time: 264.50
# Step 265, Crack depth: 0.0730716, time: 265.00
# Step 265, Crack depth: 0.0730588, time: 265.50
# Step 266, Crack depth: 0.073046, time: 266.00
# Step 266, Crack depth: 0.0730331, time: 266.50
# Step 267, Crack depth: 0.0730203, time: 267.00
# Step 267, Crack depth: 0.0730075, time: 267.50
# Step 268, Crack depth: 0.0729946, time: 268.00
# Step 268, Crack depth: 0.0729818, time: 268.50
# Step 269, Crack depth: 0.072969, time: 269.00
# Step 269, Crack depth: 0.0729561, time: 269.50
# Step 270, Crack depth: 0.0729433, time: 270.00
# Step 270, Crack depth: 0.0729305, time: 270.50
# Step 271, Crack depth: 0.0729176, time: 271.00
# Step 271, Crack depth: 0.0729048, time: 271.50
# Step 272, Crack depth: 0.072892, time: 272.00
# Step 272, Crack depth: 0.0728792, time: 272.50
# Step 273, Crack depth: 0.0728663, time: 273.00
# Step 273, Crack depth: 0.0728535, time: 273.50
# Step 274, Crack depth: 0.0728407, time: 274.00
# Step 274, Crack depth: 0.0728279, time: 274.50
# Step 275, Crack depth: 0.072815, time: 275.00
# Step 275, Crack depth: 0.0728022, time: 275.50
# Step 276, Crack depth: 0.0727894, time: 276.00
# Step 276, Crack depth: 0.0727766, time: 276.50
# Step 277, Crack depth: 0.0727638, time: 277.00
# Step 277, Crack depth: 0.0727509, time: 277.50
# Step 278, Crack depth: 0.0727381, time: 278.00
# Step 278, Crack depth: 0.0727253, time: 278.50
# Step 279, Crack depth: 0.0727125, time: 279.00
# Step 279, Crack depth: 0.0726997, time: 279.50
# Step 280, Crack depth: 0.0726868, time: 280.00
# Step 280, Crack depth: 0.072674, time: 280.50
# Step 281, Crack depth: 0.0726612, time: 281.00
# Step 281, Crack depth: 0.0726484, time: 281.50
# Step 282, Crack depth: 0.0726356, time: 282.00
# Step 282, Crack depth: 0.0726228, time: 282.50
# Step 283, Crack depth: 0.07261, time: 283.00
# Step 283, Crack depth: 0.0725971, time: 283.50
# Step 284, Crack depth: 0.0725843, time: 284.00
# Step 284, Crack depth: 0.0725715, time: 284.50
# Step 285, Crack depth: 0.0725587, time: 285.00
# Step 285, Crack depth: 0.0725459, time: 285.50
# Step 286, Crack depth: 0.0725331, time: 286.00
# Step 286, Crack depth: 0.0725203, time: 286.50
# Step 287, Crack depth: 0.0725075, time: 287.00
# Step 287, Crack depth: 0.0724947, time: 287.50
# Step 288, Crack depth: 0.0724819, time: 288.00
# Step 288, Crack depth: 0.0724691, time: 288.50
# Step 289, Crack depth: 0.0724563, time: 289.00
# Step 289, Crack depth: 0.0724435, time: 289.50
# Step 290, Crack depth: 0.0724307, time: 290.00
# Step 290, Crack depth: 0.0724179, time: 290.50
# Step 291, Crack depth: 0.0724051, time: 291.00
# Step 291, Crack depth: 0.0723923, time: 291.50
# Step 292, Crack depth: 0.0723795, time: 292.00
# Step 292, Crack depth: 0.0723667, time: 292.50
# Step 293, Crack depth: 0.0723539, time: 293.00
# Step 293, Crack depth: 0.0723411, time: 293.50
# Step 294, Crack depth: 0.0723283, time: 294.00
# Step 294, Crack depth: 0.0723155, time: 294.50
# Step 295, Crack depth: 0.0723027, time: 295.00
# Step 295, Crack depth: 0.0722899, time: 295.50
# Step 296, Crack depth: 0.0722771, time: 296.00
# Step 296, Crack depth: 0.0722643, time: 296.50
# Step 297, Crack depth: 0.0722515, time: 297.00
# Step 297, Crack depth: 0.0722387, time: 297.50
# Step 298, Crack depth: 0.0722259, time: 298.00
# Step 298, Crack depth: 0.0722131, time: 298.50
# Step 299, Crack depth: 0.0722003, time: 299.00
# Step 299, Crack depth: 0.0721875, time: 299.50
# Step 300, Crack depth: 0.0721747, time: 300.00
# Step 300, Crack depth: 0.072162, time: 300.50
# Step 301, Crack depth: 0.0721492, time: 301.00
# Step 301, Crack depth: 0.0721364, time: 301.50
# Step 302, Crack depth: 0.0721236, time: 302.00
# Step 302, Crack depth: 0.0721108, time: 302.50
# Step 303, Crack depth: 0.072098, time: 303.00
# Step 303, Crack depth: 0.0720852, time: 303.50
# Step 304, Crack depth: 0.0720725, time: 304.00
# Step 304, Crack depth: 0.0720597, time: 304.50
# Step 305, Crack depth: 0.0720469, time: 305.00
# Step 305, Crack depth: 0.0720341, time: 305.50
# Step 306, Crack depth: 0.0720213, time: 306.00
# Step 306, Crack depth: 0.0720085, time: 306.50
# Step 307, Crack depth: 0.0719958, time: 307.00
# Step 307, Crack depth: 0.071983, time: 307.50
# Step 308, Crack depth: 0.0719702, time: 308.00
# Step 308, Crack depth: 0.0719574, time: 308.50
# Step 309, Crack depth: 0.0719446, time: 309.00
# Step 309, Crack depth: 0.0719319, time: 309.50
# Step 310, Crack depth: 0.0719191, time: 310.00
# Step 310, Crack depth: 0.0719063, time: 310.50
# Step 311, Crack depth: 0.0718935, time: 311.00
# Step 311, Crack depth: 0.0718808, time: 311.50
# Step 312, Crack depth: 0.071868, time: 312.00
# Step 312, Crack depth: 0.0718552, time: 312.50
# Step 313, Crack depth: 0.0718424, time: 313.00
# Step 313, Crack depth: 0.0718297, time: 313.50
# Step 314, Crack depth: 0.0718169, time: 314.00
# Step 314, Crack depth: 0.0718041, time: 314.50
# Step 315, Crack depth: 0.0717914, time: 315.00
# Step 315, Crack depth: 0.0717786, time: 315.50
# Step 316, Crack depth: 0.0717658, time: 316.00
# Step 316, Crack depth: 0.0717531, time: 316.50
# Step 317, Crack depth: 0.0717403, time: 317.00
# Step 317, Crack depth: 0.0717275, time: 317.50
# Step 318, Crack depth: 0.0717148, time: 318.00
# Step 318, Crack depth: 0.071702, time: 318.50
# Step 319, Crack depth: 0.0716892, time: 319.00
# Step 319, Crack depth: 0.0716765, time: 319.50
# Step 320, Crack depth: 0.0716637, time: 320.00
# Step 320, Crack depth: 0.0716509, time: 320.50
# Step 321, Crack depth: 0.0716382, time: 321.00
# Step 321, Crack depth: 0.0716254, time: 321.50
# Step 322, Crack depth: 0.0716126, time: 322.00
# Step 322, Crack depth: 0.0715999, time: 322.50
# Step 323, Crack depth: 0.0715871, time: 323.00
# Step 323, Crack depth: 0.0715744, time: 323.50
# Step 324, Crack depth: 0.0715616, time: 324.00
# Step 324, Crack depth: 0.0715488, time: 324.50
# Step 325, Crack depth: 0.0715361, time: 325.00
# Step 325, Crack depth: 0.0715233, time: 325.50
# Step 326, Crack depth: 0.0715106, time: 326.00
# Step 326, Crack depth: 0.0714978, time: 326.50
# Step 327, Crack depth: 0.0714851, time: 327.00
# Step 327, Crack depth: 0.0714723, time: 327.50
# Step 328, Crack depth: 0.0714595, time: 328.00
# Step 328, Crack depth: 0.0714468, time: 328.50
# Step 329, Crack depth: 0.071434, time: 329.00
# Step 329, Crack depth: 0.0714213, time: 329.50
# Step 330, Crack depth: 0.0714085, time: 330.00
# Step 330, Crack depth: 0.0713958, time: 330.50
# Step 331, Crack depth: 0.071383, time: 331.00
# Step 331, Crack depth: 0.0713703, time: 331.50
# Step 332, Crack depth: 0.0713575, time: 332.00
# Step 332, Crack depth: 0.0713448, time: 332.50
# Step 333, Crack depth: 0.071332, time: 333.00
# Step 333, Crack depth: 0.0713193, time: 333.50
# Step 334, Crack depth: 0.0713065, time: 334.00
# Step 334, Crack depth: 0.0712938, time: 334.50
# Step 335, Crack depth: 0.071281, time: 335.00
# Step 335, Crack depth: 0.0712683, time: 335.50
# Step 336, Crack depth: 0.0712555, time: 336.00
# Step 336, Crack depth: 0.0712428, time: 336.50
# Step 337, Crack depth: 0.0712301, time: 337.00
# Step 337, Crack depth: 0.0712173, time: 337.50
# Step 338, Crack depth: 0.0712046, time: 338.00
# Step 338, Crack depth: 0.0711918, time: 338.50
# Step 339, Crack depth: 0.0711791, time: 339.00
# Step 339, Crack depth: 0.0711663, time: 339.50
# Step 340, Crack depth: 0.0711536, time: 340.00
# Step 340, Crack depth: 0.0711409, time: 340.50
# Step 341, Crack depth: 0.0711281, time: 341.00
# Step 341, Crack depth: 0.0711154, time: 341.50
# Step 342, Crack depth: 0.0711026, time: 342.00
# Step 342, Crack depth: 0.0710899, time: 342.50
# Step 343, Crack depth: 0.0710772, time: 343.00
# Step 343, Crack depth: 0.0710644, time: 343.50
# Step 344, Crack depth: 0.0710517, time: 344.00
# Step 344, Crack depth: 0.071039, time: 344.50
# Step 345, Crack depth: 0.0710262, time: 345.00
# Step 345, Crack depth: 0.0710135, time: 345.50
# Step 346, Crack depth: 0.0710007, time: 346.00
# Step 346, Crack depth: 0.070988, time: 346.50
# Step 347, Crack depth: 0.0709753, time: 347.00
# Step 347, Crack depth: 0.0709625, time: 347.50
# Step 348, Crack depth: 0.0709498, time: 348.00
# Step 348, Crack depth: 0.0709371, time: 348.50
# Step 349, Crack depth: 0.0709244, time: 349.00
# Step 349, Crack depth: 0.0709116, time: 349.50
# Step 350, Crack depth: 0.0708989, time: 350.00
# Step 350, Crack depth: 0.0708862, time: 350.50
# Step 351, Crack depth: 0.0708734, time: 351.00
# Step 351, Crack depth: 0.0708607, time: 351.50
# Step 352, Crack depth: 0.070848, time: 352.00
# Step 352, Crack depth: 0.0708352, time: 352.50
# Step 353, Crack depth: 0.0708225, time: 353.00
# Step 353, Crack depth: 0.0708098, time: 353.50
# Step 354, Crack depth: 0.0707971, time: 354.00
# Step 354, Crack depth: 0.0707843, time: 354.50
# Step 355, Crack depth: 0.0707716, time: 355.00
# Step 355, Crack depth: 0.0707589, time: 355.50
# Step 356, Crack depth: 0.0707462, time: 356.00
# Step 356, Crack depth: 0.0707334, time: 356.50
# Step 357, Crack depth: 0.0707207, time: 357.00
# Step 357, Crack depth: 0.070708, time: 357.50
# Step 358, Crack depth: 0.0706953, time: 358.00
# Step 358, Crack depth: 0.0706825, time: 358.50
# Step 359, Crack depth: 0.0706698, time: 359.00
# Step 359, Crack depth: 0.0706571, time: 359.50
# Step 360, Crack depth: 0.0706444, time: 360.00
# Step 360, Crack depth: 0.0706317, time: 360.50
# Step 361, Crack depth: 0.0706189, time: 361.00
# Step 361, Crack depth: 0.0706062, time: 361.50
# Step 362, Crack depth: 0.0705935, time: 362.00
# Step 362, Crack depth: 0.0705808, time: 362.50
# Step 363, Crack depth: 0.0705681, time: 363.00
# Step 363, Crack depth: 0.0705554, time: 363.50
# Step 364, Crack depth: 0.0705426, time: 364.00
# Step 364, Crack depth: 0.0705299, time: 364.50
# Step 365, Crack depth: 0.0705172, time: 365.00
# Step 365, Crack depth: 0.0705045, time: 365.50
# Step 366, Crack depth: 0.0704918, time: 366.00
# Step 366, Crack depth: 0.0704791, time: 366.50
# Step 367, Crack depth: 0.0704664, time: 367.00
# Step 367, Crack depth: 0.0704536, time: 367.50
# Step 368, Crack depth: 0.0704409, time: 368.00
# Step 368, Crack depth: 0.0704282, time: 368.50
# Step 369, Crack depth: 0.0704155, time: 369.00
# Step 369, Crack depth: 0.0704028, time: 369.50
# Step 370, Crack depth: 0.0703901, time: 370.00
# Step 370, Crack depth: 0.0703774, time: 370.50
# Step 371, Crack depth: 0.0703647, time: 371.00
# Step 371, Crack depth: 0.070352, time: 371.50
# Step 372, Crack depth: 0.0703392, time: 372.00
# Step 372, Crack depth: 0.0703265, time: 372.50
# Step 373, Crack depth: 0.0703138, time: 373.00
# Step 373, Crack depth: 0.0703011, time: 373.50
# Step 374, Crack depth: 0.0702884, time: 374.00
# Step 374, Crack depth: 0.0702757, time: 374.50
# Step 375, Crack depth: 0.070263, time: 375.00
# Step 375, Crack depth: 0.0702503, time: 375.50
# Step 376, Crack depth: 0.0702376, time: 376.00
# Step 376, Crack depth: 0.0702249, time: 376.50
# Step 377, Crack depth: 0.0702122, time: 377.00
# Step 377, Crack depth: 0.0701995, time: 377.50
# Step 378, Crack depth: 0.0701868, time: 378.00
# Step 378, Crack depth: 0.0701741, time: 378.50
# Step 379, Crack depth: 0.0701614, time: 379.00
# Step 379, Crack depth: 0.0701487, time: 379.50
# Step 380, Crack depth: 0.070136, time: 380.00
# Step 380, Crack depth: 0.0701233, time: 380.50
# Step 381, Crack depth: 0.0701106, time: 381.00
# Step 381, Crack depth: 0.0700979, time: 381.50
# Step 382, Crack depth: 0.0700852, time: 382.00
# Step 382, Crack depth: 0.0700725, time: 382.50
# Step 383, Crack depth: 0.0700598, time: 383.00
# Step 383, Crack depth: 0.0700471, time: 383.50
# Step 384, Crack depth: 0.0700344, time: 384.00
# Step 384, Crack depth: 0.0700217, time: 384.50
# Step 385, Crack depth: 0.070009, time: 385.00
# Step 385, Crack depth: 0.0699963, time: 385.50
# Step 386, Crack depth: 0.0699836, time: 386.00
# Step 386, Crack depth: 0.0699709, time: 386.50
# Step 387, Crack depth: 0.0699582, time: 387.00
# Step 387, Crack depth: 0.0699455, time: 387.50
# Step 388, Crack depth: 0.0699328, time: 388.00
# Step 388, Crack depth: 0.0699201, time: 388.50
# Step 389, Crack depth: 0.0699074, time: 389.00
# Step 389, Crack depth: 0.0698947, time: 389.50
# Step 390, Crack depth: 0.069882, time: 390.00
# Step 390, Crack depth: 0.0698693, time: 390.50
# Step 391, Crack depth: 0.0698566, time: 391.00
# Step 391, Crack depth: 0.0698439, time: 391.50
# Step 392, Crack depth: 0.0698313, time: 392.00
# Step 392, Crack depth: 0.0698186, time: 392.50
# Step 393, Crack depth: 0.0698059, time: 393.00
# Step 393, Crack depth: 0.0697932, time: 393.50
# Step 394, Crack depth: 0.0697805, time: 394.00
# Step 394, Crack depth: 0.0697678, time: 394.50
# Step 395, Crack depth: 0.0697551, time: 395.00
# Step 395, Crack depth: 0.0697424, time: 395.50
# Step 396, Crack depth: 0.0697297, time: 396.00
# Step 396, Crack depth: 0.0697171, time: 396.50
# Step 397, Crack depth: 0.0697044, time: 397.00
# Step 397, Crack depth: 0.0696917, time: 397.50
# Step 398, Crack depth: 0.069679, time: 398.00
# Step 398, Crack depth: 0.0696663, time: 398.50
# Step 399, Crack depth: 0.0696536, time: 399.00
# Step 399, Crack depth: 0.0696409, time: 399.50
# Step 400, Crack depth: 0.0696282, time: 400.00
# Step 400, Crack depth: 0.0696156, time: 400.50
# Step 401, Crack depth: 0.0696029, time: 401.00
# Step 401, Crack depth: 0.0695902, time: 401.50
# Step 402, Crack depth: 0.0695775, time: 402.00
# Step 402, Crack depth: 0.0695648, time: 402.50
# Step 403, Crack depth: 0.0695521, time: 403.00
# Step 403, Crack depth: 0.0695395, time: 403.50
# Step 404, Crack depth: 0.0695268, time: 404.00
# Step 404, Crack depth: 0.0695141, time: 404.50
# Step 405, Crack depth: 0.0695014, time: 405.00
# Step 405, Crack depth: 0.0694887, time: 405.50
# Step 406, Crack depth: 0.0694761, time: 406.00
# Step 406, Crack depth: 0.0694634, time: 406.50
# Step 407, Crack depth: 0.0694507, time: 407.00
# Step 407, Crack depth: 0.069438, time: 407.50
# Step 408, Crack depth: 0.0694253, time: 408.00
# Step 408, Crack depth: 0.0694127, time: 408.50
# Step 409, Crack depth: 0.0694, time: 409.00
# Step 409, Crack depth: 0.0693873, time: 409.50
# Step 410, Crack depth: 0.0693746, time: 410.00
# Step 410, Crack depth: 0.069362, time: 410.50
# Step 411, Crack depth: 0.0693493, time: 411.00
# Step 411, Crack depth: 0.0693366, time: 411.50
# Step 412, Crack depth: 0.0693239, time: 412.00
# Step 412, Crack depth: 0.0693113, time: 412.50
# Step 413, Crack depth: 0.0692986, time: 413.00
# Step 413, Crack depth: 0.0692859, time: 413.50
# Step 414, Crack depth: 0.0692732, time: 414.00
# Step 414, Crack depth: 0.0692606, time: 414.50
# Step 415, Crack depth: 0.0692479, time: 415.00
# Step 415, Crack depth: 0.0692352, time: 415.50
# Step 416, Crack depth: 0.0692225, time: 416.00
# Step 416, Crack depth: 0.0692099, time: 416.50
# Step 417, Crack depth: 0.0691972, time: 417.00
# Step 417, Crack depth: 0.0691845, time: 417.50
# Step 418, Crack depth: 0.0691718, time: 418.00
# Step 418, Crack depth: 0.0691592, time: 418.50
# Step 419, Crack depth: 0.0691465, time: 419.00
# Step 419, Crack depth: 0.0691338, time: 419.50
# Step 420, Crack depth: 0.0691212, time: 420.00
# Step 420, Crack depth: 0.0691085, time: 420.50
# Step 421, Crack depth: 0.0690958, time: 421.00
# Step 421, Crack depth: 0.0690832, time: 421.50
# Step 422, Crack depth: 0.0690705, time: 422.00
# Step 422, Crack depth: 0.0690578, time: 422.50
# Step 423, Crack depth: 0.0690452, time: 423.00
# Step 423, Crack depth: 0.0690325, time: 423.50
# Step 424, Crack depth: 0.0690198, time: 424.00
# Step 424, Crack depth: 0.0690072, time: 424.50
# Step 425, Crack depth: 0.0689945, time: 425.00
# Step 425, Crack depth: 0.0689818, time: 425.50
# Step 426, Crack depth: 0.0689692, time: 426.00
# Step 426, Crack depth: 0.0689565, time: 426.50
# Step 427, Crack depth: 0.0689438, time: 427.00
# Step 427, Crack depth: 0.0689312, time: 427.50
# Step 428, Crack depth: 0.0689185, time: 428.00
# Step 428, Crack depth: 0.0689058, time: 428.50
# Step 429, Crack depth: 0.0688932, time: 429.00
# Step 429, Crack depth: 0.0688805, time: 429.50
# Step 430, Crack depth: 0.0688678, time: 430.00
# Step 430, Crack depth: 0.0688552, time: 430.50
# Step 431, Crack depth: 0.0688425, time: 431.00
# Step 431, Crack depth: 0.0688299, time: 431.50
# Step 432, Crack depth: 0.0688172, time: 432.00
# Step 432, Crack depth: 0.0688045, time: 432.50
# Step 433, Crack depth: 0.0687919, time: 433.00
# Step 433, Crack depth: 0.0687792, time: 433.50
# Step 434, Crack depth: 0.0687665, time: 434.00
# Step 434, Crack depth: 0.0687539, time: 434.50
# Step 435, Crack depth: 0.0687412, time: 435.00
# Step 435, Crack depth: 0.0687286, time: 435.50
# Step 436, Crack depth: 0.0687159, time: 436.00
# Step 436, Crack depth: 0.0687033, time: 436.50
# Step 437, Crack depth: 0.0686906, time: 437.00
# Step 437, Crack depth: 0.0686779, time: 437.50
# Step 438, Crack depth: 0.0686653, time: 438.00
# Step 438, Crack depth: 0.0686526, time: 438.50
# Step 439, Crack depth: 0.06864, time: 439.00
# Step 439, Crack depth: 0.0686273, time: 439.50
# Step 440, Crack depth: 0.0686147, time: 440.00
# Step 440, Crack depth: 0.068602, time: 440.50
# Step 441, Crack depth: 0.0685893, time: 441.00
# Step 441, Crack depth: 0.0685767, time: 441.50
# Step 442, Crack depth: 0.068564, time: 442.00
# Step 442, Crack depth: 0.0685514, time: 442.50
# Step 443, Crack depth: 0.0685387, time: 443.00
# Step 443, Crack depth: 0.0685261, time: 443.50
# Step 444, Crack depth: 0.0685134, time: 444.00
# Step 444, Crack depth: 0.0685008, time: 444.50
# Step 445, Crack depth: 0.0684881, time: 445.00
# Step 445, Crack depth: 0.0684755, time: 445.50
# Step 446, Crack depth: 0.0684628, time: 446.00
# Step 446, Crack depth: 0.0684501, time: 446.50
# Step 447, Crack depth: 0.0684375, time: 447.00
# Step 447, Crack depth: 0.0684248, time: 447.50
# Step 448, Crack depth: 0.0684122, time: 448.00
# Step 448, Crack depth: 0.0683995, time: 448.50
# Step 449, Crack depth: 0.0683869, time: 449.00
# Step 449, Crack depth: 0.0683742, time: 449.50
# Step 450, Crack depth: 0.0683616, time: 450.00
# Step 450, Crack depth: 0.0683489, time: 450.50
# Step 451, Crack depth: 0.0683363, time: 451.00
# Step 451, Crack depth: 0.0683236, time: 451.50
# Step 452, Crack depth: 0.068311, time: 452.00
# Step 452, Crack depth: 0.0682983, time: 452.50
# Step 453, Crack depth: 0.0682857, time: 453.00
# Step 453, Crack depth: 0.068273, time: 453.50
# Step 454, Crack depth: 0.0682604, time: 454.00
# Step 454, Crack depth: 0.0682478, time: 454.50
# Step 455, Crack depth: 0.0682351, time: 455.00
# Step 455, Crack depth: 0.0682225, time: 455.50
# Step 456, Crack depth: 0.0682098, time: 456.00
# Step 456, Crack depth: 0.0681972, time: 456.50
# Step 457, Crack depth: 0.0681845, time: 457.00
# Step 457, Crack depth: 0.0681719, time: 457.50
# Step 458, Crack depth: 0.0681592, time: 458.00
# Step 458, Crack depth: 0.0681466, time: 458.50
# Step 459, Crack depth: 0.0681339, time: 459.00
# Step 459, Crack depth: 0.0681213, time: 459.50
# Step 460, Crack depth: 0.0681087, time: 460.00
# Step 460, Crack depth: 0.068096, time: 460.50
# Step 461, Crack depth: 0.0680834, time: 461.00
# Step 461, Crack depth: 0.0680707, time: 461.50
# Step 462, Crack depth: 0.0680581, time: 462.00
# Step 462, Crack depth: 0.0680454, time: 462.50
# Step 463, Crack depth: 0.0680328, time: 463.00
# Step 463, Crack depth: 0.0680201, time: 463.50
# Step 464, Crack depth: 0.0680075, time: 464.00
# Step 464, Crack depth: 0.0679949, time: 464.50
# Step 465, Crack depth: 0.0679822, time: 465.00
# Step 465, Crack depth: 0.0679696, time: 465.50
# Step 466, Crack depth: 0.0679569, time: 466.00
# Step 466, Crack depth: 0.0679443, time: 466.50
# Step 467, Crack depth: 0.0679317, time: 467.00
# Step 467, Crack depth: 0.067919, time: 467.50
# Step 468, Crack depth: 0.0679064, time: 468.00
# Step 468, Crack depth: 0.0678937, time: 468.50
# Step 469, Crack depth: 0.0678811, time: 469.00
# Step 469, Crack depth: 0.0678685, time: 469.50
# Step 470, Crack depth: 0.0678558, time: 470.00
# Step 470, Crack depth: 0.0678432, time: 470.50
# Step 471, Crack depth: 0.0678305, time: 471.00
# Step 471, Crack depth: 0.0678179, time: 471.50
# Step 472, Crack depth: 0.0678053, time: 472.00
# Step 472, Crack depth: 0.0677926, time: 472.50
# Step 473, Crack depth: 0.06778, time: 473.00
# Step 473, Crack depth: 0.0677674, time: 473.50
# Step 474, Crack depth: 0.0677547, time: 474.00
# Step 474, Crack depth: 0.0677421, time: 474.50
# Step 475, Crack depth: 0.0677295, time: 475.00
# Step 475, Crack depth: 0.0677168, time: 475.50
# Step 476, Crack depth: 0.0677042, time: 476.00
# Step 476, Crack depth: 0.0676915, time: 476.50
# Step 477, Crack depth: 0.0676789, time: 477.00
# Step 477, Crack depth: 0.0676663, time: 477.50
# Step 478, Crack depth: 0.0676536, time: 478.00
# Step 478, Crack depth: 0.067641, time: 478.50
# Step 479, Crack depth: 0.0676284, time: 479.00
# Step 479, Crack depth: 0.0676157, time: 479.50
# Step 480, Crack depth: 0.0676031, time: 480.00

# %%
# ind1 = x1 >= 0  # indices of coordinates where x1 > 0
# ind2 = x2 >= 0  # indices of coordinates where x2 > 0
# Delta_u1.vector()[ind1] = u1[ind1]*Delta_t
# Delta_u2.vector()[ind2] = u2[ind2]*Delta_t

# %%
u1*Delta_t
# Out:
# array([-5.72508172e-21,  1.88408654e-19,  8.25069925e-05, ...,
#         1.09452996e-02,  1.09563654e-02,  1.09664429e-02])

# %%
Delta_u1.vector()[:] = u1*Delta_t

# %%
Delta_u1.vector()[ind1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-bc6ad1183738> in <module>
# ----> 1 Delta_u1.vector()[ind1]
#
# NameError: name 'ind1' is not defined

# %%
Delta_u1.vector()[:]

# %%
x1

# %%
x2

# %%
plot = plot(N11)
plt.colorbar(plot)

# %%
X1x, X2x = S1.tabulate_dof_coordinates().reshape((-1, nd)).T
plt.figure(figsize=(20, 5))
tem = dmg.vector().get_local()
plt.ylim(0, H - (H % 25) + 50)
plt.xlim(0, L - (L % 25) + 50)
plots = plt.tricontourf(X1x, X2x, tem, 360, cmap=rainbow )
# plots = plot(dmg)

x1, x2 = mesh.coordinates().T
tri = np.asarray([cell.entities(0) for cell in cells(mesh)])
plt.triplot(x1, x2, tri, "k-", alpha=0.5, lw=0.75)
# plt.axes().set_aspect("equal")
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size=0.25, pad=0.5)
# cbar = plt.colorbar(plots, ticks=ct, cax=cax)
# cbar.ax.tick_params(labelsize=tick_fs)
# plt.tight_layout()
plt.colorbar(plots)
plt.savefig('S1-Dmg.jpg', dpi=300)

# %%
tem = dmg.vector().get_local()

# %%
plot(dmg)

# %%
len(tem)

# %%
len(X1x)

# %%
len(X2x)

# %%
project(u, V, form_compiler_parameters={"quadrature_degree": 3})

# %%
t11 = project(tau[0, 0], SQ,form_compiler_parameters={"quadrature_degree": 2})

# %%
plt.figure(figsize=(20, 5))
# tem = dmg.vector().array()
plot = plt.tricontourf(XQ1, XQ2, s11, 360, cmap=rainbow)
plt.colorbar(plot)
# plt.savefig('s11_hw_00.jpg', dpi=300)

# %%
plt.figure(figsize=(20, 5))
# tem = dmg.vector().array()
plot = plt.tricontourf(XQ1, XQ2, dmgc, 360, cmap=rainbow)
plt.colorbar(plot)
# plt.savefig('s11_hw_00.jpg', dpi=300)
