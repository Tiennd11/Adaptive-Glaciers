# %% [markdown]
# # Stress state within a prestine ground glacier.

# %% [markdown]
# In this code, we'll gain insight into the behaviour of  pristine glaciers that are land terminating and ocean terminating. Mimicking the conditions relevant to grounded glaciers, a free slip condition is applied to the bottom surface, restraining the displacement in the vertical direction. The normal component of the displacement field at the far left edge is restrained to prevent rigid body motion in the horizontal direction. The top surface, representing the atmosphere–ice interface, is defined as a free boundary.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step 1: Preprocessing
# - Define units: N, m
# - Prepare the design basis report

# %% [markdown]
# ## Step 2: Importing Necessary Libraries

# %%
from dolfin import *
import ufl
from helpers import *
from problem_definition import *
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Step 3: Loading the Mesh

# %%
mesh = Mesh()
with XDMFFile("mesh/ice.xdmf") as infile:
    infile.read(mesh)

# %%
mesh.hmin()
# Out:
# 0.11523524312479004

# %% [markdown]
# ## Step 4: Preparing the sets

# %%
support_left = CompiledSubDomain("on_boundary && near(x[0], 0.0, tol)", tol=1e-14)
support_bottom = CompiledSubDomain("on_boundary && near(x[1],0.0, tol)", tol=1e-14)
load_right = CompiledSubDomain("on_boundary && x[1]<= 62.5 && x[0]==500")

mf_line = MeshFunction("size_t", mesh, 1)
load_right.mark(mf_line, 1)

ds = Measure("ds")(subdomain_data=mf_line)

# %% [markdown]
# ## Step 5: Preparing output file

# %%
xdmf = XDMFFile("output/solution.xdmf")
xdmf.parameters["functions_share_mesh"] = True
xdmf.parameters["rewrite_function_mesh"] = False
xdmf.parameters["flush_output"] = True

# %% [markdown]
# ## Step 6: Defining  spaces

# %%
V1 = VectorFunctionSpace(mesh, "CG", 1)
F1 = FunctionSpace(mesh, "CG", 1)

FDG0 = FunctionSpace(mesh, "DG", 0)
TDG0 = TensorFunctionSpace(mesh, "DG", 0)

# %% [markdown]
# ## Step 7: Define functions

# %%
u, v = TrialFunction(V1), TestFunction(V1)
unew, uold = Function(V1, name="disp"), Function(V1, name="disp")
stress_xx, cdf = Function(F1, name="sigma_xx"), Function(FDG0, name="cdf")

# %%
p, q = TrialFunction(F1), TestFunction(F1)
pnew, pold = Function(F1, name="damage"), Function(F1, name="damage")

# %% [markdown]
# ## Step 8: Material Model

# %%
# N, m, Pa
g = 9.81
rho_sea = 1020
E0_ice = 9500e6
nu_ice = 0.35
rho_i_ice = 917 
sigma_c_ice = 0.1185e6

# %%
l = 0.625

# %%
ice = MaterialModel(E0_ice, nu_ice, rho_i_ice, sigma_c_ice, 1)

# %% [markdown]
# ## Step 9: Define supports

# %%
bc_sp_x = DirichletBC(V1.sub(0), Constant(0.0), support_left)
bc_sp_x2 = DirichletBC(V1.sub(1), Constant(0.0), support_bottom)
bc_u = [bc_sp_x, bc_sp_x2]

# %% [markdown]
# ## Step 10: Define Loads

# %%
t = Expression(("-(rho_sea*(125/2 -x[1]))", 0), rho_sea=rho_sea*g, degree=1)
# t = Constant((0, 0))
f = Constant((0, -ice.rho * g))

# %% [markdown]
# ## Step 11: Define the problem

# %%
a_disp = inner(degradation(pnew) * ice.stress(u), ice.strain(v)) * dx
L_disp = (1-pnew)*dot(f, v) * dx + dot(t, v) * ds(1)

# %%
a_phase = ((1 + cdf) * inner(p, q) + l**2 * inner(grad(p), grad(q))) * dx
L_phase = inner(cdf, q) * dx

# %% [markdown]
# ## Step 12: Solve

# %%
disp_problem = LinearVariationalProblem(a_disp, L_disp, unew, bc_u)
phase_problem = LinearVariationalProblem(a_phase, L_phase, pnew)

# %%
problem = FractureProblem(disp_problem, phase_problem, ice, cdf)
solver = FractureSolver(problem)

# %%
prm = solver.parameters
prm["time_start"] = 0.0
prm["time_total"] = 100.0
prm["delta_t"] = 1.0
prm["multi_staggered"]["tolerance"] = 1e-5
prm["multi_staggered"]["maximum_iterations"] = 1

# %%
solver.solve(xdmf)
# Out:
# -----------------Time Step----------------------
# err - u - 1.410e+00 -- err - phi - 1.834e+00
# -----------------Time Step----------------------
# err - u - 2.255e-03 -- err - phi - 1.889e+00
# -----------------Time Step----------------------
# err - u - 2.716e-03 -- err - phi - 1.945e+00
# -----------------Time Step----------------------
# err - u - 3.036e-03 -- err - phi - 1.986e+00
# -----------------Time Step----------------------
# err - u - 3.259e-03 -- err - phi - 1.988e+00
# -----------------Time Step----------------------
# err - u - 3.393e-03 -- err - phi - 1.979e+00
# -----------------Time Step----------------------
# err - u - 3.521e-03 -- err - phi - 1.934e+00
# -----------------Time Step----------------------
# err - u - 3.526e-03 -- err - phi - 1.882e+00
# -----------------Time Step----------------------
# err - u - 3.478e-03 -- err - phi - 1.826e+00
# -----------------Time Step----------------------
# err - u - 3.443e-03 -- err - phi - 1.743e+00
# -----------------Time Step----------------------
# err - u - 3.300e-03 -- err - phi - 1.656e+00
# -----------------Time Step----------------------
# err - u - 3.136e-03 -- err - phi - 1.567e+00
# -----------------Time Step----------------------
# err - u - 2.946e-03 -- err - phi - 1.477e+00
# -----------------Time Step----------------------
# err - u - 2.762e-03 -- err - phi - 1.380e+00
# -----------------Time Step----------------------
# err - u - 2.573e-03 -- err - phi - 1.272e+00
# -----------------Time Step----------------------
# err - u - 2.356e-03 -- err - phi - 1.198e+00
# -----------------Time Step----------------------
# err - u - 2.191e-03 -- err - phi - 1.108e+00
# -----------------Time Step----------------------
# err - u - 1.991e-03 -- err - phi - 1.023e+00
# -----------------Time Step----------------------
# err - u - 1.812e-03 -- err - phi - 9.375e-01
# -----------------Time Step----------------------
# err - u - 1.618e-03 -- err - phi - 8.744e-01
# -----------------Time Step----------------------
# err - u - 1.476e-03 -- err - phi - 8.090e-01
# -----------------Time Step----------------------
# err - u - 1.337e-03 -- err - phi - 7.366e-01
# -----------------Time Step----------------------
# err - u - 1.192e-03 -- err - phi - 6.661e-01
# -----------------Time Step----------------------
# err - u - 1.055e-03 -- err - phi - 6.071e-01
# -----------------Time Step----------------------
# err - u - 9.347e-04 -- err - phi - 5.664e-01
# -----------------Time Step----------------------
# err - u - 8.473e-04 -- err - phi - 5.201e-01
# -----------------Time Step----------------------
# err - u - 7.486e-04 -- err - phi - 4.644e-01
# -----------------Time Step----------------------
# err - u - 6.417e-04 -- err - phi - 4.286e-01
# -----------------Time Step----------------------
# err - u - 5.791e-04 -- err - phi - 3.952e-01
# -----------------Time Step----------------------
# err - u - 5.178e-04 -- err - phi - 3.664e-01
# -----------------Time Step----------------------
# err - u - 4.648e-04 -- err - phi - 3.235e-01
# -----------------Time Step----------------------
# err - u - 3.996e-04 -- err - phi - 2.982e-01
# -----------------Time Step----------------------
# err - u - 3.560e-04 -- err - phi - 2.681e-01
# -----------------Time Step----------------------
# err - u - 3.136e-04 -- err - phi - 2.552e-01
# -----------------Time Step----------------------
# err - u - 2.859e-04 -- err - phi - 2.247e-01
# -----------------Time Step----------------------
# err - u - 2.437e-04 -- err - phi - 2.065e-01
# -----------------Time Step----------------------
# err - u - 2.179e-04 -- err - phi - 2.002e-01
# -----------------Time Step----------------------
# err - u - 2.031e-04 -- err - phi - 1.720e-01
# -----------------Time Step----------------------
# err - u - 1.729e-04 -- err - phi - 1.631e-01
# -----------------Time Step----------------------
# err - u - 1.577e-04 -- err - phi - 1.424e-01
# -----------------Time Step----------------------
# err - u - 1.336e-04 -- err - phi - 1.323e-01
# -----------------Time Step----------------------
# err - u - 1.194e-04 -- err - phi - 1.124e-01
# -----------------Time Step----------------------
# err - u - 1.006e-04 -- err - phi - 1.081e-01
# -----------------Time Step----------------------
# err - u - 9.439e-05 -- err - phi - 9.829e-02
# -----------------Time Step----------------------
# err - u - 8.476e-05 -- err - phi - 9.394e-02
# -----------------Time Step----------------------
# err - u - 7.820e-05 -- err - phi - 8.257e-02
# -----------------Time Step----------------------
# err - u - 6.719e-05 -- err - phi - 7.650e-02
# -----------------Time Step----------------------
# err - u - 6.064e-05 -- err - phi - 7.419e-02
# -----------------Time Step----------------------
# err - u - 5.685e-05 -- err - phi - 6.424e-02
# -----------------Time Step----------------------
# err - u - 4.880e-05 -- err - phi - 5.935e-02
# -----------------Time Step----------------------
# err - u - 4.361e-05 -- err - phi - 5.275e-02
# -----------------Time Step----------------------
# err - u - 3.839e-05 -- err - phi - 4.973e-02
# -----------------Time Step----------------------
# err - u - 3.556e-05 -- err - phi - 4.914e-02
# -----------------Time Step----------------------
# err - u - 3.423e-05 -- err - phi - 3.904e-02
# -----------------Time Step----------------------
# err - u - 2.720e-05 -- err - phi - 3.389e-02
# -----------------Time Step----------------------
# err - u - 2.349e-05 -- err - phi - 3.237e-02
# -----------------Time Step----------------------
# err - u - 2.183e-05 -- err - phi - 2.856e-02
# -----------------Time Step----------------------
# err - u - 1.890e-05 -- err - phi - 3.463e-02
# -----------------Time Step----------------------
# err - u - 2.202e-05 -- err - phi - 3.058e-02
# -----------------Time Step----------------------

# %%
plot(unew, mode="displacement")

# %%
plt.figure(figsize=(18, 6))
c = plot(pnew)
plt.colorbar(c)  # Adds the colorbar
plt.show()

# %% [markdown]
# ## Step 13: Post processing

# %%
stress_xx.assign(project(ice.stress(unew)[0, 0] / 1e6, FDG0))  # N/m2 -> MPa
cdf.assign(project(ice.get_crack_driving_force(unew), FDG0))

# %%
plt.figure(figsize=(18, 6))
c = plot(stress_xx)
plt.colorbar(c)  # Adds the colorbar
plt.show()

# %%
plt.figure(figsize=(18, 6))
c = plot(cdf)
plt.colorbar(c)  # Adds the colorbar
plt.show()

# %%
# xdmf.write(unew, 0)
# xdmf.write(stress_xx, 0)
# xdmf.write(cdf, 0)
# xdmf.close()
